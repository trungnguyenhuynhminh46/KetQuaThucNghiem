# %%
try:
  # %tensorflow_version 2.x
except Exception:
  pass

# %%
# Phần code này dựa trên bài viết này
# https://www.sciencedirect.com/science/article/pii/S1877050919302789

# %% [markdown]
# # Import the libraries

# %%
import numpy as np
import pandas as pd
import os

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Embedding, Dense, Dropout, LeakyReLU, Flatten
import time
import datetime

from tensorflow.keras.layers import Lambda

from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model

import matplotlib.pyplot as plt
import datetime as dt
import yfinance as yf
yf.pdr_override()
from pandas_datareader import data as pdr

# %%
# Hàm vẽ mô hình miêu tả giá trị từng thuộc tính
def plot_dataframe(df):
  for column_name in df.columns:
    plt.figure()
    plt.title(column_name)
    plt.plot(df[column_name])

# %% [markdown]
# # Preprocessing

# %%
# Hàm thêm cột giá trị Ma, là đường trung bình động (Moving Average) của biến giá trị Close
def add_Ma(df, window=5):
    for i in range(window, df.shape[0]):
        sum = 0.0
        for k in range(1, window+1):
            sum += df.iloc[i-k, 4]
        df.loc[df.index[i], 'Ma'] = np.round(sum/window, 6)
    return df[window:]

# %%
# Class này kế thừa class TimeseriesGenerator
# Nó tạo ra các batch dữ liệu được chuẩn hóa (standarized)
class Standarized_TimeseriesGenerator(tf.keras.preprocessing.sequence.TimeseriesGenerator):
  def __getitem__(self, index):
    samples, targets  = super(Standarized_TimeseriesGenerator, self).__getitem__(index)
    mean = samples.mean(axis=1)
    std = samples.std(axis=1)
    samples = (samples - mean[:,None,:])/std[:,None,:]
    targets = (targets - mean)/std
    return samples, targets

# %%
# Giải thích các thông số đầu vào của class TimeseriesGenerator
# Data: Những dữ liệu liên tiếp nhau (axis 0 được kì vọng là time dimension)
# Target: Dữ liệu tương ứng với những timesteps trong data
# Length: Độ dài của các sequences đầu vào (Hay window, look-back)
# sampling_rate: Chu kỳ của các timestep input được lấy (VD: sampling_rate=2 
# thì cách 2 ngày lấy một lần)
# stride: Chu kỳ của các timestep output được lấy (VD: stride=2 
# thì cách 2 ngày lấy một lần, hay chú Sơn nói là số bước mà cửa sổ trượt)
# start_index, end_index: Khoảng dữ liệu được dùng
# bacth_size: số lượng samples 1 batch
# ([day1, day2, day3],[day4]) là 1 sample
# [([day1, day2, day3],[day4]), ([day2, day3, day4],[day5])] là 1 batch có 
# batch_size là 5
################Xét ví dụ sau############
# from keras.preprocessing.sequence import TimeseriesGenerator
# import numpy as np
# data = np.array([[i] for i in range(50)])
# targets = np.array([[i] for i in range(50)])
# data_gen = TimeseriesGenerator(data, targets,
#                                length=10, sampling_rate=2,
#                                batch_size=2)
# assert len(data_gen) == 20
# batch_0 = data_gen[0]
# x, y = batch_0
# assert np.array_equal(x,
#                       np.array([[[0], [2], [4], [6], [8]],
#                                 [[1], [3], [5], [7], [9]]]))
# assert np.array_equal(y,
#                       np.array([[10], [11]]))
# ==>length=10 nên những dữ liệu được pick cho input có index 0->9
# Và dữ liệu đầu tiên cho output có index là 10
# sampling_rate bằng 2 nên (index thứ i) - (index thứ i - 1) = 2
# Batch_size=2 --> Mỗi batch có 2 sample mà có 41 samples --> Có 21 batches

def get_gen_train_test(dataframe, n_sequence, n_batch):
    data = dataframe.drop(columns='Date').to_numpy()
    targets = data
    n_samples = data.shape[0]
    train_test_split=int(n_samples*0.9)

    data_gen_train = Standarized_TimeseriesGenerator(data, targets,
                                length=n_sequence, sampling_rate=1,
                                stride=1, batch_size=n_batch,
                                start_index = 0,
                                end_index = train_test_split,
                                shuffle = True)
    data_gen_test = Standarized_TimeseriesGenerator(data, targets,
                                length=n_sequence, sampling_rate=1,
                                stride=1, batch_size=n_batch,
                                start_index = train_test_split,
                                end_index = n_samples-1)

    return data_gen_train, data_gen_test

# %% [markdown]
# # Baseline

# %%
# Hàm dùng để tính mean squared error cho generated data
def mean_squared_error(dataset):
    mse=0
    for X_batch, y_batch in dataset:
        mse += np.mean(np.square(X_batch[:, -1, 3:4]-y_batch[:, 3:4]))
    mse /= len(dataset)
    return mse

# %% [markdown]
# # Utilities

# %%
# Các hàm tính metrics từ 2 tập thực tế và dự đoán.
def mse(y_true, y_pred):
    return tf.reduce_mean(tf.square(y_true[:,3]-y_pred[:,3]))
def mae(y_true, y_pred):
    return tf.reduce_mean(tf.keras.backend.abs((y_true[:,3]-y_pred[:,3])))
    # ***The absolute is over the whole thing as y_true can be negative
def mape(y_true, y_pred):
    return tf.reduce_mean(tf.keras.backend.abs((y_true[:,3]-y_pred[:,3])/y_true[:,3]))
    # ***The absolute is over the whole thing as y_true can be negative
def rmse(y_true, y_pred):
    return tf.sqrt(tf.reduce_mean(tf.square(y_true[:,3]-y_pred[:,3])))
def ar(y_true, y_pred):
    mask = tf.cast(y_pred[1:,3] > y_true[:-1,3],tf.float32)
    return tf.reduce_mean((y_true[1:,3]-y_true[:-1,3])*mask)

# %% [markdown]
# # GAN

# %% [markdown]
# ## Perdidas

# %%
# Vì Discriminator trong bài toán này chỉ có hai giá trị đầu ra (giống/ không giống) nên dùng hàm phân loại nhị phân
# Tìm hiểu Binary Cross Entropy là gì tại đây:
# https://ndquy.github.io/posts/loss-function-p2/#:~:text=Binary%20Cross%2DEntropy%20Loss,tr%E1%BB%8B%20%7B0%2C%201%7D.
# Cross-entropy là hàm loss được sử dụng mặc định cho bài toán phân lớp nhị phân.
# Nó được thiết kế để sử dụng với bài toán phân loại nhị phân trong đó các giá trị mục tiêu nhận một trong 2 giá trị {0, 1}.
# Trang 402
def discriminator_loss(real_output, fake_output):
    # So sách kết quả dự đoán như thể nào với 1 (đúng) (real_loss)
    real_loss = tf.keras.losses.binary_crossentropy(tf.ones_like(real_output), real_output)
    # So sách kết quả dự đoán như thể nào với 1 (đúng) (real_loss)
    fake_loss = tf.keras.losses.binary_crossentropy(tf.zeros_like(fake_output), fake_output)
    # Giá trị mất mát của Generator
    total_loss = real_loss + fake_loss
    return total_loss
# https://www.sciencedirect.com/science/article/pii/S1877050919302789
# Trang 403
def generator_loss(x, y, fake_output):
    a1=0.01
    g_loss = tf.keras.losses.binary_crossentropy(tf.ones_like(fake_output), fake_output)
    g_mse = tf.keras.losses.MSE(x, y)
    return a1*g_mse + (1-a1)*g_loss, g_mse

# %% [markdown]
# ## Generator

# %%
def make_generator_model(n_sequence, n_features):
    inputs = Input(shape=(n_sequence, n_features,))
    # return_sequences = True, Trả về cho lớp sau các điểm đầu ra trước đó thay vì chỉ các điểm đầu ra ở lớp cuối cùng
    # Trong mạng neural học sâu, kernel_initializer là một tham số được sử dụng để khởi tạo trọng số (weights) của các lớp (layer) trong mạng neural.
    lstm_1 = LSTM(units=10, return_sequences = True, activation=None, kernel_initializer='random_normal')(inputs)
    # Batch Normalization là một lớp (layer) được sử dụng trong mạng neural học sâu để chuẩn hóa đầu ra của một lớp trước khi đưa vào lớp kế tiếp
    # Cải thiện "vanishing gradient" và "exploding gradient", đồng thời giúp mô hình hội tụ nhanh hơn
    batch_norm1=tf.keras.layers.BatchNormalization()(lstm_1)
    lstm_1_LRelu = LeakyReLU(alpha=0.3)(batch_norm1) 
    lstm_1_droput = Dropout(0.3)(lstm_1_LRelu)
    lstm_2 = LSTM(units=10, return_sequences = False, activation=None, kernel_initializer='random_normal')(lstm_1_droput)
    batch_norm2=tf.keras.layers.BatchNormalization()(lstm_2)
    lstm_2_LRelu = LeakyReLU(alpha=0.3)(batch_norm2) 
    lstm_2_droput = Dropout(0.3)(lstm_2_LRelu)
    output_dense = Dense(n_features, activation=None)(lstm_2_droput)
    #  LeakyReLU
    # https://aicurious.io/blog/2019-09-23-cac-ham-kich-hoat-activation-function-trong-neural-networks
    output = LeakyReLU(alpha=0.3)(output_dense) 

    model = Model(inputs = inputs, outputs = output)
    model.compile(loss=None, metrics = [mse , mae, mape, rmse, ar])
    model.summary()

    return model
# Vì sao cần hàm kích hoạt, vì nếu có hàm kích hoạt mà là các lớp nơ ron đơn thuần xếp chồng lên nhau thì kết quả đầu ra đơn 
# là một hàm tuyến tính của giá trị đầu vào --> Việc xếp chồng mà k có hàm kích hoạt là vô nghĩa
# Sigmoid (0,1). Đạo hàm đẹp nhưng dễ bằng 0 (vanishing gradient), không có trung tâm nên hội tụ khó khăn
# tanh (-1,1). Cũng bão hòa hai đầu nhưng có trung tâm (O)
# ReLu max(0, x): Sử dụng khá nhiều gần đây do tốc độ hội tụ nhanh do nó k bị bão hòa 2 đầu
# --> Rectified Linear Unit: đơn vị tuyến tính được hiệu chỉnh
# Tính toán nhanh dO công thức đơn giản
# Nhược điểm là với những node < 0 thù activation chuyển thành 0 (Dying ReLU) (*)
# Leaky ReLU dùng để khắc phục ReLU
# LeakyReLU: f(x) = 1 với x<0 và f(x)=ax + 1 với x>=0 với a nhỏ
# Thay vì trả về 0 với x < 0 thì nó cố gắng tạo ra một đường xiên nhỏ

# %% [markdown]
# ## Discriminator

# %%
def make_discriminator_model(n_features):
    model = Sequential()
    model.add(Flatten())
    model.add(Dense(units=72, input_shape=((n_sequence+1) * n_features,), activation=None, kernel_initializer='random_normal'))
    model.add(tf.keras.layers.LeakyReLU(alpha=0.3))
    # là một lớp sinh dữ liệu ngẫu nhiên nhằm giảm thiểu overfit
    model.add(tf.keras.layers.GaussianNoise(stddev=0.2))
    model.add(Dropout(0.3))
    model.add(Dense(units=100, activation=None, kernel_initializer='random_normal'))
    model.add(tf.keras.layers.LeakyReLU(alpha=0.3))
    model.add(Dropout(0.3))
    model.add(Dense(units=10, activation=None, kernel_initializer='random_normal'))
    model.add(tf.keras.layers.LeakyReLU(alpha=0.3))
    model.add(Dropout(0.3))
    model.add(Dense(1 ,activation='sigmoid'))
    model.compile(loss=discriminator_loss)
    return model

# %% [markdown]
# # Training

# %%
def train_step_def(sequences, sequences_end):
    # GradientTape trả về  Context Manager, quản lý quan sát các thay đổi của mô hình và cập nhật lại trọng số
    # Nó theo dõi các quá trình tính toán của mô hình trong quá trình lan truyền thuận và cập nhật trong quá trình lan truyền ngược
    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        # Giải thích training=True 
        # https://stackoverflow.com/questions/57320371/what-does-training-true-mean-when-calling-a-tensorflow-keras-model
        generated_prediction = generator(sequences, training=True)
        # None là cách tăng dimension. VD: [1,2,3] --> [[1],[2],[3]]
        sequences_true = tf.concat((sequences, sequences_end[:, None, :]), axis=1)
        sequences_fake = tf.concat((sequences, generated_prediction[:, None, :]), axis=1)

        real_output = discriminator(sequences_true, training=True)
        fake_output = discriminator(sequences_fake, training=True)

        gen_loss, gen_mse_loss = generator_loss(generated_prediction, 
                                                sequences_end, 
                                                fake_output)
        disc_loss = discriminator_loss(real_output, fake_output)

    gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

    return tf.reduce_mean(gen_loss), tf.reduce_mean(disc_loss), tf.reduce_mean(gen_mse_loss)

def test_step_def(sequences, sequences_end):
    generated_prediction = generator(sequences, training=False)

    sequences_true = tf.concat((sequences, sequences_end[:,None,:]), axis=1)
    sequences_fake = tf.concat((sequences, generated_prediction[:,None,:]), axis=1)

    real_output = discriminator(sequences_true, training=False)
    fake_output = discriminator(sequences_fake, training=False)

    gen_loss, gen_mse_loss = generator_loss(generated_prediction, sequences_end, fake_output)
    disc_loss = discriminator_loss(real_output, fake_output)
    return tf.reduce_mean(gen_loss), tf.reduce_mean(disc_loss), tf.reduce_mean(gen_mse_loss)

# %%
def train(dataset, dataset_val, epochs):
    # Biến history (training) và history_val (testing) lưu các thông số liên quan đến mse, rmse, mae, mape để vẽ đồ thị ở bước sau
    history = np.empty(shape = (8, epochs))
    history_val = np.empty(shape = (8, epochs))
    len_dataset = len(dataset)
    len_dataset_val = len(dataset_val)
    for epoch in range(epochs):
        start = time.time()

        cur_dis_loss = 0
        cur_gen_loss = 0
        cur_gen_mse_loss = 0
        # Với mỗi batch
        for sequence_batch, sequence_end_batch in dataset:
            # Tiến hành train, cập nhật weight bằng Gradient Tape cho hai mô hình G và D
            aux_cur_losses = train_step(tf.cast(sequence_batch, tf.float32), 
                                      tf.cast(sequence_end_batch, tf.float32))
            # lấy ra giá trị của các loss function 
            cur_gen_loss += aux_cur_losses[0]/len_dataset
            cur_dis_loss += aux_cur_losses[1]/len_dataset
            cur_gen_mse_loss += aux_cur_losses[2]/len_dataset
        # Verbose là dài dòng, verbose=False có nghĩa là không xuất ra giá trị cụ thể
        cur_gen_metrics = generator.evaluate(dataset,verbose=False)[1:]

        #Lưu các thông số vào biến history
        history[:, epoch] = cur_gen_loss, cur_dis_loss, cur_gen_mse_loss, *cur_gen_metrics

        cur_gen_metrics_val = generator.evaluate(dataset_val,verbose=False)[1: ]

        cur_gen_loss_val = 0
        cur_dis_loss_val = 0
        cur_gen_mse_loss_val = 0
        for sequence_batch, sequence_end_batch in dataset_val:
            aux_cur_losses_val = test_step(tf.cast(sequence_batch, tf.float32), 
                                         tf.cast(sequence_end_batch, tf.float32))
            cur_gen_loss_val += aux_cur_losses_val[0]/len_dataset_val
            cur_dis_loss_val += aux_cur_losses_val[1]/len_dataset_val
            cur_gen_mse_loss_val += aux_cur_losses_val[2]/len_dataset_val
    


        history_val[:, epoch] = cur_gen_loss_val, cur_dis_loss_val, cur_gen_mse_loss_val, *cur_gen_metrics_val

        print ('Time for epoch {} is {} sec Generator Loss: {},  Discriminator_loss: {}'
               .format(epoch + 1, time.time()-start, cur_gen_loss, cur_dis_loss))

        # Save the model every 15 epochs
        if (epoch + 1) % 15 == 0:
            checkpoint.save(file_prefix = checkpoint_prefix)

    return history, history_val

# %% [markdown]
# ## Visualization

# %%
def plot_history(history, history_val):
    metrics = ["gen_loss","dis_loss","gen_mse_loss", 'mse','mae','mape','rmse','ar']
    for i, metric_name in enumerate(metrics):  
        plt.figure()
        plt.title(metric_name)
        plt.plot(history[i], label='train')
        plt.plot(history_val[i], label='test')
        plt.legend()
    plt.show()

# %%
def plot_frame(sequence, target, model):
    y_pred = model.predict(sequence)[...,3]
    y_true = target[...,3]

    plt.figure()
    plt.title("closing price")
    plt.plot(y_true, label="true")
    plt.plot(y_pred, label="prediction")
    plt.legend()
    plt.show()

# %%
def get_best_results(history):
    min_index = np.argmin(history[3, :])
    return history[:, min_index]

# %% [markdown]
# ## Variables

# %%
window = 5
n_sequence = window
n_features = 7
n_batch = 50
EPOCHS = 2000

# %% [markdown]
# ## Data loading

# %%
stock_code = "IBM"
start = dt.datetime(2000, 1, 1)
end = dt.datetime(2020, 12, 31)
raw_data = pdr.get_data_yahoo(stock_code, start, end,threads=False, proxy="http://127.0.0.1:7890")
df = raw_data.dropna();
df = df.reset_index(level=0)
df = add_Ma(df, window)
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#            Date        Open        High         Low       Close   Adj Close  \
# 5    2000-01-10  112.093689  114.125237  110.301147  112.810707   64.370789
# 6    2000-01-11  112.691208  115.798279  111.496178  113.766731   64.916267
# 7    2000-01-12  114.364243  116.634796  113.049713  114.244743   65.189049
# 8    2000-01-13  114.663002  115.678780  110.659653  113.049713   64.507149
# 9    2000-01-14  115.619026  117.889580  112.332695  114.364243   65.257240
# ...         ...         ...         ...         ...         ...         ...
# 5278 2020-12-23  118.432121  119.703636  118.298279  118.451241  106.144394
# 5279 2020-12-24  119.502869  119.598473  118.747612  119.206497  106.821182
# 5280 2020-12-28  119.598473  121.032501  118.986618  119.330788  106.932564
# 5281 2020-12-29  119.837479  119.961761  117.820267  118.355644  106.058731
# 5282 2020-12-30  118.355644  119.359467  118.193115  118.871895  106.521355
#
#         Volume          Ma
# 5      8933363  109.285373
# 6      8235472  109.667783
# 7      7116775  110.994264
# 8      8880226  111.663481
# 9     11460604  112.476100
# ...        ...         ...
# 5278   2817819  119.302103
# 5279   1842111  118.986615
# 5280   3781499  118.822179
# 5281   3647402  118.625238
# 5282   3535794  118.703633
#
# [5278 rows x 8 columns]

# %%
start_time = datetime.datetime.now()
data_gen_train, data_gen_test = get_gen_train_test(df, n_sequence, n_batch)

generator = make_generator_model(n_sequence, n_features)
discriminator=make_discriminator_model(n_features)

learning_rate=1e-4
generator_optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.5)
discriminator_optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.5)

@tf.function
def train_step(sequences, sequences_end):
  return train_step_def(sequences, sequences_end)

@tf.function
def test_step(sequences, sequences_end):
  return test_step_def(sequences, sequences_end)

checkpoint_dir = './training_checkpoints'+stock_code
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(generator_optimizer=generator_optimizer,
                                 discriminator_optimizer=discriminator_optimizer,
                                 generator=generator,
                                 discriminator=discriminator)

history, history_val = train(data_gen_train, data_gen_test, EPOCHS)

plot_history(history, history_val)
plot_frame(*data_gen_test[0], generator)

print("[MSE Baseline] train:",mean_squared_error(data_gen_train)," test:", mean_squared_error(data_gen_test))
now = datetime.datetime.now()
delta = now - start_time
print("Delta time:", delta)
generator.save("lstm_ffnn.h5")
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5, 7)]            0
#
#  lstm (LSTM)                 (None, 5, 10)             720
#
#  batch_normalization (BatchN  (None, 5, 10)            40
#  ormalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 5, 10)             0
#
#  dropout (Dropout)           (None, 5, 10)             0
#
#  lstm_1 (LSTM)               (None, 10)                840
#
#  batch_normalization_1 (Batc  (None, 10)               40
#  hNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 10)                0
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense (Dense)               (None, 7)                 77
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 7)                 0
#
# =================================================================
# Total params: 1,717
# Trainable params: 1,677
# Non-trainable params: 40
# _________________________________________________________________
# Time for epoch 1 is 8.689730405807495 sec Generator Loss: 0.7316574454307556,  Discriminator_loss: 1.369222640991211
# Time for epoch 2 is 0.8021848201751709 sec Generator Loss: 0.7301811575889587,  Discriminator_loss: 1.3273533582687378
# Time for epoch 3 is 0.8088703155517578 sec Generator Loss: 0.733133852481842,  Discriminator_loss: 1.2702387571334839
# Time for epoch 4 is 0.8472452163696289 sec Generator Loss: 0.7791096568107605,  Discriminator_loss: 1.1942172050476074
# Time for epoch 5 is 0.9217996597290039 sec Generator Loss: 0.8810731768608093,  Discriminator_loss: 1.1109943389892578
# Time for epoch 6 is 0.8953084945678711 sec Generator Loss: 0.9874762296676636,  Discriminator_loss: 1.0416924953460693
# Time for epoch 7 is 0.8491723537445068 sec Generator Loss: 1.0772534608840942,  Discriminator_loss: 1.0190802812576294
# Time for epoch 8 is 0.8869800567626953 sec Generator Loss: 1.1866674423217773,  Discriminator_loss: 0.978784441947937
# Time for epoch 9 is 0.8585226535797119 sec Generator Loss: 1.2369269132614136,  Discriminator_loss: 1.0348435640335083
# Time for epoch 10 is 0.826988697052002 sec Generator Loss: 1.2756807804107666,  Discriminator_loss: 0.9801430702209473
# Time for epoch 11 is 0.770697832107544 sec Generator Loss: 1.3254518508911133,  Discriminator_loss: 0.9365212917327881
# Time for epoch 12 is 0.778325080871582 sec Generator Loss: 1.3397825956344604,  Discriminator_loss: 0.9413580894470215
# Time for epoch 13 is 0.7780840396881104 sec Generator Loss: 1.3377768993377686,  Discriminator_loss: 0.9910233020782471
# Time for epoch 14 is 0.7848672866821289 sec Generator Loss: 1.4717859029769897,  Discriminator_loss: 0.9287359118461609
# Time for epoch 15 is 0.775712251663208 sec Generator Loss: 1.4712578058242798,  Discriminator_loss: 0.9652668833732605
# Time for epoch 16 is 0.7849922180175781 sec Generator Loss: 1.4253265857696533,  Discriminator_loss: 0.9528535008430481
# Time for epoch 17 is 0.7763838768005371 sec Generator Loss: 1.4230467081069946,  Discriminator_loss: 0.9481770992279053
# Time for epoch 18 is 0.774472713470459 sec Generator Loss: 1.4178876876831055,  Discriminator_loss: 0.9656888246536255
# Time for epoch 19 is 0.7693774700164795 sec Generator Loss: 1.396668791770935,  Discriminator_loss: 0.9702626466751099
# Time for epoch 20 is 0.8212850093841553 sec Generator Loss: 1.4382506608963013,  Discriminator_loss: 0.9539278149604797
# Time for epoch 21 is 0.8307693004608154 sec Generator Loss: 1.3936599493026733,  Discriminator_loss: 0.9829069972038269
# Time for epoch 22 is 0.814276933670044 sec Generator Loss: 1.3723164796829224,  Discriminator_loss: 0.9902730584144592
# Time for epoch 23 is 0.8108439445495605 sec Generator Loss: 1.385764479637146,  Discriminator_loss: 0.971245527267456
# Time for epoch 24 is 0.7722492218017578 sec Generator Loss: 1.3622124195098877,  Discriminator_loss: 1.002877950668335
# Time for epoch 25 is 0.7771759033203125 sec Generator Loss: 1.3479292392730713,  Discriminator_loss: 0.9932619333267212
# Time for epoch 26 is 0.7705078125 sec Generator Loss: 1.3409924507141113,  Discriminator_loss: 0.9954826235771179
# Time for epoch 27 is 0.776233434677124 sec Generator Loss: 1.3085532188415527,  Discriminator_loss: 0.9978048801422119
# Time for epoch 28 is 0.776648759841919 sec Generator Loss: 1.3314884901046753,  Discriminator_loss: 0.9994981288909912
# Time for epoch 29 is 0.7947814464569092 sec Generator Loss: 1.3356083631515503,  Discriminator_loss: 0.991098940372467
# Time for epoch 30 is 0.7662818431854248 sec Generator Loss: 1.32041597366333,  Discriminator_loss: 0.9971526265144348
# Time for epoch 31 is 0.7727880477905273 sec Generator Loss: 1.3091049194335938,  Discriminator_loss: 1.0121173858642578
# Time for epoch 32 is 0.7798535823822021 sec Generator Loss: 1.260489821434021,  Discriminator_loss: 1.0504957437515259
# Time for epoch 33 is 0.7834944725036621 sec Generator Loss: 1.2738120555877686,  Discriminator_loss: 1.0487325191497803
# Time for epoch 34 is 0.8079593181610107 sec Generator Loss: 1.2231167554855347,  Discriminator_loss: 1.0610949993133545
# Time for epoch 35 is 0.7791848182678223 sec Generator Loss: 1.234262466430664,  Discriminator_loss: 1.0573440790176392
# Time for epoch 36 is 0.7636685371398926 sec Generator Loss: 1.220058560371399,  Discriminator_loss: 1.0686008930206299
# Time for epoch 37 is 0.792811393737793 sec Generator Loss: 1.2158632278442383,  Discriminator_loss: 1.0698119401931763
# Time for epoch 38 is 0.849729061126709 sec Generator Loss: 1.191444993019104,  Discriminator_loss: 1.095872402191162
# Time for epoch 39 is 0.8664994239807129 sec Generator Loss: 1.193088412284851,  Discriminator_loss: 1.0909559726715088
# Time for epoch 40 is 0.8401727676391602 sec Generator Loss: 1.1735199689865112,  Discriminator_loss: 1.0831412076950073
# Time for epoch 41 is 0.8130292892456055 sec Generator Loss: 1.1681281328201294,  Discriminator_loss: 1.0917595624923706
# Time for epoch 42 is 0.8032453060150146 sec Generator Loss: 1.1620782613754272,  Discriminator_loss: 1.1016680002212524
# Time for epoch 43 is 0.8154904842376709 sec Generator Loss: 1.1412731409072876,  Discriminator_loss: 1.1044975519180298
# Time for epoch 44 is 0.806126594543457 sec Generator Loss: 1.130822777748108,  Discriminator_loss: 1.1064958572387695
# Time for epoch 45 is 0.8471839427947998 sec Generator Loss: 1.1522942781448364,  Discriminator_loss: 1.111550211906433
# Time for epoch 46 is 0.8722841739654541 sec Generator Loss: 1.1235803365707397,  Discriminator_loss: 1.137460470199585
# Time for epoch 47 is 0.848156213760376 sec Generator Loss: 1.1271886825561523,  Discriminator_loss: 1.1269621849060059
# Time for epoch 48 is 0.8898875713348389 sec Generator Loss: 1.1311017274856567,  Discriminator_loss: 1.1360026597976685
# Time for epoch 49 is 0.8279154300689697 sec Generator Loss: 1.1144086122512817,  Discriminator_loss: 1.1445218324661255
# Time for epoch 50 is 0.842097282409668 sec Generator Loss: 1.0904862880706787,  Discriminator_loss: 1.1526355743408203
# Time for epoch 51 is 0.8339159488677979 sec Generator Loss: 1.094303846359253,  Discriminator_loss: 1.1571327447891235
# Time for epoch 52 is 0.7665536403656006 sec Generator Loss: 1.080202341079712,  Discriminator_loss: 1.171226978302002
# Time for epoch 53 is 0.8082218170166016 sec Generator Loss: 1.0637476444244385,  Discriminator_loss: 1.182033896446228
# Time for epoch 54 is 0.8789477348327637 sec Generator Loss: 1.0511177778244019,  Discriminator_loss: 1.1972063779830933
# Time for epoch 55 is 0.8313548564910889 sec Generator Loss: 1.0353291034698486,  Discriminator_loss: 1.2119216918945312
# Time for epoch 56 is 0.807809591293335 sec Generator Loss: 1.01483154296875,  Discriminator_loss: 1.2154743671417236
# Time for epoch 57 is 0.7849776744842529 sec Generator Loss: 1.018951416015625,  Discriminator_loss: 1.2143837213516235
# Time for epoch 58 is 0.7911703586578369 sec Generator Loss: 1.0067806243896484,  Discriminator_loss: 1.2219808101654053
# Time for epoch 59 is 0.8395481109619141 sec Generator Loss: 1.0131183862686157,  Discriminator_loss: 1.213028073310852
# Time for epoch 60 is 0.8302512168884277 sec Generator Loss: 0.9898291230201721,  Discriminator_loss: 1.2291604280471802
# Time for epoch 61 is 0.7777986526489258 sec Generator Loss: 1.0100739002227783,  Discriminator_loss: 1.2046427726745605
# Time for epoch 62 is 0.804041862487793 sec Generator Loss: 1.0020424127578735,  Discriminator_loss: 1.2358756065368652
# Time for epoch 63 is 0.8493328094482422 sec Generator Loss: 0.988072395324707,  Discriminator_loss: 1.2228353023529053
# Time for epoch 64 is 0.8138177394866943 sec Generator Loss: 0.9888742566108704,  Discriminator_loss: 1.2271822690963745
# Time for epoch 65 is 0.82275390625 sec Generator Loss: 0.9837271571159363,  Discriminator_loss: 1.2427996397018433
# Time for epoch 66 is 0.7932093143463135 sec Generator Loss: 0.9905965924263,  Discriminator_loss: 1.2272233963012695
# Time for epoch 67 is 0.8116321563720703 sec Generator Loss: 0.9864025115966797,  Discriminator_loss: 1.236788272857666
# Time for epoch 68 is 0.8038315773010254 sec Generator Loss: 0.9648074507713318,  Discriminator_loss: 1.2471256256103516
# Time for epoch 69 is 0.8071050643920898 sec Generator Loss: 0.9741398096084595,  Discriminator_loss: 1.2445894479751587
# Time for epoch 70 is 0.791130781173706 sec Generator Loss: 0.9630171656608582,  Discriminator_loss: 1.251104712486267
# Time for epoch 71 is 0.8563838005065918 sec Generator Loss: 0.9690946340560913,  Discriminator_loss: 1.242841362953186
# Time for epoch 72 is 0.8729302883148193 sec Generator Loss: 0.9742251634597778,  Discriminator_loss: 1.245019555091858
# Time for epoch 73 is 0.8597443103790283 sec Generator Loss: 0.9649809002876282,  Discriminator_loss: 1.2400314807891846
# Time for epoch 74 is 0.900306224822998 sec Generator Loss: 0.9635360240936279,  Discriminator_loss: 1.2547507286071777
# Time for epoch 75 is 0.8406803607940674 sec Generator Loss: 0.9546612501144409,  Discriminator_loss: 1.2561343908309937
# Time for epoch 76 is 0.8180739879608154 sec Generator Loss: 0.9554307460784912,  Discriminator_loss: 1.2489638328552246
# Time for epoch 77 is 1.0867385864257812 sec Generator Loss: 0.9514585733413696,  Discriminator_loss: 1.2556148767471313
# Time for epoch 78 is 0.8974685668945312 sec Generator Loss: 0.9526001811027527,  Discriminator_loss: 1.2571605443954468
# Time for epoch 79 is 0.9246389865875244 sec Generator Loss: 0.9543149471282959,  Discriminator_loss: 1.2668880224227905
# Time for epoch 80 is 0.8123440742492676 sec Generator Loss: 0.9593822956085205,  Discriminator_loss: 1.2570761442184448
# Time for epoch 81 is 0.8343024253845215 sec Generator Loss: 0.9549551010131836,  Discriminator_loss: 1.2561384439468384
# Time for epoch 82 is 0.8179335594177246 sec Generator Loss: 0.9473742246627808,  Discriminator_loss: 1.2627792358398438
# Time for epoch 83 is 0.8775904178619385 sec Generator Loss: 0.937805712223053,  Discriminator_loss: 1.2736352682113647
# Time for epoch 84 is 0.825894832611084 sec Generator Loss: 0.9500647783279419,  Discriminator_loss: 1.2658019065856934
# Time for epoch 85 is 0.8463425636291504 sec Generator Loss: 0.9329082369804382,  Discriminator_loss: 1.2725391387939453
# Time for epoch 86 is 0.8384733200073242 sec Generator Loss: 0.9485793709754944,  Discriminator_loss: 1.264145851135254
# Time for epoch 87 is 0.8663010597229004 sec Generator Loss: 0.9397379159927368,  Discriminator_loss: 1.2749433517456055
# Time for epoch 88 is 0.8407394886016846 sec Generator Loss: 0.9242377877235413,  Discriminator_loss: 1.2823364734649658
# Time for epoch 89 is 0.8536102771759033 sec Generator Loss: 0.9194816946983337,  Discriminator_loss: 1.281183123588562
# Time for epoch 90 is 0.869753360748291 sec Generator Loss: 0.9387943148612976,  Discriminator_loss: 1.2732524871826172
# Time for epoch 91 is 0.882657527923584 sec Generator Loss: 0.911173403263092,  Discriminator_loss: 1.2863667011260986
# Time for epoch 92 is 0.8650572299957275 sec Generator Loss: 0.9083342552185059,  Discriminator_loss: 1.2892043590545654
# Time for epoch 93 is 0.8159341812133789 sec Generator Loss: 0.9118120670318604,  Discriminator_loss: 1.2904752492904663
# Time for epoch 94 is 0.8778243064880371 sec Generator Loss: 0.8986920118331909,  Discriminator_loss: 1.3105945587158203
# Time for epoch 95 is 0.8114974498748779 sec Generator Loss: 0.8958896398544312,  Discriminator_loss: 1.306470513343811
# Time for epoch 96 is 0.8477702140808105 sec Generator Loss: 0.8906048536300659,  Discriminator_loss: 1.3060595989227295
# Time for epoch 97 is 0.8670179843902588 sec Generator Loss: 0.8790863752365112,  Discriminator_loss: 1.3131378889083862
# Time for epoch 98 is 0.8480081558227539 sec Generator Loss: 0.88608318567276,  Discriminator_loss: 1.3054078817367554
# Time for epoch 99 is 0.7946140766143799 sec Generator Loss: 0.8955976366996765,  Discriminator_loss: 1.3062019348144531
# Time for epoch 100 is 0.8226733207702637 sec Generator Loss: 0.8744298219680786,  Discriminator_loss: 1.3145637512207031
# Time for epoch 101 is 0.9067296981811523 sec Generator Loss: 0.8865648508071899,  Discriminator_loss: 1.2984540462493896
# Time for epoch 102 is 0.8004131317138672 sec Generator Loss: 0.8860418796539307,  Discriminator_loss: 1.3026269674301147
# Time for epoch 103 is 0.8328320980072021 sec Generator Loss: 0.880237340927124,  Discriminator_loss: 1.3061535358428955
# Time for epoch 104 is 0.9048702716827393 sec Generator Loss: 0.8873143196105957,  Discriminator_loss: 1.3048596382141113
# Time for epoch 105 is 0.8279876708984375 sec Generator Loss: 0.8806894421577454,  Discriminator_loss: 1.3020524978637695
# Time for epoch 106 is 0.8327317237854004 sec Generator Loss: 0.8929755687713623,  Discriminator_loss: 1.3018869161605835
# Time for epoch 107 is 0.796717643737793 sec Generator Loss: 0.8957509398460388,  Discriminator_loss: 1.2989634275436401
# Time for epoch 108 is 0.8025927543640137 sec Generator Loss: 0.870108962059021,  Discriminator_loss: 1.3194233179092407
# Time for epoch 109 is 0.8219490051269531 sec Generator Loss: 0.8623889684677124,  Discriminator_loss: 1.31531822681427
# Time for epoch 110 is 0.84470534324646 sec Generator Loss: 0.8864189982414246,  Discriminator_loss: 1.2991546392440796
# Time for epoch 111 is 0.815361738204956 sec Generator Loss: 0.8740479946136475,  Discriminator_loss: 1.3102930784225464
# Time for epoch 112 is 0.8122525215148926 sec Generator Loss: 0.8757570385932922,  Discriminator_loss: 1.3070743083953857
# Time for epoch 113 is 0.814579963684082 sec Generator Loss: 0.8628215789794922,  Discriminator_loss: 1.314622402191162
# Time for epoch 114 is 0.802365779876709 sec Generator Loss: 0.8746843934059143,  Discriminator_loss: 1.3039301633834839
# Time for epoch 115 is 0.7978236675262451 sec Generator Loss: 0.8856814503669739,  Discriminator_loss: 1.305346965789795
# Time for epoch 116 is 0.796088695526123 sec Generator Loss: 0.8688130378723145,  Discriminator_loss: 1.3020634651184082
# Time for epoch 117 is 0.8185138702392578 sec Generator Loss: 0.8657339215278625,  Discriminator_loss: 1.3124163150787354
# Time for epoch 118 is 0.8515548706054688 sec Generator Loss: 0.8742336630821228,  Discriminator_loss: 1.3029989004135132
# Time for epoch 119 is 0.8201179504394531 sec Generator Loss: 0.8697565793991089,  Discriminator_loss: 1.3058631420135498
# Time for epoch 120 is 0.8061738014221191 sec Generator Loss: 0.8640189170837402,  Discriminator_loss: 1.3112679719924927
# Time for epoch 121 is 0.8047101497650146 sec Generator Loss: 0.8718801140785217,  Discriminator_loss: 1.307232141494751
# Time for epoch 122 is 0.8286643028259277 sec Generator Loss: 0.874679684638977,  Discriminator_loss: 1.3073177337646484
# Time for epoch 123 is 0.7928917407989502 sec Generator Loss: 0.8736093044281006,  Discriminator_loss: 1.3101551532745361
# Time for epoch 124 is 0.8015835285186768 sec Generator Loss: 0.8668060898780823,  Discriminator_loss: 1.3094356060028076
# Time for epoch 125 is 0.8135228157043457 sec Generator Loss: 0.8612554669380188,  Discriminator_loss: 1.3088278770446777
# Time for epoch 126 is 0.8384010791778564 sec Generator Loss: 0.8720805048942566,  Discriminator_loss: 1.3161896467208862
# Time for epoch 127 is 0.8053574562072754 sec Generator Loss: 0.8698870539665222,  Discriminator_loss: 1.3031944036483765
# Time for epoch 128 is 0.8022274971008301 sec Generator Loss: 0.8699800968170166,  Discriminator_loss: 1.3086447715759277
# Time for epoch 129 is 0.7976429462432861 sec Generator Loss: 0.8694638013839722,  Discriminator_loss: 1.3036898374557495
# Time for epoch 130 is 0.8129739761352539 sec Generator Loss: 0.8610856533050537,  Discriminator_loss: 1.3121241331100464
# Time for epoch 131 is 0.8028726577758789 sec Generator Loss: 0.8643866181373596,  Discriminator_loss: 1.317617416381836
# Time for epoch 132 is 0.809302568435669 sec Generator Loss: 0.8619490265846252,  Discriminator_loss: 1.3132983446121216
# Time for epoch 133 is 0.80255126953125 sec Generator Loss: 0.8667681813240051,  Discriminator_loss: 1.3211960792541504
# Time for epoch 134 is 0.8121519088745117 sec Generator Loss: 0.8580213189125061,  Discriminator_loss: 1.3180984258651733
# Time for epoch 135 is 0.8042330741882324 sec Generator Loss: 0.8629220724105835,  Discriminator_loss: 1.3090674877166748
# Time for epoch 136 is 0.7976772785186768 sec Generator Loss: 0.8532319664955139,  Discriminator_loss: 1.317658543586731
# Time for epoch 137 is 0.8241546154022217 sec Generator Loss: 0.851395845413208,  Discriminator_loss: 1.3112826347351074
# Time for epoch 138 is 0.809490442276001 sec Generator Loss: 0.858599841594696,  Discriminator_loss: 1.313019037246704
# Time for epoch 139 is 0.7894563674926758 sec Generator Loss: 0.8547755479812622,  Discriminator_loss: 1.3096551895141602
# Time for epoch 140 is 0.8064038753509521 sec Generator Loss: 0.8524357676506042,  Discriminator_loss: 1.3164759874343872
# Time for epoch 141 is 0.8466432094573975 sec Generator Loss: 0.8632983565330505,  Discriminator_loss: 1.3116856813430786
# Time for epoch 142 is 0.8155109882354736 sec Generator Loss: 0.8585701584815979,  Discriminator_loss: 1.3215203285217285
# Time for epoch 143 is 0.8231875896453857 sec Generator Loss: 0.8453476428985596,  Discriminator_loss: 1.3290698528289795
# Time for epoch 144 is 0.864727258682251 sec Generator Loss: 0.8588137626647949,  Discriminator_loss: 1.3105616569519043
# Time for epoch 145 is 0.8473193645477295 sec Generator Loss: 0.8584904074668884,  Discriminator_loss: 1.315259575843811
# Time for epoch 146 is 0.84686279296875 sec Generator Loss: 0.8507649302482605,  Discriminator_loss: 1.3310285806655884
# Time for epoch 147 is 0.8310461044311523 sec Generator Loss: 0.8531739711761475,  Discriminator_loss: 1.3188873529434204
# Time for epoch 148 is 0.8564701080322266 sec Generator Loss: 0.8553322553634644,  Discriminator_loss: 1.3165569305419922
# Time for epoch 149 is 0.8626389503479004 sec Generator Loss: 0.8544828295707703,  Discriminator_loss: 1.3248927593231201
# Time for epoch 150 is 0.8478009700775146 sec Generator Loss: 0.862977147102356,  Discriminator_loss: 1.3178201913833618
# Time for epoch 151 is 0.8623428344726562 sec Generator Loss: 0.8520033359527588,  Discriminator_loss: 1.3199472427368164
# Time for epoch 152 is 0.8930160999298096 sec Generator Loss: 0.8532413840293884,  Discriminator_loss: 1.3284499645233154
# Time for epoch 153 is 0.8410022258758545 sec Generator Loss: 0.849462628364563,  Discriminator_loss: 1.3282849788665771
# Time for epoch 154 is 0.8033502101898193 sec Generator Loss: 0.8467524647712708,  Discriminator_loss: 1.3224191665649414
# Time for epoch 155 is 0.8062245845794678 sec Generator Loss: 0.8428909778594971,  Discriminator_loss: 1.3268059492111206
# Time for epoch 156 is 0.8160922527313232 sec Generator Loss: 0.8473287224769592,  Discriminator_loss: 1.315051555633545
# Time for epoch 157 is 0.8021621704101562 sec Generator Loss: 0.8502147197723389,  Discriminator_loss: 1.3234381675720215
# Time for epoch 158 is 0.810666561126709 sec Generator Loss: 0.8392812013626099,  Discriminator_loss: 1.323663592338562
# Time for epoch 159 is 0.8062343597412109 sec Generator Loss: 0.8528500199317932,  Discriminator_loss: 1.315384864807129
# Time for epoch 160 is 0.8000357151031494 sec Generator Loss: 0.8409467339515686,  Discriminator_loss: 1.3312466144561768
# Time for epoch 161 is 0.8056743144989014 sec Generator Loss: 0.8504082560539246,  Discriminator_loss: 1.3197762966156006
# Time for epoch 162 is 0.8006339073181152 sec Generator Loss: 0.8443634510040283,  Discriminator_loss: 1.3258211612701416
# Time for epoch 163 is 0.7977480888366699 sec Generator Loss: 0.8552592992782593,  Discriminator_loss: 1.3163238763809204
# Time for epoch 164 is 0.804588794708252 sec Generator Loss: 0.8582882881164551,  Discriminator_loss: 1.320058822631836
# Time for epoch 165 is 0.8249964714050293 sec Generator Loss: 0.8390984535217285,  Discriminator_loss: 1.3213255405426025
# Time for epoch 166 is 0.8073089122772217 sec Generator Loss: 0.8528380393981934,  Discriminator_loss: 1.318751573562622
# Time for epoch 167 is 0.8089823722839355 sec Generator Loss: 0.8465784192085266,  Discriminator_loss: 1.3215819597244263
# Time for epoch 168 is 0.8340401649475098 sec Generator Loss: 0.849541962146759,  Discriminator_loss: 1.324392557144165
# Time for epoch 169 is 0.812514066696167 sec Generator Loss: 0.8391843438148499,  Discriminator_loss: 1.3260467052459717
# Time for epoch 170 is 0.7967793941497803 sec Generator Loss: 0.8428859710693359,  Discriminator_loss: 1.3191238641738892
# Time for epoch 171 is 0.8038697242736816 sec Generator Loss: 0.8465810418128967,  Discriminator_loss: 1.3239942789077759
# Time for epoch 172 is 0.8194360733032227 sec Generator Loss: 0.8574533462524414,  Discriminator_loss: 1.3198004961013794
# Time for epoch 173 is 0.8071608543395996 sec Generator Loss: 0.8509485721588135,  Discriminator_loss: 1.3244104385375977
# Time for epoch 174 is 0.8208985328674316 sec Generator Loss: 0.8435559272766113,  Discriminator_loss: 1.3284428119659424
# Time for epoch 175 is 0.8160145282745361 sec Generator Loss: 0.8431122899055481,  Discriminator_loss: 1.3282606601715088
# Time for epoch 176 is 0.8125228881835938 sec Generator Loss: 0.8451730608940125,  Discriminator_loss: 1.3163701295852661
# Time for epoch 177 is 0.8028786182403564 sec Generator Loss: 0.8466098308563232,  Discriminator_loss: 1.3222566843032837
# Time for epoch 178 is 0.8123171329498291 sec Generator Loss: 0.8486307859420776,  Discriminator_loss: 1.316975712776184
# Time for epoch 179 is 0.8008427619934082 sec Generator Loss: 0.8544704914093018,  Discriminator_loss: 1.3193607330322266
# Time for epoch 180 is 0.8147287368774414 sec Generator Loss: 0.8561267256736755,  Discriminator_loss: 1.3205578327178955
# Time for epoch 181 is 1.0037012100219727 sec Generator Loss: 0.8583115339279175,  Discriminator_loss: 1.320558786392212
# Time for epoch 182 is 0.8171918392181396 sec Generator Loss: 0.8335396647453308,  Discriminator_loss: 1.3343595266342163
# Time for epoch 183 is 0.8616080284118652 sec Generator Loss: 0.8529810905456543,  Discriminator_loss: 1.31697416305542
# Time for epoch 184 is 0.7967054843902588 sec Generator Loss: 0.8524470329284668,  Discriminator_loss: 1.318480372428894
# Time for epoch 185 is 0.8063595294952393 sec Generator Loss: 0.8489841222763062,  Discriminator_loss: 1.3175441026687622
# Time for epoch 186 is 0.8191838264465332 sec Generator Loss: 0.8520262837409973,  Discriminator_loss: 1.3262473344802856
# Time for epoch 187 is 0.8002498149871826 sec Generator Loss: 0.8451758623123169,  Discriminator_loss: 1.3364843130111694
# Time for epoch 188 is 0.8145127296447754 sec Generator Loss: 0.8480854034423828,  Discriminator_loss: 1.3245868682861328
# Time for epoch 189 is 0.801055908203125 sec Generator Loss: 0.8468995690345764,  Discriminator_loss: 1.3272124528884888
# Time for epoch 190 is 0.7964246273040771 sec Generator Loss: 0.8349744081497192,  Discriminator_loss: 1.3252837657928467
# Time for epoch 191 is 0.8190045356750488 sec Generator Loss: 0.8500046730041504,  Discriminator_loss: 1.3220773935317993
# Time for epoch 192 is 0.8104770183563232 sec Generator Loss: 0.8461569547653198,  Discriminator_loss: 1.3208590745925903
# Time for epoch 193 is 0.8022751808166504 sec Generator Loss: 0.842075765132904,  Discriminator_loss: 1.3268367052078247
# Time for epoch 194 is 0.7896535396575928 sec Generator Loss: 0.8387029767036438,  Discriminator_loss: 1.32777738571167
# Time for epoch 195 is 0.8054914474487305 sec Generator Loss: 0.8383421301841736,  Discriminator_loss: 1.3263928890228271
# Time for epoch 196 is 0.8081817626953125 sec Generator Loss: 0.8498966693878174,  Discriminator_loss: 1.3245466947555542
# Time for epoch 197 is 0.8218512535095215 sec Generator Loss: 0.834872305393219,  Discriminator_loss: 1.3315131664276123
# Time for epoch 198 is 0.8337514400482178 sec Generator Loss: 0.8392777442932129,  Discriminator_loss: 1.3271965980529785
# Time for epoch 199 is 0.8550858497619629 sec Generator Loss: 0.8339207172393799,  Discriminator_loss: 1.3252804279327393
# Time for epoch 200 is 0.9145674705505371 sec Generator Loss: 0.8446487188339233,  Discriminator_loss: 1.3291059732437134
# Time for epoch 201 is 0.8023064136505127 sec Generator Loss: 0.8367833495140076,  Discriminator_loss: 1.3223623037338257
# Time for epoch 202 is 0.7923910617828369 sec Generator Loss: 0.8365840315818787,  Discriminator_loss: 1.3323155641555786
# Time for epoch 203 is 0.8247232437133789 sec Generator Loss: 0.8374143838882446,  Discriminator_loss: 1.3224409818649292
# Time for epoch 204 is 0.8162298202514648 sec Generator Loss: 0.8466302752494812,  Discriminator_loss: 1.318131923675537
# Time for epoch 205 is 0.8347434997558594 sec Generator Loss: 0.8407069444656372,  Discriminator_loss: 1.3218568563461304
# Time for epoch 206 is 0.8065557479858398 sec Generator Loss: 0.8504316806793213,  Discriminator_loss: 1.323967695236206
# Time for epoch 207 is 0.8366410732269287 sec Generator Loss: 0.8443635106086731,  Discriminator_loss: 1.3196001052856445
# Time for epoch 208 is 0.8115019798278809 sec Generator Loss: 0.8497245907783508,  Discriminator_loss: 1.3244861364364624
# Time for epoch 209 is 0.8600368499755859 sec Generator Loss: 0.8433252573013306,  Discriminator_loss: 1.3170944452285767
# Time for epoch 210 is 0.845055341720581 sec Generator Loss: 0.8408492803573608,  Discriminator_loss: 1.3266719579696655
# Time for epoch 211 is 0.8212800025939941 sec Generator Loss: 0.8369494676589966,  Discriminator_loss: 1.3251205682754517
# Time for epoch 212 is 0.8875119686126709 sec Generator Loss: 0.8383899331092834,  Discriminator_loss: 1.3148231506347656
# Time for epoch 213 is 0.8553366661071777 sec Generator Loss: 0.8442226648330688,  Discriminator_loss: 1.3100945949554443
# Time for epoch 214 is 0.8055002689361572 sec Generator Loss: 0.8498194217681885,  Discriminator_loss: 1.3200362920761108
# Time for epoch 215 is 0.8122608661651611 sec Generator Loss: 0.8463804721832275,  Discriminator_loss: 1.327566146850586
# Time for epoch 216 is 0.8777511119842529 sec Generator Loss: 0.8333749771118164,  Discriminator_loss: 1.324155330657959
# Time for epoch 217 is 0.8467695713043213 sec Generator Loss: 0.8425428867340088,  Discriminator_loss: 1.315265417098999
# Time for epoch 218 is 0.8590075969696045 sec Generator Loss: 0.858680009841919,  Discriminator_loss: 1.29726243019104
# Time for epoch 219 is 0.8638038635253906 sec Generator Loss: 0.853334367275238,  Discriminator_loss: 1.3132884502410889
# Time for epoch 220 is 0.8921680450439453 sec Generator Loss: 0.8358477354049683,  Discriminator_loss: 1.3192472457885742
# Time for epoch 221 is 0.9063410758972168 sec Generator Loss: 0.8489278554916382,  Discriminator_loss: 1.3166056871414185
# Time for epoch 222 is 0.8369247913360596 sec Generator Loss: 0.8594145178794861,  Discriminator_loss: 1.3152714967727661
# Time for epoch 223 is 0.8229613304138184 sec Generator Loss: 0.8578065037727356,  Discriminator_loss: 1.3211121559143066
# Time for epoch 224 is 0.9278364181518555 sec Generator Loss: 0.8489853143692017,  Discriminator_loss: 1.3214218616485596
# Time for epoch 225 is 0.8557131290435791 sec Generator Loss: 0.845621645450592,  Discriminator_loss: 1.3139758110046387
# Time for epoch 226 is 0.7923886775970459 sec Generator Loss: 0.8453168272972107,  Discriminator_loss: 1.3134676218032837
# Time for epoch 227 is 0.8663368225097656 sec Generator Loss: 0.8506977558135986,  Discriminator_loss: 1.31462562084198
# Time for epoch 228 is 0.832714319229126 sec Generator Loss: 0.8427356481552124,  Discriminator_loss: 1.3185559511184692
# Time for epoch 229 is 0.8303158283233643 sec Generator Loss: 0.8538787961006165,  Discriminator_loss: 1.3138787746429443
# Time for epoch 230 is 0.8999025821685791 sec Generator Loss: 0.8475607633590698,  Discriminator_loss: 1.3123306035995483
# Time for epoch 231 is 0.8236196041107178 sec Generator Loss: 0.8590393662452698,  Discriminator_loss: 1.310657024383545
# Time for epoch 232 is 0.838831901550293 sec Generator Loss: 0.8524097204208374,  Discriminator_loss: 1.3100765943527222
# Time for epoch 233 is 0.9033670425415039 sec Generator Loss: 0.8505386114120483,  Discriminator_loss: 1.3282655477523804
# Time for epoch 234 is 0.8141872882843018 sec Generator Loss: 0.8436194658279419,  Discriminator_loss: 1.317567229270935
# Time for epoch 235 is 0.8186142444610596 sec Generator Loss: 0.8524710536003113,  Discriminator_loss: 1.3152838945388794
# Time for epoch 236 is 0.811896562576294 sec Generator Loss: 0.8552922606468201,  Discriminator_loss: 1.3178540468215942
# Time for epoch 237 is 0.8090384006500244 sec Generator Loss: 0.8530710935592651,  Discriminator_loss: 1.3137940168380737
# Time for epoch 238 is 0.8185861110687256 sec Generator Loss: 0.8573421835899353,  Discriminator_loss: 1.308451533317566
# Time for epoch 239 is 0.8251454830169678 sec Generator Loss: 0.8521704077720642,  Discriminator_loss: 1.3134599924087524
# Time for epoch 240 is 0.8798258304595947 sec Generator Loss: 0.8493773341178894,  Discriminator_loss: 1.310693621635437
# Time for epoch 241 is 0.9296042919158936 sec Generator Loss: 0.851905882358551,  Discriminator_loss: 1.3219302892684937
# Time for epoch 242 is 0.962315559387207 sec Generator Loss: 0.8517220616340637,  Discriminator_loss: 1.314597487449646
# Time for epoch 243 is 0.9578244686126709 sec Generator Loss: 0.8565053343772888,  Discriminator_loss: 1.31486177444458
# Time for epoch 244 is 0.9499480724334717 sec Generator Loss: 0.8466889262199402,  Discriminator_loss: 1.3225663900375366
# Time for epoch 245 is 1.016524314880371 sec Generator Loss: 0.8456459045410156,  Discriminator_loss: 1.3205369710922241
# Time for epoch 246 is 0.8954710960388184 sec Generator Loss: 0.8528079390525818,  Discriminator_loss: 1.3183772563934326
# Time for epoch 247 is 0.825749397277832 sec Generator Loss: 0.8502233624458313,  Discriminator_loss: 1.3102993965148926
# Time for epoch 248 is 0.7835397720336914 sec Generator Loss: 0.8662586212158203,  Discriminator_loss: 1.3029745817184448
# Time for epoch 249 is 0.7767102718353271 sec Generator Loss: 0.8538491725921631,  Discriminator_loss: 1.3139430284500122
# Time for epoch 250 is 0.7823877334594727 sec Generator Loss: 0.8484276533126831,  Discriminator_loss: 1.3189085721969604
# Time for epoch 251 is 0.792938232421875 sec Generator Loss: 0.8561127781867981,  Discriminator_loss: 1.3112739324569702
# Time for epoch 252 is 0.9103565216064453 sec Generator Loss: 0.8473588228225708,  Discriminator_loss: 1.3093359470367432
# Time for epoch 253 is 0.7918639183044434 sec Generator Loss: 0.8471955060958862,  Discriminator_loss: 1.309856653213501
# Time for epoch 254 is 0.8855693340301514 sec Generator Loss: 0.855110228061676,  Discriminator_loss: 1.3211724758148193
# Time for epoch 255 is 0.8669528961181641 sec Generator Loss: 0.8397109508514404,  Discriminator_loss: 1.3252978324890137
# Time for epoch 256 is 0.7837514877319336 sec Generator Loss: 0.8548282980918884,  Discriminator_loss: 1.3239582777023315
# Time for epoch 257 is 0.8299648761749268 sec Generator Loss: 0.8554996848106384,  Discriminator_loss: 1.311142086982727
# Time for epoch 258 is 0.9721131324768066 sec Generator Loss: 0.8621587753295898,  Discriminator_loss: 1.3069278001785278
# Time for epoch 259 is 1.1615605354309082 sec Generator Loss: 0.8435726761817932,  Discriminator_loss: 1.3203866481781006
# Time for epoch 260 is 1.0811941623687744 sec Generator Loss: 0.8500595688819885,  Discriminator_loss: 1.3151241540908813
# Time for epoch 261 is 0.9303503036499023 sec Generator Loss: 0.8492225408554077,  Discriminator_loss: 1.3201977014541626
# Time for epoch 262 is 0.8899579048156738 sec Generator Loss: 0.8506126999855042,  Discriminator_loss: 1.3247597217559814
# Time for epoch 263 is 0.8799948692321777 sec Generator Loss: 0.8348736763000488,  Discriminator_loss: 1.3257781267166138
# Time for epoch 264 is 0.8476557731628418 sec Generator Loss: 0.8482906818389893,  Discriminator_loss: 1.3184423446655273
# Time for epoch 265 is 0.8373293876647949 sec Generator Loss: 0.8447899222373962,  Discriminator_loss: 1.3318970203399658
# Time for epoch 266 is 0.8404693603515625 sec Generator Loss: 0.8449825644493103,  Discriminator_loss: 1.3195730447769165
# Time for epoch 267 is 0.8334140777587891 sec Generator Loss: 0.8468725681304932,  Discriminator_loss: 1.3199101686477661
# Time for epoch 268 is 0.8565883636474609 sec Generator Loss: 0.8468624949455261,  Discriminator_loss: 1.3201076984405518
# Time for epoch 269 is 0.8485143184661865 sec Generator Loss: 0.8565570712089539,  Discriminator_loss: 1.3163444995880127
# Time for epoch 270 is 0.8404011726379395 sec Generator Loss: 0.8528768420219421,  Discriminator_loss: 1.309935212135315
# Time for epoch 271 is 0.8662950992584229 sec Generator Loss: 0.8536196947097778,  Discriminator_loss: 1.3130054473876953
# Time for epoch 272 is 0.8915455341339111 sec Generator Loss: 0.8523510098457336,  Discriminator_loss: 1.3191845417022705
# Time for epoch 273 is 0.8487224578857422 sec Generator Loss: 0.8501750826835632,  Discriminator_loss: 1.3131393194198608
# Time for epoch 274 is 0.8747286796569824 sec Generator Loss: 0.8387161493301392,  Discriminator_loss: 1.3148741722106934
# Time for epoch 275 is 0.9047822952270508 sec Generator Loss: 0.8517210483551025,  Discriminator_loss: 1.3176697492599487
# Time for epoch 276 is 0.8621735572814941 sec Generator Loss: 0.8569090962409973,  Discriminator_loss: 1.3143757581710815
# Time for epoch 277 is 0.8413515090942383 sec Generator Loss: 0.8436993956565857,  Discriminator_loss: 1.321830153465271
# Time for epoch 278 is 0.8580856323242188 sec Generator Loss: 0.8498177528381348,  Discriminator_loss: 1.3124568462371826
# Time for epoch 279 is 0.8153584003448486 sec Generator Loss: 0.8487670421600342,  Discriminator_loss: 1.3142307996749878
# Time for epoch 280 is 0.8573663234710693 sec Generator Loss: 0.8498493432998657,  Discriminator_loss: 1.311038851737976
# Time for epoch 281 is 0.8451969623565674 sec Generator Loss: 0.8516874313354492,  Discriminator_loss: 1.3169883489608765
# Time for epoch 282 is 0.8377301692962646 sec Generator Loss: 0.8460420370101929,  Discriminator_loss: 1.3183975219726562
# Time for epoch 283 is 0.8412399291992188 sec Generator Loss: 0.8459681868553162,  Discriminator_loss: 1.3237706422805786
# Time for epoch 284 is 0.8839547634124756 sec Generator Loss: 0.8570727705955505,  Discriminator_loss: 1.3072773218154907
# Time for epoch 285 is 0.9145731925964355 sec Generator Loss: 0.8520765900611877,  Discriminator_loss: 1.3146953582763672
# Time for epoch 286 is 0.8964650630950928 sec Generator Loss: 0.842136800289154,  Discriminator_loss: 1.3155649900436401
# Time for epoch 287 is 0.9557418823242188 sec Generator Loss: 0.8523469567298889,  Discriminator_loss: 1.3062005043029785
# Time for epoch 288 is 1.046656608581543 sec Generator Loss: 0.8488954901695251,  Discriminator_loss: 1.319805383682251
# Time for epoch 289 is 0.9322826862335205 sec Generator Loss: 0.8427162766456604,  Discriminator_loss: 1.3186581134796143
# Time for epoch 290 is 0.8892765045166016 sec Generator Loss: 0.8479423522949219,  Discriminator_loss: 1.3162459135055542
# Time for epoch 291 is 0.8803112506866455 sec Generator Loss: 0.8459230661392212,  Discriminator_loss: 1.3217604160308838
# Time for epoch 292 is 0.9045913219451904 sec Generator Loss: 0.8539575934410095,  Discriminator_loss: 1.3181158304214478
# Time for epoch 293 is 0.906531572341919 sec Generator Loss: 0.8587698936462402,  Discriminator_loss: 1.3056670427322388
# Time for epoch 294 is 0.8944976329803467 sec Generator Loss: 0.8635817766189575,  Discriminator_loss: 1.3145402669906616
# Time for epoch 295 is 0.8610327243804932 sec Generator Loss: 0.8443988561630249,  Discriminator_loss: 1.32476007938385
# Time for epoch 296 is 0.8592331409454346 sec Generator Loss: 0.8498231768608093,  Discriminator_loss: 1.3137353658676147
# Time for epoch 297 is 0.8358795642852783 sec Generator Loss: 0.8605086207389832,  Discriminator_loss: 1.306174874305725
# Time for epoch 298 is 0.858344316482544 sec Generator Loss: 0.8606625199317932,  Discriminator_loss: 1.3100348711013794
# Time for epoch 299 is 0.8321411609649658 sec Generator Loss: 0.8656889796257019,  Discriminator_loss: 1.3061144351959229
# Time for epoch 300 is 0.8316254615783691 sec Generator Loss: 0.8625147938728333,  Discriminator_loss: 1.3061909675598145
# Time for epoch 301 is 0.8340411186218262 sec Generator Loss: 0.847371518611908,  Discriminator_loss: 1.3184622526168823
# Time for epoch 302 is 0.8557615280151367 sec Generator Loss: 0.8483126163482666,  Discriminator_loss: 1.3142482042312622
# Time for epoch 303 is 0.8490352630615234 sec Generator Loss: 0.8505838513374329,  Discriminator_loss: 1.321913242340088
# Time for epoch 304 is 0.8354840278625488 sec Generator Loss: 0.8448742628097534,  Discriminator_loss: 1.3277486562728882
# Time for epoch 305 is 0.84090256690979 sec Generator Loss: 0.8502227067947388,  Discriminator_loss: 1.313551664352417
# Time for epoch 306 is 0.8304097652435303 sec Generator Loss: 0.8449286222457886,  Discriminator_loss: 1.3145536184310913
# Time for epoch 307 is 0.8319492340087891 sec Generator Loss: 0.8450829386711121,  Discriminator_loss: 1.320630669593811
# Time for epoch 308 is 0.8637650012969971 sec Generator Loss: 0.8479709625244141,  Discriminator_loss: 1.3211475610733032
# Time for epoch 309 is 0.8388397693634033 sec Generator Loss: 0.8467636704444885,  Discriminator_loss: 1.316323161125183
# Time for epoch 310 is 0.8077383041381836 sec Generator Loss: 0.8575151562690735,  Discriminator_loss: 1.3019883632659912
# Time for epoch 311 is 0.837158203125 sec Generator Loss: 0.8512168526649475,  Discriminator_loss: 1.3170069456100464
# Time for epoch 312 is 1.148916482925415 sec Generator Loss: 0.8537636995315552,  Discriminator_loss: 1.3141521215438843
# Time for epoch 313 is 0.9368376731872559 sec Generator Loss: 0.8500596284866333,  Discriminator_loss: 1.3107889890670776
# Time for epoch 314 is 0.9640090465545654 sec Generator Loss: 0.8447168469429016,  Discriminator_loss: 1.3178044557571411
# Time for epoch 315 is 0.8869113922119141 sec Generator Loss: 0.8540053963661194,  Discriminator_loss: 1.3132890462875366
# Time for epoch 316 is 0.8033182621002197 sec Generator Loss: 0.8438674807548523,  Discriminator_loss: 1.3169366121292114
# Time for epoch 317 is 0.8852548599243164 sec Generator Loss: 0.8655538558959961,  Discriminator_loss: 1.3091864585876465
# Time for epoch 318 is 0.8034367561340332 sec Generator Loss: 0.837823748588562,  Discriminator_loss: 1.3230584859848022
# Time for epoch 319 is 0.7856953144073486 sec Generator Loss: 0.853590190410614,  Discriminator_loss: 1.3158812522888184
# Time for epoch 320 is 0.7791550159454346 sec Generator Loss: 0.8510226607322693,  Discriminator_loss: 1.325323224067688
# Time for epoch 321 is 0.7696900367736816 sec Generator Loss: 0.859433650970459,  Discriminator_loss: 1.3078522682189941
# Time for epoch 322 is 0.8552062511444092 sec Generator Loss: 0.851262629032135,  Discriminator_loss: 1.3117798566818237
# Time for epoch 323 is 0.8406786918640137 sec Generator Loss: 0.8610064387321472,  Discriminator_loss: 1.3075608015060425
# Time for epoch 324 is 0.8856229782104492 sec Generator Loss: 0.847285270690918,  Discriminator_loss: 1.315649390220642
# Time for epoch 325 is 0.8144228458404541 sec Generator Loss: 0.8549529910087585,  Discriminator_loss: 1.3101401329040527
# Time for epoch 326 is 0.8446102142333984 sec Generator Loss: 0.8673329949378967,  Discriminator_loss: 1.306239366531372
# Time for epoch 327 is 0.925178050994873 sec Generator Loss: 0.8645321726799011,  Discriminator_loss: 1.310253381729126
# Time for epoch 328 is 0.7760941982269287 sec Generator Loss: 0.859845757484436,  Discriminator_loss: 1.3074992895126343
# Time for epoch 329 is 0.7746052742004395 sec Generator Loss: 0.868280827999115,  Discriminator_loss: 1.3103246688842773
# Time for epoch 330 is 0.8364362716674805 sec Generator Loss: 0.8610684275627136,  Discriminator_loss: 1.3095179796218872
# Time for epoch 331 is 0.8673920631408691 sec Generator Loss: 0.8666970729827881,  Discriminator_loss: 1.3068733215332031
# Time for epoch 332 is 0.8567409515380859 sec Generator Loss: 0.8576877117156982,  Discriminator_loss: 1.3098615407943726
# Time for epoch 333 is 0.8122189044952393 sec Generator Loss: 0.8514453172683716,  Discriminator_loss: 1.3166905641555786
# Time for epoch 334 is 0.7942404747009277 sec Generator Loss: 0.8616284728050232,  Discriminator_loss: 1.3127107620239258
# Time for epoch 335 is 0.8163497447967529 sec Generator Loss: 0.8708187341690063,  Discriminator_loss: 1.3181153535842896
# Time for epoch 336 is 0.7982096672058105 sec Generator Loss: 0.8518565893173218,  Discriminator_loss: 1.3134032487869263
# Time for epoch 337 is 0.8269917964935303 sec Generator Loss: 0.873692512512207,  Discriminator_loss: 1.3025455474853516
# Time for epoch 338 is 0.8331301212310791 sec Generator Loss: 0.8586176633834839,  Discriminator_loss: 1.3124536275863647
# Time for epoch 339 is 0.7713935375213623 sec Generator Loss: 0.8632358908653259,  Discriminator_loss: 1.3110886812210083
# Time for epoch 340 is 0.7812361717224121 sec Generator Loss: 0.8676128387451172,  Discriminator_loss: 1.3102974891662598
# Time for epoch 341 is 0.7753157615661621 sec Generator Loss: 0.8643490672111511,  Discriminator_loss: 1.3028956651687622
# Time for epoch 342 is 0.8043246269226074 sec Generator Loss: 0.8784288167953491,  Discriminator_loss: 1.3029416799545288
# Time for epoch 343 is 0.8157603740692139 sec Generator Loss: 0.8757297992706299,  Discriminator_loss: 1.3009971380233765
# Time for epoch 344 is 0.8262977600097656 sec Generator Loss: 0.8717508316040039,  Discriminator_loss: 1.305612564086914
# Time for epoch 345 is 0.7773797512054443 sec Generator Loss: 0.8608192801475525,  Discriminator_loss: 1.3007749319076538
# Time for epoch 346 is 0.7686569690704346 sec Generator Loss: 0.8676938414573669,  Discriminator_loss: 1.3058178424835205
# Time for epoch 347 is 0.827660322189331 sec Generator Loss: 0.8667872548103333,  Discriminator_loss: 1.3030451536178589
# Time for epoch 348 is 0.7807073593139648 sec Generator Loss: 0.8593398928642273,  Discriminator_loss: 1.3115979433059692
# Time for epoch 349 is 0.7935695648193359 sec Generator Loss: 0.8656597137451172,  Discriminator_loss: 1.310863733291626
# Time for epoch 350 is 0.8064491748809814 sec Generator Loss: 0.8623003959655762,  Discriminator_loss: 1.3024799823760986
# Time for epoch 351 is 0.9035792350769043 sec Generator Loss: 0.8558638095855713,  Discriminator_loss: 1.3160771131515503
# Time for epoch 352 is 0.8217313289642334 sec Generator Loss: 0.8619717955589294,  Discriminator_loss: 1.3016693592071533
# Time for epoch 353 is 0.8103804588317871 sec Generator Loss: 0.8763993382453918,  Discriminator_loss: 1.3025497198104858
# Time for epoch 354 is 0.8653321266174316 sec Generator Loss: 0.8729276657104492,  Discriminator_loss: 1.3034839630126953
# Time for epoch 355 is 0.857464075088501 sec Generator Loss: 0.8703559637069702,  Discriminator_loss: 1.3069822788238525
# Time for epoch 356 is 0.8622379302978516 sec Generator Loss: 0.871159553527832,  Discriminator_loss: 1.2974976301193237
# Time for epoch 357 is 0.8846490383148193 sec Generator Loss: 0.8643947243690491,  Discriminator_loss: 1.3115887641906738
# Time for epoch 358 is 0.8614747524261475 sec Generator Loss: 0.8707383871078491,  Discriminator_loss: 1.3122658729553223
# Time for epoch 359 is 0.8319153785705566 sec Generator Loss: 0.8623022437095642,  Discriminator_loss: 1.307472586631775
# Time for epoch 360 is 0.844477653503418 sec Generator Loss: 0.866641104221344,  Discriminator_loss: 1.3086169958114624
# Time for epoch 361 is 0.865551233291626 sec Generator Loss: 0.8544481992721558,  Discriminator_loss: 1.3057811260223389
# Time for epoch 362 is 0.949481725692749 sec Generator Loss: 0.8646916747093201,  Discriminator_loss: 1.305281639099121
# Time for epoch 363 is 0.9040875434875488 sec Generator Loss: 0.8544330596923828,  Discriminator_loss: 1.3150889873504639
# Time for epoch 364 is 0.9637250900268555 sec Generator Loss: 0.8618561029434204,  Discriminator_loss: 1.3064460754394531
# Time for epoch 365 is 1.0492067337036133 sec Generator Loss: 0.8586379289627075,  Discriminator_loss: 1.3121662139892578
# Time for epoch 366 is 0.9274764060974121 sec Generator Loss: 0.867578387260437,  Discriminator_loss: 1.3036775588989258
# Time for epoch 367 is 0.8459129333496094 sec Generator Loss: 0.8656430244445801,  Discriminator_loss: 1.3088643550872803
# Time for epoch 368 is 0.8230671882629395 sec Generator Loss: 0.8519132733345032,  Discriminator_loss: 1.3083823919296265
# Time for epoch 369 is 0.7973654270172119 sec Generator Loss: 0.8790060877799988,  Discriminator_loss: 1.3020466566085815
# Time for epoch 370 is 0.7786967754364014 sec Generator Loss: 0.8698376417160034,  Discriminator_loss: 1.2991501092910767
# Time for epoch 371 is 0.8377251625061035 sec Generator Loss: 0.8597511053085327,  Discriminator_loss: 1.3042337894439697
# Time for epoch 372 is 0.8384444713592529 sec Generator Loss: 0.8734090328216553,  Discriminator_loss: 1.3052023649215698
# Time for epoch 373 is 0.8306412696838379 sec Generator Loss: 0.8661175966262817,  Discriminator_loss: 1.3009600639343262
# Time for epoch 374 is 0.793586254119873 sec Generator Loss: 0.8691722750663757,  Discriminator_loss: 1.305544137954712
# Time for epoch 375 is 0.7966043949127197 sec Generator Loss: 0.8612546920776367,  Discriminator_loss: 1.3056925535202026
# Time for epoch 376 is 0.8084285259246826 sec Generator Loss: 0.8741333484649658,  Discriminator_loss: 1.3033170700073242
# Time for epoch 377 is 0.8695449829101562 sec Generator Loss: 0.8769605755805969,  Discriminator_loss: 1.3040682077407837
# Time for epoch 378 is 0.7859833240509033 sec Generator Loss: 0.8810214400291443,  Discriminator_loss: 1.303552269935608
# Time for epoch 379 is 0.8003230094909668 sec Generator Loss: 0.87353515625,  Discriminator_loss: 1.3104857206344604
# Time for epoch 380 is 0.7915546894073486 sec Generator Loss: 0.8685057163238525,  Discriminator_loss: 1.3018548488616943
# Time for epoch 381 is 0.7789664268493652 sec Generator Loss: 0.8737125396728516,  Discriminator_loss: 1.2975410223007202
# Time for epoch 382 is 0.8080489635467529 sec Generator Loss: 0.8643491268157959,  Discriminator_loss: 1.3088221549987793
# ...
# Time for epoch 1871 is 0.8118016719818115 sec Generator Loss: 0.8882723450660706,  Discriminator_loss: 1.3055031299591064
# Time for epoch 1872 is 0.7950012683868408 sec Generator Loss: 0.8981674313545227,  Discriminator_loss: 1.3011274337768555
# Time for epoch 1873 is 0.7830784320831299 sec Generator Loss: 0.8790608644485474,  Discriminator_loss: 1.310631513595581
# Time for epoch 1874 is 0.7523863315582275 sec Generator Loss: 0.8858899474143982,  Discriminator_loss: 1.2980844974517822
# Time for epoch 1875 is 0.8065037727355957 sec Generator Loss: 0.9005372524261475,  Discriminator_loss: 1.2939025163650513
# Time for epoch 1876 is 0.7808201313018799 sec Generator Loss: 0.8919298648834229,  Discriminator_loss: 1.3073854446411133
# Time for epoch 1877 is 0.8572783470153809 sec Generator Loss: 0.8781388998031616,  Discriminator_loss: 1.3091140985488892
# Time for epoch 1878 is 0.7557001113891602 sec Generator Loss: 0.8963242769241333,  Discriminator_loss: 1.3013659715652466
# Time for epoch 1879 is 0.7610375881195068 sec Generator Loss: 0.8927881717681885,  Discriminator_loss: 1.303871989250183
# Time for epoch 1880 is 0.7779390811920166 sec Generator Loss: 0.8774779438972473,  Discriminator_loss: 1.3146730661392212
# Time for epoch 1881 is 0.8151884078979492 sec Generator Loss: 0.8942698836326599,  Discriminator_loss: 1.3034545183181763
# Time for epoch 1882 is 0.7837722301483154 sec Generator Loss: 0.88656085729599,  Discriminator_loss: 1.3129446506500244
# Time for epoch 1883 is 0.8192975521087646 sec Generator Loss: 0.889130175113678,  Discriminator_loss: 1.3039153814315796
# Time for epoch 1884 is 0.7822277545928955 sec Generator Loss: 0.8829339146614075,  Discriminator_loss: 1.3098313808441162
# Time for epoch 1885 is 0.767038106918335 sec Generator Loss: 0.8927464485168457,  Discriminator_loss: 1.3018099069595337
# Time for epoch 1886 is 0.7378501892089844 sec Generator Loss: 0.888075590133667,  Discriminator_loss: 1.3014568090438843
# Time for epoch 1887 is 0.7295985221862793 sec Generator Loss: 0.8890096545219421,  Discriminator_loss: 1.2984788417816162
# Time for epoch 1888 is 0.7427952289581299 sec Generator Loss: 0.8807172775268555,  Discriminator_loss: 1.3039655685424805
# Time for epoch 1889 is 0.7101538181304932 sec Generator Loss: 0.8859565854072571,  Discriminator_loss: 1.3002036809921265
# Time for epoch 1890 is 0.7187566757202148 sec Generator Loss: 0.8999713659286499,  Discriminator_loss: 1.2924827337265015
# Time for epoch 1891 is 0.7228209972381592 sec Generator Loss: 0.8889250159263611,  Discriminator_loss: 1.310417652130127
# Time for epoch 1892 is 0.7223293781280518 sec Generator Loss: 0.8921639919281006,  Discriminator_loss: 1.3018308877944946
# Time for epoch 1893 is 0.7323169708251953 sec Generator Loss: 0.8596119284629822,  Discriminator_loss: 1.3184810876846313
# Time for epoch 1894 is 0.732886791229248 sec Generator Loss: 0.878747820854187,  Discriminator_loss: 1.3136944770812988
# Time for epoch 1895 is 0.7249705791473389 sec Generator Loss: 0.875831127166748,  Discriminator_loss: 1.3149876594543457
# Time for epoch 1896 is 0.7909352779388428 sec Generator Loss: 0.8787050247192383,  Discriminator_loss: 1.3043310642242432
# Time for epoch 1897 is 0.8237919807434082 sec Generator Loss: 0.8900988101959229,  Discriminator_loss: 1.3062728643417358
# Time for epoch 1898 is 0.7883908748626709 sec Generator Loss: 0.8779850602149963,  Discriminator_loss: 1.311903476715088
# Time for epoch 1899 is 0.79840087890625 sec Generator Loss: 0.8765807151794434,  Discriminator_loss: 1.308593988418579
# Time for epoch 1900 is 0.7643454074859619 sec Generator Loss: 0.8843607902526855,  Discriminator_loss: 1.3120144605636597
# Time for epoch 1901 is 0.7370803356170654 sec Generator Loss: 0.8646304607391357,  Discriminator_loss: 1.3148711919784546
# Time for epoch 1902 is 0.7726602554321289 sec Generator Loss: 0.8840215802192688,  Discriminator_loss: 1.305896282196045
# Time for epoch 1903 is 0.7690691947937012 sec Generator Loss: 0.8710888624191284,  Discriminator_loss: 1.3179329633712769
# Time for epoch 1904 is 0.7838661670684814 sec Generator Loss: 0.8669159412384033,  Discriminator_loss: 1.3114171028137207
# Time for epoch 1905 is 0.8298518657684326 sec Generator Loss: 0.8900076150894165,  Discriminator_loss: 1.3014545440673828
# Time for epoch 1906 is 0.9183657169342041 sec Generator Loss: 0.8813819289207458,  Discriminator_loss: 1.307477355003357
# Time for epoch 1907 is 0.898651123046875 sec Generator Loss: 0.9010193347930908,  Discriminator_loss: 1.3028064966201782
# Time for epoch 1908 is 0.8161141872406006 sec Generator Loss: 0.8723673224449158,  Discriminator_loss: 1.3121920824050903
# Time for epoch 1909 is 0.8202850818634033 sec Generator Loss: 0.8873202204704285,  Discriminator_loss: 1.2993876934051514
# Time for epoch 1910 is 0.8773119449615479 sec Generator Loss: 0.8732218742370605,  Discriminator_loss: 1.314035177230835
# Time for epoch 1911 is 0.7859277725219727 sec Generator Loss: 0.8859466910362244,  Discriminator_loss: 1.309882402420044
# Time for epoch 1912 is 0.806687593460083 sec Generator Loss: 0.8797796368598938,  Discriminator_loss: 1.3125262260437012
# Time for epoch 1913 is 0.778820276260376 sec Generator Loss: 0.8844927549362183,  Discriminator_loss: 1.3016166687011719
# Time for epoch 1914 is 0.7621381282806396 sec Generator Loss: 0.8825684189796448,  Discriminator_loss: 1.3101270198822021
# Time for epoch 1915 is 0.7754120826721191 sec Generator Loss: 0.8880143761634827,  Discriminator_loss: 1.3061977624893188
# Time for epoch 1916 is 0.8037312030792236 sec Generator Loss: 0.87869793176651,  Discriminator_loss: 1.3094602823257446
# Time for epoch 1917 is 0.7448890209197998 sec Generator Loss: 0.8959517478942871,  Discriminator_loss: 1.2980960607528687
# Time for epoch 1918 is 0.772754430770874 sec Generator Loss: 0.894990086555481,  Discriminator_loss: 1.302775502204895
# Time for epoch 1919 is 0.7616848945617676 sec Generator Loss: 0.8999142646789551,  Discriminator_loss: 1.3059667348861694
# Time for epoch 1920 is 0.7436559200286865 sec Generator Loss: 0.8769328594207764,  Discriminator_loss: 1.3087592124938965
# Time for epoch 1921 is 0.7722959518432617 sec Generator Loss: 0.8728687167167664,  Discriminator_loss: 1.3102182149887085
# Time for epoch 1922 is 0.7302405834197998 sec Generator Loss: 0.8832244277000427,  Discriminator_loss: 1.3060274124145508
# Time for epoch 1923 is 0.7296876907348633 sec Generator Loss: 0.881079912185669,  Discriminator_loss: 1.3114391565322876
# Time for epoch 1924 is 0.7484688758850098 sec Generator Loss: 0.8900569081306458,  Discriminator_loss: 1.3075218200683594
# Time for epoch 1925 is 0.8236179351806641 sec Generator Loss: 0.8779307007789612,  Discriminator_loss: 1.309843897819519
# Time for epoch 1926 is 0.7749567031860352 sec Generator Loss: 0.8824564218521118,  Discriminator_loss: 1.3007014989852905
# Time for epoch 1927 is 0.7158324718475342 sec Generator Loss: 0.885751485824585,  Discriminator_loss: 1.3074018955230713
# Time for epoch 1928 is 0.7259278297424316 sec Generator Loss: 0.8691938519477844,  Discriminator_loss: 1.3192706108093262
# Time for epoch 1929 is 0.7297070026397705 sec Generator Loss: 0.8770471811294556,  Discriminator_loss: 1.3118374347686768
# Time for epoch 1930 is 0.7571969032287598 sec Generator Loss: 0.8633860945701599,  Discriminator_loss: 1.317124843597412
# Time for epoch 1931 is 0.7824721336364746 sec Generator Loss: 0.8753339648246765,  Discriminator_loss: 1.3093180656433105
# Time for epoch 1932 is 0.7881543636322021 sec Generator Loss: 0.8878822326660156,  Discriminator_loss: 1.2972798347473145
# Time for epoch 1933 is 0.746842622756958 sec Generator Loss: 0.8940315842628479,  Discriminator_loss: 1.2995104789733887
# Time for epoch 1934 is 0.7626197338104248 sec Generator Loss: 0.8783413171768188,  Discriminator_loss: 1.3177506923675537
# Time for epoch 1935 is 0.7640924453735352 sec Generator Loss: 0.8707675337791443,  Discriminator_loss: 1.3083350658416748
# Time for epoch 1936 is 0.7542757987976074 sec Generator Loss: 0.8779329061508179,  Discriminator_loss: 1.3104592561721802
# Time for epoch 1937 is 0.7747433185577393 sec Generator Loss: 0.8760786056518555,  Discriminator_loss: 1.3058875799179077
# Time for epoch 1938 is 0.7869224548339844 sec Generator Loss: 0.8789464831352234,  Discriminator_loss: 1.3153547048568726
# Time for epoch 1939 is 0.7583656311035156 sec Generator Loss: 0.8795611262321472,  Discriminator_loss: 1.3145349025726318
# Time for epoch 1940 is 0.7196547985076904 sec Generator Loss: 0.8570846915245056,  Discriminator_loss: 1.3181232213974
# Time for epoch 1941 is 0.7382144927978516 sec Generator Loss: 0.8817238807678223,  Discriminator_loss: 1.3105313777923584
# Time for epoch 1942 is 0.7338745594024658 sec Generator Loss: 0.8683823943138123,  Discriminator_loss: 1.3154672384262085
# Time for epoch 1943 is 0.7406301498413086 sec Generator Loss: 0.8735204935073853,  Discriminator_loss: 1.308841347694397
# Time for epoch 1944 is 0.7495088577270508 sec Generator Loss: 0.8811735510826111,  Discriminator_loss: 1.3104302883148193
# Time for epoch 1945 is 0.7248313426971436 sec Generator Loss: 0.8729172945022583,  Discriminator_loss: 1.303934931755066
# Time for epoch 1946 is 0.8076210021972656 sec Generator Loss: 0.8776213526725769,  Discriminator_loss: 1.3100121021270752
# Time for epoch 1947 is 0.7382090091705322 sec Generator Loss: 0.8813759088516235,  Discriminator_loss: 1.3030376434326172
# Time for epoch 1948 is 0.7378580570220947 sec Generator Loss: 0.8861885070800781,  Discriminator_loss: 1.311381220817566
# Time for epoch 1949 is 0.7140622138977051 sec Generator Loss: 0.8756343722343445,  Discriminator_loss: 1.3085477352142334
# Time for epoch 1950 is 0.7241365909576416 sec Generator Loss: 0.898271381855011,  Discriminator_loss: 1.2995672225952148
# Time for epoch 1951 is 0.7300324440002441 sec Generator Loss: 0.8801543712615967,  Discriminator_loss: 1.3110885620117188
# Time for epoch 1952 is 0.7370023727416992 sec Generator Loss: 0.8835573792457581,  Discriminator_loss: 1.3006422519683838
# Time for epoch 1953 is 0.7230043411254883 sec Generator Loss: 0.9019473195075989,  Discriminator_loss: 1.2919094562530518
# Time for epoch 1954 is 0.7214436531066895 sec Generator Loss: 0.8810969591140747,  Discriminator_loss: 1.3074746131896973
# Time for epoch 1955 is 0.7483830451965332 sec Generator Loss: 0.8751804828643799,  Discriminator_loss: 1.3029063940048218
# Time for epoch 1956 is 0.7593798637390137 sec Generator Loss: 0.8839541673660278,  Discriminator_loss: 1.3078293800354004
# Time for epoch 1957 is 0.7266979217529297 sec Generator Loss: 0.8792161345481873,  Discriminator_loss: 1.3176425695419312
# Time for epoch 1958 is 0.7381665706634521 sec Generator Loss: 0.8906710743904114,  Discriminator_loss: 1.306581735610962
# Time for epoch 1959 is 0.7209112644195557 sec Generator Loss: 0.8737146854400635,  Discriminator_loss: 1.312269926071167
# Time for epoch 1960 is 0.720705509185791 sec Generator Loss: 0.8668283820152283,  Discriminator_loss: 1.3177400827407837
# Time for epoch 1961 is 0.7459712028503418 sec Generator Loss: 0.879202663898468,  Discriminator_loss: 1.3067737817764282
# Time for epoch 1962 is 0.7221639156341553 sec Generator Loss: 0.8781182765960693,  Discriminator_loss: 1.310752034187317
# Time for epoch 1963 is 0.722069501876831 sec Generator Loss: 0.8802003860473633,  Discriminator_loss: 1.3027681112289429
# Time for epoch 1964 is 0.7219893932342529 sec Generator Loss: 0.8836694359779358,  Discriminator_loss: 1.30691659450531
# Time for epoch 1965 is 0.7313997745513916 sec Generator Loss: 0.9004441499710083,  Discriminator_loss: 1.2927098274230957
# Time for epoch 1966 is 0.813112735748291 sec Generator Loss: 0.8825318813323975,  Discriminator_loss: 1.3120611906051636
# Time for epoch 1967 is 0.82694411277771 sec Generator Loss: 0.8806253671646118,  Discriminator_loss: 1.3085262775421143
# Time for epoch 1968 is 0.7454273700714111 sec Generator Loss: 0.8685479164123535,  Discriminator_loss: 1.3152596950531006
# Time for epoch 1969 is 0.7560052871704102 sec Generator Loss: 0.8761823177337646,  Discriminator_loss: 1.3116453886032104
# Time for epoch 1970 is 0.7575111389160156 sec Generator Loss: 0.8788253664970398,  Discriminator_loss: 1.3038185834884644
# Time for epoch 1971 is 0.8050575256347656 sec Generator Loss: 0.8874995708465576,  Discriminator_loss: 1.3001291751861572
# Time for epoch 1972 is 0.7291131019592285 sec Generator Loss: 0.8950663805007935,  Discriminator_loss: 1.302510380744934
# Time for epoch 1973 is 0.7856032848358154 sec Generator Loss: 0.8882593512535095,  Discriminator_loss: 1.3095192909240723
# Time for epoch 1974 is 0.7431790828704834 sec Generator Loss: 0.8803039193153381,  Discriminator_loss: 1.312074899673462
# Time for epoch 1975 is 0.7712171077728271 sec Generator Loss: 0.8756852149963379,  Discriminator_loss: 1.314495325088501
# Time for epoch 1976 is 0.7476565837860107 sec Generator Loss: 0.8915607929229736,  Discriminator_loss: 1.2965421676635742
# Time for epoch 1977 is 0.7689228057861328 sec Generator Loss: 0.8942501544952393,  Discriminator_loss: 1.3014122247695923
# Time for epoch 1978 is 0.8413193225860596 sec Generator Loss: 0.8858484625816345,  Discriminator_loss: 1.3078440427780151
# Time for epoch 1979 is 0.812047004699707 sec Generator Loss: 0.8884644508361816,  Discriminator_loss: 1.3101211786270142
# Time for epoch 1980 is 0.8411104679107666 sec Generator Loss: 0.8909578323364258,  Discriminator_loss: 1.3007043600082397
# Time for epoch 1981 is 0.8240444660186768 sec Generator Loss: 0.8891642093658447,  Discriminator_loss: 1.3030000925064087
# Time for epoch 1982 is 0.7830030918121338 sec Generator Loss: 0.8866989612579346,  Discriminator_loss: 1.300464391708374
# Time for epoch 1983 is 0.7740728855133057 sec Generator Loss: 0.8654279708862305,  Discriminator_loss: 1.3146865367889404
# Time for epoch 1984 is 0.8254718780517578 sec Generator Loss: 0.8873098492622375,  Discriminator_loss: 1.3076493740081787
# Time for epoch 1985 is 0.8229520320892334 sec Generator Loss: 0.8831723928451538,  Discriminator_loss: 1.3116341829299927
# Time for epoch 1986 is 0.835944652557373 sec Generator Loss: 0.888430655002594,  Discriminator_loss: 1.3077119588851929
# Time for epoch 1987 is 0.81221604347229 sec Generator Loss: 0.8762226700782776,  Discriminator_loss: 1.3148740530014038
# Time for epoch 1988 is 0.8098509311676025 sec Generator Loss: 0.8677980899810791,  Discriminator_loss: 1.3177841901779175
# Time for epoch 1989 is 0.7992839813232422 sec Generator Loss: 0.876632809638977,  Discriminator_loss: 1.3036181926727295
# Time for epoch 1990 is 0.7859623432159424 sec Generator Loss: 0.8848945498466492,  Discriminator_loss: 1.3072792291641235
# Time for epoch 1991 is 0.7771615982055664 sec Generator Loss: 0.8787224292755127,  Discriminator_loss: 1.3088077306747437
# Time for epoch 1992 is 0.7652633190155029 sec Generator Loss: 0.886125922203064,  Discriminator_loss: 1.3113656044006348
# Time for epoch 1993 is 0.7809813022613525 sec Generator Loss: 0.8798348903656006,  Discriminator_loss: 1.3103222846984863
# Time for epoch 1994 is 0.7719805240631104 sec Generator Loss: 0.8905344605445862,  Discriminator_loss: 1.3023955821990967
# Time for epoch 1995 is 0.7630319595336914 sec Generator Loss: 0.883213460445404,  Discriminator_loss: 1.317591667175293
# Time for epoch 1996 is 0.8054490089416504 sec Generator Loss: 0.8769106268882751,  Discriminator_loss: 1.3121989965438843
# Time for epoch 1997 is 0.7876718044281006 sec Generator Loss: 0.8795199990272522,  Discriminator_loss: 1.3026890754699707
# Time for epoch 1998 is 0.7652978897094727 sec Generator Loss: 0.8932822346687317,  Discriminator_loss: 1.3037221431732178
# Time for epoch 1999 is 0.7694199085235596 sec Generator Loss: 0.8916172385215759,  Discriminator_loss: 1.2996734380722046
# Time for epoch 2000 is 0.7699854373931885 sec Generator Loss: 0.875057578086853,  Discriminator_loss: 1.3165137767791748
# 2/2 [==============================] - 0s 3ms/step
# [MSE Baseline] train: 3.9615075769722132  test: 4.988566607603537
# Delta time: 0:28:24.188868
