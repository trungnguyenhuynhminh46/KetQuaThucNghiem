# %%
try:
  # %tensorflow_version 2.x
except Exception:
  pass

# %% [markdown]
# # Import the libraries

# %%
import numpy as np
import pandas as pd
import os

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Embedding, Dense, Dropout, LeakyReLU, Flatten, Bidirectional, Reshape, Conv1D, GaussianNoise, BatchNormalization
import time
import datetime

from tensorflow.keras.layers import Lambda

from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model

import matplotlib.pyplot as plt
import datetime as dt
import yfinance as yf
yf.pdr_override()
from pandas_datareader import data as pdr

# %%
def plot_dataframe(df):
  for column_name in df.columns:
    plt.figure()
    plt.title(column_name)
    plt.plot(df[column_name])

# %% [markdown]
# # Preprocessing

# %%
def add_Ma(df, window=5):
    for i in range(window, df.shape[0]):
        sum = 0.0
        for k in range(1, window+1):
            sum += df.iloc[i-k, 4]
        df.loc[df.index[i], 'Ma'] = np.round(sum/window, 6)
    return df[window:]

# %%
class Standarized_TimeseriesGenerator(tf.keras.preprocessing.sequence.TimeseriesGenerator):
  def __getitem__(self, index):
    samples, targets  = super(Standarized_TimeseriesGenerator, self).__getitem__(index)
    mean = samples.mean(axis=1)
    std = samples.std(axis=1)
    samples = (samples - mean[:,None,:])/std[:,None,:]
    targets = (targets - mean)/std
    return samples, targets

# %%
def get_gen_train_test(dataframe, n_sequence, n_batch):
    data = dataframe.drop(columns='Date').to_numpy()
    targets = data
    n_samples = data.shape[0]
    train_test_split=int(n_samples*0.9)

    data_gen_train = Standarized_TimeseriesGenerator(data, targets,
                                length=n_sequence, sampling_rate=1,
                                stride=1, batch_size=n_batch,
                                start_index = 0,
                                end_index = train_test_split,
                                shuffle = True)
    data_gen_test = Standarized_TimeseriesGenerator(data, targets,
                                length=n_sequence, sampling_rate=1,
                                stride=1, batch_size=n_batch,
                                start_index = train_test_split,
                                end_index = n_samples-1)

    return data_gen_train, data_gen_test

# %% [markdown]
# # Baseline

# %%
def mean_squared_error(dataset):
    mse=0
    for X_batch, y_batch in dataset:
        mse += np.mean(np.square(X_batch[:, -1, 3:4]-y_batch[:, 3:4]))
    mse /= len(dataset)
    return mse

# %% [markdown]
# # Utilities

# %%
def mse(y_true, y_pred):
    return tf.reduce_mean(tf.square(y_true[:,3]-y_pred[:,3]))
def mae(y_true, y_pred):
    return tf.reduce_mean(tf.keras.backend.abs((y_true[:,3]-y_pred[:,3])))
    # ***The absolute is over the whole thing as y_true can be negative
def mape(y_true, y_pred):
    return tf.reduce_mean(tf.keras.backend.abs((y_true[:,3]-y_pred[:,3])/y_true[:,3]))
    # ***The absolute is over the whole thing as y_true can be negative
def rmse(y_true, y_pred):
    return tf.sqrt(tf.reduce_mean(tf.square(y_true[:,3]-y_pred[:,3])))
def ar(y_true, y_pred):
    mask = tf.cast(y_pred[1:,3] > y_true[:-1,3],tf.float32)
    return tf.reduce_mean((y_true[1:,3]-y_true[:-1,3])*mask)

# %% [markdown]
# # GAN

# %% [markdown]
# ## Perdidas

# %%
def discriminator_loss(real_output, fake_output):
    real_loss = tf.keras.losses.binary_crossentropy(tf.ones_like(real_output), real_output)
    fake_loss = tf.keras.losses.binary_crossentropy(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss
    return total_loss

def generator_loss(x, y, fake_output):
    a1=0.01
    g_loss = tf.keras.losses.binary_crossentropy(tf.ones_like(fake_output), fake_output)
    g_mse = tf.keras.losses.MSE(x, y)
    return a1*g_mse + (1-a1)*g_loss, g_mse

# %% [markdown]
# ## Generator

# %%
def make_generator_model(n_sequence, n_features):
    inputs = Input(shape=(n_sequence, n_features,))
    lstm = Bidirectional(LSTM(units=10, return_sequences=True, activation=None, kernel_initializer='random_normal'))
    lstm_1 = lstm(inputs)
    batch_norm1 = BatchNormalization()(lstm_1)
    lstm_1_LRelu = LeakyReLU(alpha=0.3)(batch_norm1)
    lstm_1_droput = Dropout(0.3)(lstm_1_LRelu)
    lstm_2 = Bidirectional(LSTM(units=10, return_sequences=False, activation=None, kernel_initializer='random_normal'))
    lstm_2_output = lstm_2(lstm_1_droput)
    batch_norm2 = BatchNormalization()(lstm_2_output)
    lstm_2_LRelu = LeakyReLU(alpha=0.3)(batch_norm2)
    lstm_2_dropout = Dropout(0.3)(lstm_2_LRelu)
    output_dense = Dense(n_features, activation=None)(lstm_2_dropout)
    output = LeakyReLU(alpha=0.3)(output_dense)
    model = Model(inputs=inputs, outputs=output)
    model.compile(loss=None, metrics=[mse, mae, mape, rmse, ar])
    model.summary()

    return model

# %% [markdown]
# ## Discriminator

# %%
def make_discriminator_model(n_features):
    model = Sequential()
    model.add(Flatten())
    model.add(Dense(units=72, input_shape=((n_sequence+1) * n_features,), activation=None, kernel_initializer='random_normal'))
    model.add(tf.keras.layers.LeakyReLU(alpha=0.3))
    model.add(tf.keras.layers.GaussianNoise(stddev=0.2))
    model.add(Dropout(0.3))
    model.add(Dense(units=100, activation=None, kernel_initializer='random_normal'))
    model.add(tf.keras.layers.LeakyReLU(alpha=0.3))
    model.add(Dropout(0.3))
    model.add(Dense(units=10, activation=None, kernel_initializer='random_normal'))
    model.add(tf.keras.layers.LeakyReLU(alpha=0.3))
    model.add(Dropout(0.3))
    model.add(Dense(1 ,activation='sigmoid'))
    model.compile(loss=discriminator_loss)
    return model

# %% [markdown]
# # Training

# %%
def train_step_def(sequences, sequences_end):
    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        generated_prediction = generator(sequences, training=True)

        sequences_true = tf.concat((sequences, sequences_end[:, None, :]), axis=1)
        sequences_fake = tf.concat((sequences, generated_prediction[:, None, :]), axis=1)

        real_output = discriminator(sequences_true, training=True)
        fake_output = discriminator(sequences_fake, training=True)

        gen_loss, gen_mse_loss = generator_loss(generated_prediction, 
                                                sequences_end, 
                                                fake_output)
        disc_loss = discriminator_loss(real_output, fake_output)

    gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

    return tf.reduce_mean(gen_loss), tf.reduce_mean(disc_loss), tf.reduce_mean(gen_mse_loss)

def test_step_def(sequences, sequences_end):
    generated_prediction = generator(sequences, training=False)

    sequences_true = tf.concat((sequences, sequences_end[:,None,:]), axis=1)
    sequences_fake = tf.concat((sequences, generated_prediction[:,None,:]), axis=1)

    real_output = discriminator(sequences_true, training=False)
    fake_output = discriminator(sequences_fake, training=False)

    gen_loss, gen_mse_loss = generator_loss(generated_prediction, sequences_end, fake_output)
    disc_loss = discriminator_loss(real_output, fake_output)
    return tf.reduce_mean(gen_loss), tf.reduce_mean(disc_loss), tf.reduce_mean(gen_mse_loss)

# %%
def train(dataset, dataset_val, epochs):
    history = np.empty(shape = (8, epochs))
    history_val = np.empty(shape = (8, epochs))
    len_dataset = len(dataset)
    len_dataset_val = len(dataset_val)
    for epoch in range(epochs):
        start = time.time()

        cur_dis_loss = 0
        cur_gen_loss = 0
        cur_gen_mse_loss = 0
        for sequence_batch, sequence_end_batch in dataset:
            aux_cur_losses = train_step(tf.cast(sequence_batch, tf.float32), 
                                      tf.cast(sequence_end_batch, tf.float32))
            cur_gen_loss += aux_cur_losses[0]/len_dataset
            cur_dis_loss += aux_cur_losses[1]/len_dataset
            cur_gen_mse_loss += aux_cur_losses[2]/len_dataset
        cur_gen_metrics = generator.evaluate(dataset,verbose=False)[1:]

        history[:, epoch] = cur_gen_loss, cur_dis_loss, cur_gen_mse_loss, *cur_gen_metrics

        cur_gen_metrics_val = generator.evaluate(dataset_val,verbose=False)[1: ]

        cur_gen_loss_val = 0
        cur_dis_loss_val = 0
        cur_gen_mse_loss_val = 0
        for sequence_batch, sequence_end_batch in dataset_val:
            aux_cur_losses_val = test_step(tf.cast(sequence_batch, tf.float32), 
                                         tf.cast(sequence_end_batch, tf.float32))
            cur_gen_loss_val += aux_cur_losses_val[0]/len_dataset_val
            cur_dis_loss_val += aux_cur_losses_val[1]/len_dataset_val
            cur_gen_mse_loss_val += aux_cur_losses_val[2]/len_dataset_val
    


        history_val[:, epoch] = cur_gen_loss_val, cur_dis_loss_val, cur_gen_mse_loss_val, *cur_gen_metrics_val

        print ('Time for epoch {} is {} sec Generator Loss: {},  Discriminator_loss: {}'
               .format(epoch + 1, time.time()-start, cur_gen_loss, cur_dis_loss))

        # Save the model every 15 epochs
        if (epoch + 1) % 15 == 0:
            checkpoint.save(file_prefix = checkpoint_prefix)
        # Threshhold
#         if(cur_gen_loss > 0.8):
#                 break;

    return history, history_val

# %% [markdown]
# ## Visualization

# %%
def plot_history(history, history_val):
    metrics = ["gen_loss","dis_loss","gen_mse_loss", 'mse','mae','mape','rmse','ar']
    for i, metric_name in enumerate(metrics):  
        plt.figure()
        plt.title(metric_name)
        plt.plot(history[i], label='train')
        plt.plot(history_val[i], label='test')
        plt.legend()
    plt.show()

# %%
def plot_frame(sequence, target, model):
    y_pred = model.predict(sequence)[...,3]
    y_true = target[...,3]

    plt.figure()
    plt.title("closing price")
    plt.plot(y_true, label="true")
    plt.plot(y_pred, label="prediction")
    plt.legend()
    plt.show()

# %%
def get_best_results(history):
    min_index = np.argmin(history[3, :])
    return history[:, min_index]

# %% [markdown]
# ## Variables

# %%
window = 5
n_sequence = window
n_features = 7
n_batch = 50

# %% [markdown]
# ## Data loading

# %%
stock_code = "IBM"
start = dt.datetime(2000, 1, 1)
end = dt.datetime(2020, 12, 31)
raw_data = pdr.get_data_yahoo(stock_code, start, end,threads=False, proxy="http://127.0.0.1:7890")
df = raw_data.dropna();
df = df.reset_index(level=0)
df = add_Ma(df, window)
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#            Date        Open        High         Low       Close   Adj Close  \
# 5    2000-01-10  112.093689  114.125237  110.301147  112.810707   64.370758
# 6    2000-01-11  112.691208  115.798279  111.496178  113.766731   64.916306
# 7    2000-01-12  114.364243  116.634796  113.049713  114.244743   65.189049
# 8    2000-01-13  114.663002  115.678780  110.659653  113.049713   64.507141
# 9    2000-01-14  115.619026  117.889580  112.332695  114.364243   65.257233
# ...         ...         ...         ...         ...         ...         ...
# 5278 2020-12-23  118.432121  119.703636  118.298279  118.451241  106.144394
# 5279 2020-12-24  119.502869  119.598473  118.747612  119.206497  106.821190
# 5280 2020-12-28  119.598473  121.032501  118.986618  119.330788  106.932564
# 5281 2020-12-29  119.837479  119.961761  117.820267  118.355644  106.058723
# 5282 2020-12-30  118.355644  119.359467  118.193115  118.871895  106.521347
#
#         Volume          Ma
# 5      8933363  109.285373
# 6      8235472  109.667783
# 7      7116775  110.994264
# 8      8880226  111.663481
# 9     11460604  112.476100
# ...        ...         ...
# 5278   2817819  119.302103
# 5279   1842111  118.986615
# 5280   3781499  118.822179
# 5281   3647402  118.625238
# 5282   3535794  118.703633
#
# [5278 rows x 8 columns]

# %%
for epochs in [200, 450, 700, 950, 1200, 1450, 1700, 1950]:
    start_time = datetime.datetime.now()
    df = add_Ma(df)
    data_gen_train, data_gen_test = get_gen_train_test(df, n_sequence, n_batch)

    generator = make_generator_model(n_sequence, n_features)
    discriminator=make_discriminator_model(n_features)

    learning_rate=1e-4
    generator_optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.5)
    discriminator_optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.5)

    @tf.function
    def train_step(sequences, sequences_end):
      return train_step_def(sequences, sequences_end)

    @tf.function
    def test_step(sequences, sequences_end):
      return test_step_def(sequences, sequences_end)

    checkpoint_dir = './training_checkpoints'+stock_code
    checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
    checkpoint = tf.train.Checkpoint(generator_optimizer=generator_optimizer,
                                     discriminator_optimizer=discriminator_optimizer,
                                     generator=generator,
                                     discriminator=discriminator)

    history, history_val = train(data_gen_train, data_gen_test, epochs)

    plot_history(history, history_val)
    plot_frame(*data_gen_test[0], generator)

    print("[MSE Baseline] train:",mean_squared_error(data_gen_train)," test:", mean_squared_error(data_gen_test))
    now = datetime.datetime.now()
    delta = now - start_time
    print("Delta time with epochs = {0}:".format(epochs), delta)
    generator.save("bilstm_ffnn_epochs_{0}.h5".format(epochs))
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5, 7)]            0
#
#  bidirectional (Bidirectiona  (None, 5, 20)            1440
#  l)
#
#  batch_normalization (BatchN  (None, 5, 20)            80
#  ormalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 5, 20)             0
#
#  dropout (Dropout)           (None, 5, 20)             0
#
#  bidirectional_1 (Bidirectio  (None, 20)               2480
#  nal)
#
#  batch_normalization_1 (Batc  (None, 20)               80
#  hNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 20)                0
#
#  dropout_1 (Dropout)         (None, 20)                0
#
#  dense (Dense)               (None, 7)                 147
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 7)                 0
#
# =================================================================
# Total params: 4,227
# Trainable params: 4,147
# Non-trainable params: 80
# _________________________________________________________________
# Time for epoch 1 is 10.371407747268677 sec Generator Loss: 0.7384316325187683,  Discriminator_loss: 1.374283790588379
# Time for epoch 2 is 0.8066349029541016 sec Generator Loss: 0.7201293110847473,  Discriminator_loss: 1.3442976474761963
# Time for epoch 3 is 0.8131682872772217 sec Generator Loss: 0.7177671194076538,  Discriminator_loss: 1.3047090768814087
# Time for epoch 4 is 0.8068668842315674 sec Generator Loss: 0.7434170246124268,  Discriminator_loss: 1.2549737691879272
# Time for epoch 5 is 0.8355145454406738 sec Generator Loss: 0.7886559367179871,  Discriminator_loss: 1.2031116485595703
# Time for epoch 6 is 0.8776319026947021 sec Generator Loss: 0.8142284154891968,  Discriminator_loss: 1.1846030950546265
# Time for epoch 7 is 0.8950204849243164 sec Generator Loss: 0.8453577160835266,  Discriminator_loss: 1.186280369758606
# Time for epoch 8 is 0.9216094017028809 sec Generator Loss: 0.8583712577819824,  Discriminator_loss: 1.2093818187713623
# Time for epoch 9 is 0.9262404441833496 sec Generator Loss: 0.8889247179031372,  Discriminator_loss: 1.2164274454116821
# Time for epoch 10 is 0.9791016578674316 sec Generator Loss: 0.9095430970191956,  Discriminator_loss: 1.2104500532150269
# Time for epoch 11 is 0.9405889511108398 sec Generator Loss: 0.9095907211303711,  Discriminator_loss: 1.2162559032440186
# Time for epoch 12 is 0.9280016422271729 sec Generator Loss: 0.9169654846191406,  Discriminator_loss: 1.218654751777649
# Time for epoch 13 is 0.9169783592224121 sec Generator Loss: 0.9146044254302979,  Discriminator_loss: 1.2433488368988037
# Time for epoch 14 is 0.9061307907104492 sec Generator Loss: 0.9021360278129578,  Discriminator_loss: 1.2369459867477417
# Time for epoch 15 is 0.9364144802093506 sec Generator Loss: 0.896420955657959,  Discriminator_loss: 1.2423344850540161
# Time for epoch 16 is 1.2117362022399902 sec Generator Loss: 0.9038296341896057,  Discriminator_loss: 1.2386239767074585
# Time for epoch 17 is 1.1285381317138672 sec Generator Loss: 0.8972112536430359,  Discriminator_loss: 1.233391284942627
# Time for epoch 18 is 1.108774185180664 sec Generator Loss: 0.9026269316673279,  Discriminator_loss: 1.2442808151245117
# Time for epoch 19 is 1.0589985847473145 sec Generator Loss: 0.8836848735809326,  Discriminator_loss: 1.259101390838623
# Time for epoch 20 is 0.979811429977417 sec Generator Loss: 0.8996822834014893,  Discriminator_loss: 1.2553308010101318
# Time for epoch 21 is 0.981508731842041 sec Generator Loss: 0.8919323086738586,  Discriminator_loss: 1.2833656072616577
# Time for epoch 22 is 0.917943000793457 sec Generator Loss: 0.8831819891929626,  Discriminator_loss: 1.2938488721847534
# Time for epoch 23 is 0.8989448547363281 sec Generator Loss: 0.8654454350471497,  Discriminator_loss: 1.2979518175125122
# Time for epoch 24 is 0.9392795562744141 sec Generator Loss: 0.8610687255859375,  Discriminator_loss: 1.3092713356018066
# Time for epoch 25 is 0.8672828674316406 sec Generator Loss: 0.851072371006012,  Discriminator_loss: 1.3197437524795532
# Time for epoch 26 is 0.9284694194793701 sec Generator Loss: 0.8539490103721619,  Discriminator_loss: 1.318070888519287
# Time for epoch 27 is 0.852372407913208 sec Generator Loss: 0.848156213760376,  Discriminator_loss: 1.3255763053894043
# Time for epoch 28 is 0.8381750583648682 sec Generator Loss: 0.8452293276786804,  Discriminator_loss: 1.3274070024490356
# Time for epoch 29 is 0.8739616870880127 sec Generator Loss: 0.8414286375045776,  Discriminator_loss: 1.3400330543518066
# Time for epoch 30 is 0.8596541881561279 sec Generator Loss: 0.84219890832901,  Discriminator_loss: 1.3315656185150146
# Time for epoch 31 is 0.839684247970581 sec Generator Loss: 0.8355256915092468,  Discriminator_loss: 1.33918035030365
# Time for epoch 32 is 0.8710346221923828 sec Generator Loss: 0.8354255557060242,  Discriminator_loss: 1.3342119455337524
# Time for epoch 33 is 0.8418674468994141 sec Generator Loss: 0.8289064168930054,  Discriminator_loss: 1.3362149000167847
# Time for epoch 34 is 0.8429388999938965 sec Generator Loss: 0.8294718861579895,  Discriminator_loss: 1.3285841941833496
# Time for epoch 35 is 0.9902973175048828 sec Generator Loss: 0.8263307809829712,  Discriminator_loss: 1.3348023891448975
# Time for epoch 36 is 0.9221312999725342 sec Generator Loss: 0.8284754157066345,  Discriminator_loss: 1.3371106386184692
# Time for epoch 37 is 0.8756861686706543 sec Generator Loss: 0.8247959613800049,  Discriminator_loss: 1.3328938484191895
# Time for epoch 38 is 0.8535866737365723 sec Generator Loss: 0.8245343565940857,  Discriminator_loss: 1.3383558988571167
# Time for epoch 39 is 0.920353889465332 sec Generator Loss: 0.8119087815284729,  Discriminator_loss: 1.3479140996932983
# Time for epoch 40 is 0.8837873935699463 sec Generator Loss: 0.8109754323959351,  Discriminator_loss: 1.3451331853866577
# Time for epoch 41 is 1.1249690055847168 sec Generator Loss: 0.8128725290298462,  Discriminator_loss: 1.336790680885315
# Time for epoch 42 is 0.9993083477020264 sec Generator Loss: 0.8244786858558655,  Discriminator_loss: 1.3444210290908813
# Time for epoch 43 is 0.9818603992462158 sec Generator Loss: 0.8145716786384583,  Discriminator_loss: 1.341951608657837
# Time for epoch 44 is 0.9382328987121582 sec Generator Loss: 0.8127074837684631,  Discriminator_loss: 1.3509677648544312
# Time for epoch 45 is 0.9399721622467041 sec Generator Loss: 0.8133642077445984,  Discriminator_loss: 1.3543055057525635
# Time for epoch 46 is 1.037121057510376 sec Generator Loss: 0.8072177767753601,  Discriminator_loss: 1.3495476245880127
# Time for epoch 47 is 1.1680405139923096 sec Generator Loss: 0.8057733774185181,  Discriminator_loss: 1.349339246749878
# Time for epoch 48 is 1.0771920680999756 sec Generator Loss: 0.7974177598953247,  Discriminator_loss: 1.3624935150146484
# Time for epoch 49 is 1.023411512374878 sec Generator Loss: 0.7872011661529541,  Discriminator_loss: 1.365514874458313
# Time for epoch 50 is 1.1154797077178955 sec Generator Loss: 0.796605110168457,  Discriminator_loss: 1.3579505681991577
# Time for epoch 51 is 1.1200611591339111 sec Generator Loss: 0.7879131436347961,  Discriminator_loss: 1.3639861345291138
# Time for epoch 52 is 0.9457411766052246 sec Generator Loss: 0.7927007079124451,  Discriminator_loss: 1.3595895767211914
# Time for epoch 53 is 0.9414854049682617 sec Generator Loss: 0.7803720235824585,  Discriminator_loss: 1.3626346588134766
# Time for epoch 54 is 0.9327144622802734 sec Generator Loss: 0.7912588715553284,  Discriminator_loss: 1.3580071926116943
# Time for epoch 55 is 0.9205904006958008 sec Generator Loss: 0.7858408689498901,  Discriminator_loss: 1.3580901622772217
# Time for epoch 56 is 0.9157702922821045 sec Generator Loss: 0.7802634835243225,  Discriminator_loss: 1.364109992980957
# Time for epoch 57 is 0.9722626209259033 sec Generator Loss: 0.792089581489563,  Discriminator_loss: 1.3633995056152344
# Time for epoch 58 is 0.9401793479919434 sec Generator Loss: 0.7876116633415222,  Discriminator_loss: 1.3648316860198975
# Time for epoch 59 is 1.0069620609283447 sec Generator Loss: 0.7869018316268921,  Discriminator_loss: 1.3690160512924194
# Time for epoch 60 is 0.8962864875793457 sec Generator Loss: 0.7883766293525696,  Discriminator_loss: 1.3665333986282349
# Time for epoch 61 is 0.9179880619049072 sec Generator Loss: 0.7815084457397461,  Discriminator_loss: 1.3626196384429932
# Time for epoch 62 is 1.0316579341888428 sec Generator Loss: 0.7807691097259521,  Discriminator_loss: 1.3637151718139648
# Time for epoch 63 is 0.9666821956634521 sec Generator Loss: 0.7785986065864563,  Discriminator_loss: 1.3592784404754639
# Time for epoch 64 is 0.9962220191955566 sec Generator Loss: 0.7850626707077026,  Discriminator_loss: 1.3627147674560547
# Time for epoch 65 is 0.971874475479126 sec Generator Loss: 0.7763188481330872,  Discriminator_loss: 1.3627147674560547
# Time for epoch 66 is 0.9408667087554932 sec Generator Loss: 0.7805821299552917,  Discriminator_loss: 1.3605188131332397
# Time for epoch 67 is 0.9625356197357178 sec Generator Loss: 0.7855754494667053,  Discriminator_loss: 1.358272910118103
# Time for epoch 68 is 1.107945203781128 sec Generator Loss: 0.7767667174339294,  Discriminator_loss: 1.3606339693069458
# Time for epoch 69 is 0.983088493347168 sec Generator Loss: 0.7810416221618652,  Discriminator_loss: 1.3607933521270752
# Time for epoch 70 is 0.9872174263000488 sec Generator Loss: 0.7933638095855713,  Discriminator_loss: 1.362673044204712
# Time for epoch 71 is 1.1762275695800781 sec Generator Loss: 0.7788820862770081,  Discriminator_loss: 1.3603767156600952
# Time for epoch 72 is 1.0720107555389404 sec Generator Loss: 0.7913572192192078,  Discriminator_loss: 1.3625013828277588
# Time for epoch 73 is 1.1312284469604492 sec Generator Loss: 0.7784228920936584,  Discriminator_loss: 1.3653104305267334
# Time for epoch 74 is 1.4930014610290527 sec Generator Loss: 0.7745361924171448,  Discriminator_loss: 1.3634793758392334
# Time for epoch 75 is 1.0322668552398682 sec Generator Loss: 0.7784737944602966,  Discriminator_loss: 1.3652734756469727
# Time for epoch 76 is 1.1441571712493896 sec Generator Loss: 0.7751938700675964,  Discriminator_loss: 1.3665484189987183
# Time for epoch 77 is 1.0582993030548096 sec Generator Loss: 0.7738302946090698,  Discriminator_loss: 1.3635526895523071
# Time for epoch 78 is 1.1445164680480957 sec Generator Loss: 0.77750164270401,  Discriminator_loss: 1.3651280403137207
# Time for epoch 79 is 1.1795284748077393 sec Generator Loss: 0.7762323021888733,  Discriminator_loss: 1.3703999519348145
# Time for epoch 80 is 1.1913461685180664 sec Generator Loss: 0.7766492366790771,  Discriminator_loss: 1.3634264469146729
# Time for epoch 81 is 1.0087435245513916 sec Generator Loss: 0.7784469723701477,  Discriminator_loss: 1.3644771575927734
# Time for epoch 82 is 0.9869205951690674 sec Generator Loss: 0.7773560881614685,  Discriminator_loss: 1.36186683177948
# Time for epoch 83 is 1.0083088874816895 sec Generator Loss: 0.7800099849700928,  Discriminator_loss: 1.3598754405975342
# Time for epoch 84 is 0.9392719268798828 sec Generator Loss: 0.7851529717445374,  Discriminator_loss: 1.36324143409729
# Time for epoch 85 is 1.0832018852233887 sec Generator Loss: 0.7810488343238831,  Discriminator_loss: 1.3646641969680786
# Time for epoch 86 is 0.986724853515625 sec Generator Loss: 0.7735261917114258,  Discriminator_loss: 1.3653157949447632
# Time for epoch 87 is 1.0982666015625 sec Generator Loss: 0.7821825742721558,  Discriminator_loss: 1.3624627590179443
# Time for epoch 88 is 1.202143669128418 sec Generator Loss: 0.7756593823432922,  Discriminator_loss: 1.3598692417144775
# Time for epoch 89 is 1.0144712924957275 sec Generator Loss: 0.7753382921218872,  Discriminator_loss: 1.3646010160446167
# Time for epoch 90 is 0.9835045337677002 sec Generator Loss: 0.777823269367218,  Discriminator_loss: 1.3597356081008911
# Time for epoch 91 is 0.9965415000915527 sec Generator Loss: 0.7816417217254639,  Discriminator_loss: 1.359743595123291
# Time for epoch 92 is 1.0435657501220703 sec Generator Loss: 0.783744752407074,  Discriminator_loss: 1.35993230342865
# Time for epoch 93 is 1.0778062343597412 sec Generator Loss: 0.7758132219314575,  Discriminator_loss: 1.3608465194702148
# Time for epoch 94 is 1.0037381649017334 sec Generator Loss: 0.7856003642082214,  Discriminator_loss: 1.3631701469421387
# Time for epoch 95 is 1.0850050449371338 sec Generator Loss: 0.7834277749061584,  Discriminator_loss: 1.3606237173080444
# Time for epoch 96 is 1.0594627857208252 sec Generator Loss: 0.7805987000465393,  Discriminator_loss: 1.3646918535232544
# Time for epoch 97 is 1.016467809677124 sec Generator Loss: 0.7848089337348938,  Discriminator_loss: 1.3610789775848389
# Time for epoch 98 is 0.9569706916809082 sec Generator Loss: 0.7755974531173706,  Discriminator_loss: 1.3632490634918213
# Time for epoch 99 is 0.9914741516113281 sec Generator Loss: 0.7820701599121094,  Discriminator_loss: 1.366578459739685
# Time for epoch 100 is 0.9838662147521973 sec Generator Loss: 0.770383358001709,  Discriminator_loss: 1.365052580833435
# Time for epoch 101 is 0.9582986831665039 sec Generator Loss: 0.7730743885040283,  Discriminator_loss: 1.3650169372558594
# Time for epoch 102 is 0.9481678009033203 sec Generator Loss: 0.7779627442359924,  Discriminator_loss: 1.3623037338256836
# Time for epoch 103 is 0.9439208507537842 sec Generator Loss: 0.7759491801261902,  Discriminator_loss: 1.3673001527786255
# Time for epoch 104 is 0.9331138134002686 sec Generator Loss: 0.7720422744750977,  Discriminator_loss: 1.3661432266235352
# Time for epoch 105 is 0.995290994644165 sec Generator Loss: 0.777670681476593,  Discriminator_loss: 1.3676166534423828
# Time for epoch 106 is 1.0408670902252197 sec Generator Loss: 0.7764289379119873,  Discriminator_loss: 1.3589612245559692
# Time for epoch 107 is 0.9379222393035889 sec Generator Loss: 0.7751486301422119,  Discriminator_loss: 1.3637707233428955
# Time for epoch 108 is 0.9437234401702881 sec Generator Loss: 0.7806545495986938,  Discriminator_loss: 1.3610800504684448
# Time for epoch 109 is 1.0050108432769775 sec Generator Loss: 0.7788485288619995,  Discriminator_loss: 1.3672046661376953
# Time for epoch 110 is 1.0048484802246094 sec Generator Loss: 0.7739745378494263,  Discriminator_loss: 1.3631342649459839
# Time for epoch 111 is 0.9627223014831543 sec Generator Loss: 0.7791544795036316,  Discriminator_loss: 1.3618608713150024
# Time for epoch 112 is 0.942577600479126 sec Generator Loss: 0.7851956486701965,  Discriminator_loss: 1.3620529174804688
# Time for epoch 113 is 0.9575052261352539 sec Generator Loss: 0.7757787108421326,  Discriminator_loss: 1.3654896020889282
# Time for epoch 114 is 0.9578046798706055 sec Generator Loss: 0.771751344203949,  Discriminator_loss: 1.3693435192108154
# Time for epoch 115 is 1.0332186222076416 sec Generator Loss: 0.7739713191986084,  Discriminator_loss: 1.3583978414535522
# Time for epoch 116 is 0.9741129875183105 sec Generator Loss: 0.7801432609558105,  Discriminator_loss: 1.363661289215088
# Time for epoch 117 is 0.9570820331573486 sec Generator Loss: 0.7815216779708862,  Discriminator_loss: 1.3653969764709473
# Time for epoch 118 is 0.9244303703308105 sec Generator Loss: 0.7759497761726379,  Discriminator_loss: 1.3636575937271118
# Time for epoch 119 is 0.9178445339202881 sec Generator Loss: 0.7794467210769653,  Discriminator_loss: 1.3628350496292114
# Time for epoch 120 is 0.9288585186004639 sec Generator Loss: 0.7786327004432678,  Discriminator_loss: 1.3667279481887817
# Time for epoch 121 is 1.024993658065796 sec Generator Loss: 0.7707762718200684,  Discriminator_loss: 1.3684754371643066
# Time for epoch 122 is 0.939063549041748 sec Generator Loss: 0.7786566019058228,  Discriminator_loss: 1.366500973701477
# Time for epoch 123 is 0.9489405155181885 sec Generator Loss: 0.7742772698402405,  Discriminator_loss: 1.3650788068771362
# Time for epoch 124 is 0.9305458068847656 sec Generator Loss: 0.7684380412101746,  Discriminator_loss: 1.3651013374328613
# Time for epoch 125 is 0.937345027923584 sec Generator Loss: 0.7688471674919128,  Discriminator_loss: 1.3691916465759277
# Time for epoch 126 is 0.9764542579650879 sec Generator Loss: 0.765164315700531,  Discriminator_loss: 1.3714638948440552
# Time for epoch 127 is 1.038994312286377 sec Generator Loss: 0.7717718482017517,  Discriminator_loss: 1.3657389879226685
# Time for epoch 128 is 0.9743201732635498 sec Generator Loss: 0.7727635502815247,  Discriminator_loss: 1.3629646301269531
# Time for epoch 129 is 1.0833580493927002 sec Generator Loss: 0.76622474193573,  Discriminator_loss: 1.3681445121765137
# Time for epoch 130 is 1.1024668216705322 sec Generator Loss: 0.7737390995025635,  Discriminator_loss: 1.3659666776657104
# Time for epoch 131 is 1.6681249141693115 sec Generator Loss: 0.7772207856178284,  Discriminator_loss: 1.3639627695083618
# Time for epoch 132 is 1.071387767791748 sec Generator Loss: 0.766112208366394,  Discriminator_loss: 1.3686870336532593
# Time for epoch 133 is 1.0550141334533691 sec Generator Loss: 0.7847652435302734,  Discriminator_loss: 1.3627612590789795
# Time for epoch 134 is 1.1030848026275635 sec Generator Loss: 0.7740170359611511,  Discriminator_loss: 1.3657175302505493
# Time for epoch 135 is 1.0142223834991455 sec Generator Loss: 0.779708743095398,  Discriminator_loss: 1.3636577129364014
# Time for epoch 136 is 0.9775066375732422 sec Generator Loss: 0.7745813131332397,  Discriminator_loss: 1.3639343976974487
# Time for epoch 137 is 1.0735020637512207 sec Generator Loss: 0.7647926211357117,  Discriminator_loss: 1.3711023330688477
# Time for epoch 138 is 0.997302770614624 sec Generator Loss: 0.7720905542373657,  Discriminator_loss: 1.3629162311553955
# Time for epoch 139 is 1.0141847133636475 sec Generator Loss: 0.7786759734153748,  Discriminator_loss: 1.368261456489563
# Time for epoch 140 is 0.9944329261779785 sec Generator Loss: 0.7722142934799194,  Discriminator_loss: 1.3661643266677856
# Time for epoch 141 is 0.9749963283538818 sec Generator Loss: 0.7750729918479919,  Discriminator_loss: 1.366838812828064
# Time for epoch 142 is 0.973231315612793 sec Generator Loss: 0.7761755585670471,  Discriminator_loss: 1.361999750137329
# Time for epoch 143 is 0.9421932697296143 sec Generator Loss: 0.7792685031890869,  Discriminator_loss: 1.3679251670837402
# Time for epoch 144 is 0.9553024768829346 sec Generator Loss: 0.7735910415649414,  Discriminator_loss: 1.3659268617630005
# Time for epoch 145 is 0.9417684078216553 sec Generator Loss: 0.7701859474182129,  Discriminator_loss: 1.3661718368530273
# Time for epoch 146 is 0.9291329383850098 sec Generator Loss: 0.7715457677841187,  Discriminator_loss: 1.365350365638733
# Time for epoch 147 is 0.9453094005584717 sec Generator Loss: 0.7779681086540222,  Discriminator_loss: 1.3651965856552124
# Time for epoch 148 is 0.917855978012085 sec Generator Loss: 0.7735608816146851,  Discriminator_loss: 1.3646986484527588
# Time for epoch 149 is 0.9015967845916748 sec Generator Loss: 0.7794983983039856,  Discriminator_loss: 1.3623722791671753
# Time for epoch 150 is 0.940960168838501 sec Generator Loss: 0.7690142393112183,  Discriminator_loss: 1.3661624193191528
# Time for epoch 151 is 0.9426403045654297 sec Generator Loss: 0.7715741991996765,  Discriminator_loss: 1.3627303838729858
# Time for epoch 152 is 0.9424066543579102 sec Generator Loss: 0.7727957963943481,  Discriminator_loss: 1.3640637397766113
# Time for epoch 153 is 0.8989930152893066 sec Generator Loss: 0.7637678980827332,  Discriminator_loss: 1.369822382926941
# Time for epoch 154 is 0.896507740020752 sec Generator Loss: 0.7750779986381531,  Discriminator_loss: 1.3682104349136353
# Time for epoch 155 is 0.8963205814361572 sec Generator Loss: 0.7755841016769409,  Discriminator_loss: 1.3680475950241089
# Time for epoch 156 is 0.9075088500976562 sec Generator Loss: 0.7821947932243347,  Discriminator_loss: 1.3622857332229614
# Time for epoch 157 is 0.8989729881286621 sec Generator Loss: 0.7618052959442139,  Discriminator_loss: 1.367725133895874
# Time for epoch 158 is 0.9143102169036865 sec Generator Loss: 0.778801441192627,  Discriminator_loss: 1.363933801651001
# Time for epoch 159 is 0.9504745006561279 sec Generator Loss: 0.7697018384933472,  Discriminator_loss: 1.364526391029358
# Time for epoch 160 is 0.9039175510406494 sec Generator Loss: 0.7644944190979004,  Discriminator_loss: 1.3686319589614868
# Time for epoch 161 is 0.9276490211486816 sec Generator Loss: 0.7733681797981262,  Discriminator_loss: 1.3675183057785034
# Time for epoch 162 is 0.9287807941436768 sec Generator Loss: 0.7624083757400513,  Discriminator_loss: 1.368514895439148
# Time for epoch 163 is 0.9105751514434814 sec Generator Loss: 0.7654539346694946,  Discriminator_loss: 1.3684972524642944
# Time for epoch 164 is 0.9441421031951904 sec Generator Loss: 0.7658689618110657,  Discriminator_loss: 1.3659157752990723
# Time for epoch 165 is 0.911299467086792 sec Generator Loss: 0.7737078666687012,  Discriminator_loss: 1.365681767463684
# Time for epoch 166 is 0.9123287200927734 sec Generator Loss: 0.7706887125968933,  Discriminator_loss: 1.365100383758545
# Time for epoch 167 is 0.9380002021789551 sec Generator Loss: 0.7597842216491699,  Discriminator_loss: 1.366870403289795
# Time for epoch 168 is 0.90897536277771 sec Generator Loss: 0.7707584500312805,  Discriminator_loss: 1.3630975484848022
# Time for epoch 169 is 0.9133856296539307 sec Generator Loss: 0.7678147554397583,  Discriminator_loss: 1.368403434753418
# Time for epoch 170 is 0.9220318794250488 sec Generator Loss: 0.7751476764678955,  Discriminator_loss: 1.362320065498352
# Time for epoch 171 is 0.9008240699768066 sec Generator Loss: 0.7722221612930298,  Discriminator_loss: 1.3630646467208862
# Time for epoch 172 is 0.9084663391113281 sec Generator Loss: 0.7726870179176331,  Discriminator_loss: 1.3591969013214111
# Time for epoch 173 is 1.1117238998413086 sec Generator Loss: 0.7823876738548279,  Discriminator_loss: 1.358362078666687
# Time for epoch 174 is 1.0380375385284424 sec Generator Loss: 0.7773901224136353,  Discriminator_loss: 1.362596869468689
# Time for epoch 175 is 1.037177324295044 sec Generator Loss: 0.7801226377487183,  Discriminator_loss: 1.3625257015228271
# Time for epoch 176 is 0.9708700180053711 sec Generator Loss: 0.7687768936157227,  Discriminator_loss: 1.3651955127716064
# Time for epoch 177 is 0.9896070957183838 sec Generator Loss: 0.7733801007270813,  Discriminator_loss: 1.3619946241378784
# Time for epoch 178 is 0.9052155017852783 sec Generator Loss: 0.7744117379188538,  Discriminator_loss: 1.3639429807662964
# Time for epoch 179 is 0.9037232398986816 sec Generator Loss: 0.774752140045166,  Discriminator_loss: 1.3606892824172974
# Time for epoch 180 is 0.9450275897979736 sec Generator Loss: 0.7734987735748291,  Discriminator_loss: 1.3655301332473755
# Time for epoch 181 is 0.9233264923095703 sec Generator Loss: 0.7650117874145508,  Discriminator_loss: 1.3676643371582031
# Time for epoch 182 is 1.0486571788787842 sec Generator Loss: 0.7760774493217468,  Discriminator_loss: 1.36406409740448
# Time for epoch 183 is 1.1010775566101074 sec Generator Loss: 0.7771376967430115,  Discriminator_loss: 1.3618919849395752
# Time for epoch 184 is 1.142876148223877 sec Generator Loss: 0.7723044753074646,  Discriminator_loss: 1.3617582321166992
# Time for epoch 185 is 1.0296006202697754 sec Generator Loss: 0.7730227708816528,  Discriminator_loss: 1.371368646621704
# Time for epoch 186 is 0.9557318687438965 sec Generator Loss: 0.7720107436180115,  Discriminator_loss: 1.3685479164123535
# Time for epoch 187 is 0.9710638523101807 sec Generator Loss: 0.7743024826049805,  Discriminator_loss: 1.3650095462799072
# Time for epoch 188 is 1.0550141334533691 sec Generator Loss: 0.7716656923294067,  Discriminator_loss: 1.3618015050888062
# Time for epoch 189 is 1.1131927967071533 sec Generator Loss: 0.7696183919906616,  Discriminator_loss: 1.3634793758392334
# Time for epoch 190 is 1.07906174659729 sec Generator Loss: 0.767949104309082,  Discriminator_loss: 1.3687540292739868
# Time for epoch 191 is 1.1283831596374512 sec Generator Loss: 0.7758198976516724,  Discriminator_loss: 1.360676884651184
# Time for epoch 192 is 1.1130459308624268 sec Generator Loss: 0.7649155259132385,  Discriminator_loss: 1.366237759590149
# Time for epoch 193 is 1.0218119621276855 sec Generator Loss: 0.7737915515899658,  Discriminator_loss: 1.3682247400283813
# Time for epoch 194 is 0.9557051658630371 sec Generator Loss: 0.7724825143814087,  Discriminator_loss: 1.3663756847381592
# Time for epoch 195 is 0.9547665119171143 sec Generator Loss: 0.7735445499420166,  Discriminator_loss: 1.3619751930236816
# Time for epoch 196 is 1.0080995559692383 sec Generator Loss: 0.7717021703720093,  Discriminator_loss: 1.3673015832901
# Time for epoch 197 is 1.09814453125 sec Generator Loss: 0.7735600471496582,  Discriminator_loss: 1.3610501289367676
# Time for epoch 198 is 0.9834115505218506 sec Generator Loss: 0.774341344833374,  Discriminator_loss: 1.361469030380249
# Time for epoch 199 is 0.9418973922729492 sec Generator Loss: 0.7732055187225342,  Discriminator_loss: 1.3633875846862793
# Time for epoch 200 is 0.9510684013366699 sec Generator Loss: 0.7781121134757996,  Discriminator_loss: 1.3620754480361938
# 2/2 [==============================] - 1s 3ms/step
# [MSE Baseline] train: 3.8793362963174918  test: 4.988566607603537
# Delta time with epochs = 200: 0:03:31.225112
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 5, 7)]            0
#
#  bidirectional_2 (Bidirectio  (None, 5, 20)            1440
#  nal)
#
#  batch_normalization_2 (Batc  (None, 5, 20)            80
#  hNormalization)
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 5, 20)             0
#
#  dropout_5 (Dropout)         (None, 5, 20)             0
#
#  bidirectional_3 (Bidirectio  (None, 20)               2480
#  nal)
#
#  batch_normalization_3 (Batc  (None, 20)               80
#  hNormalization)
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 20)                0
#
#  dropout_6 (Dropout)         (None, 20)                0
#
#  dense_5 (Dense)             (None, 7)                 147
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 7)                 0
#
# =================================================================
# Total params: 4,227
# Trainable params: 4,147
# Non-trainable params: 80
# _________________________________________________________________
# Time for epoch 1 is 15.04303765296936 sec Generator Loss: 0.7644534707069397,  Discriminator_loss: 1.384000539779663
# Time for epoch 2 is 0.9466207027435303 sec Generator Loss: 0.744398295879364,  Discriminator_loss: 1.3660342693328857
# Time for epoch 3 is 1.003174066543579 sec Generator Loss: 0.7522437572479248,  Discriminator_loss: 1.333814263343811
# Time for epoch 4 is 1.017120599746704 sec Generator Loss: 0.7876467704772949,  Discriminator_loss: 1.2811977863311768
# Time for epoch 5 is 0.979388952255249 sec Generator Loss: 0.8455799221992493,  Discriminator_loss: 1.222231149673462
# Time for epoch 6 is 1.2463746070861816 sec Generator Loss: 0.8814082145690918,  Discriminator_loss: 1.2027943134307861
# Time for epoch 7 is 1.0574288368225098 sec Generator Loss: 0.9102805852890015,  Discriminator_loss: 1.1988722085952759
# Time for epoch 8 is 1.1110806465148926 sec Generator Loss: 0.9623401761054993,  Discriminator_loss: 1.1924378871917725
# Time for epoch 9 is 1.252394199371338 sec Generator Loss: 0.9260396361351013,  Discriminator_loss: 1.2692972421646118
# Time for epoch 10 is 1.1235942840576172 sec Generator Loss: 0.9211019277572632,  Discriminator_loss: 1.2475215196609497
# Time for epoch 11 is 1.094059705734253 sec Generator Loss: 0.9196436405181885,  Discriminator_loss: 1.2249833345413208
# Time for epoch 12 is 1.203864336013794 sec Generator Loss: 0.890739381313324,  Discriminator_loss: 1.2701674699783325
# Time for epoch 13 is 1.3463189601898193 sec Generator Loss: 0.930810272693634,  Discriminator_loss: 1.2322757244110107
# Time for epoch 14 is 1.2833404541015625 sec Generator Loss: 0.9195670485496521,  Discriminator_loss: 1.2484796047210693
# Time for epoch 15 is 1.206641435623169 sec Generator Loss: 0.920976459980011,  Discriminator_loss: 1.2328979969024658
# Time for epoch 16 is 1.1210846900939941 sec Generator Loss: 0.8863849639892578,  Discriminator_loss: 1.2705355882644653
# Time for epoch 17 is 1.170541763305664 sec Generator Loss: 0.9068256616592407,  Discriminator_loss: 1.243896722793579
# Time for epoch 18 is 1.068403959274292 sec Generator Loss: 0.8881789445877075,  Discriminator_loss: 1.2666797637939453
# Time for epoch 19 is 1.0629487037658691 sec Generator Loss: 0.8815534114837646,  Discriminator_loss: 1.2553602457046509
# Time for epoch 20 is 1.1119954586029053 sec Generator Loss: 0.8594844937324524,  Discriminator_loss: 1.3061054944992065
# Time for epoch 21 is 1.1641299724578857 sec Generator Loss: 0.8723431825637817,  Discriminator_loss: 1.294000267982483
# Time for epoch 22 is 1.1537258625030518 sec Generator Loss: 0.8491722941398621,  Discriminator_loss: 1.3032810688018799
# Time for epoch 23 is 1.1092309951782227 sec Generator Loss: 0.8546645641326904,  Discriminator_loss: 1.3102489709854126
# Time for epoch 24 is 1.1891381740570068 sec Generator Loss: 0.8474046587944031,  Discriminator_loss: 1.299131155014038
# Time for epoch 25 is 1.1813850402832031 sec Generator Loss: 0.8541037440299988,  Discriminator_loss: 1.300830364227295
# Time for epoch 26 is 1.126265048980713 sec Generator Loss: 0.8489773869514465,  Discriminator_loss: 1.3047298192977905
# Time for epoch 27 is 1.108332633972168 sec Generator Loss: 0.8439437747001648,  Discriminator_loss: 1.3067160844802856
# Time for epoch 28 is 1.0376863479614258 sec Generator Loss: 0.8446071147918701,  Discriminator_loss: 1.3019508123397827
# Time for epoch 29 is 0.9460964202880859 sec Generator Loss: 0.8332376480102539,  Discriminator_loss: 1.3270134925842285
# Time for epoch 30 is 1.2185876369476318 sec Generator Loss: 0.8341057896614075,  Discriminator_loss: 1.3307324647903442
# Time for epoch 31 is 0.923018217086792 sec Generator Loss: 0.8193303346633911,  Discriminator_loss: 1.3298583030700684
# Time for epoch 32 is 1.1057260036468506 sec Generator Loss: 0.8301003575325012,  Discriminator_loss: 1.339442253112793
# Time for epoch 33 is 1.1488733291625977 sec Generator Loss: 0.8299317955970764,  Discriminator_loss: 1.3289953470230103
# Time for epoch 34 is 1.1130435466766357 sec Generator Loss: 0.8273503184318542,  Discriminator_loss: 1.3354995250701904
# Time for epoch 35 is 1.0397827625274658 sec Generator Loss: 0.8239130973815918,  Discriminator_loss: 1.3384711742401123
# Time for epoch 36 is 1.0352740287780762 sec Generator Loss: 0.8209397792816162,  Discriminator_loss: 1.3450448513031006
# Time for epoch 37 is 1.108978033065796 sec Generator Loss: 0.8241252303123474,  Discriminator_loss: 1.3476239442825317
# Time for epoch 38 is 1.119941234588623 sec Generator Loss: 0.8059566617012024,  Discriminator_loss: 1.3635047674179077
# Time for epoch 39 is 1.1687135696411133 sec Generator Loss: 0.8066977262496948,  Discriminator_loss: 1.3499629497528076
# Time for epoch 40 is 1.1638107299804688 sec Generator Loss: 0.7996140718460083,  Discriminator_loss: 1.351022720336914
# Time for epoch 41 is 1.1448254585266113 sec Generator Loss: 0.7920946478843689,  Discriminator_loss: 1.3590306043624878
# Time for epoch 42 is 1.1578054428100586 sec Generator Loss: 0.7943150401115417,  Discriminator_loss: 1.3644731044769287
# Time for epoch 43 is 1.1336462497711182 sec Generator Loss: 0.7893623113632202,  Discriminator_loss: 1.3675671815872192
# Time for epoch 44 is 1.0306415557861328 sec Generator Loss: 0.7867399454116821,  Discriminator_loss: 1.3624558448791504
# Time for epoch 45 is 1.063967227935791 sec Generator Loss: 0.7949561476707458,  Discriminator_loss: 1.3631162643432617
# Time for epoch 46 is 1.1008110046386719 sec Generator Loss: 0.7933186292648315,  Discriminator_loss: 1.3606200218200684
# Time for epoch 47 is 1.144688367843628 sec Generator Loss: 0.7974456548690796,  Discriminator_loss: 1.3666813373565674
# Time for epoch 48 is 1.1146950721740723 sec Generator Loss: 0.8016745448112488,  Discriminator_loss: 1.36443030834198
# Time for epoch 49 is 0.9807453155517578 sec Generator Loss: 0.7993656396865845,  Discriminator_loss: 1.3640906810760498
# Time for epoch 50 is 0.9737508296966553 sec Generator Loss: 0.8017562031745911,  Discriminator_loss: 1.3646941184997559
# Time for epoch 51 is 0.9758331775665283 sec Generator Loss: 0.7884154915809631,  Discriminator_loss: 1.366174578666687
# Time for epoch 52 is 0.9690301418304443 sec Generator Loss: 0.7937104105949402,  Discriminator_loss: 1.3631047010421753
# Time for epoch 53 is 1.0720350742340088 sec Generator Loss: 0.7911725640296936,  Discriminator_loss: 1.3626164197921753
# Time for epoch 54 is 0.9890539646148682 sec Generator Loss: 0.7955135703086853,  Discriminator_loss: 1.3642250299453735
# Time for epoch 55 is 1.0532631874084473 sec Generator Loss: 0.7932114005088806,  Discriminator_loss: 1.3605281114578247
# Time for epoch 56 is 0.9935688972473145 sec Generator Loss: 0.7851341366767883,  Discriminator_loss: 1.360379695892334
# Time for epoch 57 is 0.9802677631378174 sec Generator Loss: 0.7815855145454407,  Discriminator_loss: 1.3618037700653076
# Time for epoch 58 is 1.0163817405700684 sec Generator Loss: 0.787693202495575,  Discriminator_loss: 1.3629335165023804
# Time for epoch 59 is 0.9922783374786377 sec Generator Loss: 0.7847476601600647,  Discriminator_loss: 1.356114149093628
# Time for epoch 60 is 1.0013020038604736 sec Generator Loss: 0.7822041511535645,  Discriminator_loss: 1.3628435134887695
# Time for epoch 61 is 0.9874749183654785 sec Generator Loss: 0.7774937748908997,  Discriminator_loss: 1.3593082427978516
# Time for epoch 62 is 1.0014410018920898 sec Generator Loss: 0.7894221544265747,  Discriminator_loss: 1.3590588569641113
# Time for epoch 63 is 1.0213961601257324 sec Generator Loss: 0.7851364612579346,  Discriminator_loss: 1.3592768907546997
# Time for epoch 64 is 0.9851977825164795 sec Generator Loss: 0.7901860475540161,  Discriminator_loss: 1.3580000400543213
# Time for epoch 65 is 1.0254590511322021 sec Generator Loss: 0.7807047963142395,  Discriminator_loss: 1.3633322715759277
# Time for epoch 66 is 1.0095274448394775 sec Generator Loss: 0.7748613953590393,  Discriminator_loss: 1.3682007789611816
# Time for epoch 67 is 0.9893453121185303 sec Generator Loss: 0.7761039137840271,  Discriminator_loss: 1.369530200958252
# Time for epoch 68 is 1.0200083255767822 sec Generator Loss: 0.7815842628479004,  Discriminator_loss: 1.3772391080856323
# Time for epoch 69 is 0.9852304458618164 sec Generator Loss: 0.7768264412879944,  Discriminator_loss: 1.3726319074630737
# Time for epoch 70 is 0.9921178817749023 sec Generator Loss: 0.7779161334037781,  Discriminator_loss: 1.3672919273376465
# Time for epoch 71 is 1.0048675537109375 sec Generator Loss: 0.770997941493988,  Discriminator_loss: 1.3691282272338867
# Time for epoch 72 is 1.0890426635742188 sec Generator Loss: 0.7850867509841919,  Discriminator_loss: 1.3660632371902466
# Time for epoch 73 is 1.0242125988006592 sec Generator Loss: 0.7739713788032532,  Discriminator_loss: 1.365217685699463
# Time for epoch 74 is 0.9919333457946777 sec Generator Loss: 0.772089958190918,  Discriminator_loss: 1.3710331916809082
# Time for epoch 75 is 0.995849609375 sec Generator Loss: 0.7759057879447937,  Discriminator_loss: 1.362251877784729
# Time for epoch 76 is 1.0934042930603027 sec Generator Loss: 0.7818122506141663,  Discriminator_loss: 1.359877586364746
# Time for epoch 77 is 1.0444495677947998 sec Generator Loss: 0.7762989401817322,  Discriminator_loss: 1.365364909172058
# Time for epoch 78 is 1.0777404308319092 sec Generator Loss: 0.7850833535194397,  Discriminator_loss: 1.364267349243164
# Time for epoch 79 is 1.1852478981018066 sec Generator Loss: 0.7805950045585632,  Discriminator_loss: 1.3611929416656494
# Time for epoch 80 is 1.0619385242462158 sec Generator Loss: 0.7753993272781372,  Discriminator_loss: 1.3590216636657715
# Time for epoch 81 is 1.3119499683380127 sec Generator Loss: 0.7740921378135681,  Discriminator_loss: 1.3681159019470215
# Time for epoch 82 is 1.1957345008850098 sec Generator Loss: 0.7855515480041504,  Discriminator_loss: 1.3645309209823608
# Time for epoch 83 is 1.36808180809021 sec Generator Loss: 0.7799026370048523,  Discriminator_loss: 1.3686970472335815
# Time for epoch 84 is 1.1170368194580078 sec Generator Loss: 0.7823629975318909,  Discriminator_loss: 1.367417812347412
# Time for epoch 85 is 1.2597107887268066 sec Generator Loss: 0.7832067012786865,  Discriminator_loss: 1.3683900833129883
# Time for epoch 86 is 1.0985321998596191 sec Generator Loss: 0.7763112187385559,  Discriminator_loss: 1.367996096611023
# Time for epoch 87 is 0.9664938449859619 sec Generator Loss: 0.7770389914512634,  Discriminator_loss: 1.3664647340774536
# Time for epoch 88 is 0.9676361083984375 sec Generator Loss: 0.7747666239738464,  Discriminator_loss: 1.3672990798950195
# Time for epoch 89 is 0.9629511833190918 sec Generator Loss: 0.7780346870422363,  Discriminator_loss: 1.3671032190322876
# Time for epoch 90 is 0.966285228729248 sec Generator Loss: 0.7781093716621399,  Discriminator_loss: 1.3651492595672607
# Time for epoch 91 is 0.9591612815856934 sec Generator Loss: 0.7677739858627319,  Discriminator_loss: 1.3684463500976562
# Time for epoch 92 is 0.9862146377563477 sec Generator Loss: 0.7664824724197388,  Discriminator_loss: 1.370615005493164
# Time for epoch 93 is 1.0303773880004883 sec Generator Loss: 0.7789350152015686,  Discriminator_loss: 1.370010256767273
# Time for epoch 94 is 0.9784412384033203 sec Generator Loss: 0.7781922817230225,  Discriminator_loss: 1.3683656454086304
# Time for epoch 95 is 0.9717574119567871 sec Generator Loss: 0.7838916182518005,  Discriminator_loss: 1.361334204673767
# Time for epoch 96 is 1.0784785747528076 sec Generator Loss: 0.7771924138069153,  Discriminator_loss: 1.365635871887207
# Time for epoch 97 is 1.084343671798706 sec Generator Loss: 0.774380624294281,  Discriminator_loss: 1.3718000650405884
# Time for epoch 98 is 1.2801587581634521 sec Generator Loss: 0.7762873768806458,  Discriminator_loss: 1.3701026439666748
# Time for epoch 99 is 1.192972183227539 sec Generator Loss: 0.7765965461730957,  Discriminator_loss: 1.365959644317627
# Time for epoch 100 is 1.1125304698944092 sec Generator Loss: 0.7711701989173889,  Discriminator_loss: 1.367295742034912
# Time for epoch 101 is 1.0680437088012695 sec Generator Loss: 0.7761822938919067,  Discriminator_loss: 1.3687174320220947
# Time for epoch 102 is 0.9836432933807373 sec Generator Loss: 0.7742118835449219,  Discriminator_loss: 1.3664265871047974
# Time for epoch 103 is 0.9371075630187988 sec Generator Loss: 0.7670198082923889,  Discriminator_loss: 1.3728739023208618
# Time for epoch 104 is 0.9409511089324951 sec Generator Loss: 0.7670773863792419,  Discriminator_loss: 1.3700495958328247
# Time for epoch 105 is 0.9683403968811035 sec Generator Loss: 0.7754942774772644,  Discriminator_loss: 1.3702319860458374
# Time for epoch 106 is 0.965146541595459 sec Generator Loss: 0.7714621424674988,  Discriminator_loss: 1.3637652397155762
# Time for epoch 107 is 0.9470870494842529 sec Generator Loss: 0.7700572609901428,  Discriminator_loss: 1.3664530515670776
# Time for epoch 108 is 0.9322812557220459 sec Generator Loss: 0.7629972100257874,  Discriminator_loss: 1.3698837757110596
# Time for epoch 109 is 0.9392321109771729 sec Generator Loss: 0.7633562684059143,  Discriminator_loss: 1.3708381652832031
# Time for epoch 110 is 0.979233980178833 sec Generator Loss: 0.7744803428649902,  Discriminator_loss: 1.3654156923294067
# Time for epoch 111 is 0.9767434597015381 sec Generator Loss: 0.7712410688400269,  Discriminator_loss: 1.3672641515731812
# Time for epoch 112 is 0.9287064075469971 sec Generator Loss: 0.7688321471214294,  Discriminator_loss: 1.373556137084961
# Time for epoch 113 is 0.9209661483764648 sec Generator Loss: 0.7709592580795288,  Discriminator_loss: 1.3693649768829346
# Time for epoch 114 is 0.9417665004730225 sec Generator Loss: 0.7701805233955383,  Discriminator_loss: 1.3662071228027344
# Time for epoch 115 is 1.0452876091003418 sec Generator Loss: 0.7676617503166199,  Discriminator_loss: 1.3740314245224
# Time for epoch 116 is 0.9612796306610107 sec Generator Loss: 0.7747130393981934,  Discriminator_loss: 1.3697031736373901
# Time for epoch 117 is 0.923372745513916 sec Generator Loss: 0.776971161365509,  Discriminator_loss: 1.3659827709197998
# Time for epoch 118 is 0.9206461906433105 sec Generator Loss: 0.7789055109024048,  Discriminator_loss: 1.3590861558914185
# Time for epoch 119 is 0.9216799736022949 sec Generator Loss: 0.7700481414794922,  Discriminator_loss: 1.3659758567810059
# Time for epoch 120 is 0.9330480098724365 sec Generator Loss: 0.7793988585472107,  Discriminator_loss: 1.3666880130767822
# Time for epoch 121 is 1.0321342945098877 sec Generator Loss: 0.7808526158332825,  Discriminator_loss: 1.3640981912612915
# Time for epoch 122 is 1.0361003875732422 sec Generator Loss: 0.775864839553833,  Discriminator_loss: 1.3640552759170532
# Time for epoch 123 is 1.034691333770752 sec Generator Loss: 0.7739710211753845,  Discriminator_loss: 1.3688673973083496
# Time for epoch 124 is 1.0332512855529785 sec Generator Loss: 0.7789391875267029,  Discriminator_loss: 1.3633229732513428
# Time for epoch 125 is 1.0219547748565674 sec Generator Loss: 0.7639483213424683,  Discriminator_loss: 1.3695603609085083
# Time for epoch 126 is 1.0613164901733398 sec Generator Loss: 0.7758471369743347,  Discriminator_loss: 1.3618415594100952
# Time for epoch 127 is 0.9700675010681152 sec Generator Loss: 0.7730415463447571,  Discriminator_loss: 1.3650190830230713
# Time for epoch 128 is 0.9350082874298096 sec Generator Loss: 0.7710421681404114,  Discriminator_loss: 1.3625285625457764
# Time for epoch 129 is 0.9237768650054932 sec Generator Loss: 0.7819264531135559,  Discriminator_loss: 1.3629555702209473
# Time for epoch 130 is 0.9456226825714111 sec Generator Loss: 0.7788156867027283,  Discriminator_loss: 1.3626636266708374
# Time for epoch 131 is 0.9900949001312256 sec Generator Loss: 0.7761064767837524,  Discriminator_loss: 1.3666468858718872
# Time for epoch 132 is 0.9389491081237793 sec Generator Loss: 0.7693302035331726,  Discriminator_loss: 1.3655683994293213
# Time for epoch 133 is 0.9243943691253662 sec Generator Loss: 0.7810795307159424,  Discriminator_loss: 1.3628352880477905
# Time for epoch 134 is 0.9236388206481934 sec Generator Loss: 0.7732837200164795,  Discriminator_loss: 1.3631609678268433
# Time for epoch 135 is 0.9292466640472412 sec Generator Loss: 0.7760276794433594,  Discriminator_loss: 1.3629518747329712
# Time for epoch 136 is 1.0431108474731445 sec Generator Loss: 0.7755935192108154,  Discriminator_loss: 1.3697782754898071
# Time for epoch 137 is 1.0252964496612549 sec Generator Loss: 0.7698584198951721,  Discriminator_loss: 1.366127371788025
# Time for epoch 138 is 0.9747283458709717 sec Generator Loss: 0.7705325484275818,  Discriminator_loss: 1.3629281520843506
# Time for epoch 139 is 0.9700863361358643 sec Generator Loss: 0.772595226764679,  Discriminator_loss: 1.3642733097076416
# Time for epoch 140 is 0.9691877365112305 sec Generator Loss: 0.7720983028411865,  Discriminator_loss: 1.366409420967102
# Time for epoch 141 is 1.0066814422607422 sec Generator Loss: 0.778627872467041,  Discriminator_loss: 1.364930510520935
# Time for epoch 142 is 1.0030834674835205 sec Generator Loss: 0.7764037847518921,  Discriminator_loss: 1.363631248474121
# Time for epoch 143 is 0.9602041244506836 sec Generator Loss: 0.7802436351776123,  Discriminator_loss: 1.3676612377166748
# Time for epoch 144 is 0.9700047969818115 sec Generator Loss: 0.7824064493179321,  Discriminator_loss: 1.3675429821014404
# Time for epoch 145 is 0.9812479019165039 sec Generator Loss: 0.7781247496604919,  Discriminator_loss: 1.3652726411819458
# Time for epoch 146 is 1.0642640590667725 sec Generator Loss: 0.7610721588134766,  Discriminator_loss: 1.3663874864578247
# Time for epoch 147 is 1.0055267810821533 sec Generator Loss: 0.7739399671554565,  Discriminator_loss: 1.363276720046997
# Time for epoch 148 is 0.9679677486419678 sec Generator Loss: 0.7718002200126648,  Discriminator_loss: 1.3671302795410156
# Time for epoch 149 is 0.9657642841339111 sec Generator Loss: 0.7760397791862488,  Discriminator_loss: 1.361619472503662
# Time for epoch 150 is 0.9654510021209717 sec Generator Loss: 0.7733062505722046,  Discriminator_loss: 1.3650532960891724
# Time for epoch 151 is 1.0039012432098389 sec Generator Loss: 0.7743936777114868,  Discriminator_loss: 1.3697797060012817
# Time for epoch 152 is 1.0779001712799072 sec Generator Loss: 0.7774885296821594,  Discriminator_loss: 1.3613537549972534
# Time for epoch 153 is 0.9783191680908203 sec Generator Loss: 0.7869642972946167,  Discriminator_loss: 1.3613395690917969
# Time for epoch 154 is 0.9379425048828125 sec Generator Loss: 0.7717311978340149,  Discriminator_loss: 1.3645156621932983
# Time for epoch 155 is 0.9468555450439453 sec Generator Loss: 0.7748117446899414,  Discriminator_loss: 1.364993691444397
# Time for epoch 156 is 0.9690449237823486 sec Generator Loss: 0.7681999206542969,  Discriminator_loss: 1.3714921474456787
# Time for epoch 157 is 0.9935777187347412 sec Generator Loss: 0.7668911218643188,  Discriminator_loss: 1.36508047580719
# Time for epoch 158 is 0.9594135284423828 sec Generator Loss: 0.7752079367637634,  Discriminator_loss: 1.3640090227127075
# Time for epoch 159 is 0.9473612308502197 sec Generator Loss: 0.7749161720275879,  Discriminator_loss: 1.3654342889785767
# Time for epoch 160 is 0.9399645328521729 sec Generator Loss: 0.7716573476791382,  Discriminator_loss: 1.3658140897750854
# Time for epoch 161 is 0.9339361190795898 sec Generator Loss: 0.7751196026802063,  Discriminator_loss: 1.3671878576278687
# Time for epoch 162 is 1.0090374946594238 sec Generator Loss: 0.7709841132164001,  Discriminator_loss: 1.367979645729065
# Time for epoch 163 is 0.9632489681243896 sec Generator Loss: 0.7677954435348511,  Discriminator_loss: 1.3725202083587646
# ...
# Time for epoch 849 is 1.152050256729126 sec Generator Loss: 0.7979613542556763,  Discriminator_loss: 1.347623586654663
# Time for epoch 850 is 1.0933327674865723 sec Generator Loss: 0.7982100248336792,  Discriminator_loss: 1.3454780578613281
# Time for epoch 851 is 1.0676262378692627 sec Generator Loss: 0.7948923707008362,  Discriminator_loss: 1.3541576862335205
# Time for epoch 852 is 1.0335938930511475 sec Generator Loss: 0.7879307866096497,  Discriminator_loss: 1.348564624786377
# Time for epoch 853 is 1.0589039325714111 sec Generator Loss: 0.7887284755706787,  Discriminator_loss: 1.3526194095611572
# Time for epoch 854 is 1.0483973026275635 sec Generator Loss: 0.7940148711204529,  Discriminator_loss: 1.3469467163085938
# Time for epoch 855 is 1.0705833435058594 sec Generator Loss: 0.7911726832389832,  Discriminator_loss: 1.347631573677063
# Time for epoch 856 is 1.0396199226379395 sec Generator Loss: 0.7957901954650879,  Discriminator_loss: 1.3490849733352661
# Time for epoch 857 is 1.0612311363220215 sec Generator Loss: 0.7916281223297119,  Discriminator_loss: 1.358734369277954
# Time for epoch 858 is 1.0391871929168701 sec Generator Loss: 0.7936364412307739,  Discriminator_loss: 1.3487154245376587
# Time for epoch 859 is 1.1041622161865234 sec Generator Loss: 0.8003390431404114,  Discriminator_loss: 1.3510221242904663
# Time for epoch 860 is 1.1126997470855713 sec Generator Loss: 0.8019106388092041,  Discriminator_loss: 1.3521037101745605
# Time for epoch 861 is 1.0768921375274658 sec Generator Loss: 0.7981429100036621,  Discriminator_loss: 1.3448702096939087
# Time for epoch 862 is 1.0871319770812988 sec Generator Loss: 0.79496169090271,  Discriminator_loss: 1.350911259651184
# Time for epoch 863 is 1.041367769241333 sec Generator Loss: 0.7943825721740723,  Discriminator_loss: 1.3503835201263428
# Time for epoch 864 is 1.1233525276184082 sec Generator Loss: 0.7920533418655396,  Discriminator_loss: 1.3543215990066528
# Time for epoch 865 is 1.098487377166748 sec Generator Loss: 0.7968336939811707,  Discriminator_loss: 1.3535096645355225
# Time for epoch 866 is 1.0692486763000488 sec Generator Loss: 0.7903104424476624,  Discriminator_loss: 1.3536075353622437
# Time for epoch 867 is 1.078730583190918 sec Generator Loss: 0.7874568700790405,  Discriminator_loss: 1.350044846534729
# Time for epoch 868 is 1.0451970100402832 sec Generator Loss: 0.792844295501709,  Discriminator_loss: 1.3512146472930908
# Time for epoch 869 is 1.0747160911560059 sec Generator Loss: 0.7897804975509644,  Discriminator_loss: 1.3483848571777344
# Time for epoch 870 is 1.0605578422546387 sec Generator Loss: 0.7998368740081787,  Discriminator_loss: 1.3429380655288696
# Time for epoch 871 is 1.0849945545196533 sec Generator Loss: 0.7985293865203857,  Discriminator_loss: 1.351805329322815
# Time for epoch 872 is 1.0821216106414795 sec Generator Loss: 0.8017082214355469,  Discriminator_loss: 1.3474199771881104
# Time for epoch 873 is 1.0458221435546875 sec Generator Loss: 0.7957829236984253,  Discriminator_loss: 1.347015142440796
# Time for epoch 874 is 1.107731580734253 sec Generator Loss: 0.7906873822212219,  Discriminator_loss: 1.354742169380188
# Time for epoch 875 is 1.0495686531066895 sec Generator Loss: 0.7944582104682922,  Discriminator_loss: 1.3462995290756226
# Time for epoch 876 is 1.069110631942749 sec Generator Loss: 0.797675609588623,  Discriminator_loss: 1.348511815071106
# Time for epoch 877 is 1.0601727962493896 sec Generator Loss: 0.7920404672622681,  Discriminator_loss: 1.3521909713745117
# Time for epoch 878 is 1.091233253479004 sec Generator Loss: 0.7912483215332031,  Discriminator_loss: 1.3489265441894531
# Time for epoch 879 is 1.0943315029144287 sec Generator Loss: 0.7886658310890198,  Discriminator_loss: 1.3595308065414429
# Time for epoch 880 is 1.1424808502197266 sec Generator Loss: 0.7929220199584961,  Discriminator_loss: 1.3466242551803589
# Time for epoch 881 is 1.135951042175293 sec Generator Loss: 0.7904165983200073,  Discriminator_loss: 1.3515808582305908
# Time for epoch 882 is 1.0833027362823486 sec Generator Loss: 0.7974382638931274,  Discriminator_loss: 1.348673939704895
# Time for epoch 883 is 1.2287800312042236 sec Generator Loss: 0.7958421111106873,  Discriminator_loss: 1.3485050201416016
# Time for epoch 884 is 1.0740973949432373 sec Generator Loss: 0.7885903120040894,  Discriminator_loss: 1.3474221229553223
# Time for epoch 885 is 1.073150634765625 sec Generator Loss: 0.7984180450439453,  Discriminator_loss: 1.3488236665725708
# Time for epoch 886 is 1.0625841617584229 sec Generator Loss: 0.7935781478881836,  Discriminator_loss: 1.3498210906982422
# Time for epoch 887 is 1.0968854427337646 sec Generator Loss: 0.7944638729095459,  Discriminator_loss: 1.346762776374817
# Time for epoch 888 is 1.1625926494598389 sec Generator Loss: 0.7970054745674133,  Discriminator_loss: 1.3504480123519897
# Time for epoch 889 is 1.0924797058105469 sec Generator Loss: 0.7896511554718018,  Discriminator_loss: 1.3498120307922363
# Time for epoch 890 is 1.0920147895812988 sec Generator Loss: 0.7927536368370056,  Discriminator_loss: 1.3489493131637573
# Time for epoch 891 is 1.043797254562378 sec Generator Loss: 0.7958479523658752,  Discriminator_loss: 1.3508974313735962
# Time for epoch 892 is 1.0814285278320312 sec Generator Loss: 0.8007835149765015,  Discriminator_loss: 1.3457801342010498
# Time for epoch 893 is 1.0632612705230713 sec Generator Loss: 0.7903168797492981,  Discriminator_loss: 1.3494420051574707
# Time for epoch 894 is 1.0875718593597412 sec Generator Loss: 0.8031945824623108,  Discriminator_loss: 1.3513144254684448
# Time for epoch 895 is 1.0359504222869873 sec Generator Loss: 0.7876712083816528,  Discriminator_loss: 1.3494659662246704
# Time for epoch 896 is 1.032137155532837 sec Generator Loss: 0.7912500500679016,  Discriminator_loss: 1.3604739904403687
# Time for epoch 897 is 1.071000099182129 sec Generator Loss: 0.7935208082199097,  Discriminator_loss: 1.351043939590454
# Time for epoch 898 is 1.0280086994171143 sec Generator Loss: 0.7895768284797668,  Discriminator_loss: 1.3510843515396118
# Time for epoch 899 is 1.0557405948638916 sec Generator Loss: 0.7940298318862915,  Discriminator_loss: 1.347498893737793
# Time for epoch 900 is 1.0450608730316162 sec Generator Loss: 0.8050246238708496,  Discriminator_loss: 1.3496735095977783
# Time for epoch 901 is 1.0662658214569092 sec Generator Loss: 0.7963396906852722,  Discriminator_loss: 1.347548246383667
# Time for epoch 902 is 1.023608684539795 sec Generator Loss: 0.7929022312164307,  Discriminator_loss: 1.3526320457458496
# Time for epoch 903 is 1.072282075881958 sec Generator Loss: 0.784324049949646,  Discriminator_loss: 1.3566889762878418
# Time for epoch 904 is 1.0430057048797607 sec Generator Loss: 0.7876337766647339,  Discriminator_loss: 1.3508245944976807
# Time for epoch 905 is 0.9874765872955322 sec Generator Loss: 0.7956485152244568,  Discriminator_loss: 1.3436403274536133
# Time for epoch 906 is 1.000401496887207 sec Generator Loss: 0.788969874382019,  Discriminator_loss: 1.3467806577682495
# Time for epoch 907 is 0.9919180870056152 sec Generator Loss: 0.7976505160331726,  Discriminator_loss: 1.351609706878662
# Time for epoch 908 is 1.001347541809082 sec Generator Loss: 0.7964621782302856,  Discriminator_loss: 1.350462555885315
# Time for epoch 909 is 0.9920303821563721 sec Generator Loss: 0.7971251010894775,  Discriminator_loss: 1.3459649085998535
# Time for epoch 910 is 0.9777772426605225 sec Generator Loss: 0.7993625998497009,  Discriminator_loss: 1.3435389995574951
# Time for epoch 911 is 1.0122411251068115 sec Generator Loss: 0.7942687273025513,  Discriminator_loss: 1.3514827489852905
# Time for epoch 912 is 0.9877939224243164 sec Generator Loss: 0.7925058007240295,  Discriminator_loss: 1.3479810953140259
# Time for epoch 913 is 1.0047264099121094 sec Generator Loss: 0.7947295308113098,  Discriminator_loss: 1.3481179475784302
# Time for epoch 914 is 1.0107269287109375 sec Generator Loss: 0.7883376479148865,  Discriminator_loss: 1.355100393295288
# Time for epoch 915 is 0.9982545375823975 sec Generator Loss: 0.7939171195030212,  Discriminator_loss: 1.3470969200134277
# Time for epoch 916 is 1.0128164291381836 sec Generator Loss: 0.7899985313415527,  Discriminator_loss: 1.3558255434036255
# Time for epoch 917 is 1.0853400230407715 sec Generator Loss: 0.794381320476532,  Discriminator_loss: 1.3526109457015991
# Time for epoch 918 is 1.047333002090454 sec Generator Loss: 0.7986910343170166,  Discriminator_loss: 1.3443615436553955
# Time for epoch 919 is 1.0269877910614014 sec Generator Loss: 0.7977252006530762,  Discriminator_loss: 1.3488123416900635
# Time for epoch 920 is 0.9953179359436035 sec Generator Loss: 0.7919921875,  Discriminator_loss: 1.3507513999938965
# Time for epoch 921 is 1.0417962074279785 sec Generator Loss: 0.7963674068450928,  Discriminator_loss: 1.3520846366882324
# Time for epoch 922 is 0.9913194179534912 sec Generator Loss: 0.7830989956855774,  Discriminator_loss: 1.3571807146072388
# Time for epoch 923 is 1.0176668167114258 sec Generator Loss: 0.7909291386604309,  Discriminator_loss: 1.3512043952941895
# Time for epoch 924 is 1.0133426189422607 sec Generator Loss: 0.8029935359954834,  Discriminator_loss: 1.3461862802505493
# Time for epoch 925 is 1.0122976303100586 sec Generator Loss: 0.7892934083938599,  Discriminator_loss: 1.3489134311676025
# Time for epoch 926 is 1.0966882705688477 sec Generator Loss: 0.7911576628684998,  Discriminator_loss: 1.3459858894348145
# Time for epoch 927 is 0.9921374320983887 sec Generator Loss: 0.7950567007064819,  Discriminator_loss: 1.3539880514144897
# Time for epoch 928 is 1.0079500675201416 sec Generator Loss: 0.8077409267425537,  Discriminator_loss: 1.3482223749160767
# Time for epoch 929 is 1.028357982635498 sec Generator Loss: 0.7943682670593262,  Discriminator_loss: 1.350673794746399
# Time for epoch 930 is 0.9965801239013672 sec Generator Loss: 0.7966704368591309,  Discriminator_loss: 1.3486303091049194
# Time for epoch 931 is 1.0426769256591797 sec Generator Loss: 0.7943711876869202,  Discriminator_loss: 1.3501965999603271
# Time for epoch 932 is 1.1072943210601807 sec Generator Loss: 0.7930598855018616,  Discriminator_loss: 1.3521387577056885
# Time for epoch 933 is 1.0434927940368652 sec Generator Loss: 0.7964645624160767,  Discriminator_loss: 1.3465405702590942
# Time for epoch 934 is 1.020627737045288 sec Generator Loss: 0.795717716217041,  Discriminator_loss: 1.3541339635849
# Time for epoch 935 is 1.0225279331207275 sec Generator Loss: 0.8051348328590393,  Discriminator_loss: 1.3434126377105713
# Time for epoch 936 is 1.0915195941925049 sec Generator Loss: 0.8010961413383484,  Discriminator_loss: 1.3457581996917725
# Time for epoch 937 is 1.0453100204467773 sec Generator Loss: 0.7973179221153259,  Discriminator_loss: 1.3513983488082886
# Time for epoch 938 is 1.0809645652770996 sec Generator Loss: 0.7960355877876282,  Discriminator_loss: 1.3528262376785278
# Time for epoch 939 is 1.05051851272583 sec Generator Loss: 0.7989493012428284,  Discriminator_loss: 1.3529845476150513
# Time for epoch 940 is 1.068769931793213 sec Generator Loss: 0.7997143864631653,  Discriminator_loss: 1.347642183303833
# Time for epoch 941 is 1.0582258701324463 sec Generator Loss: 0.7977502346038818,  Discriminator_loss: 1.3475342988967896
# Time for epoch 942 is 1.0193705558776855 sec Generator Loss: 0.7974185943603516,  Discriminator_loss: 1.354114055633545
# Time for epoch 943 is 1.0632760524749756 sec Generator Loss: 0.7979278564453125,  Discriminator_loss: 1.3453350067138672
# Time for epoch 944 is 1.064328670501709 sec Generator Loss: 0.7959667444229126,  Discriminator_loss: 1.3423445224761963
# Time for epoch 945 is 1.0940523147583008 sec Generator Loss: 0.7958486676216125,  Discriminator_loss: 1.347374677658081
# Time for epoch 946 is 1.0403969287872314 sec Generator Loss: 0.7862327098846436,  Discriminator_loss: 1.3478279113769531
# Time for epoch 947 is 1.084155797958374 sec Generator Loss: 0.7881770730018616,  Discriminator_loss: 1.3514446020126343
# Time for epoch 948 is 1.0818800926208496 sec Generator Loss: 0.8004695773124695,  Discriminator_loss: 1.3488085269927979
# Time for epoch 949 is 1.0292885303497314 sec Generator Loss: 0.79853355884552,  Discriminator_loss: 1.3498042821884155
# Time for epoch 950 is 1.1181025505065918 sec Generator Loss: 0.7920689582824707,  Discriminator_loss: 1.3530857563018799
# Time for epoch 951 is 1.0689349174499512 sec Generator Loss: 0.7899479866027832,  Discriminator_loss: 1.352433681488037
# Time for epoch 952 is 1.089954137802124 sec Generator Loss: 0.7908423542976379,  Discriminator_loss: 1.348720669746399
# Time for epoch 953 is 1.0758159160614014 sec Generator Loss: 0.7973554134368896,  Discriminator_loss: 1.3521817922592163
# Time for epoch 954 is 1.0789852142333984 sec Generator Loss: 0.7990736961364746,  Discriminator_loss: 1.347166895866394
# Time for epoch 955 is 1.0169739723205566 sec Generator Loss: 0.7860658764839172,  Discriminator_loss: 1.353392481803894
# Time for epoch 956 is 1.0302696228027344 sec Generator Loss: 0.7846416234970093,  Discriminator_loss: 1.3564331531524658
# Time for epoch 957 is 1.0365800857543945 sec Generator Loss: 0.7945485711097717,  Discriminator_loss: 1.347272276878357
# Time for epoch 958 is 1.1626906394958496 sec Generator Loss: 0.7971861958503723,  Discriminator_loss: 1.3515350818634033
# Time for epoch 959 is 1.3762943744659424 sec Generator Loss: 0.7927267551422119,  Discriminator_loss: 1.349274754524231
# Time for epoch 960 is 1.2979438304901123 sec Generator Loss: 0.8058800101280212,  Discriminator_loss: 1.3481764793395996
# Time for epoch 961 is 1.4946224689483643 sec Generator Loss: 0.7973585724830627,  Discriminator_loss: 1.3537232875823975
# Time for epoch 962 is 1.4022858142852783 sec Generator Loss: 0.7912342548370361,  Discriminator_loss: 1.3465440273284912
# Time for epoch 963 is 1.1900718212127686 sec Generator Loss: 0.7948192358016968,  Discriminator_loss: 1.3504422903060913
# Time for epoch 964 is 1.1542654037475586 sec Generator Loss: 0.7925935387611389,  Discriminator_loss: 1.345375895500183
# Time for epoch 965 is 1.128638505935669 sec Generator Loss: 0.7890881299972534,  Discriminator_loss: 1.3444777727127075
# Time for epoch 966 is 1.0370678901672363 sec Generator Loss: 0.7965921759605408,  Discriminator_loss: 1.350356101989746
# Time for epoch 967 is 1.129530668258667 sec Generator Loss: 0.7998250126838684,  Discriminator_loss: 1.348954200744629
# Time for epoch 968 is 1.0338466167449951 sec Generator Loss: 0.7859343886375427,  Discriminator_loss: 1.364108920097351
# Time for epoch 969 is 1.1054091453552246 sec Generator Loss: 0.7948262095451355,  Discriminator_loss: 1.3521682024002075
# Time for epoch 970 is 1.056626319885254 sec Generator Loss: 0.8001284003257751,  Discriminator_loss: 1.3522521257400513
# Time for epoch 971 is 1.0711669921875 sec Generator Loss: 0.8031917214393616,  Discriminator_loss: 1.3448647260665894
# Time for epoch 972 is 1.1406137943267822 sec Generator Loss: 0.7929307818412781,  Discriminator_loss: 1.3477002382278442
# Time for epoch 973 is 1.0648231506347656 sec Generator Loss: 0.7958672046661377,  Discriminator_loss: 1.3484841585159302
# Time for epoch 974 is 1.0747416019439697 sec Generator Loss: 0.7896173596382141,  Discriminator_loss: 1.3456628322601318
# Time for epoch 975 is 1.180307388305664 sec Generator Loss: 0.8008725643157959,  Discriminator_loss: 1.3485416173934937
# Time for epoch 976 is 1.2131164073944092 sec Generator Loss: 0.7982078790664673,  Discriminator_loss: 1.3449397087097168
# Time for epoch 977 is 1.1383531093597412 sec Generator Loss: 0.7916960716247559,  Discriminator_loss: 1.3511826992034912
# Time for epoch 978 is 1.068164348602295 sec Generator Loss: 0.7902935743331909,  Discriminator_loss: 1.3550118207931519
# Time for epoch 979 is 1.0762979984283447 sec Generator Loss: 0.7986516952514648,  Discriminator_loss: 1.3478573560714722
# Time for epoch 980 is 1.2231414318084717 sec Generator Loss: 0.794289767742157,  Discriminator_loss: 1.3473759889602661

# %%
for epochs in [1450, 1700, 1950]:
    start_time = datetime.datetime.now()
    df = add_Ma(df)
    data_gen_train, data_gen_test = get_gen_train_test(df, n_sequence, n_batch)

    generator = make_generator_model(n_sequence, n_features)
    discriminator=make_discriminator_model(n_features)

    learning_rate=1e-4
    generator_optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.5)
    discriminator_optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.5)

    @tf.function
    def train_step(sequences, sequences_end):
      return train_step_def(sequences, sequences_end)

    @tf.function
    def test_step(sequences, sequences_end):
      return test_step_def(sequences, sequences_end)

    checkpoint_dir = './training_checkpoints'+stock_code
    checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
    checkpoint = tf.train.Checkpoint(generator_optimizer=generator_optimizer,
                                     discriminator_optimizer=discriminator_optimizer,
                                     generator=generator,
                                     discriminator=discriminator)

    history, history_val = train(data_gen_train, data_gen_test, epochs)

    plot_history(history, history_val)
    plot_frame(*data_gen_test[0], generator)

    print("[MSE Baseline] train:",mean_squared_error(data_gen_train)," test:", mean_squared_error(data_gen_test))
    now = datetime.datetime.now()
    delta = now - start_time
    print("Delta time with epochs = {0}:".format(epochs), delta)
    generator.save("bilstm_ffnn_epochs_{0}.h5".format(epochs))
