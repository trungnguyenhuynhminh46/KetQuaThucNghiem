# %%
try:
  # %tensorflow_version 2.x
except Exception:
  pass

# %% [markdown]
# # Import the libraries

# %%
import numpy as np
import pandas as pd
import os

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Embedding, Dense, Dropout, LeakyReLU, Flatten, SimpleRNN, BatchNormalization
import time
import datetime

from tensorflow.keras.layers import Lambda

from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model

import matplotlib.pyplot as plt
import datetime as dt
import yfinance as yf
yf.pdr_override()
from pandas_datareader import data as pdr

# %%
def plot_dataframe(df):
  for column_name in df.columns:
    plt.figure()
    plt.title(column_name)
    plt.plot(df[column_name])

# %% [markdown]
# # Preprocessing

# %%
def add_Ma(df, window=5):
    for i in range(window, df.shape[0]):
        sum = 0.0
        for k in range(1, window+1):
            sum += df.iloc[i-k, 4]
        df.loc[df.index[i], 'Ma'] = np.round(sum/window, 6)
    return df[window:]

# %%
class Standarized_TimeseriesGenerator(tf.keras.preprocessing.sequence.TimeseriesGenerator):
  def __getitem__(self, index):
    samples, targets  = super(Standarized_TimeseriesGenerator, self).__getitem__(index)
    mean = samples.mean(axis=1)
    std = samples.std(axis=1)
    samples = (samples - mean[:,None,:])/std[:,None,:]
    targets = (targets - mean)/std
    return samples, targets

# %%
def get_gen_train_test(dataframe, n_sequence, n_batch):
    data = dataframe.drop(columns='Date').to_numpy()
    targets = data
    n_samples = data.shape[0]
    train_test_split=int(n_samples*0.9)

    data_gen_train = Standarized_TimeseriesGenerator(data, targets,
                                length=n_sequence, sampling_rate=1,
                                stride=1, batch_size=n_batch,
                                start_index = 0,
                                end_index = train_test_split,
                                shuffle = True)
    data_gen_test = Standarized_TimeseriesGenerator(data, targets,
                                length=n_sequence, sampling_rate=1,
                                stride=1, batch_size=n_batch,
                                start_index = train_test_split,
                                end_index = n_samples-1)

    return data_gen_train, data_gen_test

# %% [markdown]
# # Baseline

# %%
def mean_squared_error(X, lenght = 5):
    squared_error = 0
    for i in range(0, X.shape[0] - lenght):
        x = X[i:i+lenght]
        mean = x.mean()
        std = x.std()
        x = (x - mean)/std
        y = (X[i+lenght] - mean)/std
        squared_error += np.square(x[-1]-y)
    return squared_error/X.shape[0]

# %%
# For generated data
def mean_squared_error(dataset):
    mse=0
    for X_batch, y_batch in dataset:
        mse += np.mean(np.square(X_batch[:, -1, 3:4]-y_batch[:, 3:4]))
    mse /= len(dataset)
    return mse

# %% [markdown]
# # Utilities

# %%
def mse(y_true, y_pred):
    return tf.reduce_mean(tf.square(y_true[:,3]-y_pred[:,3]))
def mae(y_true, y_pred):
    return tf.reduce_mean(tf.keras.backend.abs((y_true[:,3]-y_pred[:,3])))
    # ***The absolute is over the whole thing as y_true can be negative
def mape(y_true, y_pred):
    return tf.reduce_mean(tf.keras.backend.abs((y_true[:,3]-y_pred[:,3])/y_true[:,3]))
    # ***The absolute is over the whole thing as y_true can be negative
def rmse(y_true, y_pred):
    return tf.sqrt(tf.reduce_mean(tf.square(y_true[:,3]-y_pred[:,3])))
def ar(y_true, y_pred):
    mask = tf.cast(y_pred[1:,3] > y_true[:-1,3],tf.float32)
    return tf.reduce_mean((y_true[1:,3]-y_true[:-1,3])*mask)

# %% [markdown]
# # GAN

# %% [markdown]
# ## Perdidas

# %%
def discriminator_loss(real_output, fake_output):
    real_loss = tf.keras.losses.binary_crossentropy(tf.ones_like(real_output), real_output)
    fake_loss = tf.keras.losses.binary_crossentropy(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss
    return total_loss

def generator_loss(x, y, fake_output):
    a1=0.01
    g_loss = tf.keras.losses.binary_crossentropy(tf.ones_like(fake_output), fake_output)
    g_mse = tf.keras.losses.MSE(x, y)
    return a1*g_mse + (1-a1)*g_loss, g_mse

# %% [markdown]
# ## Generator

# %%
def make_generator_model(n_sequence, n_features):
    inputs = Input(shape=(n_sequence, n_features,))
    rnn_1 = SimpleRNN(units=10, return_sequences=True, activation=None, kernel_initializer='random_normal')(inputs)
    batch_norm1 = BatchNormalization()(rnn_1)
    rnn_1_LRelu = LeakyReLU(alpha=0.3)(batch_norm1) 
    rnn_1_droput = Dropout(0.3)(rnn_1_LRelu)
    rnn_2 = SimpleRNN(units=10, return_sequences=False, activation=None, kernel_initializer='random_normal')(rnn_1_droput)
    batch_norm2 = BatchNormalization()(rnn_2)
    rnn_2_LRelu = LeakyReLU(alpha=0.3)(batch_norm2) 
    rnn_2_droput = Dropout(0.3)(rnn_2_LRelu)
    output_dense = Dense(n_features, activation=None)(rnn_2_droput)
    output = LeakyReLU(alpha=0.3)(output_dense) 

    model = Model(inputs=inputs, outputs=output)
    model.compile(loss=None, metrics=[mse, mae, mape, rmse, ar])
    model.summary()

    return model

# %% [markdown]
# ## Discriminator

# %%
def make_discriminator_model(n_features):
    model = Sequential()
    model.add(Flatten())
    model.add(Dense(units=72, input_shape=((n_sequence+1) * n_features,), activation=None, kernel_initializer='random_normal'))
    model.add(tf.keras.layers.LeakyReLU(alpha=0.3))
    model.add(tf.keras.layers.GaussianNoise(stddev=0.2))
    model.add(Dropout(0.3))
    model.add(Dense(units=100, activation=None, kernel_initializer='random_normal'))
    model.add(tf.keras.layers.LeakyReLU(alpha=0.3))
    model.add(Dropout(0.3))
    model.add(Dense(units=10, activation=None, kernel_initializer='random_normal'))
    model.add(tf.keras.layers.LeakyReLU(alpha=0.3))
    model.add(Dropout(0.3))
    model.add(Dense(1 ,activation='sigmoid'))
    model.compile(loss=discriminator_loss)
    return model

# %% [markdown]
# # Training

# %%
def train_step_def(sequences, sequences_end):
    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        generated_prediction = generator(sequences, training=True)

        sequences_true = tf.concat((sequences, sequences_end[:, None, :]), axis=1)
        sequences_fake = tf.concat((sequences, generated_prediction[:, None, :]), axis=1)

        real_output = discriminator(sequences_true, training=True)
        fake_output = discriminator(sequences_fake, training=True)

        gen_loss, gen_mse_loss = generator_loss(generated_prediction, 
                                                sequences_end, 
                                                fake_output)
        disc_loss = discriminator_loss(real_output, fake_output)

    gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

    return tf.reduce_mean(gen_loss), tf.reduce_mean(disc_loss), tf.reduce_mean(gen_mse_loss)

def test_step_def(sequences, sequences_end):
    generated_prediction = generator(sequences, training=False)

    sequences_true = tf.concat((sequences, sequences_end[:,None,:]), axis=1)
    sequences_fake = tf.concat((sequences, generated_prediction[:,None,:]), axis=1)

    real_output = discriminator(sequences_true, training=False)
    fake_output = discriminator(sequences_fake, training=False)

    gen_loss, gen_mse_loss = generator_loss(generated_prediction, sequences_end, fake_output)
    disc_loss = discriminator_loss(real_output, fake_output)
    return tf.reduce_mean(gen_loss), tf.reduce_mean(disc_loss), tf.reduce_mean(gen_mse_loss)

# %%
def train(dataset, dataset_val, epochs):
    history = np.empty(shape = (8, epochs))
    history_val = np.empty(shape = (8, epochs))
    len_dataset = len(dataset)
    len_dataset_val = len(dataset_val)
    for epoch in range(epochs):
        start = time.time()

        cur_dis_loss = 0
        cur_gen_loss = 0
        cur_gen_mse_loss = 0
        for sequence_batch, sequence_end_batch in dataset:
            aux_cur_losses = train_step(tf.cast(sequence_batch, tf.float32), 
                                      tf.cast(sequence_end_batch, tf.float32))
            cur_gen_loss += aux_cur_losses[0]/len_dataset
            cur_dis_loss += aux_cur_losses[1]/len_dataset
            cur_gen_mse_loss += aux_cur_losses[2]/len_dataset
        cur_gen_metrics = generator.evaluate(dataset,verbose=False)[1:]

        history[:, epoch] = cur_gen_loss, cur_dis_loss, cur_gen_mse_loss, *cur_gen_metrics

        cur_gen_metrics_val = generator.evaluate(dataset_val,verbose=False)[1: ]

        cur_gen_loss_val = 0
        cur_dis_loss_val = 0
        cur_gen_mse_loss_val = 0
        for sequence_batch, sequence_end_batch in dataset_val:
            aux_cur_losses_val = test_step(tf.cast(sequence_batch, tf.float32), 
                                         tf.cast(sequence_end_batch, tf.float32))
            cur_gen_loss_val += aux_cur_losses_val[0]/len_dataset_val
            cur_dis_loss_val += aux_cur_losses_val[1]/len_dataset_val
            cur_gen_mse_loss_val += aux_cur_losses_val[2]/len_dataset_val
    


        history_val[:, epoch] = cur_gen_loss_val, cur_dis_loss_val, cur_gen_mse_loss_val, *cur_gen_metrics_val

        print ('Time for epoch {} is {} sec Generator Loss: {},  Discriminator_loss: {}'
               .format(epoch + 1, time.time()-start, cur_gen_loss, cur_dis_loss))

        # Save the model every 15 epochs
        if (epoch + 1) % 15 == 0:
            checkpoint.save(file_prefix = checkpoint_prefix)

    return history, history_val

# %% [markdown]
# ## Visualization

# %%
def plot_history(history, history_val):
    metrics = ["gen_loss","dis_loss","gen_mse_loss", 'mse','mae','mape','rmse','ar']
    for i, metric_name in enumerate(metrics):  
        plt.figure()
        plt.title(metric_name)
        plt.plot(history[i], label='train')
        plt.plot(history_val[i], label='test')
        plt.legend()
    plt.show()

# %%
def plot_frame(sequence, target, model):
    y_pred = model.predict(sequence)[...,3]
    y_true = target[...,3]

    plt.figure()
    plt.title("closing price")
    plt.plot(y_true, label="true")
    plt.plot(y_pred, label="prediction")
    plt.legend()
    plt.show()

# %%
def get_best_results(history):
    min_index = np.argmin(history[3, :])
    return history[:, min_index]

# %% [markdown]
# ## Variables

# %%
window = 5
n_sequence = window
n_features = 7
n_batch = 50

# %% [markdown]
# ## Data loading

# %%
stock_code = "IBM"
start = dt.datetime(2000, 1, 1)
end = dt.datetime(2020, 12, 31)
raw_data = pdr.get_data_yahoo(stock_code, start, end,threads=False, proxy="http://127.0.0.1:7890")
df = raw_data.dropna();
df = df.reset_index(level=0)
df = add_Ma(df, window)
df

# %%
for epochs in [200, 450, 700, 950]:
    start_time = datetime.datetime.now()
    df = add_Ma(df)
    data_gen_train, data_gen_test = get_gen_train_test(df, n_sequence, n_batch)

    generator = make_generator_model(n_sequence, n_features)
    discriminator=make_discriminator_model(n_features)

    learning_rate=1e-4
    generator_optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.5)
    discriminator_optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.5)

    @tf.function
    def train_step(sequences, sequences_end):
      return train_step_def(sequences, sequences_end)

    @tf.function
    def test_step(sequences, sequences_end):
      return test_step_def(sequences, sequences_end)

    checkpoint_dir = './training_checkpoints'+stock_code
    checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
    checkpoint = tf.train.Checkpoint(generator_optimizer=generator_optimizer,
                                     discriminator_optimizer=discriminator_optimizer,
                                     generator=generator,
                                     discriminator=discriminator)

    history, history_val = train(data_gen_train, data_gen_test, epochs)

    plot_history(history, history_val)
    plot_frame(*data_gen_test[0], generator)

    print("[MSE Baseline] train:",mean_squared_error(data_gen_train)," test:", mean_squared_error(data_gen_test))
    now = datetime.datetime.now()
    delta = now - start_time
    print("Delta time with epochs = {0}:".format(epochs), delta)
    generator.save("rnn_ffnn_epochs_{0}.h5".format(epochs))
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5, 7)]            0
#
#  simple_rnn (SimpleRNN)      (None, 5, 10)             180
#
#  batch_normalization (BatchN  (None, 5, 10)            40
#  ormalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 5, 10)             0
#
#  dropout (Dropout)           (None, 5, 10)             0
#
#  simple_rnn_1 (SimpleRNN)    (None, 10)                210
#
#  batch_normalization_1 (Batc  (None, 10)               40
#  hNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 10)                0
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense (Dense)               (None, 7)                 77
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 7)                 0
#
# =================================================================
# Total params: 547
# Trainable params: 507
# Non-trainable params: 40
# _________________________________________________________________
# Time for epoch 1 is 6.62726092338562 sec Generator Loss: 0.7549434900283813,  Discriminator_loss: 1.3718514442443848
# Time for epoch 2 is 0.6797389984130859 sec Generator Loss: 0.7581689357757568,  Discriminator_loss: 1.3370616436004639
# Time for epoch 3 is 0.6984062194824219 sec Generator Loss: 0.7934291362762451,  Discriminator_loss: 1.280360221862793
# Time for epoch 4 is 0.7100324630737305 sec Generator Loss: 0.8741040229797363,  Discriminator_loss: 1.1843594312667847
# Time for epoch 5 is 0.7987959384918213 sec Generator Loss: 0.9705907106399536,  Discriminator_loss: 1.0960819721221924
# Time for epoch 6 is 0.8733289241790771 sec Generator Loss: 1.0840282440185547,  Discriminator_loss: 1.0085480213165283
# Time for epoch 7 is 0.845405101776123 sec Generator Loss: 1.1831845045089722,  Discriminator_loss: 0.9516855478286743
# Time for epoch 8 is 0.7960786819458008 sec Generator Loss: 1.2534821033477783,  Discriminator_loss: 0.9393543601036072
# Time for epoch 9 is 0.7972836494445801 sec Generator Loss: 1.337907314300537,  Discriminator_loss: 0.9166068434715271
# Time for epoch 10 is 0.7921707630157471 sec Generator Loss: 1.3436907529830933,  Discriminator_loss: 0.9471403360366821
# Time for epoch 11 is 0.7984533309936523 sec Generator Loss: 1.3360320329666138,  Discriminator_loss: 0.9754338264465332
# Time for epoch 12 is 0.9631330966949463 sec Generator Loss: 1.3518853187561035,  Discriminator_loss: 0.9616005420684814
# Time for epoch 13 is 0.7908320426940918 sec Generator Loss: 1.386033296585083,  Discriminator_loss: 1.0095020532608032
# Time for epoch 14 is 0.7702724933624268 sec Generator Loss: 1.38289475440979,  Discriminator_loss: 0.9764329791069031
# Time for epoch 15 is 0.7983264923095703 sec Generator Loss: 1.3231738805770874,  Discriminator_loss: 0.9754847884178162
# Time for epoch 16 is 0.8458652496337891 sec Generator Loss: 1.3134609460830688,  Discriminator_loss: 1.0037685632705688
# Time for epoch 17 is 0.7793617248535156 sec Generator Loss: 1.3460670709609985,  Discriminator_loss: 1.0021083354949951
# Time for epoch 18 is 0.7835173606872559 sec Generator Loss: 1.3433728218078613,  Discriminator_loss: 1.0238673686981201
# Time for epoch 19 is 0.7876131534576416 sec Generator Loss: 1.3069875240325928,  Discriminator_loss: 1.0274792909622192
# Time for epoch 20 is 0.7697243690490723 sec Generator Loss: 1.3129839897155762,  Discriminator_loss: 1.0154361724853516
# Time for epoch 21 is 0.7745320796966553 sec Generator Loss: 1.2884938716888428,  Discriminator_loss: 1.0387049913406372
# Time for epoch 22 is 0.7797327041625977 sec Generator Loss: 1.305208444595337,  Discriminator_loss: 1.0164633989334106
# Time for epoch 23 is 0.8140969276428223 sec Generator Loss: 1.2679036855697632,  Discriminator_loss: 1.050907850265503
# Time for epoch 24 is 0.7852487564086914 sec Generator Loss: 1.2480964660644531,  Discriminator_loss: 1.0448215007781982
# Time for epoch 25 is 0.8013348579406738 sec Generator Loss: 1.2553294897079468,  Discriminator_loss: 1.0427677631378174
# Time for epoch 26 is 0.7766008377075195 sec Generator Loss: 1.2218350172042847,  Discriminator_loss: 1.0550146102905273
# Time for epoch 27 is 0.7791001796722412 sec Generator Loss: 1.2284692525863647,  Discriminator_loss: 1.0420606136322021
# Time for epoch 28 is 0.786801815032959 sec Generator Loss: 1.2250406742095947,  Discriminator_loss: 1.0473201274871826
# Time for epoch 29 is 0.7773504257202148 sec Generator Loss: 1.2245981693267822,  Discriminator_loss: 1.0448660850524902
# Time for epoch 30 is 0.787708044052124 sec Generator Loss: 1.2294689416885376,  Discriminator_loss: 1.0280208587646484
# Time for epoch 31 is 0.7866342067718506 sec Generator Loss: 1.1842049360275269,  Discriminator_loss: 1.058951497077942
# Time for epoch 32 is 0.7904784679412842 sec Generator Loss: 1.1961432695388794,  Discriminator_loss: 1.0416462421417236
# Time for epoch 33 is 0.7590901851654053 sec Generator Loss: 1.1784065961837769,  Discriminator_loss: 1.0609416961669922
# Time for epoch 34 is 0.7310717105865479 sec Generator Loss: 1.1638222932815552,  Discriminator_loss: 1.075332760810852
# Time for epoch 35 is 0.7141995429992676 sec Generator Loss: 1.181941270828247,  Discriminator_loss: 1.071643590927124
# Time for epoch 36 is 0.7219476699829102 sec Generator Loss: 1.1603819131851196,  Discriminator_loss: 1.0828980207443237
# Time for epoch 37 is 0.7652106285095215 sec Generator Loss: 1.1410598754882812,  Discriminator_loss: 1.0986772775650024
# Time for epoch 38 is 0.7514255046844482 sec Generator Loss: 1.1373118162155151,  Discriminator_loss: 1.1124025583267212
# Time for epoch 39 is 0.7590329647064209 sec Generator Loss: 1.12721848487854,  Discriminator_loss: 1.1255898475646973
# Time for epoch 40 is 0.7636897563934326 sec Generator Loss: 1.1047829389572144,  Discriminator_loss: 1.1622873544692993
# Time for epoch 41 is 0.8018455505371094 sec Generator Loss: 1.0869942903518677,  Discriminator_loss: 1.1593596935272217
# Time for epoch 42 is 0.7616174221038818 sec Generator Loss: 1.0649007558822632,  Discriminator_loss: 1.1648404598236084
# Time for epoch 43 is 0.7417910099029541 sec Generator Loss: 1.0754766464233398,  Discriminator_loss: 1.1767258644104004
# Time for epoch 44 is 0.7373063564300537 sec Generator Loss: 1.0613163709640503,  Discriminator_loss: 1.18451726436615
# Time for epoch 45 is 0.7227327823638916 sec Generator Loss: 1.0643203258514404,  Discriminator_loss: 1.178910255432129
# Time for epoch 46 is 0.7115762233734131 sec Generator Loss: 1.0478839874267578,  Discriminator_loss: 1.1722369194030762
# Time for epoch 47 is 0.7238266468048096 sec Generator Loss: 1.0474215745925903,  Discriminator_loss: 1.1872721910476685
# Time for epoch 48 is 0.7218132019042969 sec Generator Loss: 1.0455151796340942,  Discriminator_loss: 1.182425856590271
# Time for epoch 49 is 0.7112729549407959 sec Generator Loss: 1.0426136255264282,  Discriminator_loss: 1.1824332475662231
# Time for epoch 50 is 0.7095201015472412 sec Generator Loss: 1.0437157154083252,  Discriminator_loss: 1.1877505779266357
# Time for epoch 51 is 0.7192604541778564 sec Generator Loss: 1.0258264541625977,  Discriminator_loss: 1.189701795578003
# Time for epoch 52 is 0.7139902114868164 sec Generator Loss: 1.0251085758209229,  Discriminator_loss: 1.1930056810379028
# Time for epoch 53 is 0.7261698246002197 sec Generator Loss: 1.0240870714187622,  Discriminator_loss: 1.205265998840332
# Time for epoch 54 is 0.7242453098297119 sec Generator Loss: 1.012535572052002,  Discriminator_loss: 1.207343578338623
# Time for epoch 55 is 0.717644214630127 sec Generator Loss: 1.011589765548706,  Discriminator_loss: 1.213531494140625
# Time for epoch 56 is 0.7282416820526123 sec Generator Loss: 1.0122714042663574,  Discriminator_loss: 1.213888168334961
# Time for epoch 57 is 0.726346492767334 sec Generator Loss: 1.007582187652588,  Discriminator_loss: 1.2242459058761597
# Time for epoch 58 is 0.7175664901733398 sec Generator Loss: 0.9812235832214355,  Discriminator_loss: 1.2124429941177368
# Time for epoch 59 is 0.7208449840545654 sec Generator Loss: 0.9696910381317139,  Discriminator_loss: 1.2318711280822754
# Time for epoch 60 is 0.7276878356933594 sec Generator Loss: 0.9789727330207825,  Discriminator_loss: 1.232420802116394
# Time for epoch 61 is 0.7620823383331299 sec Generator Loss: 0.9808563590049744,  Discriminator_loss: 1.2313176393508911
# Time for epoch 62 is 0.7559571266174316 sec Generator Loss: 0.9777552485466003,  Discriminator_loss: 1.235451340675354
# Time for epoch 63 is 0.7139797210693359 sec Generator Loss: 0.9642031788825989,  Discriminator_loss: 1.230276107788086
# Time for epoch 64 is 0.7201366424560547 sec Generator Loss: 0.9785863161087036,  Discriminator_loss: 1.2301539182662964
# Time for epoch 65 is 0.7257158756256104 sec Generator Loss: 0.9830560088157654,  Discriminator_loss: 1.2302087545394897
# Time for epoch 66 is 0.7210488319396973 sec Generator Loss: 0.9665801525115967,  Discriminator_loss: 1.2434484958648682
# Time for epoch 67 is 0.718766450881958 sec Generator Loss: 0.984687328338623,  Discriminator_loss: 1.2270135879516602
# Time for epoch 68 is 0.7228319644927979 sec Generator Loss: 0.9682835936546326,  Discriminator_loss: 1.245456576347351
# Time for epoch 69 is 0.7195479869842529 sec Generator Loss: 0.9748766422271729,  Discriminator_loss: 1.2283297777175903
# Time for epoch 70 is 0.7208633422851562 sec Generator Loss: 0.9796379804611206,  Discriminator_loss: 1.2355700731277466
# Time for epoch 71 is 0.7345726490020752 sec Generator Loss: 0.9637115597724915,  Discriminator_loss: 1.2469068765640259
# Time for epoch 72 is 0.7173073291778564 sec Generator Loss: 0.9624949097633362,  Discriminator_loss: 1.2456740140914917
# Time for epoch 73 is 0.7242770195007324 sec Generator Loss: 0.9669403433799744,  Discriminator_loss: 1.237768292427063
# Time for epoch 74 is 0.7246506214141846 sec Generator Loss: 0.9674663543701172,  Discriminator_loss: 1.244278907775879
# Time for epoch 75 is 0.7151069641113281 sec Generator Loss: 0.958793580532074,  Discriminator_loss: 1.2457952499389648
# Time for epoch 76 is 0.7150325775146484 sec Generator Loss: 0.9628103375434875,  Discriminator_loss: 1.2412056922912598
# Time for epoch 77 is 0.7288417816162109 sec Generator Loss: 0.9592599868774414,  Discriminator_loss: 1.246817708015442
# Time for epoch 78 is 0.7166357040405273 sec Generator Loss: 0.9615418314933777,  Discriminator_loss: 1.246721863746643
# Time for epoch 79 is 0.7213256359100342 sec Generator Loss: 0.9466272592544556,  Discriminator_loss: 1.245124101638794
# Time for epoch 80 is 0.7834482192993164 sec Generator Loss: 0.9612971544265747,  Discriminator_loss: 1.2476006746292114
# Time for epoch 81 is 0.7191140651702881 sec Generator Loss: 0.9514860510826111,  Discriminator_loss: 1.2558801174163818
# Time for epoch 82 is 0.7213432788848877 sec Generator Loss: 0.9525569081306458,  Discriminator_loss: 1.2421661615371704
# Time for epoch 83 is 0.7196893692016602 sec Generator Loss: 0.9565013647079468,  Discriminator_loss: 1.2462705373764038
# Time for epoch 84 is 0.7152566909790039 sec Generator Loss: 0.9386798739433289,  Discriminator_loss: 1.252058982849121
# Time for epoch 85 is 0.7395520210266113 sec Generator Loss: 0.9462401866912842,  Discriminator_loss: 1.2608798742294312
# Time for epoch 86 is 0.7655341625213623 sec Generator Loss: 0.9569683074951172,  Discriminator_loss: 1.2392094135284424
# Time for epoch 87 is 0.7436556816101074 sec Generator Loss: 0.9458422660827637,  Discriminator_loss: 1.2626163959503174
# Time for epoch 88 is 0.7257776260375977 sec Generator Loss: 0.9550274610519409,  Discriminator_loss: 1.2633603811264038
# Time for epoch 89 is 0.7389140129089355 sec Generator Loss: 0.9381224513053894,  Discriminator_loss: 1.2642194032669067
# Time for epoch 90 is 0.7251367568969727 sec Generator Loss: 0.9370856881141663,  Discriminator_loss: 1.2695201635360718
# Time for epoch 91 is 0.7252447605133057 sec Generator Loss: 0.9333530068397522,  Discriminator_loss: 1.278325080871582
# Time for epoch 92 is 0.7150490283966064 sec Generator Loss: 0.9209592342376709,  Discriminator_loss: 1.2726482152938843
# Time for epoch 93 is 0.7429869174957275 sec Generator Loss: 0.9229317903518677,  Discriminator_loss: 1.2700905799865723
# Time for epoch 94 is 0.7488300800323486 sec Generator Loss: 0.9306325316429138,  Discriminator_loss: 1.268868088722229
# Time for epoch 95 is 0.7696194648742676 sec Generator Loss: 0.9296376705169678,  Discriminator_loss: 1.2641717195510864
# Time for epoch 96 is 0.7545702457427979 sec Generator Loss: 0.9212519526481628,  Discriminator_loss: 1.283823013305664
# Time for epoch 97 is 0.7286710739135742 sec Generator Loss: 0.9120298624038696,  Discriminator_loss: 1.2863739728927612
# Time for epoch 98 is 0.7220065593719482 sec Generator Loss: 0.9198070168495178,  Discriminator_loss: 1.2753398418426514
# Time for epoch 99 is 0.7777729034423828 sec Generator Loss: 0.9117594957351685,  Discriminator_loss: 1.2746111154556274
# Time for epoch 100 is 0.8973433971405029 sec Generator Loss: 0.9159390926361084,  Discriminator_loss: 1.2833694219589233
# Time for epoch 101 is 0.7250797748565674 sec Generator Loss: 0.9131738543510437,  Discriminator_loss: 1.2784881591796875
# Time for epoch 102 is 0.7282345294952393 sec Generator Loss: 0.9121372103691101,  Discriminator_loss: 1.279585361480713
# Time for epoch 103 is 0.7212650775909424 sec Generator Loss: 0.9110657572746277,  Discriminator_loss: 1.2849313020706177
# Time for epoch 104 is 0.7237851619720459 sec Generator Loss: 0.9191675782203674,  Discriminator_loss: 1.2856905460357666
# Time for epoch 105 is 0.7156319618225098 sec Generator Loss: 0.903859555721283,  Discriminator_loss: 1.2843255996704102
# Time for epoch 106 is 0.7227702140808105 sec Generator Loss: 0.9030571579933167,  Discriminator_loss: 1.281898856163025
# Time for epoch 107 is 0.7589647769927979 sec Generator Loss: 0.9110004305839539,  Discriminator_loss: 1.2683147192001343
# Time for epoch 108 is 0.7197067737579346 sec Generator Loss: 0.9168434143066406,  Discriminator_loss: 1.2759573459625244
# Time for epoch 109 is 0.7221517562866211 sec Generator Loss: 0.8960528373718262,  Discriminator_loss: 1.2825547456741333
# Time for epoch 110 is 0.7259640693664551 sec Generator Loss: 0.9119303226470947,  Discriminator_loss: 1.2812904119491577
# Time for epoch 111 is 0.7148776054382324 sec Generator Loss: 0.9078890681266785,  Discriminator_loss: 1.2787933349609375
# Time for epoch 112 is 0.742002010345459 sec Generator Loss: 0.9097908139228821,  Discriminator_loss: 1.2838555574417114
# Time for epoch 113 is 0.7449862957000732 sec Generator Loss: 0.9068628549575806,  Discriminator_loss: 1.285685658454895
# Time for epoch 114 is 0.75217604637146 sec Generator Loss: 0.8942545056343079,  Discriminator_loss: 1.2954550981521606
# Time for epoch 115 is 0.7670567035675049 sec Generator Loss: 0.8987749814987183,  Discriminator_loss: 1.2842925786972046
# Time for epoch 116 is 0.8159139156341553 sec Generator Loss: 0.9019002318382263,  Discriminator_loss: 1.2902649641036987
# Time for epoch 117 is 0.7658624649047852 sec Generator Loss: 0.9017155766487122,  Discriminator_loss: 1.2860767841339111
# Time for epoch 118 is 0.7419588565826416 sec Generator Loss: 0.9030767679214478,  Discriminator_loss: 1.2823927402496338
# Time for epoch 119 is 0.7197248935699463 sec Generator Loss: 0.8993721604347229,  Discriminator_loss: 1.2840635776519775
# Time for epoch 120 is 0.7226405143737793 sec Generator Loss: 0.9100045561790466,  Discriminator_loss: 1.2842200994491577
# Time for epoch 121 is 0.7202506065368652 sec Generator Loss: 0.9105168581008911,  Discriminator_loss: 1.2763235569000244
# Time for epoch 122 is 0.7199883460998535 sec Generator Loss: 0.911495566368103,  Discriminator_loss: 1.2769368886947632
# Time for epoch 123 is 0.7232716083526611 sec Generator Loss: 0.9034396409988403,  Discriminator_loss: 1.2806121110916138
# Time for epoch 124 is 0.7185144424438477 sec Generator Loss: 0.8954979181289673,  Discriminator_loss: 1.2868479490280151
# Time for epoch 125 is 0.7372992038726807 sec Generator Loss: 0.8942992091178894,  Discriminator_loss: 1.2851536273956299
# Time for epoch 126 is 0.7698140144348145 sec Generator Loss: 0.903151273727417,  Discriminator_loss: 1.2914332151412964
# Time for epoch 127 is 0.76481032371521 sec Generator Loss: 0.8863186836242676,  Discriminator_loss: 1.287988543510437
# Time for epoch 128 is 0.7500026226043701 sec Generator Loss: 0.8850702047348022,  Discriminator_loss: 1.2848693132400513
# Time for epoch 129 is 0.7599105834960938 sec Generator Loss: 0.8877187371253967,  Discriminator_loss: 1.2810510396957397
# Time for epoch 130 is 0.7478816509246826 sec Generator Loss: 0.8923378586769104,  Discriminator_loss: 1.286746621131897
# Time for epoch 131 is 0.7628462314605713 sec Generator Loss: 0.9000479578971863,  Discriminator_loss: 1.3012797832489014
# Time for epoch 132 is 0.7676401138305664 sec Generator Loss: 0.8967972993850708,  Discriminator_loss: 1.2795308828353882
# Time for epoch 133 is 0.7710111141204834 sec Generator Loss: 0.8897349834442139,  Discriminator_loss: 1.2910621166229248
# Time for epoch 134 is 0.7253103256225586 sec Generator Loss: 0.909132719039917,  Discriminator_loss: 1.279375672340393
# Time for epoch 135 is 0.7233681678771973 sec Generator Loss: 0.9011343717575073,  Discriminator_loss: 1.2876715660095215
# Time for epoch 136 is 0.7155213356018066 sec Generator Loss: 0.8862742185592651,  Discriminator_loss: 1.2946017980575562
# Time for epoch 137 is 0.7276010513305664 sec Generator Loss: 0.8940612077713013,  Discriminator_loss: 1.286010503768921
# Time for epoch 138 is 0.7344563007354736 sec Generator Loss: 0.8834380507469177,  Discriminator_loss: 1.2794429063796997
# Time for epoch 139 is 0.7222518920898438 sec Generator Loss: 0.9029890298843384,  Discriminator_loss: 1.2871865034103394
# Time for epoch 140 is 0.7211446762084961 sec Generator Loss: 0.9026368260383606,  Discriminator_loss: 1.2825969457626343
# Time for epoch 141 is 0.7245831489562988 sec Generator Loss: 0.8916850090026855,  Discriminator_loss: 1.292471170425415
# Time for epoch 142 is 0.7202427387237549 sec Generator Loss: 0.8863535523414612,  Discriminator_loss: 1.293021321296692
# Time for epoch 143 is 0.7276015281677246 sec Generator Loss: 0.8866969347000122,  Discriminator_loss: 1.2877999544143677
# Time for epoch 144 is 0.7247364521026611 sec Generator Loss: 0.8920177817344666,  Discriminator_loss: 1.2925596237182617
# Time for epoch 145 is 0.7256982326507568 sec Generator Loss: 0.8752502202987671,  Discriminator_loss: 1.298071026802063
# Time for epoch 146 is 0.7296490669250488 sec Generator Loss: 0.8815360069274902,  Discriminator_loss: 1.295062780380249
# Time for epoch 147 is 0.7201056480407715 sec Generator Loss: 0.8853788375854492,  Discriminator_loss: 1.2952861785888672
# Time for epoch 148 is 0.7180290222167969 sec Generator Loss: 0.8779801726341248,  Discriminator_loss: 1.293134093284607
# Time for epoch 149 is 0.7217991352081299 sec Generator Loss: 0.8875632882118225,  Discriminator_loss: 1.293492317199707
# Time for epoch 150 is 0.7182590961456299 sec Generator Loss: 0.893239438533783,  Discriminator_loss: 1.2898080348968506
# Time for epoch 151 is 0.7238314151763916 sec Generator Loss: 0.878411591053009,  Discriminator_loss: 1.2922642230987549
# Time for epoch 152 is 0.8016831874847412 sec Generator Loss: 0.8823046684265137,  Discriminator_loss: 1.2899128198623657
# Time for epoch 153 is 0.7183835506439209 sec Generator Loss: 0.8878018260002136,  Discriminator_loss: 1.2917113304138184
# Time for epoch 154 is 0.7225637435913086 sec Generator Loss: 0.8732553720474243,  Discriminator_loss: 1.3008267879486084
# Time for epoch 155 is 0.7260580062866211 sec Generator Loss: 0.8862355947494507,  Discriminator_loss: 1.2910207509994507
# Time for epoch 156 is 0.7150733470916748 sec Generator Loss: 0.8816735744476318,  Discriminator_loss: 1.2960948944091797
# Time for epoch 157 is 0.7224175930023193 sec Generator Loss: 0.8884527683258057,  Discriminator_loss: 1.286458134651184
# Time for epoch 158 is 0.7249994277954102 sec Generator Loss: 0.8975619077682495,  Discriminator_loss: 1.2886605262756348
# Time for epoch 159 is 0.7130682468414307 sec Generator Loss: 0.8931430578231812,  Discriminator_loss: 1.2897884845733643
# Time for epoch 160 is 0.7194745540618896 sec Generator Loss: 0.8751609921455383,  Discriminator_loss: 1.2989087104797363
# Time for epoch 161 is 0.7183732986450195 sec Generator Loss: 0.8801829814910889,  Discriminator_loss: 1.303607702255249
# Time for epoch 162 is 0.728041410446167 sec Generator Loss: 0.8931962847709656,  Discriminator_loss: 1.2933586835861206
# Time for epoch 163 is 0.725640058517456 sec Generator Loss: 0.8864539265632629,  Discriminator_loss: 1.2941153049468994
# Time for epoch 164 is 0.7293112277984619 sec Generator Loss: 0.8901572823524475,  Discriminator_loss: 1.2987980842590332
# Time for epoch 165 is 0.8152241706848145 sec Generator Loss: 0.8772276639938354,  Discriminator_loss: 1.2887961864471436
# Time for epoch 166 is 0.8763103485107422 sec Generator Loss: 0.8860084414482117,  Discriminator_loss: 1.2889704704284668
# Time for epoch 167 is 0.9606659412384033 sec Generator Loss: 0.8771469593048096,  Discriminator_loss: 1.3054372072219849
# Time for epoch 168 is 0.8813173770904541 sec Generator Loss: 0.8881635069847107,  Discriminator_loss: 1.2893006801605225
# Time for epoch 169 is 0.838184118270874 sec Generator Loss: 0.8881756067276001,  Discriminator_loss: 1.2916927337646484
# Time for epoch 170 is 0.7780787944793701 sec Generator Loss: 0.8879159688949585,  Discriminator_loss: 1.2970473766326904
# Time for epoch 171 is 0.7998569011688232 sec Generator Loss: 0.8912417888641357,  Discriminator_loss: 1.2950444221496582
# Time for epoch 172 is 0.7940495014190674 sec Generator Loss: 0.8802863359451294,  Discriminator_loss: 1.3040708303451538
# Time for epoch 173 is 0.8011593818664551 sec Generator Loss: 0.8767834901809692,  Discriminator_loss: 1.3002099990844727
# Time for epoch 174 is 0.7874531745910645 sec Generator Loss: 0.890947163105011,  Discriminator_loss: 1.2947149276733398
# Time for epoch 175 is 0.7402951717376709 sec Generator Loss: 0.8820320963859558,  Discriminator_loss: 1.297878623008728
# Time for epoch 176 is 0.7202832698822021 sec Generator Loss: 0.8900042772293091,  Discriminator_loss: 1.2877941131591797
# Time for epoch 177 is 0.728184700012207 sec Generator Loss: 0.8770434260368347,  Discriminator_loss: 1.2983763217926025
# Time for epoch 178 is 0.7229158878326416 sec Generator Loss: 0.8860509395599365,  Discriminator_loss: 1.2978414297103882
# Time for epoch 179 is 0.7770001888275146 sec Generator Loss: 0.8836593627929688,  Discriminator_loss: 1.293391227722168
# Time for epoch 180 is 0.7694790363311768 sec Generator Loss: 0.8752117156982422,  Discriminator_loss: 1.2932101488113403
# Time for epoch 181 is 0.7920677661895752 sec Generator Loss: 0.8823583126068115,  Discriminator_loss: 1.2966670989990234
# Time for epoch 182 is 0.9030711650848389 sec Generator Loss: 0.869429886341095,  Discriminator_loss: 1.3007621765136719
# Time for epoch 183 is 0.8703839778900146 sec Generator Loss: 0.8749806880950928,  Discriminator_loss: 1.2933849096298218
# Time for epoch 184 is 0.762129545211792 sec Generator Loss: 0.8775960206985474,  Discriminator_loss: 1.3045159578323364
# Time for epoch 185 is 0.7855579853057861 sec Generator Loss: 0.8884345889091492,  Discriminator_loss: 1.296504020690918
# Time for epoch 186 is 0.7930998802185059 sec Generator Loss: 0.8796952962875366,  Discriminator_loss: 1.3043053150177002
# Time for epoch 187 is 0.7097899913787842 sec Generator Loss: 0.8706517815589905,  Discriminator_loss: 1.302829623222351
# Time for epoch 188 is 0.7065684795379639 sec Generator Loss: 0.8735093474388123,  Discriminator_loss: 1.2996326684951782
# Time for epoch 189 is 0.6826426982879639 sec Generator Loss: 0.8798409700393677,  Discriminator_loss: 1.2938801050186157
# Time for epoch 190 is 0.6991486549377441 sec Generator Loss: 0.8789404034614563,  Discriminator_loss: 1.2967652082443237
# Time for epoch 191 is 0.6768078804016113 sec Generator Loss: 0.8761366009712219,  Discriminator_loss: 1.2937369346618652
# Time for epoch 192 is 0.6987192630767822 sec Generator Loss: 0.8837506175041199,  Discriminator_loss: 1.295029878616333
# Time for epoch 193 is 0.7238304615020752 sec Generator Loss: 0.883822500705719,  Discriminator_loss: 1.3030575513839722
# Time for epoch 194 is 0.7045056819915771 sec Generator Loss: 0.8726086020469666,  Discriminator_loss: 1.3040341138839722
# Time for epoch 195 is 0.673701286315918 sec Generator Loss: 0.8799999952316284,  Discriminator_loss: 1.296687126159668
# Time for epoch 196 is 0.6551697254180908 sec Generator Loss: 0.8700897693634033,  Discriminator_loss: 1.3090384006500244
# Time for epoch 197 is 0.6879162788391113 sec Generator Loss: 0.8730843663215637,  Discriminator_loss: 1.3034781217575073
# Time for epoch 198 is 0.7177550792694092 sec Generator Loss: 0.879638671875,  Discriminator_loss: 1.2955118417739868
# Time for epoch 199 is 0.733238935470581 sec Generator Loss: 0.8677919507026672,  Discriminator_loss: 1.3046406507492065
# Time for epoch 200 is 0.6656031608581543 sec Generator Loss: 0.8801891803741455,  Discriminator_loss: 1.3045352697372437
# 2/2 [==============================] - 0s 3ms/step
# [MSE Baseline] train: 4.597040181619752  test: 4.988566607603537
# Delta time with epochs = 200: 0:02:39.712537
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 5, 7)]            0
#
#  simple_rnn_2 (SimpleRNN)    (None, 5, 10)             180
#
#  batch_normalization_2 (Batc  (None, 5, 10)            40
#  hNormalization)
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 5, 10)             0
#
#  dropout_5 (Dropout)         (None, 5, 10)             0
#
#  simple_rnn_3 (SimpleRNN)    (None, 10)                210
#
#  batch_normalization_3 (Batc  (None, 10)               40
#  hNormalization)
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 10)                0
#
#  dropout_6 (Dropout)         (None, 10)                0
#
#  dense_5 (Dense)             (None, 7)                 77
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 7)                 0
#
# =================================================================
# Total params: 547
# Trainable params: 507
# Non-trainable params: 40
# _________________________________________________________________
# Time for epoch 1 is 7.333516597747803 sec Generator Loss: 0.7263522744178772,  Discriminator_loss: 1.3604862689971924
# Time for epoch 2 is 0.6899504661560059 sec Generator Loss: 0.7235627174377441,  Discriminator_loss: 1.3016977310180664
# Time for epoch 3 is 0.6782138347625732 sec Generator Loss: 0.7468301057815552,  Discriminator_loss: 1.2127811908721924
# Time for epoch 4 is 0.6842882633209229 sec Generator Loss: 0.8082401156425476,  Discriminator_loss: 1.12599515914917
# Time for epoch 5 is 0.6810963153839111 sec Generator Loss: 0.8706265687942505,  Discriminator_loss: 1.070373773574829
# Time for epoch 6 is 0.6647577285766602 sec Generator Loss: 0.9362231492996216,  Discriminator_loss: 1.0472952127456665
# Time for epoch 7 is 0.6579127311706543 sec Generator Loss: 1.0056583881378174,  Discriminator_loss: 1.0252561569213867
# Time for epoch 8 is 0.6742243766784668 sec Generator Loss: 1.0510687828063965,  Discriminator_loss: 1.007592797279358
# Time for epoch 9 is 0.6625955104827881 sec Generator Loss: 1.0850235223770142,  Discriminator_loss: 1.0109707117080688
# Time for epoch 10 is 0.7072122097015381 sec Generator Loss: 1.125859260559082,  Discriminator_loss: 0.9984603524208069
# Time for epoch 11 is 0.6744112968444824 sec Generator Loss: 1.133893609046936,  Discriminator_loss: 1.003636121749878
# Time for epoch 12 is 0.6520800590515137 sec Generator Loss: 1.1486101150512695,  Discriminator_loss: 1.0015202760696411
# Time for epoch 13 is 0.6577677726745605 sec Generator Loss: 1.1939926147460938,  Discriminator_loss: 0.9836159944534302
# Time for epoch 14 is 0.6566212177276611 sec Generator Loss: 1.201694130897522,  Discriminator_loss: 0.9876629114151001
# Time for epoch 15 is 0.7117884159088135 sec Generator Loss: 1.2357358932495117,  Discriminator_loss: 0.9691471457481384
# Time for epoch 16 is 0.6803038120269775 sec Generator Loss: 1.220473051071167,  Discriminator_loss: 0.9752998948097229
# Time for epoch 17 is 0.7106268405914307 sec Generator Loss: 1.2538702487945557,  Discriminator_loss: 0.9611573815345764
# Time for epoch 18 is 0.7084062099456787 sec Generator Loss: 1.2426135540008545,  Discriminator_loss: 0.9840088486671448
# Time for epoch 19 is 0.7655003070831299 sec Generator Loss: 1.258995532989502,  Discriminator_loss: 0.9655370116233826
# Time for epoch 20 is 0.6562840938568115 sec Generator Loss: 1.2607142925262451,  Discriminator_loss: 0.9607177972793579
# Time for epoch 21 is 0.6574151515960693 sec Generator Loss: 1.2759459018707275,  Discriminator_loss: 0.9475977420806885
# Time for epoch 22 is 0.6817638874053955 sec Generator Loss: 1.2781654596328735,  Discriminator_loss: 0.9569804072380066
# Time for epoch 23 is 0.6527049541473389 sec Generator Loss: 1.2466745376586914,  Discriminator_loss: 0.9730789065361023
# Time for epoch 24 is 0.6922714710235596 sec Generator Loss: 1.2665164470672607,  Discriminator_loss: 0.9383370280265808
# Time for epoch 25 is 0.6800544261932373 sec Generator Loss: 1.2609823942184448,  Discriminator_loss: 0.9554951190948486
# Time for epoch 26 is 0.6615314483642578 sec Generator Loss: 1.230341911315918,  Discriminator_loss: 0.9703227877616882
# Time for epoch 27 is 0.6552910804748535 sec Generator Loss: 1.27443528175354,  Discriminator_loss: 0.9792044758796692
# Time for epoch 28 is 0.719733476638794 sec Generator Loss: 1.2585110664367676,  Discriminator_loss: 0.9777618050575256
# Time for epoch 29 is 0.6562089920043945 sec Generator Loss: 1.2481153011322021,  Discriminator_loss: 1.0053069591522217
# Time for epoch 30 is 0.6748995780944824 sec Generator Loss: 1.2479175329208374,  Discriminator_loss: 1.0351372957229614
# Time for epoch 31 is 0.6784391403198242 sec Generator Loss: 1.2446258068084717,  Discriminator_loss: 1.040503978729248
# Time for epoch 32 is 0.7454898357391357 sec Generator Loss: 1.2056101560592651,  Discriminator_loss: 1.0867877006530762
# Time for epoch 33 is 0.8201911449432373 sec Generator Loss: 1.2038875818252563,  Discriminator_loss: 1.0781105756759644
# Time for epoch 34 is 0.8019402027130127 sec Generator Loss: 1.1813397407531738,  Discriminator_loss: 1.1043899059295654
# Time for epoch 35 is 0.7668085098266602 sec Generator Loss: 1.159622073173523,  Discriminator_loss: 1.1127986907958984
# Time for epoch 36 is 0.7666301727294922 sec Generator Loss: 1.141261100769043,  Discriminator_loss: 1.1219325065612793
# Time for epoch 37 is 0.792339563369751 sec Generator Loss: 1.137107014656067,  Discriminator_loss: 1.146602988243103
# Time for epoch 38 is 0.7008800506591797 sec Generator Loss: 1.1148055791854858,  Discriminator_loss: 1.1503372192382812
# Time for epoch 39 is 0.7299344539642334 sec Generator Loss: 1.1031979322433472,  Discriminator_loss: 1.160766839981079
# Time for epoch 40 is 0.6992902755737305 sec Generator Loss: 1.0860278606414795,  Discriminator_loss: 1.1644726991653442
# Time for epoch 41 is 0.6605587005615234 sec Generator Loss: 1.0647602081298828,  Discriminator_loss: 1.1846568584442139
# Time for epoch 42 is 0.7193801403045654 sec Generator Loss: 1.0645227432250977,  Discriminator_loss: 1.1757949590682983
# Time for epoch 43 is 0.6653053760528564 sec Generator Loss: 1.0519355535507202,  Discriminator_loss: 1.1905964612960815
# Time for epoch 44 is 0.6822564601898193 sec Generator Loss: 1.045574426651001,  Discriminator_loss: 1.194501519203186
# Time for epoch 45 is 0.6943366527557373 sec Generator Loss: 1.0362879037857056,  Discriminator_loss: 1.184710144996643
# Time for epoch 46 is 0.7110927104949951 sec Generator Loss: 1.023277997970581,  Discriminator_loss: 1.1960936784744263
# Time for epoch 47 is 0.7012698650360107 sec Generator Loss: 1.0265223979949951,  Discriminator_loss: 1.1916784048080444
# Time for epoch 48 is 0.6694421768188477 sec Generator Loss: 1.0189746618270874,  Discriminator_loss: 1.198996663093567
# Time for epoch 49 is 0.6993005275726318 sec Generator Loss: 1.0065170526504517,  Discriminator_loss: 1.2105554342269897
# Time for epoch 50 is 0.991145133972168 sec Generator Loss: 1.0064135789871216,  Discriminator_loss: 1.2109013795852661
# Time for epoch 51 is 0.741581916809082 sec Generator Loss: 1.009611964225769,  Discriminator_loss: 1.2100014686584473
# Time for epoch 52 is 0.6757497787475586 sec Generator Loss: 1.008623480796814,  Discriminator_loss: 1.2143124341964722
# Time for epoch 53 is 0.6609020233154297 sec Generator Loss: 0.9870527386665344,  Discriminator_loss: 1.2242138385772705
# Time for epoch 54 is 0.6674251556396484 sec Generator Loss: 0.9846628904342651,  Discriminator_loss: 1.227191686630249
# Time for epoch 55 is 0.6829643249511719 sec Generator Loss: 0.9821076989173889,  Discriminator_loss: 1.222124457359314
# Time for epoch 56 is 0.695542573928833 sec Generator Loss: 0.9691953063011169,  Discriminator_loss: 1.239060878753662
# Time for epoch 57 is 0.6828262805938721 sec Generator Loss: 0.9682479500770569,  Discriminator_loss: 1.2222720384597778
# Time for epoch 58 is 0.68648362159729 sec Generator Loss: 0.9686843156814575,  Discriminator_loss: 1.2261909246444702
# Time for epoch 59 is 0.6695272922515869 sec Generator Loss: 0.962805449962616,  Discriminator_loss: 1.2423012256622314
# Time for epoch 60 is 0.6949818134307861 sec Generator Loss: 0.9599975943565369,  Discriminator_loss: 1.2367193698883057
# Time for epoch 61 is 0.6980249881744385 sec Generator Loss: 0.9592779278755188,  Discriminator_loss: 1.2310422658920288
# Time for epoch 62 is 0.6614041328430176 sec Generator Loss: 0.9656109809875488,  Discriminator_loss: 1.2406189441680908
# Time for epoch 63 is 0.6615123748779297 sec Generator Loss: 0.9650058150291443,  Discriminator_loss: 1.2315484285354614
# Time for epoch 64 is 0.669919490814209 sec Generator Loss: 0.9637747406959534,  Discriminator_loss: 1.2321304082870483
# Time for epoch 65 is 0.681100606918335 sec Generator Loss: 0.951554000377655,  Discriminator_loss: 1.246728539466858
# Time for epoch 66 is 0.7736327648162842 sec Generator Loss: 0.9449521899223328,  Discriminator_loss: 1.2524341344833374
# Time for epoch 67 is 0.7849791049957275 sec Generator Loss: 0.934357762336731,  Discriminator_loss: 1.2594566345214844
# Time for epoch 68 is 0.873039960861206 sec Generator Loss: 0.9330880641937256,  Discriminator_loss: 1.2565672397613525
# Time for epoch 69 is 0.8341009616851807 sec Generator Loss: 0.93841952085495,  Discriminator_loss: 1.2539231777191162
# Time for epoch 70 is 0.8403360843658447 sec Generator Loss: 0.9373548626899719,  Discriminator_loss: 1.2623058557510376
# Time for epoch 71 is 0.8467707633972168 sec Generator Loss: 0.9314451217651367,  Discriminator_loss: 1.2517086267471313
# Time for epoch 72 is 0.8099148273468018 sec Generator Loss: 0.9475211501121521,  Discriminator_loss: 1.2523308992385864
# Time for epoch 73 is 0.8449587821960449 sec Generator Loss: 0.9329512715339661,  Discriminator_loss: 1.2642995119094849
# Time for epoch 74 is 0.765967845916748 sec Generator Loss: 0.9218186736106873,  Discriminator_loss: 1.2678742408752441
# Time for epoch 75 is 0.8461711406707764 sec Generator Loss: 0.9332682490348816,  Discriminator_loss: 1.254220962524414
# Time for epoch 76 is 0.8291306495666504 sec Generator Loss: 0.9366853833198547,  Discriminator_loss: 1.2564048767089844
# Time for epoch 77 is 0.7725980281829834 sec Generator Loss: 0.9295993447303772,  Discriminator_loss: 1.2736984491348267
# Time for epoch 78 is 0.7165672779083252 sec Generator Loss: 0.9334600567817688,  Discriminator_loss: 1.2788556814193726
# Time for epoch 79 is 0.7845771312713623 sec Generator Loss: 0.9187144637107849,  Discriminator_loss: 1.2826191186904907
# Time for epoch 80 is 0.7301182746887207 sec Generator Loss: 0.9107500314712524,  Discriminator_loss: 1.2804807424545288
# Time for epoch 81 is 0.7538266181945801 sec Generator Loss: 0.9141203761100769,  Discriminator_loss: 1.2706912755966187
# Time for epoch 82 is 0.6922237873077393 sec Generator Loss: 0.9185952544212341,  Discriminator_loss: 1.2785784006118774
# Time for epoch 83 is 0.6813077926635742 sec Generator Loss: 0.915770411491394,  Discriminator_loss: 1.2826379537582397
# Time for epoch 84 is 0.7140541076660156 sec Generator Loss: 0.9035580158233643,  Discriminator_loss: 1.2784520387649536
# Time for epoch 85 is 0.7258894443511963 sec Generator Loss: 0.908005952835083,  Discriminator_loss: 1.2852829694747925
# Time for epoch 86 is 0.6850793361663818 sec Generator Loss: 0.8940938115119934,  Discriminator_loss: 1.2915966510772705
# Time for epoch 87 is 0.6970016956329346 sec Generator Loss: 0.908442497253418,  Discriminator_loss: 1.2915802001953125
# Time for epoch 88 is 0.6848030090332031 sec Generator Loss: 0.9008966088294983,  Discriminator_loss: 1.2981566190719604
# Time for epoch 89 is 0.6939437389373779 sec Generator Loss: 0.8932082653045654,  Discriminator_loss: 1.3003730773925781
# Time for epoch 90 is 0.686734676361084 sec Generator Loss: 0.8854820728302002,  Discriminator_loss: 1.2997586727142334
# Time for epoch 91 is 0.7461044788360596 sec Generator Loss: 0.898524284362793,  Discriminator_loss: 1.296593189239502
# Time for epoch 92 is 0.7177510261535645 sec Generator Loss: 0.8985238075256348,  Discriminator_loss: 1.2936588525772095
# Time for epoch 93 is 0.7375481128692627 sec Generator Loss: 0.8889302015304565,  Discriminator_loss: 1.2939388751983643
# Time for epoch 94 is 0.7064352035522461 sec Generator Loss: 0.8840048909187317,  Discriminator_loss: 1.3005119562149048
# Time for epoch 95 is 0.7058672904968262 sec Generator Loss: 0.8860723972320557,  Discriminator_loss: 1.3034465312957764
# Time for epoch 96 is 0.7675697803497314 sec Generator Loss: 0.878013551235199,  Discriminator_loss: 1.3069010972976685
# Time for epoch 97 is 0.7835874557495117 sec Generator Loss: 0.8757987022399902,  Discriminator_loss: 1.3061294555664062
# Time for epoch 98 is 0.7925999164581299 sec Generator Loss: 0.8758896589279175,  Discriminator_loss: 1.3017503023147583
# Time for epoch 99 is 0.7619736194610596 sec Generator Loss: 0.8750840425491333,  Discriminator_loss: 1.3036532402038574
# Time for epoch 100 is 0.7018847465515137 sec Generator Loss: 0.8758335709571838,  Discriminator_loss: 1.301277995109558
# Time for epoch 101 is 0.6718618869781494 sec Generator Loss: 0.8744277954101562,  Discriminator_loss: 1.3012751340866089
# Time for epoch 102 is 0.7793471813201904 sec Generator Loss: 0.8809104561805725,  Discriminator_loss: 1.2911508083343506
# Time for epoch 103 is 0.7023687362670898 sec Generator Loss: 0.8802402019500732,  Discriminator_loss: 1.2894810438156128
# Time for epoch 104 is 0.6954555511474609 sec Generator Loss: 0.8755837082862854,  Discriminator_loss: 1.2993593215942383
# Time for epoch 105 is 0.7285492420196533 sec Generator Loss: 0.8741041421890259,  Discriminator_loss: 1.3100669384002686
# Time for epoch 106 is 0.7613582611083984 sec Generator Loss: 0.8856985569000244,  Discriminator_loss: 1.2902297973632812
# Time for epoch 107 is 0.7565693855285645 sec Generator Loss: 0.8695879578590393,  Discriminator_loss: 1.3042783737182617
# Time for epoch 108 is 0.7753791809082031 sec Generator Loss: 0.8732743263244629,  Discriminator_loss: 1.302952766418457
# Time for epoch 109 is 0.6954610347747803 sec Generator Loss: 0.8791217803955078,  Discriminator_loss: 1.294538140296936
# Time for epoch 110 is 0.7354960441589355 sec Generator Loss: 0.8837244510650635,  Discriminator_loss: 1.3035929203033447
# Time for epoch 111 is 0.7486135959625244 sec Generator Loss: 0.8771623969078064,  Discriminator_loss: 1.2952494621276855
# Time for epoch 112 is 0.6781132221221924 sec Generator Loss: 0.874546468257904,  Discriminator_loss: 1.303035020828247
# Time for epoch 113 is 0.6759767532348633 sec Generator Loss: 0.8751834034919739,  Discriminator_loss: 1.3052836656570435
# Time for epoch 114 is 0.6806013584136963 sec Generator Loss: 0.8830095529556274,  Discriminator_loss: 1.2895640134811401
# Time for epoch 115 is 0.6730668544769287 sec Generator Loss: 0.8751926422119141,  Discriminator_loss: 1.2960748672485352
# Time for epoch 116 is 0.6688125133514404 sec Generator Loss: 0.8803772330284119,  Discriminator_loss: 1.2993557453155518
# Time for epoch 117 is 0.6762957572937012 sec Generator Loss: 0.8636834621429443,  Discriminator_loss: 1.307793140411377
# Time for epoch 118 is 0.7056493759155273 sec Generator Loss: 0.8674833178520203,  Discriminator_loss: 1.299697756767273
# Time for epoch 119 is 0.6941661834716797 sec Generator Loss: 0.8706881999969482,  Discriminator_loss: 1.2933571338653564
# Time for epoch 120 is 0.7097718715667725 sec Generator Loss: 0.8706647753715515,  Discriminator_loss: 1.2920180559158325
# Time for epoch 121 is 0.737107515335083 sec Generator Loss: 0.8674723505973816,  Discriminator_loss: 1.30331289768219
# Time for epoch 122 is 0.6894786357879639 sec Generator Loss: 0.8665528297424316,  Discriminator_loss: 1.296415090560913
# Time for epoch 123 is 0.6886661052703857 sec Generator Loss: 0.8780423998832703,  Discriminator_loss: 1.2890297174453735
# Time for epoch 124 is 0.7710318565368652 sec Generator Loss: 0.8775091171264648,  Discriminator_loss: 1.297416090965271
# Time for epoch 125 is 0.6862845420837402 sec Generator Loss: 0.8620246648788452,  Discriminator_loss: 1.3040275573730469
# Time for epoch 126 is 0.6806902885437012 sec Generator Loss: 0.8761312365531921,  Discriminator_loss: 1.3051331043243408
# Time for epoch 127 is 0.7239794731140137 sec Generator Loss: 0.864491879940033,  Discriminator_loss: 1.3014832735061646
# Time for epoch 128 is 0.7727823257446289 sec Generator Loss: 0.8804461359977722,  Discriminator_loss: 1.2963968515396118
# Time for epoch 129 is 0.7265844345092773 sec Generator Loss: 0.8690913915634155,  Discriminator_loss: 1.3011668920516968
# Time for epoch 130 is 0.6902549266815186 sec Generator Loss: 0.8664510250091553,  Discriminator_loss: 1.2930266857147217
# Time for epoch 131 is 0.7616190910339355 sec Generator Loss: 0.8779237270355225,  Discriminator_loss: 1.2819527387619019
# Time for epoch 132 is 0.6833889484405518 sec Generator Loss: 0.8783644437789917,  Discriminator_loss: 1.295363187789917
# Time for epoch 133 is 0.6869213581085205 sec Generator Loss: 0.8725217580795288,  Discriminator_loss: 1.3036202192306519
# Time for epoch 134 is 0.7303783893585205 sec Generator Loss: 0.8761535286903381,  Discriminator_loss: 1.2945433855056763
# Time for epoch 135 is 0.699880838394165 sec Generator Loss: 0.8628374338150024,  Discriminator_loss: 1.3078663349151611
# Time for epoch 136 is 0.7361226081848145 sec Generator Loss: 0.8667843341827393,  Discriminator_loss: 1.3103619813919067
# Time for epoch 137 is 0.7661118507385254 sec Generator Loss: 0.8730071783065796,  Discriminator_loss: 1.3010197877883911
# Time for epoch 138 is 0.6855959892272949 sec Generator Loss: 0.8639116287231445,  Discriminator_loss: 1.3014124631881714
# Time for epoch 139 is 0.6862189769744873 sec Generator Loss: 0.8675578832626343,  Discriminator_loss: 1.2981566190719604
# Time for epoch 140 is 0.6860232353210449 sec Generator Loss: 0.8719686269760132,  Discriminator_loss: 1.302689790725708
# Time for epoch 141 is 0.7647945880889893 sec Generator Loss: 0.8679599165916443,  Discriminator_loss: 1.2981891632080078
# Time for epoch 142 is 0.7291398048400879 sec Generator Loss: 0.8665134310722351,  Discriminator_loss: 1.300335168838501
# Time for epoch 143 is 0.6784412860870361 sec Generator Loss: 0.8655061721801758,  Discriminator_loss: 1.2913579940795898
# Time for epoch 144 is 0.7596354484558105 sec Generator Loss: 0.8634361028671265,  Discriminator_loss: 1.2974960803985596
# Time for epoch 145 is 0.6787457466125488 sec Generator Loss: 0.8675500750541687,  Discriminator_loss: 1.292887568473816
# Time for epoch 146 is 0.7399709224700928 sec Generator Loss: 0.8631539940834045,  Discriminator_loss: 1.2969894409179688
# Time for epoch 147 is 0.7465617656707764 sec Generator Loss: 0.8624681830406189,  Discriminator_loss: 1.2985254526138306
# Time for epoch 148 is 0.6844372749328613 sec Generator Loss: 0.8758860230445862,  Discriminator_loss: 1.2915951013565063
# Time for epoch 149 is 0.741283655166626 sec Generator Loss: 0.8646788001060486,  Discriminator_loss: 1.2970117330551147
# Time for epoch 150 is 0.7202491760253906 sec Generator Loss: 0.8763667345046997,  Discriminator_loss: 1.3005696535110474
# Time for epoch 151 is 0.6908771991729736 sec Generator Loss: 0.8699020147323608,  Discriminator_loss: 1.2931357622146606
# Time for epoch 152 is 0.73409104347229 sec Generator Loss: 0.8610941767692566,  Discriminator_loss: 1.3011393547058105
# Time for epoch 153 is 0.7734358310699463 sec Generator Loss: 0.8610424995422363,  Discriminator_loss: 1.3015245199203491
# Time for epoch 154 is 0.6993660926818848 sec Generator Loss: 0.873479962348938,  Discriminator_loss: 1.2874348163604736
# Time for epoch 155 is 0.6701743602752686 sec Generator Loss: 0.8723779320716858,  Discriminator_loss: 1.292701244354248
# Time for epoch 156 is 0.7323846817016602 sec Generator Loss: 0.8732193112373352,  Discriminator_loss: 1.2922364473342896
# Time for epoch 157 is 0.6935253143310547 sec Generator Loss: 0.8742156624794006,  Discriminator_loss: 1.3038713932037354
# Time for epoch 158 is 0.6923632621765137 sec Generator Loss: 0.878288209438324,  Discriminator_loss: 1.2841371297836304
# Time for epoch 159 is 0.663191556930542 sec Generator Loss: 0.8628382086753845,  Discriminator_loss: 1.301291584968567
# Time for epoch 160 is 0.654477596282959 sec Generator Loss: 0.8747562766075134,  Discriminator_loss: 1.285971760749817
# Time for epoch 161 is 0.7437748908996582 sec Generator Loss: 0.8732775449752808,  Discriminator_loss: 1.2891677618026733
# Time for epoch 162 is 0.6959893703460693 sec Generator Loss: 0.8622397780418396,  Discriminator_loss: 1.29087495803833
# Time for epoch 163 is 0.718127965927124 sec Generator Loss: 0.8681638836860657,  Discriminator_loss: 1.2914226055145264
# Time for epoch 164 is 0.6931331157684326 sec Generator Loss: 0.8744122982025146,  Discriminator_loss: 1.2865840196609497
# Time for epoch 165 is 0.682161808013916 sec Generator Loss: 0.8620584607124329,  Discriminator_loss: 1.2967801094055176
# ...
# Time for epoch 910 is 0.8066623210906982 sec Generator Loss: 0.9476426243782043,  Discriminator_loss: 1.2402653694152832
# Time for epoch 911 is 0.8173830509185791 sec Generator Loss: 0.9404312372207642,  Discriminator_loss: 1.2558590173721313
# Time for epoch 912 is 0.8019189834594727 sec Generator Loss: 0.9475985765457153,  Discriminator_loss: 1.242814064025879
# Time for epoch 913 is 0.8154678344726562 sec Generator Loss: 0.9395298957824707,  Discriminator_loss: 1.249017596244812
# Time for epoch 914 is 0.8090765476226807 sec Generator Loss: 0.9420827031135559,  Discriminator_loss: 1.2567013502120972
# Time for epoch 915 is 0.8353393077850342 sec Generator Loss: 0.9723893404006958,  Discriminator_loss: 1.2345458269119263
# Time for epoch 916 is 0.8064031600952148 sec Generator Loss: 0.9584550857543945,  Discriminator_loss: 1.2474478483200073
# Time for epoch 917 is 0.8062188625335693 sec Generator Loss: 0.9538754224777222,  Discriminator_loss: 1.257672667503357
# Time for epoch 918 is 0.807654857635498 sec Generator Loss: 0.953583300113678,  Discriminator_loss: 1.2494227886199951
# Time for epoch 919 is 0.8198087215423584 sec Generator Loss: 0.9588306546211243,  Discriminator_loss: 1.240639567375183
# Time for epoch 920 is 0.8252418041229248 sec Generator Loss: 0.9592413306236267,  Discriminator_loss: 1.236282467842102
# Time for epoch 921 is 0.8723564147949219 sec Generator Loss: 0.965714693069458,  Discriminator_loss: 1.2483407258987427
# Time for epoch 922 is 0.8156642913818359 sec Generator Loss: 0.9490779638290405,  Discriminator_loss: 1.2569448947906494
# Time for epoch 923 is 0.8203833103179932 sec Generator Loss: 0.966391921043396,  Discriminator_loss: 1.2431343793869019
# Time for epoch 924 is 0.8004922866821289 sec Generator Loss: 0.9637153148651123,  Discriminator_loss: 1.2456238269805908
# Time for epoch 925 is 0.8183417320251465 sec Generator Loss: 0.9566584825515747,  Discriminator_loss: 1.2452234029769897
# Time for epoch 926 is 0.8133232593536377 sec Generator Loss: 0.9682320952415466,  Discriminator_loss: 1.2416926622390747
# Time for epoch 927 is 0.827733039855957 sec Generator Loss: 0.9570357799530029,  Discriminator_loss: 1.2340288162231445
# Time for epoch 928 is 0.8062732219696045 sec Generator Loss: 0.9632989764213562,  Discriminator_loss: 1.2385215759277344
# Time for epoch 929 is 0.8056719303131104 sec Generator Loss: 0.959348738193512,  Discriminator_loss: 1.2536965608596802
# Time for epoch 930 is 0.8148312568664551 sec Generator Loss: 0.9507601857185364,  Discriminator_loss: 1.2442001104354858
# Time for epoch 931 is 0.800940752029419 sec Generator Loss: 0.972585916519165,  Discriminator_loss: 1.2306439876556396
# Time for epoch 932 is 0.844395637512207 sec Generator Loss: 0.9537082314491272,  Discriminator_loss: 1.25030517578125
# Time for epoch 933 is 0.8352243900299072 sec Generator Loss: 0.9687523245811462,  Discriminator_loss: 1.2497310638427734
# Time for epoch 934 is 0.8134706020355225 sec Generator Loss: 0.9580395221710205,  Discriminator_loss: 1.2524768114089966
# Time for epoch 935 is 0.8061716556549072 sec Generator Loss: 0.9591408371925354,  Discriminator_loss: 1.2597615718841553
# Time for epoch 936 is 0.8256912231445312 sec Generator Loss: 0.9613158702850342,  Discriminator_loss: 1.2493610382080078
# Time for epoch 937 is 0.7994105815887451 sec Generator Loss: 0.9568221569061279,  Discriminator_loss: 1.2554141283035278
# Time for epoch 938 is 0.8068130016326904 sec Generator Loss: 0.9522764682769775,  Discriminator_loss: 1.248457431793213
# Time for epoch 939 is 0.8269779682159424 sec Generator Loss: 0.9503362774848938,  Discriminator_loss: 1.2510251998901367
# Time for epoch 940 is 0.8871562480926514 sec Generator Loss: 0.9730968475341797,  Discriminator_loss: 1.2343214750289917
# Time for epoch 941 is 0.8090784549713135 sec Generator Loss: 0.9610764980316162,  Discriminator_loss: 1.240755319595337
# Time for epoch 942 is 0.8203189373016357 sec Generator Loss: 0.9423924684524536,  Discriminator_loss: 1.2707544565200806
# Time for epoch 943 is 0.8551640510559082 sec Generator Loss: 0.945170521736145,  Discriminator_loss: 1.2431280612945557
# Time for epoch 944 is 0.8255805969238281 sec Generator Loss: 0.9411138296127319,  Discriminator_loss: 1.2557368278503418
# Time for epoch 945 is 0.8316164016723633 sec Generator Loss: 0.9380950331687927,  Discriminator_loss: 1.2558449506759644
# Time for epoch 946 is 0.8151710033416748 sec Generator Loss: 0.9427043795585632,  Discriminator_loss: 1.2425780296325684
# Time for epoch 947 is 0.8319158554077148 sec Generator Loss: 0.9488336443901062,  Discriminator_loss: 1.2468929290771484
# Time for epoch 948 is 0.8259322643280029 sec Generator Loss: 0.9554816484451294,  Discriminator_loss: 1.2454553842544556
# Time for epoch 949 is 0.79958176612854 sec Generator Loss: 0.9550723433494568,  Discriminator_loss: 1.2361773252487183
# Time for epoch 950 is 0.8113322257995605 sec Generator Loss: 0.9639886617660522,  Discriminator_loss: 1.2441480159759521
# Time for epoch 951 is 0.8393466472625732 sec Generator Loss: 0.9640399813652039,  Discriminator_loss: 1.2372912168502808
# Time for epoch 952 is 0.8136508464813232 sec Generator Loss: 0.9720323085784912,  Discriminator_loss: 1.2340868711471558
# Time for epoch 953 is 0.8151125907897949 sec Generator Loss: 0.9647948145866394,  Discriminator_loss: 1.2539958953857422
# Time for epoch 954 is 0.8024163246154785 sec Generator Loss: 0.9585148692131042,  Discriminator_loss: 1.242904782295227
# Time for epoch 955 is 0.8358492851257324 sec Generator Loss: 0.960930347442627,  Discriminator_loss: 1.2426912784576416
# Time for epoch 956 is 0.8276700973510742 sec Generator Loss: 0.9464424252510071,  Discriminator_loss: 1.2541881799697876
# Time for epoch 957 is 0.8478224277496338 sec Generator Loss: 0.9581583142280579,  Discriminator_loss: 1.2459797859191895
# Time for epoch 958 is 0.8170325756072998 sec Generator Loss: 0.9355219006538391,  Discriminator_loss: 1.2471624612808228
# Time for epoch 959 is 0.8230817317962646 sec Generator Loss: 0.9690272808074951,  Discriminator_loss: 1.2442266941070557
# Time for epoch 960 is 0.8199558258056641 sec Generator Loss: 0.9544855952262878,  Discriminator_loss: 1.2508052587509155
# Time for epoch 961 is 0.8275094032287598 sec Generator Loss: 0.9574695229530334,  Discriminator_loss: 1.2444210052490234
# Time for epoch 962 is 0.8570206165313721 sec Generator Loss: 0.9636160731315613,  Discriminator_loss: 1.241760015487671
# Time for epoch 963 is 0.822723388671875 sec Generator Loss: 0.9556389451026917,  Discriminator_loss: 1.2509102821350098
# Time for epoch 964 is 0.8573613166809082 sec Generator Loss: 0.9445540904998779,  Discriminator_loss: 1.253436803817749
# Time for epoch 965 is 0.8070242404937744 sec Generator Loss: 0.9552819132804871,  Discriminator_loss: 1.248853325843811
# Time for epoch 966 is 0.8164057731628418 sec Generator Loss: 0.9557602405548096,  Discriminator_loss: 1.2415794134140015
# Time for epoch 967 is 0.873741626739502 sec Generator Loss: 0.9671972393989563,  Discriminator_loss: 1.2411890029907227
# Time for epoch 968 is 0.8117020130157471 sec Generator Loss: 0.9509096741676331,  Discriminator_loss: 1.2449687719345093
# Time for epoch 969 is 0.8951907157897949 sec Generator Loss: 0.9717547297477722,  Discriminator_loss: 1.2203518152236938
# Time for epoch 970 is 0.86464524269104 sec Generator Loss: 0.9498814344406128,  Discriminator_loss: 1.250524878501892
# Time for epoch 971 is 0.863412618637085 sec Generator Loss: 0.9698048830032349,  Discriminator_loss: 1.2520878314971924
# Time for epoch 972 is 0.861114501953125 sec Generator Loss: 0.960271418094635,  Discriminator_loss: 1.243351697921753
# Time for epoch 973 is 0.8950669765472412 sec Generator Loss: 0.9633777141571045,  Discriminator_loss: 1.247833251953125
# Time for epoch 974 is 0.8666226863861084 sec Generator Loss: 0.9592108726501465,  Discriminator_loss: 1.2320986986160278
# Time for epoch 975 is 0.8748106956481934 sec Generator Loss: 0.9721170663833618,  Discriminator_loss: 1.236055850982666
# Time for epoch 976 is 0.8494558334350586 sec Generator Loss: 0.9645285606384277,  Discriminator_loss: 1.2328590154647827
# Time for epoch 977 is 0.8783669471740723 sec Generator Loss: 0.9618934392929077,  Discriminator_loss: 1.2516872882843018
# Time for epoch 978 is 0.8337075710296631 sec Generator Loss: 0.9577050805091858,  Discriminator_loss: 1.239384412765503
# Time for epoch 979 is 0.8357863426208496 sec Generator Loss: 0.9773452877998352,  Discriminator_loss: 1.2312759160995483
# Time for epoch 980 is 0.8550798892974854 sec Generator Loss: 0.9637604355812073,  Discriminator_loss: 1.2443045377731323
# Time for epoch 981 is 0.8703494071960449 sec Generator Loss: 0.9697445034980774,  Discriminator_loss: 1.2413103580474854
# Time for epoch 982 is 0.8627667427062988 sec Generator Loss: 0.9642109274864197,  Discriminator_loss: 1.2422966957092285
# Time for epoch 983 is 0.8772544860839844 sec Generator Loss: 0.977738618850708,  Discriminator_loss: 1.2384121417999268
# Time for epoch 984 is 0.8653199672698975 sec Generator Loss: 0.9776289463043213,  Discriminator_loss: 1.2327181100845337
# Time for epoch 985 is 0.8685462474822998 sec Generator Loss: 0.9592471718788147,  Discriminator_loss: 1.2487826347351074
# Time for epoch 986 is 0.9095449447631836 sec Generator Loss: 0.9739980697631836,  Discriminator_loss: 1.236587405204773
# Time for epoch 987 is 0.8667547702789307 sec Generator Loss: 0.9654651284217834,  Discriminator_loss: 1.2420086860656738
# Time for epoch 988 is 0.9121408462524414 sec Generator Loss: 0.9661128520965576,  Discriminator_loss: 1.2410566806793213
# Time for epoch 989 is 0.8719170093536377 sec Generator Loss: 0.9652750492095947,  Discriminator_loss: 1.248429298400879
# Time for epoch 990 is 0.8811182975769043 sec Generator Loss: 0.9735302925109863,  Discriminator_loss: 1.2383639812469482
# Time for epoch 991 is 0.9022443294525146 sec Generator Loss: 0.965944230556488,  Discriminator_loss: 1.238598346710205
# Time for epoch 992 is 0.8910202980041504 sec Generator Loss: 0.9573510885238647,  Discriminator_loss: 1.2431998252868652
# Time for epoch 993 is 0.8743593692779541 sec Generator Loss: 0.9680864214897156,  Discriminator_loss: 1.2280926704406738
# Time for epoch 994 is 0.8769280910491943 sec Generator Loss: 0.970810055732727,  Discriminator_loss: 1.2410835027694702
# Time for epoch 995 is 0.8930883407592773 sec Generator Loss: 0.9775679707527161,  Discriminator_loss: 1.2378594875335693
# Time for epoch 996 is 0.8798267841339111 sec Generator Loss: 0.9748454093933105,  Discriminator_loss: 1.2376234531402588
# Time for epoch 997 is 0.921039342880249 sec Generator Loss: 0.9632705450057983,  Discriminator_loss: 1.2358806133270264
# Time for epoch 998 is 0.8724350929260254 sec Generator Loss: 0.9678916931152344,  Discriminator_loss: 1.2424641847610474
# Time for epoch 999 is 0.9066789150238037 sec Generator Loss: 0.9715030193328857,  Discriminator_loss: 1.24787175655365
# Time for epoch 1000 is 0.8838293552398682 sec Generator Loss: 0.9626160860061646,  Discriminator_loss: 1.2447421550750732
# Time for epoch 1001 is 0.8799784183502197 sec Generator Loss: 0.9740817546844482,  Discriminator_loss: 1.2360060214996338
# Time for epoch 1002 is 0.8809998035430908 sec Generator Loss: 0.9802389740943909,  Discriminator_loss: 1.2262519598007202
# Time for epoch 1003 is 0.9125323295593262 sec Generator Loss: 0.9711534380912781,  Discriminator_loss: 1.2359739542007446
# Time for epoch 1004 is 0.8749477863311768 sec Generator Loss: 0.975683331489563,  Discriminator_loss: 1.2286778688430786
# Time for epoch 1005 is 0.8674705028533936 sec Generator Loss: 0.9637997150421143,  Discriminator_loss: 1.2531909942626953
# Time for epoch 1006 is 0.886420488357544 sec Generator Loss: 0.9667726159095764,  Discriminator_loss: 1.240098476409912
# Time for epoch 1007 is 0.9048879146575928 sec Generator Loss: 0.9727548956871033,  Discriminator_loss: 1.2412675619125366
# Time for epoch 1008 is 0.8323981761932373 sec Generator Loss: 0.9564183354377747,  Discriminator_loss: 1.2368453741073608
# Time for epoch 1009 is 0.8591225147247314 sec Generator Loss: 0.9607491493225098,  Discriminator_loss: 1.2498085498809814
# Time for epoch 1010 is 0.8224990367889404 sec Generator Loss: 0.9833387136459351,  Discriminator_loss: 1.2444783449172974
# Time for epoch 1011 is 0.8401463031768799 sec Generator Loss: 0.9429410696029663,  Discriminator_loss: 1.2579755783081055
# Time for epoch 1012 is 0.826770544052124 sec Generator Loss: 0.9697549343109131,  Discriminator_loss: 1.2423421144485474
# Time for epoch 1013 is 0.8529672622680664 sec Generator Loss: 0.9615052342414856,  Discriminator_loss: 1.2486704587936401
# Time for epoch 1014 is 0.8363361358642578 sec Generator Loss: 0.9549058079719543,  Discriminator_loss: 1.2424368858337402
# Time for epoch 1015 is 0.8541209697723389 sec Generator Loss: 0.9846050143241882,  Discriminator_loss: 1.2254503965377808
# Time for epoch 1016 is 0.8224368095397949 sec Generator Loss: 0.9818382859230042,  Discriminator_loss: 1.2334297895431519
# Time for epoch 1017 is 0.8344697952270508 sec Generator Loss: 0.9771798253059387,  Discriminator_loss: 1.2407993078231812
# Time for epoch 1018 is 0.8276693820953369 sec Generator Loss: 0.9728394746780396,  Discriminator_loss: 1.2391767501831055
# Time for epoch 1019 is 0.8379189968109131 sec Generator Loss: 0.9552549123764038,  Discriminator_loss: 1.252439260482788
# Time for epoch 1020 is 0.8513908386230469 sec Generator Loss: 0.969196081161499,  Discriminator_loss: 1.232283115386963
# Time for epoch 1021 is 0.852780818939209 sec Generator Loss: 0.9639747142791748,  Discriminator_loss: 1.241327166557312
# Time for epoch 1022 is 0.8322653770446777 sec Generator Loss: 0.9572346806526184,  Discriminator_loss: 1.2524036169052124
# Time for epoch 1023 is 0.8243088722229004 sec Generator Loss: 0.9742001295089722,  Discriminator_loss: 1.2304449081420898
# Time for epoch 1024 is 0.8380002975463867 sec Generator Loss: 0.9702814221382141,  Discriminator_loss: 1.2462105751037598
# Time for epoch 1025 is 0.8547420501708984 sec Generator Loss: 0.9718402028083801,  Discriminator_loss: 1.2405695915222168
# Time for epoch 1026 is 0.8708388805389404 sec Generator Loss: 0.9659862518310547,  Discriminator_loss: 1.2279980182647705
# Time for epoch 1027 is 0.8945348262786865 sec Generator Loss: 0.9723896980285645,  Discriminator_loss: 1.2340370416641235
# Time for epoch 1028 is 0.8547439575195312 sec Generator Loss: 0.9704800844192505,  Discriminator_loss: 1.2360857725143433
# Time for epoch 1029 is 0.8484370708465576 sec Generator Loss: 0.9828009605407715,  Discriminator_loss: 1.23846435546875
# Time for epoch 1030 is 0.8255822658538818 sec Generator Loss: 0.9608242511749268,  Discriminator_loss: 1.2362349033355713
# Time for epoch 1031 is 0.826873779296875 sec Generator Loss: 0.9873844385147095,  Discriminator_loss: 1.2308748960494995
# Time for epoch 1032 is 0.8420085906982422 sec Generator Loss: 0.9729316830635071,  Discriminator_loss: 1.2365950345993042
# Time for epoch 1033 is 0.8514368534088135 sec Generator Loss: 0.9830952286720276,  Discriminator_loss: 1.240543246269226
# Time for epoch 1034 is 0.839555025100708 sec Generator Loss: 0.9623973369598389,  Discriminator_loss: 1.2400315999984741
# Time for epoch 1035 is 0.8370163440704346 sec Generator Loss: 0.9695508480072021,  Discriminator_loss: 1.2318758964538574
# Time for epoch 1036 is 0.8454720973968506 sec Generator Loss: 0.9678107500076294,  Discriminator_loss: 1.2438197135925293
# Time for epoch 1037 is 0.8457183837890625 sec Generator Loss: 0.9681557416915894,  Discriminator_loss: 1.2477748394012451
# Time for epoch 1038 is 0.9093647003173828 sec Generator Loss: 0.9740555882453918,  Discriminator_loss: 1.2323228120803833
# Time for epoch 1039 is 0.8951137065887451 sec Generator Loss: 0.9736565351486206,  Discriminator_loss: 1.2311590909957886
# Time for epoch 1040 is 0.9055371284484863 sec Generator Loss: 0.9710087776184082,  Discriminator_loss: 1.2443301677703857
# Time for epoch 1041 is 0.8700764179229736 sec Generator Loss: 0.9842103123664856,  Discriminator_loss: 1.2429959774017334

# %%
for epochs in [1200, 1450, 1700, 1950]:
    start_time = datetime.datetime.now()
    df = add_Ma(df)
    data_gen_train, data_gen_test = get_gen_train_test(df, n_sequence, n_batch)

    generator = make_generator_model(n_sequence, n_features)
    discriminator=make_discriminator_model(n_features)

    learning_rate=1e-4
    generator_optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.5)
    discriminator_optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.5)

    @tf.function
    def train_step(sequences, sequences_end):
      return train_step_def(sequences, sequences_end)

    @tf.function
    def test_step(sequences, sequences_end):
      return test_step_def(sequences, sequences_end)

    checkpoint_dir = './training_checkpoints'+stock_code
    checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
    checkpoint = tf.train.Checkpoint(generator_optimizer=generator_optimizer,
                                     discriminator_optimizer=discriminator_optimizer,
                                     generator=generator,
                                     discriminator=discriminator)

    history, history_val = train(data_gen_train, data_gen_test, epochs)

    plot_history(history, history_val)
    plot_frame(*data_gen_test[0], generator)

    print("[MSE Baseline] train:",mean_squared_error(data_gen_train)," test:", mean_squared_error(data_gen_test))
    now = datetime.datetime.now()
    delta = now - start_time
    print("Delta time with epochs = {0}:".format(epochs), delta)
    generator.save("rnn_ffnn_epochs_{0}.h5".format(epochs))
