# %%
try:
  # %tensorflow_version 2.x
except Exception:
  pass

# %% [markdown]
# # Import the libraries

# %%
import numpy as np
import pandas as pd
import os

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Embedding, Dense, Dropout, LeakyReLU, Flatten, Bidirectional, Reshape, Conv1D, GaussianNoise, BatchNormalization
import time
import datetime

from tensorflow.keras.layers import Lambda

from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model

import matplotlib.pyplot as plt
import datetime as dt
import yfinance as yf
yf.pdr_override()
from pandas_datareader import data as pdr

# %%
def plot_dataframe(df):
  for column_name in df.columns:
    plt.figure()
    plt.title(column_name)
    plt.plot(df[column_name])

# %% [markdown]
# # Preprocessing

# %%
def add_Ma(df, window=5):
    for i in range(window, df.shape[0]):
        sum = 0.0
        for k in range(1, window+1):
            sum += df.iloc[i-k, 4]
        df.loc[df.index[i], 'Ma'] = np.round(sum/window, 6)
    return df[window:]

# %%
class Standarized_TimeseriesGenerator(tf.keras.preprocessing.sequence.TimeseriesGenerator):
  def __getitem__(self, index):
    samples, targets  = super(Standarized_TimeseriesGenerator, self).__getitem__(index)
    mean = samples.mean(axis=1)
    std = samples.std(axis=1)
    samples = (samples - mean[:,None,:])/std[:,None,:]
    targets = (targets - mean)/std
    return samples, targets

# %%
def get_gen_train_test(dataframe, n_sequence, n_batch):
    data = dataframe.drop(columns='Date').to_numpy()
    targets = data
    n_samples = data.shape[0]
    train_test_split=int(n_samples*0.9)

    data_gen_train = Standarized_TimeseriesGenerator(data, targets,
                                length=n_sequence, sampling_rate=1,
                                stride=1, batch_size=n_batch,
                                start_index = 0,
                                end_index = train_test_split,
                                shuffle = True)
    data_gen_test = Standarized_TimeseriesGenerator(data, targets,
                                length=n_sequence, sampling_rate=1,
                                stride=1, batch_size=n_batch,
                                start_index = train_test_split,
                                end_index = n_samples-1)

    return data_gen_train, data_gen_test

# %% [markdown]
# # Baseline

# %%
def mean_squared_error(dataset):
    mse=0
    for X_batch, y_batch in dataset:
        mse += np.mean(np.square(X_batch[:, -1, 3:4]-y_batch[:, 3:4]))
    mse /= len(dataset)
    return mse

# %% [markdown]
# # Utilities

# %%
def mse(y_true, y_pred):
    return tf.reduce_mean(tf.square(y_true[:,3]-y_pred[:,3]))
def mae(y_true, y_pred):
    return tf.reduce_mean(tf.keras.backend.abs((y_true[:,3]-y_pred[:,3])))
    # ***The absolute is over the whole thing as y_true can be negative
def mape(y_true, y_pred):
    return tf.reduce_mean(tf.keras.backend.abs((y_true[:,3]-y_pred[:,3])/y_true[:,3]))
    # ***The absolute is over the whole thing as y_true can be negative
def rmse(y_true, y_pred):
    return tf.sqrt(tf.reduce_mean(tf.square(y_true[:,3]-y_pred[:,3])))
def ar(y_true, y_pred):
    mask = tf.cast(y_pred[1:,3] > y_true[:-1,3],tf.float32)
    return tf.reduce_mean((y_true[1:,3]-y_true[:-1,3])*mask)

# %% [markdown]
# # GAN

# %% [markdown]
# ## Perdidas

# %%
def discriminator_loss(real_output, fake_output):
    real_loss = tf.keras.losses.binary_crossentropy(tf.ones_like(real_output), real_output)
    fake_loss = tf.keras.losses.binary_crossentropy(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss
    return total_loss

def generator_loss(x, y, fake_output):
    a1=0.01
    g_loss = tf.keras.losses.binary_crossentropy(tf.ones_like(fake_output), fake_output)
    g_mse = tf.keras.losses.MSE(x, y)
    return a1*g_mse + (1-a1)*g_loss, g_mse

# %% [markdown]
# ## Generator

# %%
def make_generator_model(n_sequence, n_features):
    inputs = Input(shape=(n_sequence, n_features,))
    lstm = Bidirectional(LSTM(units=10, return_sequences=True, activation=None, kernel_initializer='random_normal'))
    lstm_1 = lstm(inputs)
    batch_norm1 = BatchNormalization()(lstm_1)
    lstm_1_LRelu = LeakyReLU(alpha=0.3)(batch_norm1)
    lstm_1_droput = Dropout(0.3)(lstm_1_LRelu)
    lstm_2 = Bidirectional(LSTM(units=10, return_sequences=False, activation=None, kernel_initializer='random_normal'))
    lstm_2_output = lstm_2(lstm_1_droput)
    batch_norm2 = BatchNormalization()(lstm_2_output)
    lstm_2_LRelu = LeakyReLU(alpha=0.3)(batch_norm2)
    lstm_2_dropout = Dropout(0.3)(lstm_2_LRelu)
    output_dense = Dense(n_features, activation=None)(lstm_2_dropout)
    output = LeakyReLU(alpha=0.3)(output_dense)
    model = Model(inputs=inputs, outputs=output)
    model.compile(loss=None, metrics=[mse, mae, mape, rmse, ar])
    model.summary()

    return model

# %% [markdown]
# ## Discriminator

# %%
def make_discriminator_model(n_features):
    model = Sequential()
    model.add(Flatten())
    model.add(Dense(units=72, input_shape=((n_sequence+1) * n_features,), activation=None, kernel_initializer='random_normal'))
    model.add(tf.keras.layers.LeakyReLU(alpha=0.3))
    model.add(tf.keras.layers.GaussianNoise(stddev=0.2))
    model.add(Dropout(0.3))
    model.add(Dense(units=100, activation=None, kernel_initializer='random_normal'))
    model.add(tf.keras.layers.LeakyReLU(alpha=0.3))
    model.add(Dropout(0.3))
    model.add(Dense(units=10, activation=None, kernel_initializer='random_normal'))
    model.add(tf.keras.layers.LeakyReLU(alpha=0.3))
    model.add(Dropout(0.3))
    model.add(Dense(1 ,activation='sigmoid'))
    model.compile(loss=discriminator_loss)
    return model

# %% [markdown]
# # Training

# %%
def train_step_def(sequences, sequences_end):
    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        generated_prediction = generator(sequences, training=True)

        sequences_true = tf.concat((sequences, sequences_end[:, None, :]), axis=1)
        sequences_fake = tf.concat((sequences, generated_prediction[:, None, :]), axis=1)

        real_output = discriminator(sequences_true, training=True)
        fake_output = discriminator(sequences_fake, training=True)

        gen_loss, gen_mse_loss = generator_loss(generated_prediction, 
                                                sequences_end, 
                                                fake_output)
        disc_loss = discriminator_loss(real_output, fake_output)

    gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

    return tf.reduce_mean(gen_loss), tf.reduce_mean(disc_loss), tf.reduce_mean(gen_mse_loss)

def test_step_def(sequences, sequences_end):
    generated_prediction = generator(sequences, training=False)

    sequences_true = tf.concat((sequences, sequences_end[:,None,:]), axis=1)
    sequences_fake = tf.concat((sequences, generated_prediction[:,None,:]), axis=1)

    real_output = discriminator(sequences_true, training=False)
    fake_output = discriminator(sequences_fake, training=False)

    gen_loss, gen_mse_loss = generator_loss(generated_prediction, sequences_end, fake_output)
    disc_loss = discriminator_loss(real_output, fake_output)
    return tf.reduce_mean(gen_loss), tf.reduce_mean(disc_loss), tf.reduce_mean(gen_mse_loss)

# %%
def train(dataset, dataset_val, epochs):
    history = np.empty(shape = (8, epochs))
    history_val = np.empty(shape = (8, epochs))
    len_dataset = len(dataset)
    len_dataset_val = len(dataset_val)
    for epoch in range(epochs):
        start = time.time()

        cur_dis_loss = 0
        cur_gen_loss = 0
        cur_gen_mse_loss = 0
        for sequence_batch, sequence_end_batch in dataset:
            aux_cur_losses = train_step(tf.cast(sequence_batch, tf.float32), 
                                      tf.cast(sequence_end_batch, tf.float32))
            cur_gen_loss += aux_cur_losses[0]/len_dataset
            cur_dis_loss += aux_cur_losses[1]/len_dataset
            cur_gen_mse_loss += aux_cur_losses[2]/len_dataset
        cur_gen_metrics = generator.evaluate(dataset,verbose=False)[1:]

        history[:, epoch] = cur_gen_loss, cur_dis_loss, cur_gen_mse_loss, *cur_gen_metrics

        cur_gen_metrics_val = generator.evaluate(dataset_val,verbose=False)[1: ]

        cur_gen_loss_val = 0
        cur_dis_loss_val = 0
        cur_gen_mse_loss_val = 0
        for sequence_batch, sequence_end_batch in dataset_val:
            aux_cur_losses_val = test_step(tf.cast(sequence_batch, tf.float32), 
                                         tf.cast(sequence_end_batch, tf.float32))
            cur_gen_loss_val += aux_cur_losses_val[0]/len_dataset_val
            cur_dis_loss_val += aux_cur_losses_val[1]/len_dataset_val
            cur_gen_mse_loss_val += aux_cur_losses_val[2]/len_dataset_val
    


        history_val[:, epoch] = cur_gen_loss_val, cur_dis_loss_val, cur_gen_mse_loss_val, *cur_gen_metrics_val

        print ('Time for epoch {} is {} sec Generator Loss: {},  Discriminator_loss: {}'
               .format(epoch + 1, time.time()-start, cur_gen_loss, cur_dis_loss))

        # Save the model every 15 epochs
        if (epoch + 1) % 15 == 0:
            checkpoint.save(file_prefix = checkpoint_prefix)
        # Threshhold
#         if(cur_gen_loss > 0.8):
#                 break;

    return history, history_val

# %% [markdown]
# ## Visualization

# %%
def plot_history(history, history_val):
    metrics = ["gen_loss","dis_loss","gen_mse_loss", 'mse','mae','mape','rmse','ar']
    for i, metric_name in enumerate(metrics):  
        plt.figure()
        plt.title(metric_name)
        plt.plot(history[i], label='train')
        plt.plot(history_val[i], label='test')
        plt.legend()
    plt.show()

# %%
def plot_frame(sequence, target, model):
    y_pred = model.predict(sequence)[...,3]
    y_true = target[...,3]

    plt.figure()
    plt.title("closing price")
    plt.plot(y_true, label="true")
    plt.plot(y_pred, label="prediction")
    plt.legend()
    plt.show()

# %%
def get_best_results(history):
    min_index = np.argmin(history[3, :])
    return history[:, min_index]

# %% [markdown]
# ## Variables

# %%
window = 5
n_sequence = window
n_features = 7
n_batch = 50
EPOCHS = 2000

# %% [markdown]
# ## Data loading

# %%
stock_code = "TSLA"
start = dt.datetime(2000, 1, 1)
end = dt.datetime(2020, 12, 31)
raw_data = pdr.get_data_yahoo(stock_code, start, end,threads=False, proxy="http://127.0.0.1:7890")
df = raw_data.dropna();
df = df.reset_index(level=0)
df = add_Ma(df, window)
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#            Date        Open        High         Low       Close   Adj Close  \
# 5    2000-01-10  112.093689  114.125237  110.301147  112.810707   64.370789
# 6    2000-01-11  112.691208  115.798279  111.496178  113.766731   64.916267
# 7    2000-01-12  114.364243  116.634796  113.049713  114.244743   65.189049
# 8    2000-01-13  114.663002  115.678780  110.659653  113.049713   64.507164
# 9    2000-01-14  115.619026  117.889580  112.332695  114.364243   65.257233
# ...         ...         ...         ...         ...         ...         ...
# 5278 2020-12-23  118.432121  119.703636  118.298279  118.451241  106.144402
# 5279 2020-12-24  119.502869  119.598473  118.747612  119.206497  106.821190
# 5280 2020-12-28  119.598473  121.032501  118.986618  119.330788  106.932556
# 5281 2020-12-29  119.837479  119.961761  117.820267  118.355644  106.058739
# 5282 2020-12-30  118.355644  119.359467  118.193115  118.871895  106.521355
#
#         Volume          Ma
# 5      8933363  109.285373
# 6      8235472  109.667783
# 7      7116775  110.994264
# 8      8880226  111.663481
# 9     11460604  112.476100
# ...        ...         ...
# 5278   2817819  119.302103
# 5279   1842111  118.986615
# 5280   3781499  118.822179
# 5281   3647402  118.625238
# 5282   3535794  118.703633
#
# [5278 rows x 8 columns]

# %%
start_time = datetime.datetime.now()
df = add_Ma(df)
data_gen_train, data_gen_test = get_gen_train_test(df, n_sequence, n_batch)

generator = make_generator_model(n_sequence, n_features)
discriminator=make_discriminator_model(n_features)

learning_rate=1e-4
generator_optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.5)
discriminator_optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.5)

@tf.function
def train_step(sequences, sequences_end):
  return train_step_def(sequences, sequences_end)

@tf.function
def test_step(sequences, sequences_end):
  return test_step_def(sequences, sequences_end)

checkpoint_dir = './training_checkpoints'+stock_code
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(generator_optimizer=generator_optimizer,
                                 discriminator_optimizer=discriminator_optimizer,
                                 generator=generator,
                                 discriminator=discriminator)

history, history_val = train(data_gen_train, data_gen_test, EPOCHS)

plot_history(history, history_val)
plot_frame(*data_gen_test[0], generator)

print("[MSE Baseline] train:",mean_squared_error(data_gen_train)," test:", mean_squared_error(data_gen_test))
now = datetime.datetime.now()
delta = now - start_time
print("Delta time:", delta)
generator.save("bilstm_ffnn.h5")
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5, 7)]            0
#
#  bidirectional (Bidirectiona  (None, 5, 20)            1440
#  l)
#
#  batch_normalization (BatchN  (None, 5, 20)            80
#  ormalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 5, 20)             0
#
#  dropout (Dropout)           (None, 5, 20)             0
#
#  bidirectional_1 (Bidirectio  (None, 20)               2480
#  nal)
#
#  batch_normalization_1 (Batc  (None, 20)               80
#  hNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 20)                0
#
#  dropout_1 (Dropout)         (None, 20)                0
#
#  dense (Dense)               (None, 7)                 147
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 7)                 0
#
# =================================================================
# Total params: 4,227
# Trainable params: 4,147
# Non-trainable params: 80
# _________________________________________________________________
# Time for epoch 1 is 10.338447570800781 sec Generator Loss: 0.7194374799728394,  Discriminator_loss: 1.3692353963851929
# Time for epoch 2 is 0.8038671016693115 sec Generator Loss: 0.7201235890388489,  Discriminator_loss: 1.3244353532791138
# Time for epoch 3 is 0.8452901840209961 sec Generator Loss: 0.7276362776756287,  Discriminator_loss: 1.2623543739318848
# Time for epoch 4 is 0.8823983669281006 sec Generator Loss: 0.765982985496521,  Discriminator_loss: 1.1984244585037231
# Time for epoch 5 is 0.9099438190460205 sec Generator Loss: 0.8318325877189636,  Discriminator_loss: 1.1279953718185425
# Time for epoch 6 is 0.8876984119415283 sec Generator Loss: 0.9015692472457886,  Discriminator_loss: 1.1002769470214844
# Time for epoch 7 is 1.0530095100402832 sec Generator Loss: 0.9405444264411926,  Discriminator_loss: 1.1050050258636475
# Time for epoch 8 is 0.9218826293945312 sec Generator Loss: 1.0069241523742676,  Discriminator_loss: 1.080153465270996
# Time for epoch 9 is 0.87919020652771 sec Generator Loss: 1.0026767253875732,  Discriminator_loss: 1.1286425590515137
# Time for epoch 10 is 0.8560760021209717 sec Generator Loss: 1.0783705711364746,  Discriminator_loss: 1.071806788444519
# Time for epoch 11 is 0.864548921585083 sec Generator Loss: 1.077784538269043,  Discriminator_loss: 1.105878472328186
# Time for epoch 12 is 0.8452625274658203 sec Generator Loss: 1.0427114963531494,  Discriminator_loss: 1.119269847869873
# Time for epoch 13 is 0.8186740875244141 sec Generator Loss: 1.0223157405853271,  Discriminator_loss: 1.1664352416992188
# Time for epoch 14 is 0.8151264190673828 sec Generator Loss: 1.045881748199463,  Discriminator_loss: 1.1534982919692993
# Time for epoch 15 is 0.808068037033081 sec Generator Loss: 1.0185370445251465,  Discriminator_loss: 1.1701065301895142
# Time for epoch 16 is 0.8263552188873291 sec Generator Loss: 0.9908295273780823,  Discriminator_loss: 1.198093056678772
# Time for epoch 17 is 0.8891806602478027 sec Generator Loss: 0.9843155145645142,  Discriminator_loss: 1.206270694732666
# Time for epoch 18 is 0.8506288528442383 sec Generator Loss: 0.9551435112953186,  Discriminator_loss: 1.217552661895752
# Time for epoch 19 is 0.8670670986175537 sec Generator Loss: 0.9529960751533508,  Discriminator_loss: 1.243693232536316
# Time for epoch 20 is 0.8610134124755859 sec Generator Loss: 0.947604775428772,  Discriminator_loss: 1.242962121963501
# Time for epoch 21 is 0.8477573394775391 sec Generator Loss: 0.9287980794906616,  Discriminator_loss: 1.258466124534607
# Time for epoch 22 is 0.8586204051971436 sec Generator Loss: 0.925426185131073,  Discriminator_loss: 1.2577747106552124
# Time for epoch 23 is 0.8427314758300781 sec Generator Loss: 0.9250192642211914,  Discriminator_loss: 1.264262080192566
# Time for epoch 24 is 0.8433349132537842 sec Generator Loss: 0.925482451915741,  Discriminator_loss: 1.2511898279190063
# Time for epoch 25 is 0.8631350994110107 sec Generator Loss: 0.8944001793861389,  Discriminator_loss: 1.2668097019195557
# Time for epoch 26 is 0.8232464790344238 sec Generator Loss: 0.8904935717582703,  Discriminator_loss: 1.2812097072601318
# Time for epoch 27 is 0.8451046943664551 sec Generator Loss: 0.8725979924201965,  Discriminator_loss: 1.2910205125808716
# Time for epoch 28 is 0.8515961170196533 sec Generator Loss: 0.8641738295555115,  Discriminator_loss: 1.310558557510376
# Time for epoch 29 is 0.8419675827026367 sec Generator Loss: 0.8508625626564026,  Discriminator_loss: 1.313133716583252
# Time for epoch 30 is 0.8447489738464355 sec Generator Loss: 0.8517152070999146,  Discriminator_loss: 1.3187870979309082
# Time for epoch 31 is 0.8370845317840576 sec Generator Loss: 0.8590916991233826,  Discriminator_loss: 1.3005681037902832
# Time for epoch 32 is 0.8745031356811523 sec Generator Loss: 0.8340005874633789,  Discriminator_loss: 1.3107975721359253
# Time for epoch 33 is 0.8442718982696533 sec Generator Loss: 0.8349541425704956,  Discriminator_loss: 1.2988699674606323
# Time for epoch 34 is 0.8439974784851074 sec Generator Loss: 0.83123379945755,  Discriminator_loss: 1.3055354356765747
# Time for epoch 35 is 0.9950485229492188 sec Generator Loss: 0.8342185020446777,  Discriminator_loss: 1.3060965538024902
# Time for epoch 36 is 0.8376674652099609 sec Generator Loss: 0.8451350331306458,  Discriminator_loss: 1.2940359115600586
# Time for epoch 37 is 0.8832390308380127 sec Generator Loss: 0.8336873054504395,  Discriminator_loss: 1.3164043426513672
# Time for epoch 38 is 0.8470151424407959 sec Generator Loss: 0.8296794891357422,  Discriminator_loss: 1.3297368288040161
# Time for epoch 39 is 0.8586134910583496 sec Generator Loss: 0.8338026404380798,  Discriminator_loss: 1.3346233367919922
# Time for epoch 40 is 0.8682236671447754 sec Generator Loss: 0.837491512298584,  Discriminator_loss: 1.3350560665130615
# Time for epoch 41 is 0.8804445266723633 sec Generator Loss: 0.8329906463623047,  Discriminator_loss: 1.3399964570999146
# Time for epoch 42 is 0.8811581134796143 sec Generator Loss: 0.8198959231376648,  Discriminator_loss: 1.3429079055786133
# Time for epoch 43 is 0.8961951732635498 sec Generator Loss: 0.8189504146575928,  Discriminator_loss: 1.3372085094451904
# Time for epoch 44 is 0.8788983821868896 sec Generator Loss: 0.8214370012283325,  Discriminator_loss: 1.3354099988937378
# Time for epoch 45 is 0.893730640411377 sec Generator Loss: 0.8169518709182739,  Discriminator_loss: 1.334900975227356
# Time for epoch 46 is 0.8800196647644043 sec Generator Loss: 0.8153894543647766,  Discriminator_loss: 1.333964228630066
# Time for epoch 47 is 0.8932938575744629 sec Generator Loss: 0.8146517276763916,  Discriminator_loss: 1.32701575756073
# Time for epoch 48 is 0.8932723999023438 sec Generator Loss: 0.8155624270439148,  Discriminator_loss: 1.331052541732788
# Time for epoch 49 is 0.9580349922180176 sec Generator Loss: 0.8058684468269348,  Discriminator_loss: 1.3392947912216187
# Time for epoch 50 is 0.9374854564666748 sec Generator Loss: 0.812362790107727,  Discriminator_loss: 1.3391529321670532
# Time for epoch 51 is 0.9250953197479248 sec Generator Loss: 0.8204922080039978,  Discriminator_loss: 1.3399453163146973
# Time for epoch 52 is 0.9068548679351807 sec Generator Loss: 0.812828779220581,  Discriminator_loss: 1.3376201391220093
# Time for epoch 53 is 0.8698081970214844 sec Generator Loss: 0.8157466650009155,  Discriminator_loss: 1.338987112045288
# Time for epoch 54 is 0.9206271171569824 sec Generator Loss: 0.814799427986145,  Discriminator_loss: 1.3371825218200684
# Time for epoch 55 is 0.8827168941497803 sec Generator Loss: 0.8163255453109741,  Discriminator_loss: 1.3429205417633057
# Time for epoch 56 is 0.8937435150146484 sec Generator Loss: 0.8104338049888611,  Discriminator_loss: 1.3362423181533813
# Time for epoch 57 is 0.9286830425262451 sec Generator Loss: 0.8087136745452881,  Discriminator_loss: 1.346777319908142
# Time for epoch 58 is 0.9659762382507324 sec Generator Loss: 0.8134567737579346,  Discriminator_loss: 1.3615679740905762
# Time for epoch 59 is 0.9688360691070557 sec Generator Loss: 0.8268898725509644,  Discriminator_loss: 1.3512431383132935
# Time for epoch 60 is 0.9422595500946045 sec Generator Loss: 0.8021692633628845,  Discriminator_loss: 1.3570687770843506
# Time for epoch 61 is 0.9283273220062256 sec Generator Loss: 0.7888607978820801,  Discriminator_loss: 1.3615295886993408
# Time for epoch 62 is 0.8678305149078369 sec Generator Loss: 0.8042917251586914,  Discriminator_loss: 1.3591567277908325
# Time for epoch 63 is 0.845569372177124 sec Generator Loss: 0.7968543767929077,  Discriminator_loss: 1.3636733293533325
# Time for epoch 64 is 0.894559383392334 sec Generator Loss: 0.798873245716095,  Discriminator_loss: 1.3580807447433472
# Time for epoch 65 is 0.8826091289520264 sec Generator Loss: 0.7983561158180237,  Discriminator_loss: 1.3571107387542725
# Time for epoch 66 is 0.9015557765960693 sec Generator Loss: 0.789213240146637,  Discriminator_loss: 1.352250576019287
# Time for epoch 67 is 0.9262607097625732 sec Generator Loss: 0.792971134185791,  Discriminator_loss: 1.3476492166519165
# Time for epoch 68 is 0.916170597076416 sec Generator Loss: 0.7908284068107605,  Discriminator_loss: 1.3490883111953735
# Time for epoch 69 is 0.9708466529846191 sec Generator Loss: 0.7985049486160278,  Discriminator_loss: 1.3479139804840088
# Time for epoch 70 is 1.0317800045013428 sec Generator Loss: 0.787786066532135,  Discriminator_loss: 1.3535903692245483
# Time for epoch 71 is 0.9825332164764404 sec Generator Loss: 0.7901624441146851,  Discriminator_loss: 1.3531397581100464
# Time for epoch 72 is 0.9496908187866211 sec Generator Loss: 0.7966756224632263,  Discriminator_loss: 1.3586674928665161
# Time for epoch 73 is 0.9579007625579834 sec Generator Loss: 0.7862999439239502,  Discriminator_loss: 1.3562474250793457
# Time for epoch 74 is 0.8768877983093262 sec Generator Loss: 0.7918559312820435,  Discriminator_loss: 1.3524837493896484
# Time for epoch 75 is 0.8482584953308105 sec Generator Loss: 0.7936146855354309,  Discriminator_loss: 1.3480329513549805
# Time for epoch 76 is 0.8560218811035156 sec Generator Loss: 0.7886898517608643,  Discriminator_loss: 1.3632018566131592
# Time for epoch 77 is 0.8793644905090332 sec Generator Loss: 0.7943421602249146,  Discriminator_loss: 1.3713593482971191
# Time for epoch 78 is 0.9142389297485352 sec Generator Loss: 0.7911374568939209,  Discriminator_loss: 1.3629343509674072
# Time for epoch 79 is 0.8764834403991699 sec Generator Loss: 0.787967324256897,  Discriminator_loss: 1.364025592803955
# Time for epoch 80 is 0.9260499477386475 sec Generator Loss: 0.789408802986145,  Discriminator_loss: 1.3630156517028809
# Time for epoch 81 is 1.1595683097839355 sec Generator Loss: 0.782751202583313,  Discriminator_loss: 1.3687320947647095
# Time for epoch 82 is 1.1905546188354492 sec Generator Loss: 0.7877261638641357,  Discriminator_loss: 1.3645224571228027
# Time for epoch 83 is 1.1046912670135498 sec Generator Loss: 0.7936391830444336,  Discriminator_loss: 1.3578108549118042
# Time for epoch 84 is 1.126086711883545 sec Generator Loss: 0.784359872341156,  Discriminator_loss: 1.3546661138534546
# Time for epoch 85 is 1.122532844543457 sec Generator Loss: 0.7860531210899353,  Discriminator_loss: 1.3500944375991821
# Time for epoch 86 is 0.9725854396820068 sec Generator Loss: 0.780066967010498,  Discriminator_loss: 1.359212875366211
# Time for epoch 87 is 1.1045217514038086 sec Generator Loss: 0.7801884412765503,  Discriminator_loss: 1.356383204460144
# Time for epoch 88 is 1.1773271560668945 sec Generator Loss: 0.7850595116615295,  Discriminator_loss: 1.3629659414291382
# Time for epoch 89 is 1.1621458530426025 sec Generator Loss: 0.7891915440559387,  Discriminator_loss: 1.3478052616119385
# Time for epoch 90 is 1.1283636093139648 sec Generator Loss: 0.7707828283309937,  Discriminator_loss: 1.3605338335037231
# Time for epoch 91 is 1.1438419818878174 sec Generator Loss: 0.7880275845527649,  Discriminator_loss: 1.3616182804107666
# Time for epoch 92 is 1.0702359676361084 sec Generator Loss: 0.7856375575065613,  Discriminator_loss: 1.358632206916809
# Time for epoch 93 is 1.0741002559661865 sec Generator Loss: 0.7870423197746277,  Discriminator_loss: 1.3551793098449707
# Time for epoch 94 is 1.0785205364227295 sec Generator Loss: 0.7831959128379822,  Discriminator_loss: 1.3620305061340332
# Time for epoch 95 is 1.0835974216461182 sec Generator Loss: 0.7874969840049744,  Discriminator_loss: 1.3592923879623413
# Time for epoch 96 is 1.0562012195587158 sec Generator Loss: 0.7896528244018555,  Discriminator_loss: 1.3560373783111572
# Time for epoch 97 is 1.0640449523925781 sec Generator Loss: 0.7850706577301025,  Discriminator_loss: 1.3545681238174438
# Time for epoch 98 is 1.0716321468353271 sec Generator Loss: 0.789012610912323,  Discriminator_loss: 1.355241298675537
# Time for epoch 99 is 1.0773062705993652 sec Generator Loss: 0.7947565317153931,  Discriminator_loss: 1.3564199209213257
# Time for epoch 100 is 1.0762555599212646 sec Generator Loss: 0.786169707775116,  Discriminator_loss: 1.3597769737243652
# Time for epoch 101 is 1.06976318359375 sec Generator Loss: 0.7841291427612305,  Discriminator_loss: 1.3578678369522095
# Time for epoch 102 is 1.0718767642974854 sec Generator Loss: 0.7799609899520874,  Discriminator_loss: 1.3643856048583984
# Time for epoch 103 is 1.0672049522399902 sec Generator Loss: 0.7829042673110962,  Discriminator_loss: 1.3596322536468506
# Time for epoch 104 is 1.068584680557251 sec Generator Loss: 0.7899928689002991,  Discriminator_loss: 1.360172986984253
# Time for epoch 105 is 1.061495065689087 sec Generator Loss: 0.7784377336502075,  Discriminator_loss: 1.3596546649932861
# Time for epoch 106 is 1.0948443412780762 sec Generator Loss: 0.7764803171157837,  Discriminator_loss: 1.3609166145324707
# Time for epoch 107 is 1.0714716911315918 sec Generator Loss: 0.7754013538360596,  Discriminator_loss: 1.3568637371063232
# Time for epoch 108 is 1.0779240131378174 sec Generator Loss: 0.7754530906677246,  Discriminator_loss: 1.3663350343704224
# Time for epoch 109 is 1.1886227130889893 sec Generator Loss: 0.7837386131286621,  Discriminator_loss: 1.3583905696868896
# Time for epoch 110 is 1.207686185836792 sec Generator Loss: 0.7849363684654236,  Discriminator_loss: 1.360725998878479
# Time for epoch 111 is 1.1849355697631836 sec Generator Loss: 0.774169385433197,  Discriminator_loss: 1.3638278245925903
# Time for epoch 112 is 1.1889140605926514 sec Generator Loss: 0.7724138498306274,  Discriminator_loss: 1.3604018688201904
# Time for epoch 113 is 1.1624658107757568 sec Generator Loss: 0.7796327471733093,  Discriminator_loss: 1.3605420589447021
# Time for epoch 114 is 1.1102471351623535 sec Generator Loss: 0.7844481468200684,  Discriminator_loss: 1.35593843460083
# Time for epoch 115 is 1.1338222026824951 sec Generator Loss: 0.783220648765564,  Discriminator_loss: 1.3556276559829712
# Time for epoch 116 is 1.0654726028442383 sec Generator Loss: 0.7861564755439758,  Discriminator_loss: 1.3616764545440674
# Time for epoch 117 is 1.064342737197876 sec Generator Loss: 0.7838085293769836,  Discriminator_loss: 1.3591134548187256
# Time for epoch 118 is 1.0844900608062744 sec Generator Loss: 0.7791669964790344,  Discriminator_loss: 1.361401915550232
# Time for epoch 119 is 1.1524567604064941 sec Generator Loss: 0.7785553336143494,  Discriminator_loss: 1.3610211610794067
# Time for epoch 120 is 1.1460940837860107 sec Generator Loss: 0.7891252636909485,  Discriminator_loss: 1.3528884649276733
# Time for epoch 121 is 1.1503500938415527 sec Generator Loss: 0.7842817902565002,  Discriminator_loss: 1.3579427003860474
# Time for epoch 122 is 1.1820900440216064 sec Generator Loss: 0.7851173281669617,  Discriminator_loss: 1.3584142923355103
# Time for epoch 123 is 1.130262851715088 sec Generator Loss: 0.7856658101081848,  Discriminator_loss: 1.3535959720611572
# Time for epoch 124 is 1.1238069534301758 sec Generator Loss: 0.793144166469574,  Discriminator_loss: 1.3571075201034546
# Time for epoch 125 is 1.1238062381744385 sec Generator Loss: 0.7862886786460876,  Discriminator_loss: 1.3622747659683228
# Time for epoch 126 is 1.1305558681488037 sec Generator Loss: 0.7836498618125916,  Discriminator_loss: 1.3598438501358032
# Time for epoch 127 is 1.1209070682525635 sec Generator Loss: 0.7799978852272034,  Discriminator_loss: 1.3573065996170044
# Time for epoch 128 is 1.1321790218353271 sec Generator Loss: 0.7821640968322754,  Discriminator_loss: 1.358628511428833
# Time for epoch 129 is 1.1267383098602295 sec Generator Loss: 0.7852334976196289,  Discriminator_loss: 1.3575581312179565
# Time for epoch 130 is 1.0990495681762695 sec Generator Loss: 0.7743370532989502,  Discriminator_loss: 1.3602789640426636
# Time for epoch 131 is 1.3348698616027832 sec Generator Loss: 0.7852267026901245,  Discriminator_loss: 1.355142593383789
# Time for epoch 132 is 1.063929557800293 sec Generator Loss: 0.7796670198440552,  Discriminator_loss: 1.3603107929229736
# Time for epoch 133 is 1.0650250911712646 sec Generator Loss: 0.7844654321670532,  Discriminator_loss: 1.3535118103027344
# Time for epoch 134 is 1.0484373569488525 sec Generator Loss: 0.7828848361968994,  Discriminator_loss: 1.3604544401168823
# Time for epoch 135 is 1.0878973007202148 sec Generator Loss: 0.7829563021659851,  Discriminator_loss: 1.3569813966751099
# Time for epoch 136 is 1.0747008323669434 sec Generator Loss: 0.7825446128845215,  Discriminator_loss: 1.3545666933059692
# Time for epoch 137 is 1.2406203746795654 sec Generator Loss: 0.7837899923324585,  Discriminator_loss: 1.355383276939392
# Time for epoch 138 is 1.1567416191101074 sec Generator Loss: 0.7825707197189331,  Discriminator_loss: 1.3575290441513062
# Time for epoch 139 is 1.4522922039031982 sec Generator Loss: 0.7802021503448486,  Discriminator_loss: 1.363507866859436
# Time for epoch 140 is 1.3222386837005615 sec Generator Loss: 0.7754802703857422,  Discriminator_loss: 1.3601218461990356
# Time for epoch 141 is 1.1640417575836182 sec Generator Loss: 0.7814704775810242,  Discriminator_loss: 1.3600202798843384
# Time for epoch 142 is 1.1197822093963623 sec Generator Loss: 0.7786334753036499,  Discriminator_loss: 1.356925368309021
# Time for epoch 143 is 1.1677489280700684 sec Generator Loss: 0.7809810042381287,  Discriminator_loss: 1.3553099632263184
# Time for epoch 144 is 1.168180227279663 sec Generator Loss: 0.7827565670013428,  Discriminator_loss: 1.359525442123413
# Time for epoch 145 is 1.2000482082366943 sec Generator Loss: 0.7804672718048096,  Discriminator_loss: 1.35646390914917
# Time for epoch 146 is 1.1628508567810059 sec Generator Loss: 0.780244767665863,  Discriminator_loss: 1.3579052686691284
# Time for epoch 147 is 1.2791781425476074 sec Generator Loss: 0.7844410538673401,  Discriminator_loss: 1.359291434288025
# Time for epoch 148 is 1.2018656730651855 sec Generator Loss: 0.7868638634681702,  Discriminator_loss: 1.3560867309570312
# Time for epoch 149 is 1.1658174991607666 sec Generator Loss: 0.7877237796783447,  Discriminator_loss: 1.3598246574401855
# Time for epoch 150 is 1.1442794799804688 sec Generator Loss: 0.7880995273590088,  Discriminator_loss: 1.3586578369140625
# Time for epoch 151 is 1.136683702468872 sec Generator Loss: 0.7780230641365051,  Discriminator_loss: 1.3632868528366089
# Time for epoch 152 is 1.168630599975586 sec Generator Loss: 0.7780568599700928,  Discriminator_loss: 1.3529034852981567
# Time for epoch 153 is 1.1112158298492432 sec Generator Loss: 0.7778918743133545,  Discriminator_loss: 1.3601093292236328
# Time for epoch 154 is 1.1531062126159668 sec Generator Loss: 0.7841050624847412,  Discriminator_loss: 1.3561866283416748
# Time for epoch 155 is 1.145824909210205 sec Generator Loss: 0.7775281071662903,  Discriminator_loss: 1.3584727048873901
# Time for epoch 156 is 1.1409492492675781 sec Generator Loss: 0.7703338861465454,  Discriminator_loss: 1.3603211641311646
# Time for epoch 157 is 1.1795029640197754 sec Generator Loss: 0.789243757724762,  Discriminator_loss: 1.3509680032730103
# Time for epoch 158 is 1.1182448863983154 sec Generator Loss: 0.7831371426582336,  Discriminator_loss: 1.3621854782104492
# Time for epoch 159 is 1.1376707553863525 sec Generator Loss: 0.788271963596344,  Discriminator_loss: 1.358300805091858
# Time for epoch 160 is 1.1675498485565186 sec Generator Loss: 0.7883696556091309,  Discriminator_loss: 1.357000708580017
# Time for epoch 161 is 1.1942179203033447 sec Generator Loss: 0.7790271639823914,  Discriminator_loss: 1.3595432043075562
# Time for epoch 162 is 1.1870214939117432 sec Generator Loss: 0.7784726023674011,  Discriminator_loss: 1.3616000413894653
# Time for epoch 163 is 1.1670641899108887 sec Generator Loss: 0.777965784072876,  Discriminator_loss: 1.3596086502075195
# Time for epoch 164 is 1.0795063972473145 sec Generator Loss: 0.7768269181251526,  Discriminator_loss: 1.3617345094680786
# Time for epoch 165 is 1.0753631591796875 sec Generator Loss: 0.7827589511871338,  Discriminator_loss: 1.3579211235046387
# Time for epoch 166 is 1.0907096862792969 sec Generator Loss: 0.7833470702171326,  Discriminator_loss: 1.3570104837417603
# Time for epoch 167 is 1.0953164100646973 sec Generator Loss: 0.7777079343795776,  Discriminator_loss: 1.3592591285705566
# Time for epoch 168 is 1.0823359489440918 sec Generator Loss: 0.7802930474281311,  Discriminator_loss: 1.3564300537109375
# Time for epoch 169 is 1.0854663848876953 sec Generator Loss: 0.7804834842681885,  Discriminator_loss: 1.3573267459869385
# Time for epoch 170 is 1.0966801643371582 sec Generator Loss: 0.779289960861206,  Discriminator_loss: 1.363848328590393
# Time for epoch 171 is 1.1224091053009033 sec Generator Loss: 0.7782912850379944,  Discriminator_loss: 1.3561378717422485
# Time for epoch 172 is 1.0667529106140137 sec Generator Loss: 0.7819467782974243,  Discriminator_loss: 1.3590091466903687
# Time for epoch 173 is 1.0880777835845947 sec Generator Loss: 0.774757981300354,  Discriminator_loss: 1.3594540357589722
# Time for epoch 174 is 1.0923631191253662 sec Generator Loss: 0.7858993411064148,  Discriminator_loss: 1.359979271888733
# Time for epoch 175 is 1.0803756713867188 sec Generator Loss: 0.7799497246742249,  Discriminator_loss: 1.3567664623260498
# Time for epoch 176 is 1.1197052001953125 sec Generator Loss: 0.7845333814620972,  Discriminator_loss: 1.3611690998077393
# Time for epoch 177 is 1.0930252075195312 sec Generator Loss: 0.7836728692054749,  Discriminator_loss: 1.3581278324127197
# Time for epoch 178 is 1.0945420265197754 sec Generator Loss: 0.7757777571678162,  Discriminator_loss: 1.3606926202774048
# Time for epoch 179 is 1.0840764045715332 sec Generator Loss: 0.7799074053764343,  Discriminator_loss: 1.3564987182617188
# Time for epoch 180 is 1.083245038986206 sec Generator Loss: 0.7765564322471619,  Discriminator_loss: 1.3597222566604614
# Time for epoch 181 is 1.0935640335083008 sec Generator Loss: 0.7751209735870361,  Discriminator_loss: 1.364687204360962
# Time for epoch 182 is 1.0736138820648193 sec Generator Loss: 0.7776073813438416,  Discriminator_loss: 1.3599025011062622
# Time for epoch 183 is 1.066960334777832 sec Generator Loss: 0.7878550291061401,  Discriminator_loss: 1.3605730533599854
# Time for epoch 184 is 1.0911517143249512 sec Generator Loss: 0.7763239741325378,  Discriminator_loss: 1.358252763748169
# Time for epoch 185 is 1.0982677936553955 sec Generator Loss: 0.7758274078369141,  Discriminator_loss: 1.365769863128662
# Time for epoch 186 is 1.1027867794036865 sec Generator Loss: 0.780098021030426,  Discriminator_loss: 1.356458306312561
# Time for epoch 187 is 1.151245355606079 sec Generator Loss: 0.7747502326965332,  Discriminator_loss: 1.359281301498413
# Time for epoch 188 is 1.197514533996582 sec Generator Loss: 0.7741271257400513,  Discriminator_loss: 1.3602994680404663
# Time for epoch 189 is 1.1838154792785645 sec Generator Loss: 0.7729559540748596,  Discriminator_loss: 1.3579583168029785
# Time for epoch 190 is 1.2288737297058105 sec Generator Loss: 0.7777384519577026,  Discriminator_loss: 1.3611220121383667
# Time for epoch 191 is 1.1707406044006348 sec Generator Loss: 0.7796320915222168,  Discriminator_loss: 1.3637254238128662
# Time for epoch 192 is 1.1234419345855713 sec Generator Loss: 0.7852533459663391,  Discriminator_loss: 1.359153389930725
# Time for epoch 193 is 1.0230681896209717 sec Generator Loss: 0.7801654934883118,  Discriminator_loss: 1.358528733253479
# Time for epoch 194 is 1.0554308891296387 sec Generator Loss: 0.7823201417922974,  Discriminator_loss: 1.3583751916885376
# Time for epoch 195 is 1.0057663917541504 sec Generator Loss: 0.7738834023475647,  Discriminator_loss: 1.3576483726501465
# Time for epoch 196 is 1.0452580451965332 sec Generator Loss: 0.7841702699661255,  Discriminator_loss: 1.3559255599975586
# Time for epoch 197 is 1.0492169857025146 sec Generator Loss: 0.7775397300720215,  Discriminator_loss: 1.3540066480636597
# Time for epoch 198 is 1.0300319194793701 sec Generator Loss: 0.785496711730957,  Discriminator_loss: 1.353698968887329
# Time for epoch 199 is 1.0448567867279053 sec Generator Loss: 0.7913838624954224,  Discriminator_loss: 1.3537755012512207
# Time for epoch 200 is 1.0254285335540771 sec Generator Loss: 0.7811493277549744,  Discriminator_loss: 1.3530170917510986
# Time for epoch 201 is 1.0350024700164795 sec Generator Loss: 0.786390483379364,  Discriminator_loss: 1.3552343845367432
# Time for epoch 202 is 1.0259335041046143 sec Generator Loss: 0.7848660945892334,  Discriminator_loss: 1.355449914932251
# Time for epoch 203 is 1.0279150009155273 sec Generator Loss: 0.7860730290412903,  Discriminator_loss: 1.3555922508239746
# Time for epoch 204 is 1.04121994972229 sec Generator Loss: 0.7793202996253967,  Discriminator_loss: 1.3616106510162354
# Time for epoch 205 is 1.0113253593444824 sec Generator Loss: 0.7940236926078796,  Discriminator_loss: 1.3551439046859741
# Time for epoch 206 is 1.0372271537780762 sec Generator Loss: 0.78060382604599,  Discriminator_loss: 1.354795217514038
# Time for epoch 207 is 1.0379676818847656 sec Generator Loss: 0.7849339246749878,  Discriminator_loss: 1.3595081567764282
# Time for epoch 208 is 1.0415701866149902 sec Generator Loss: 0.7797263860702515,  Discriminator_loss: 1.3657249212265015
# Time for epoch 209 is 1.0659961700439453 sec Generator Loss: 0.7810681462287903,  Discriminator_loss: 1.3557240962982178
# Time for epoch 210 is 1.0477428436279297 sec Generator Loss: 0.7789598703384399,  Discriminator_loss: 1.3633953332901
# Time for epoch 211 is 1.0856797695159912 sec Generator Loss: 0.788720965385437,  Discriminator_loss: 1.3571734428405762
# Time for epoch 212 is 1.2635948657989502 sec Generator Loss: 0.7835379242897034,  Discriminator_loss: 1.3591045141220093
# Time for epoch 213 is 1.0302760601043701 sec Generator Loss: 0.7772315740585327,  Discriminator_loss: 1.3572707176208496
# Time for epoch 214 is 1.0115971565246582 sec Generator Loss: 0.7797345519065857,  Discriminator_loss: 1.3614842891693115
# Time for epoch 215 is 1.206838846206665 sec Generator Loss: 0.7804588675498962,  Discriminator_loss: 1.3607839345932007
# Time for epoch 216 is 1.0885848999023438 sec Generator Loss: 0.784025251865387,  Discriminator_loss: 1.3532296419143677
# Time for epoch 217 is 1.037078857421875 sec Generator Loss: 0.7823482155799866,  Discriminator_loss: 1.3508583307266235
# Time for epoch 218 is 0.9944756031036377 sec Generator Loss: 0.7825311422348022,  Discriminator_loss: 1.3583914041519165
# Time for epoch 219 is 0.9971065521240234 sec Generator Loss: 0.7805132865905762,  Discriminator_loss: 1.359288215637207
# Time for epoch 220 is 0.9551334381103516 sec Generator Loss: 0.7819646596908569,  Discriminator_loss: 1.3574199676513672
# Time for epoch 221 is 0.9645633697509766 sec Generator Loss: 0.7797074913978577,  Discriminator_loss: 1.3518904447555542
# Time for epoch 222 is 0.9784603118896484 sec Generator Loss: 0.7843762040138245,  Discriminator_loss: 1.3584181070327759
# Time for epoch 223 is 1.0668601989746094 sec Generator Loss: 0.7821675539016724,  Discriminator_loss: 1.3559362888336182
# Time for epoch 224 is 1.0974764823913574 sec Generator Loss: 0.7826866507530212,  Discriminator_loss: 1.353158950805664
# Time for epoch 225 is 1.0259194374084473 sec Generator Loss: 0.7824563980102539,  Discriminator_loss: 1.3598140478134155
# Time for epoch 226 is 1.041599988937378 sec Generator Loss: 0.7879224419593811,  Discriminator_loss: 1.3577497005462646
# Time for epoch 227 is 1.0418877601623535 sec Generator Loss: 0.7948325276374817,  Discriminator_loss: 1.3570550680160522
# Time for epoch 228 is 1.0391759872436523 sec Generator Loss: 0.7889074087142944,  Discriminator_loss: 1.3543838262557983
# Time for epoch 229 is 1.0733599662780762 sec Generator Loss: 0.7866035103797913,  Discriminator_loss: 1.3560848236083984
# Time for epoch 230 is 0.9968364238739014 sec Generator Loss: 0.7862992882728577,  Discriminator_loss: 1.358750343322754
# Time for epoch 231 is 1.1288537979125977 sec Generator Loss: 0.7835642695426941,  Discriminator_loss: 1.3562006950378418
# Time for epoch 232 is 1.1399452686309814 sec Generator Loss: 0.7894143462181091,  Discriminator_loss: 1.3525699377059937
# Time for epoch 233 is 1.1096510887145996 sec Generator Loss: 0.7846377491950989,  Discriminator_loss: 1.3565722703933716
# Time for epoch 234 is 0.9462184906005859 sec Generator Loss: 0.7816658616065979,  Discriminator_loss: 1.3642624616622925
# Time for epoch 235 is 1.226271629333496 sec Generator Loss: 0.78565514087677,  Discriminator_loss: 1.3558359146118164
# Time for epoch 236 is 1.201279640197754 sec Generator Loss: 0.780974268913269,  Discriminator_loss: 1.3508566617965698
# Time for epoch 237 is 1.238342046737671 sec Generator Loss: 0.7789958715438843,  Discriminator_loss: 1.3544178009033203
# Time for epoch 238 is 0.9985730648040771 sec Generator Loss: 0.7860193252563477,  Discriminator_loss: 1.3513083457946777
# Time for epoch 239 is 0.9484312534332275 sec Generator Loss: 0.7874796986579895,  Discriminator_loss: 1.3535206317901611
# Time for epoch 240 is 0.9305331707000732 sec Generator Loss: 0.7941663861274719,  Discriminator_loss: 1.3515079021453857
# Time for epoch 241 is 1.0128533840179443 sec Generator Loss: 0.7832768559455872,  Discriminator_loss: 1.3579145669937134
# Time for epoch 242 is 0.9857437610626221 sec Generator Loss: 0.79228276014328,  Discriminator_loss: 1.352226972579956
# Time for epoch 243 is 1.0143630504608154 sec Generator Loss: 0.7874301075935364,  Discriminator_loss: 1.3566877841949463
# Time for epoch 244 is 1.103755235671997 sec Generator Loss: 0.796826183795929,  Discriminator_loss: 1.3537347316741943
# Time for epoch 245 is 1.1622545719146729 sec Generator Loss: 0.7869873642921448,  Discriminator_loss: 1.3522924184799194
# Time for epoch 246 is 1.103273868560791 sec Generator Loss: 0.7814742922782898,  Discriminator_loss: 1.360954761505127
# Time for epoch 247 is 1.1344630718231201 sec Generator Loss: 0.7840146422386169,  Discriminator_loss: 1.3571572303771973
# Time for epoch 248 is 1.020751953125 sec Generator Loss: 0.7843322157859802,  Discriminator_loss: 1.3590599298477173
# Time for epoch 249 is 1.0371077060699463 sec Generator Loss: 0.7804467678070068,  Discriminator_loss: 1.3536090850830078
# Time for epoch 250 is 1.0166096687316895 sec Generator Loss: 0.7877897024154663,  Discriminator_loss: 1.3541711568832397
# Time for epoch 251 is 0.976210355758667 sec Generator Loss: 0.7868520021438599,  Discriminator_loss: 1.358056902885437
# Time for epoch 252 is 0.9858753681182861 sec Generator Loss: 0.7819764018058777,  Discriminator_loss: 1.3587790727615356
# Time for epoch 253 is 1.0412204265594482 sec Generator Loss: 0.7820703387260437,  Discriminator_loss: 1.3529261350631714
# Time for epoch 254 is 1.2603719234466553 sec Generator Loss: 0.7827649712562561,  Discriminator_loss: 1.3563729524612427
# Time for epoch 255 is 1.1404788494110107 sec Generator Loss: 0.7826181054115295,  Discriminator_loss: 1.3546651601791382
# Time for epoch 256 is 1.3435204029083252 sec Generator Loss: 0.7875012159347534,  Discriminator_loss: 1.352671504020691
# Time for epoch 257 is 1.0789594650268555 sec Generator Loss: 0.782584547996521,  Discriminator_loss: 1.3608763217926025
# Time for epoch 258 is 1.0806479454040527 sec Generator Loss: 0.7889900207519531,  Discriminator_loss: 1.3550571203231812
# Time for epoch 259 is 1.0209736824035645 sec Generator Loss: 0.7821164131164551,  Discriminator_loss: 1.355363130569458
# Time for epoch 260 is 0.9977226257324219 sec Generator Loss: 0.7963515520095825,  Discriminator_loss: 1.3533686399459839
# Time for epoch 261 is 1.0130400657653809 sec Generator Loss: 0.7921810746192932,  Discriminator_loss: 1.3505891561508179
# Time for epoch 262 is 1.0531260967254639 sec Generator Loss: 0.7885177135467529,  Discriminator_loss: 1.3624135255813599
# Time for epoch 263 is 1.0490241050720215 sec Generator Loss: 0.7900010943412781,  Discriminator_loss: 1.3589645624160767
# Time for epoch 264 is 1.0250108242034912 sec Generator Loss: 0.7884395718574524,  Discriminator_loss: 1.3533403873443604
# Time for epoch 265 is 1.0029664039611816 sec Generator Loss: 0.7889114618301392,  Discriminator_loss: 1.357406735420227
# Time for epoch 266 is 1.0673792362213135 sec Generator Loss: 0.7909896969795227,  Discriminator_loss: 1.3482940196990967
# Time for epoch 267 is 1.0494532585144043 sec Generator Loss: 0.7913985252380371,  Discriminator_loss: 1.351209044456482
# Time for epoch 268 is 1.0210886001586914 sec Generator Loss: 0.7833357453346252,  Discriminator_loss: 1.354339838027954
# Time for epoch 269 is 1.0031814575195312 sec Generator Loss: 0.8002179265022278,  Discriminator_loss: 1.3489140272140503
# Time for epoch 270 is 1.0438518524169922 sec Generator Loss: 0.7942153811454773,  Discriminator_loss: 1.3506380319595337
# Time for epoch 271 is 1.3132035732269287 sec Generator Loss: 0.7762075066566467,  Discriminator_loss: 1.3606667518615723
# Time for epoch 272 is 1.207315444946289 sec Generator Loss: 0.7776460647583008,  Discriminator_loss: 1.3564318418502808
# Time for epoch 273 is 1.0900547504425049 sec Generator Loss: 0.7870075702667236,  Discriminator_loss: 1.355812668800354
# Time for epoch 274 is 1.0613396167755127 sec Generator Loss: 0.7828942537307739,  Discriminator_loss: 1.3535821437835693
# Time for epoch 275 is 1.0803451538085938 sec Generator Loss: 0.7856142520904541,  Discriminator_loss: 1.3540343046188354
# Time for epoch 276 is 1.0666472911834717 sec Generator Loss: 0.7802139520645142,  Discriminator_loss: 1.3526982069015503
# Time for epoch 277 is 1.0082955360412598 sec Generator Loss: 0.7840943932533264,  Discriminator_loss: 1.3548482656478882
# Time for epoch 278 is 0.9966871738433838 sec Generator Loss: 0.7853832244873047,  Discriminator_loss: 1.3522040843963623
# Time for epoch 279 is 1.029435157775879 sec Generator Loss: 0.7875761985778809,  Discriminator_loss: 1.3565716743469238
# Time for epoch 280 is 0.9120469093322754 sec Generator Loss: 0.7877143025398254,  Discriminator_loss: 1.3517913818359375
# Time for epoch 281 is 1.0681421756744385 sec Generator Loss: 0.7854645252227783,  Discriminator_loss: 1.3585724830627441
# Time for epoch 282 is 1.1307923793792725 sec Generator Loss: 0.7878322601318359,  Discriminator_loss: 1.3487616777420044
# Time for epoch 283 is 1.1543927192687988 sec Generator Loss: 0.7847104072570801,  Discriminator_loss: 1.351675033569336
# Time for epoch 284 is 1.0895812511444092 sec Generator Loss: 0.7903407216072083,  Discriminator_loss: 1.351070523262024
# Time for epoch 285 is 1.1475787162780762 sec Generator Loss: 0.7819063663482666,  Discriminator_loss: 1.3539193868637085
# Time for epoch 286 is 1.1794946193695068 sec Generator Loss: 0.7851901650428772,  Discriminator_loss: 1.3551522493362427
# Time for epoch 287 is 1.1071186065673828 sec Generator Loss: 0.7920860052108765,  Discriminator_loss: 1.3526843786239624
# Time for epoch 288 is 1.0671865940093994 sec Generator Loss: 0.7897735238075256,  Discriminator_loss: 1.3584457635879517
# Time for epoch 289 is 1.0936689376831055 sec Generator Loss: 0.7837541103363037,  Discriminator_loss: 1.3515263795852661
# Time for epoch 290 is 1.1019623279571533 sec Generator Loss: 0.7818211317062378,  Discriminator_loss: 1.3548648357391357
# Time for epoch 291 is 1.0445547103881836 sec Generator Loss: 0.7805216908454895,  Discriminator_loss: 1.3603181838989258
# Time for epoch 292 is 1.0434918403625488 sec Generator Loss: 0.7872642278671265,  Discriminator_loss: 1.3490625619888306
# Time for epoch 293 is 1.0185797214508057 sec Generator Loss: 0.780569851398468,  Discriminator_loss: 1.3530946969985962
# Time for epoch 294 is 0.9820075035095215 sec Generator Loss: 0.7852449417114258,  Discriminator_loss: 1.3500882387161255
# Time for epoch 295 is 1.045236349105835 sec Generator Loss: 0.7853051424026489,  Discriminator_loss: 1.352851152420044
# Time for epoch 296 is 0.9716684818267822 sec Generator Loss: 0.7939212322235107,  Discriminator_loss: 1.342071533203125
# Time for epoch 297 is 0.9680449962615967 sec Generator Loss: 0.7944325804710388,  Discriminator_loss: 1.3479893207550049
# Time for epoch 298 is 0.9778163433074951 sec Generator Loss: 0.7855501770973206,  Discriminator_loss: 1.3538165092468262
# Time for epoch 299 is 0.9916672706604004 sec Generator Loss: 0.7919920086860657,  Discriminator_loss: 1.3495293855667114
# Time for epoch 300 is 1.0349464416503906 sec Generator Loss: 0.7930566072463989,  Discriminator_loss: 1.3501993417739868
# Time for epoch 301 is 0.981114387512207 sec Generator Loss: 0.7906498908996582,  Discriminator_loss: 1.3462777137756348
# Time for epoch 302 is 1.0456254482269287 sec Generator Loss: 0.7873730659484863,  Discriminator_loss: 1.3535935878753662
# Time for epoch 303 is 1.0570354461669922 sec Generator Loss: 0.7878146171569824,  Discriminator_loss: 1.3534165620803833
# Time for epoch 304 is 1.0363132953643799 sec Generator Loss: 0.781990110874176,  Discriminator_loss: 1.3567798137664795
# Time for epoch 305 is 1.1283485889434814 sec Generator Loss: 0.7844974994659424,  Discriminator_loss: 1.3562971353530884
# Time for epoch 306 is 0.9371078014373779 sec Generator Loss: 0.7907538414001465,  Discriminator_loss: 1.3559798002243042
# Time for epoch 307 is 0.8804121017456055 sec Generator Loss: 0.7831081748008728,  Discriminator_loss: 1.3536903858184814
# Time for epoch 308 is 0.879436731338501 sec Generator Loss: 0.7864152193069458,  Discriminator_loss: 1.3623161315917969
# Time for epoch 309 is 0.8798022270202637 sec Generator Loss: 0.7881978750228882,  Discriminator_loss: 1.3481037616729736
# Time for epoch 310 is 0.9163262844085693 sec Generator Loss: 0.7827106714248657,  Discriminator_loss: 1.3531532287597656
# Time for epoch 311 is 0.9584465026855469 sec Generator Loss: 0.7853783369064331,  Discriminator_loss: 1.3534923791885376
# Time for epoch 312 is 1.046827793121338 sec Generator Loss: 0.7860355973243713,  Discriminator_loss: 1.35306978225708
# Time for epoch 313 is 1.098747730255127 sec Generator Loss: 0.7846818566322327,  Discriminator_loss: 1.3529900312423706
# Time for epoch 314 is 1.0044333934783936 sec Generator Loss: 0.7905404567718506,  Discriminator_loss: 1.3477474451065063
# Time for epoch 315 is 1.0856468677520752 sec Generator Loss: 0.7854043841362,  Discriminator_loss: 1.3554152250289917
# Time for epoch 316 is 1.0511970520019531 sec Generator Loss: 0.7908043265342712,  Discriminator_loss: 1.3540513515472412
# Time for epoch 317 is 0.9931230545043945 sec Generator Loss: 0.788170576095581,  Discriminator_loss: 1.3530596494674683
# Time for epoch 318 is 0.9733703136444092 sec Generator Loss: 0.7854309678077698,  Discriminator_loss: 1.3537776470184326
# Time for epoch 319 is 0.9742569923400879 sec Generator Loss: 0.7901247143745422,  Discriminator_loss: 1.3479933738708496
# Time for epoch 320 is 0.9186305999755859 sec Generator Loss: 0.795444130897522,  Discriminator_loss: 1.3537485599517822
# Time for epoch 321 is 0.9379193782806396 sec Generator Loss: 0.7957611083984375,  Discriminator_loss: 1.3546695709228516
# Time for epoch 322 is 0.9892497062683105 sec Generator Loss: 0.7888893485069275,  Discriminator_loss: 1.3511879444122314
# Time for epoch 323 is 0.9819815158843994 sec Generator Loss: 0.7858061194419861,  Discriminator_loss: 1.3534374237060547
# Time for epoch 324 is 0.9869515895843506 sec Generator Loss: 0.794987678527832,  Discriminator_loss: 1.3489116430282593
# Time for epoch 325 is 0.9774215221405029 sec Generator Loss: 0.7804772853851318,  Discriminator_loss: 1.3526026010513306
# Time for epoch 326 is 0.9099767208099365 sec Generator Loss: 0.7824461460113525,  Discriminator_loss: 1.3495614528656006
# Time for epoch 327 is 0.8840250968933105 sec Generator Loss: 0.7882243990898132,  Discriminator_loss: 1.3502212762832642
# Time for epoch 328 is 0.8837358951568604 sec Generator Loss: 0.789493203163147,  Discriminator_loss: 1.350591778755188
# Time for epoch 329 is 0.8837599754333496 sec Generator Loss: 0.7916580438613892,  Discriminator_loss: 1.350829005241394
# Time for epoch 330 is 0.881206750869751 sec Generator Loss: 0.7889561057090759,  Discriminator_loss: 1.348332166671753
# Time for epoch 331 is 0.9646425247192383 sec Generator Loss: 0.7934468388557434,  Discriminator_loss: 1.3540788888931274
# Time for epoch 332 is 0.9557943344116211 sec Generator Loss: 0.7974278330802917,  Discriminator_loss: 1.3516316413879395
# Time for epoch 333 is 0.9314019680023193 sec Generator Loss: 0.7938616871833801,  Discriminator_loss: 1.3563345670700073
# Time for epoch 334 is 0.929495096206665 sec Generator Loss: 0.7892881631851196,  Discriminator_loss: 1.3527474403381348
# Time for epoch 335 is 0.8790380954742432 sec Generator Loss: 0.7858564257621765,  Discriminator_loss: 1.3499751091003418
# Time for epoch 336 is 0.9150779247283936 sec Generator Loss: 0.7855884432792664,  Discriminator_loss: 1.3564876317977905
# Time for epoch 337 is 0.8819849491119385 sec Generator Loss: 0.7835296392440796,  Discriminator_loss: 1.3528286218643188
# Time for epoch 338 is 0.9102118015289307 sec Generator Loss: 0.7950059771537781,  Discriminator_loss: 1.3474147319793701
# Time for epoch 339 is 0.9821195602416992 sec Generator Loss: 0.7937982678413391,  Discriminator_loss: 1.3517417907714844
# Time for epoch 340 is 1.0065133571624756 sec Generator Loss: 0.7959780097007751,  Discriminator_loss: 1.3532569408416748
# Time for epoch 341 is 1.0088400840759277 sec Generator Loss: 0.7958560585975647,  Discriminator_loss: 1.347680687904358
# Time for epoch 342 is 1.029315710067749 sec Generator Loss: 0.7938631176948547,  Discriminator_loss: 1.3464293479919434
# Time for epoch 343 is 0.9398057460784912 sec Generator Loss: 0.7855169773101807,  Discriminator_loss: 1.351054310798645
# Time for epoch 344 is 0.8961913585662842 sec Generator Loss: 0.788833498954773,  Discriminator_loss: 1.349452257156372
# Time for epoch 345 is 0.8853166103363037 sec Generator Loss: 0.7923693656921387,  Discriminator_loss: 1.3553221225738525
# Time for epoch 346 is 0.8977639675140381 sec Generator Loss: 0.784976065158844,  Discriminator_loss: 1.3538004159927368
# Time for epoch 347 is 0.9354920387268066 sec Generator Loss: 0.7942619323730469,  Discriminator_loss: 1.3495988845825195
# Time for epoch 348 is 0.8895282745361328 sec Generator Loss: 0.7882204055786133,  Discriminator_loss: 1.3521264791488647
# Time for epoch 349 is 0.8960959911346436 sec Generator Loss: 0.7923577427864075,  Discriminator_loss: 1.3493435382843018
# Time for epoch 350 is 0.8937520980834961 sec Generator Loss: 0.7981808185577393,  Discriminator_loss: 1.3497313261032104
# Time for epoch 351 is 0.977294921875 sec Generator Loss: 0.7892640233039856,  Discriminator_loss: 1.3502390384674072
# Time for epoch 352 is 1.0223793983459473 sec Generator Loss: 0.7953301668167114,  Discriminator_loss: 1.3470855951309204
# Time for epoch 353 is 1.0176525115966797 sec Generator Loss: 0.7908955216407776,  Discriminator_loss: 1.3542827367782593
# Time for epoch 354 is 1.0067534446716309 sec Generator Loss: 0.7864150404930115,  Discriminator_loss: 1.3490643501281738
# Time for epoch 355 is 1.0160377025604248 sec Generator Loss: 0.7879868149757385,  Discriminator_loss: 1.349453330039978
# Time for epoch 356 is 1.0249574184417725 sec Generator Loss: 0.7977249026298523,  Discriminator_loss: 1.3486659526824951
# Time for epoch 357 is 1.090284824371338 sec Generator Loss: 0.788948118686676,  Discriminator_loss: 1.3515348434448242
# Time for epoch 358 is 1.0017354488372803 sec Generator Loss: 0.7925811409950256,  Discriminator_loss: 1.3505494594573975
# Time for epoch 359 is 1.0496826171875 sec Generator Loss: 0.7921009063720703,  Discriminator_loss: 1.3498740196228027
# Time for epoch 360 is 1.2006514072418213 sec Generator Loss: 0.7915418148040771,  Discriminator_loss: 1.3496090173721313
# Time for epoch 361 is 1.1813404560089111 sec Generator Loss: 0.7907386422157288,  Discriminator_loss: 1.3490643501281738
# Time for epoch 362 is 1.0277254581451416 sec Generator Loss: 0.7964257597923279,  Discriminator_loss: 1.3481125831604004
# Time for epoch 363 is 0.9467258453369141 sec Generator Loss: 0.7961361408233643,  Discriminator_loss: 1.3427724838256836
# Time for epoch 364 is 0.9045381546020508 sec Generator Loss: 0.79756760597229,  Discriminator_loss: 1.3534986972808838
# Time for epoch 365 is 0.954688549041748 sec Generator Loss: 0.7911046147346497,  Discriminator_loss: 1.3537590503692627
# Time for epoch 366 is 1.0921297073364258 sec Generator Loss: 0.7919268012046814,  Discriminator_loss: 1.3485838174819946
# Time for epoch 367 is 1.0121049880981445 sec Generator Loss: 0.7921385765075684,  Discriminator_loss: 1.3493175506591797
# Time for epoch 368 is 0.985532283782959 sec Generator Loss: 0.7884694337844849,  Discriminator_loss: 1.3477894067764282
# Time for epoch 369 is 0.9183812141418457 sec Generator Loss: 0.7950751781463623,  Discriminator_loss: 1.3454562425613403
# Time for epoch 370 is 0.9417505264282227 sec Generator Loss: 0.7911655902862549,  Discriminator_loss: 1.351661205291748
# Time for epoch 371 is 0.9873847961425781 sec Generator Loss: 0.7905092835426331,  Discriminator_loss: 1.349104404449463
# Time for epoch 372 is 0.9997458457946777 sec Generator Loss: 0.7980054020881653,  Discriminator_loss: 1.3489078283309937
# Time for epoch 373 is 1.1171352863311768 sec Generator Loss: 0.7915492057800293,  Discriminator_loss: 1.3484976291656494
# Time for epoch 374 is 1.0221703052520752 sec Generator Loss: 0.7890044450759888,  Discriminator_loss: 1.3567756414413452
# Time for epoch 375 is 0.9106495380401611 sec Generator Loss: 0.7877577543258667,  Discriminator_loss: 1.3500241041183472
# Time for epoch 376 is 0.9251453876495361 sec Generator Loss: 0.7987503409385681,  Discriminator_loss: 1.3553016185760498
# Time for epoch 377 is 0.932072639465332 sec Generator Loss: 0.7863376140594482,  Discriminator_loss: 1.3507417440414429
# Time for epoch 378 is 0.9000139236450195 sec Generator Loss: 0.7910867929458618,  Discriminator_loss: 1.351313591003418
# Time for epoch 379 is 0.901787519454956 sec Generator Loss: 0.79510897397995,  Discriminator_loss: 1.3528584241867065
# Time for epoch 380 is 0.9834949970245361 sec Generator Loss: 0.7894731163978577,  Discriminator_loss: 1.3552905321121216
# Time for epoch 381 is 0.9620683193206787 sec Generator Loss: 0.7965158224105835,  Discriminator_loss: 1.3432629108428955
# ...
# Time for epoch 1871 is 0.9729282855987549 sec Generator Loss: 0.7933370471000671,  Discriminator_loss: 1.3525217771530151
# Time for epoch 1872 is 0.9728262424468994 sec Generator Loss: 0.7933529615402222,  Discriminator_loss: 1.3491489887237549
# Time for epoch 1873 is 0.9526548385620117 sec Generator Loss: 0.7872070074081421,  Discriminator_loss: 1.3496686220169067
# Time for epoch 1874 is 0.9720792770385742 sec Generator Loss: 0.795761227607727,  Discriminator_loss: 1.3524423837661743
# Time for epoch 1875 is 0.9729080200195312 sec Generator Loss: 0.7963619232177734,  Discriminator_loss: 1.3512160778045654
# Time for epoch 1876 is 0.9932732582092285 sec Generator Loss: 0.7884809374809265,  Discriminator_loss: 1.3506314754486084
# Time for epoch 1877 is 1.0248594284057617 sec Generator Loss: 0.7917982339859009,  Discriminator_loss: 1.3524173498153687
# Time for epoch 1878 is 0.9672389030456543 sec Generator Loss: 0.7960699796676636,  Discriminator_loss: 1.3459174633026123
# Time for epoch 1879 is 0.9799802303314209 sec Generator Loss: 0.791386067867279,  Discriminator_loss: 1.3507572412490845
# Time for epoch 1880 is 0.9647672176361084 sec Generator Loss: 0.8003103137016296,  Discriminator_loss: 1.34816312789917
# Time for epoch 1881 is 0.9668149948120117 sec Generator Loss: 0.8037521243095398,  Discriminator_loss: 1.3490463495254517
# Time for epoch 1882 is 0.9668760299682617 sec Generator Loss: 0.7944684624671936,  Discriminator_loss: 1.353076457977295
# Time for epoch 1883 is 0.992138147354126 sec Generator Loss: 0.7864456176757812,  Discriminator_loss: 1.3542592525482178
# Time for epoch 1884 is 0.9969577789306641 sec Generator Loss: 0.7966066002845764,  Discriminator_loss: 1.355573058128357
# Time for epoch 1885 is 0.9691944122314453 sec Generator Loss: 0.7883744239807129,  Discriminator_loss: 1.3517431020736694
# Time for epoch 1886 is 0.9701876640319824 sec Generator Loss: 0.7880600094795227,  Discriminator_loss: 1.3532568216323853
# Time for epoch 1887 is 1.8394372463226318 sec Generator Loss: 0.791827917098999,  Discriminator_loss: 1.3548272848129272
# Time for epoch 1888 is 0.9979860782623291 sec Generator Loss: 0.7936396598815918,  Discriminator_loss: 1.3526521921157837
# Time for epoch 1889 is 1.0287401676177979 sec Generator Loss: 0.7880408763885498,  Discriminator_loss: 1.3565406799316406
# Time for epoch 1890 is 1.018399715423584 sec Generator Loss: 0.7917052507400513,  Discriminator_loss: 1.3478163480758667
# Time for epoch 1891 is 0.9726746082305908 sec Generator Loss: 0.7938746213912964,  Discriminator_loss: 1.3531248569488525
# Time for epoch 1892 is 0.9889442920684814 sec Generator Loss: 0.8029522895812988,  Discriminator_loss: 1.3477200269699097
# Time for epoch 1893 is 0.9674851894378662 sec Generator Loss: 0.7952768206596375,  Discriminator_loss: 1.3473507165908813
# Time for epoch 1894 is 0.9701778888702393 sec Generator Loss: 0.78789222240448,  Discriminator_loss: 1.3587816953659058
# Time for epoch 1895 is 0.9658167362213135 sec Generator Loss: 0.7820155024528503,  Discriminator_loss: 1.3561782836914062
# Time for epoch 1896 is 0.9685049057006836 sec Generator Loss: 0.7932406663894653,  Discriminator_loss: 1.3530850410461426
# Time for epoch 1897 is 1.0421292781829834 sec Generator Loss: 0.8000485897064209,  Discriminator_loss: 1.3494211435317993
# Time for epoch 1898 is 1.05352783203125 sec Generator Loss: 0.7886857390403748,  Discriminator_loss: 1.352759599685669
# Time for epoch 1899 is 1.023810863494873 sec Generator Loss: 0.7907430529594421,  Discriminator_loss: 1.3492279052734375
# Time for epoch 1900 is 0.9860107898712158 sec Generator Loss: 0.7949431538581848,  Discriminator_loss: 1.3503469228744507
# Time for epoch 1901 is 1.004948377609253 sec Generator Loss: 0.7937783598899841,  Discriminator_loss: 1.3482812643051147
# Time for epoch 1902 is 1.0066943168640137 sec Generator Loss: 0.7965313196182251,  Discriminator_loss: 1.3525010347366333
# Time for epoch 1903 is 0.987842321395874 sec Generator Loss: 0.7967653274536133,  Discriminator_loss: 1.3493351936340332
# Time for epoch 1904 is 0.966172456741333 sec Generator Loss: 0.7893230319023132,  Discriminator_loss: 1.3584622144699097
# Time for epoch 1905 is 0.9882807731628418 sec Generator Loss: 0.7828338146209717,  Discriminator_loss: 1.35798180103302
# Time for epoch 1906 is 1.0105433464050293 sec Generator Loss: 0.7865792512893677,  Discriminator_loss: 1.3571659326553345
# Time for epoch 1907 is 1.057021141052246 sec Generator Loss: 0.7955687046051025,  Discriminator_loss: 1.3582910299301147
# Time for epoch 1908 is 0.978287935256958 sec Generator Loss: 0.7973639369010925,  Discriminator_loss: 1.3473517894744873
# Time for epoch 1909 is 0.9794425964355469 sec Generator Loss: 0.793047308921814,  Discriminator_loss: 1.3582028150558472
# Time for epoch 1910 is 0.9793672561645508 sec Generator Loss: 0.7995347380638123,  Discriminator_loss: 1.3527098894119263
# Time for epoch 1911 is 0.9764494895935059 sec Generator Loss: 0.7910659909248352,  Discriminator_loss: 1.3508905172348022
# Time for epoch 1912 is 0.9795641899108887 sec Generator Loss: 0.7972093224525452,  Discriminator_loss: 1.3453471660614014
# Time for epoch 1913 is 0.9867730140686035 sec Generator Loss: 0.7913529276847839,  Discriminator_loss: 1.3485722541809082
# Time for epoch 1914 is 0.9798324108123779 sec Generator Loss: 0.7974807024002075,  Discriminator_loss: 1.3505536317825317
# Time for epoch 1915 is 0.9756374359130859 sec Generator Loss: 0.792591392993927,  Discriminator_loss: 1.3504201173782349
# Time for epoch 1916 is 0.9741888046264648 sec Generator Loss: 0.7919926047325134,  Discriminator_loss: 1.3553472757339478
# Time for epoch 1917 is 0.9721484184265137 sec Generator Loss: 0.7974742650985718,  Discriminator_loss: 1.3482835292816162
# Time for epoch 1918 is 0.9711916446685791 sec Generator Loss: 0.7904579639434814,  Discriminator_loss: 1.3575934171676636
# Time for epoch 1919 is 0.9576256275177002 sec Generator Loss: 0.7900159358978271,  Discriminator_loss: 1.3493925333023071
# Time for epoch 1920 is 0.9702785015106201 sec Generator Loss: 0.7918525338172913,  Discriminator_loss: 1.349570393562317
# Time for epoch 1921 is 0.9379494190216064 sec Generator Loss: 0.7875165939331055,  Discriminator_loss: 1.358138918876648
# Time for epoch 1922 is 0.9283962249755859 sec Generator Loss: 0.7964121699333191,  Discriminator_loss: 1.349203109741211
# Time for epoch 1923 is 0.9552865028381348 sec Generator Loss: 0.7967515587806702,  Discriminator_loss: 1.3516243696212769
# Time for epoch 1924 is 0.9418644905090332 sec Generator Loss: 0.7972339987754822,  Discriminator_loss: 1.3498852252960205
# Time for epoch 1925 is 0.9727020263671875 sec Generator Loss: 0.7892007827758789,  Discriminator_loss: 1.3532474040985107
# Time for epoch 1926 is 0.987921953201294 sec Generator Loss: 0.7999616265296936,  Discriminator_loss: 1.3498804569244385
# Time for epoch 1927 is 0.9734723567962646 sec Generator Loss: 0.7895038723945618,  Discriminator_loss: 1.3551959991455078
# Time for epoch 1928 is 0.9664323329925537 sec Generator Loss: 0.7851418256759644,  Discriminator_loss: 1.3512014150619507
# Time for epoch 1929 is 0.9776742458343506 sec Generator Loss: 0.7922415137290955,  Discriminator_loss: 1.3528298139572144
# Time for epoch 1930 is 0.9785583019256592 sec Generator Loss: 0.7822555303573608,  Discriminator_loss: 1.3569869995117188
# Time for epoch 1931 is 0.9506464004516602 sec Generator Loss: 0.7831417918205261,  Discriminator_loss: 1.356688141822815
# Time for epoch 1932 is 0.9224648475646973 sec Generator Loss: 0.7895275950431824,  Discriminator_loss: 1.3554569482803345
# Time for epoch 1933 is 0.938730001449585 sec Generator Loss: 0.7966985106468201,  Discriminator_loss: 1.3516911268234253
# Time for epoch 1934 is 0.9324922561645508 sec Generator Loss: 0.8040162920951843,  Discriminator_loss: 1.3453484773635864
# Time for epoch 1935 is 0.9095792770385742 sec Generator Loss: 0.8013333678245544,  Discriminator_loss: 1.3479222059249878
# Time for epoch 1936 is 0.9100744724273682 sec Generator Loss: 0.7954978942871094,  Discriminator_loss: 1.3505581617355347
# Time for epoch 1937 is 0.9111378192901611 sec Generator Loss: 0.7895056009292603,  Discriminator_loss: 1.3510558605194092
# Time for epoch 1938 is 0.9158303737640381 sec Generator Loss: 0.7880421876907349,  Discriminator_loss: 1.3558743000030518
# Time for epoch 1939 is 0.9323348999023438 sec Generator Loss: 0.7870742678642273,  Discriminator_loss: 1.354932427406311
# Time for epoch 1940 is 0.9135339260101318 sec Generator Loss: 0.7858563661575317,  Discriminator_loss: 1.3564674854278564
# Time for epoch 1941 is 0.9226505756378174 sec Generator Loss: 0.7854363322257996,  Discriminator_loss: 1.3573635816574097
# Time for epoch 1942 is 0.9123289585113525 sec Generator Loss: 0.7908837199211121,  Discriminator_loss: 1.3510273694992065
# Time for epoch 1943 is 0.9170911312103271 sec Generator Loss: 0.7982917428016663,  Discriminator_loss: 1.3506340980529785
# Time for epoch 1944 is 0.9128293991088867 sec Generator Loss: 0.7910709977149963,  Discriminator_loss: 1.3522651195526123
# Time for epoch 1945 is 0.9463527202606201 sec Generator Loss: 0.7928577661514282,  Discriminator_loss: 1.3536722660064697
# Time for epoch 1946 is 1.0101940631866455 sec Generator Loss: 0.7880697250366211,  Discriminator_loss: 1.3558976650238037
# Time for epoch 1947 is 1.0595765113830566 sec Generator Loss: 0.7929096817970276,  Discriminator_loss: 1.3532601594924927
# Time for epoch 1948 is 1.0785243511199951 sec Generator Loss: 0.7919750213623047,  Discriminator_loss: 1.3573521375656128
# Time for epoch 1949 is 1.096956729888916 sec Generator Loss: 0.7971417307853699,  Discriminator_loss: 1.3502116203308105
# Time for epoch 1950 is 1.0975532531738281 sec Generator Loss: 0.7915535569190979,  Discriminator_loss: 1.3501938581466675
# Time for epoch 1951 is 1.0013551712036133 sec Generator Loss: 0.8026098012924194,  Discriminator_loss: 1.3420442342758179
# Time for epoch 1952 is 0.9831764698028564 sec Generator Loss: 0.7871394753456116,  Discriminator_loss: 1.3531550168991089
# Time for epoch 1953 is 0.9104568958282471 sec Generator Loss: 0.790090024471283,  Discriminator_loss: 1.3518154621124268
# Time for epoch 1954 is 0.9219331741333008 sec Generator Loss: 0.7954641580581665,  Discriminator_loss: 1.3546828031539917
# Time for epoch 1955 is 0.9227571487426758 sec Generator Loss: 0.795319139957428,  Discriminator_loss: 1.3537636995315552
# Time for epoch 1956 is 0.9251065254211426 sec Generator Loss: 0.7921873331069946,  Discriminator_loss: 1.3530924320220947
# Time for epoch 1957 is 0.9233732223510742 sec Generator Loss: 0.7954563498497009,  Discriminator_loss: 1.348341464996338
# Time for epoch 1958 is 0.9356784820556641 sec Generator Loss: 0.7913015484809875,  Discriminator_loss: 1.3542062044143677
# Time for epoch 1959 is 0.9121949672698975 sec Generator Loss: 0.7777613401412964,  Discriminator_loss: 1.3589364290237427
# Time for epoch 1960 is 0.9323287010192871 sec Generator Loss: 0.7910996079444885,  Discriminator_loss: 1.3509176969528198
# Time for epoch 1961 is 0.9209799766540527 sec Generator Loss: 0.7899291515350342,  Discriminator_loss: 1.3519189357757568
# Time for epoch 1962 is 0.9030699729919434 sec Generator Loss: 0.7959187030792236,  Discriminator_loss: 1.3495874404907227
# Time for epoch 1963 is 0.9208564758300781 sec Generator Loss: 0.7935081124305725,  Discriminator_loss: 1.349003791809082
# Time for epoch 1964 is 0.9305930137634277 sec Generator Loss: 0.7930285930633545,  Discriminator_loss: 1.3550516366958618
# Time for epoch 1965 is 0.9199934005737305 sec Generator Loss: 0.7941911220550537,  Discriminator_loss: 1.3550140857696533
# Time for epoch 1966 is 0.9247026443481445 sec Generator Loss: 0.788428783416748,  Discriminator_loss: 1.351364254951477
# Time for epoch 1967 is 0.9225027561187744 sec Generator Loss: 0.7948588132858276,  Discriminator_loss: 1.3492647409439087
# Time for epoch 1968 is 0.9126102924346924 sec Generator Loss: 0.7899332642555237,  Discriminator_loss: 1.3536049127578735
# Time for epoch 1969 is 0.9139828681945801 sec Generator Loss: 0.7937837243080139,  Discriminator_loss: 1.3506964445114136
# Time for epoch 1970 is 0.9174540042877197 sec Generator Loss: 0.7922306060791016,  Discriminator_loss: 1.3491857051849365
# Time for epoch 1971 is 0.9301843643188477 sec Generator Loss: 0.8005715012550354,  Discriminator_loss: 1.3472480773925781
# Time for epoch 1972 is 0.9087700843811035 sec Generator Loss: 0.7995578050613403,  Discriminator_loss: 1.3502652645111084
# Time for epoch 1973 is 0.933509349822998 sec Generator Loss: 0.7841081619262695,  Discriminator_loss: 1.353969693183899
# Time for epoch 1974 is 0.9242570400238037 sec Generator Loss: 0.7843038439750671,  Discriminator_loss: 1.3556692600250244
# Time for epoch 1975 is 0.9290399551391602 sec Generator Loss: 0.7935442328453064,  Discriminator_loss: 1.354689121246338
# Time for epoch 1976 is 0.9153761863708496 sec Generator Loss: 0.7948768138885498,  Discriminator_loss: 1.3517422676086426
# Time for epoch 1977 is 0.9178268909454346 sec Generator Loss: 0.793430507183075,  Discriminator_loss: 1.3483487367630005
# Time for epoch 1978 is 0.9145147800445557 sec Generator Loss: 0.7998026013374329,  Discriminator_loss: 1.3524837493896484
# Time for epoch 1979 is 0.9176979064941406 sec Generator Loss: 0.7954384684562683,  Discriminator_loss: 1.3500725030899048
# Time for epoch 1980 is 0.9213922023773193 sec Generator Loss: 0.787999153137207,  Discriminator_loss: 1.3504194021224976
# Time for epoch 1981 is 0.9302666187286377 sec Generator Loss: 0.7904644012451172,  Discriminator_loss: 1.3547555208206177
# Time for epoch 1982 is 0.9400534629821777 sec Generator Loss: 0.7893095016479492,  Discriminator_loss: 1.3551208972930908
# Time for epoch 1983 is 0.9129176139831543 sec Generator Loss: 0.7946433424949646,  Discriminator_loss: 1.3520675897598267
# Time for epoch 1984 is 0.9111249446868896 sec Generator Loss: 0.7923977971076965,  Discriminator_loss: 1.3571898937225342
# Time for epoch 1985 is 0.91725754737854 sec Generator Loss: 0.7920795679092407,  Discriminator_loss: 1.347197413444519
# Time for epoch 1986 is 0.906743049621582 sec Generator Loss: 0.7935680150985718,  Discriminator_loss: 1.3554840087890625
# Time for epoch 1987 is 0.930335521697998 sec Generator Loss: 0.7935168147087097,  Discriminator_loss: 1.353784441947937
# Time for epoch 1988 is 0.9146864414215088 sec Generator Loss: 0.7834962010383606,  Discriminator_loss: 1.3552231788635254
# Time for epoch 1989 is 0.9197683334350586 sec Generator Loss: 0.7923051714897156,  Discriminator_loss: 1.3466225862503052
# Time for epoch 1990 is 0.9181785583496094 sec Generator Loss: 0.7857663631439209,  Discriminator_loss: 1.354644775390625
# Time for epoch 1991 is 0.9210128784179688 sec Generator Loss: 0.7859088182449341,  Discriminator_loss: 1.354547381401062
# Time for epoch 1992 is 0.9159092903137207 sec Generator Loss: 0.7950201630592346,  Discriminator_loss: 1.3518160581588745
# Time for epoch 1993 is 0.9185347557067871 sec Generator Loss: 0.7875404357910156,  Discriminator_loss: 1.3546545505523682
# Time for epoch 1994 is 0.9100542068481445 sec Generator Loss: 0.7908286452293396,  Discriminator_loss: 1.3526380062103271
# Time for epoch 1995 is 0.9074361324310303 sec Generator Loss: 0.7825496792793274,  Discriminator_loss: 1.3548389673233032
# Time for epoch 1996 is 0.9163353443145752 sec Generator Loss: 0.7938410639762878,  Discriminator_loss: 1.3543845415115356
# Time for epoch 1997 is 0.9457159042358398 sec Generator Loss: 0.7950342893600464,  Discriminator_loss: 1.3521469831466675
# Time for epoch 1998 is 0.9299678802490234 sec Generator Loss: 0.8007673621177673,  Discriminator_loss: 1.3515530824661255
# Time for epoch 1999 is 0.9175682067871094 sec Generator Loss: 0.7906319499015808,  Discriminator_loss: 1.3516672849655151
# Time for epoch 2000 is 0.9300565719604492 sec Generator Loss: 0.792500376701355,  Discriminator_loss: 1.3531227111816406
# 2/2 [==============================] - 1s 4ms/step
# [MSE Baseline] train: 4.259861562582889  test: 4.988566607603537
# Delta time: 0:33:45.740618
