# %%
try:
  # %tensorflow_version 2.x
except Exception:
  pass

# %% [markdown]
# # Import the libraries

# %%
import numpy as np
import pandas as pd
import os

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Embedding, Dense, Dropout, LeakyReLU, Flatten, Bidirectional, Reshape, Conv1D, GaussianNoise, BatchNormalization
import time
import datetime

from tensorflow.keras.layers import Lambda

from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model

import matplotlib.pyplot as plt
import datetime as dt
import yfinance as yf
yf.pdr_override()
from pandas_datareader import data as pdr

# %%
def plot_dataframe(df):
  for column_name in df.columns:
    plt.figure()
    plt.title(column_name)
    plt.plot(df[column_name])

# %% [markdown]
# # Preprocessing

# %%
def add_Ma(df, window=5):
    for i in range(window, df.shape[0]):
        sum = 0.0
        for k in range(1, window+1):
            sum += df.iloc[i-k, 4]
        df.loc[df.index[i], 'Ma'] = np.round(sum/window, 6)
    return df[window:]

# %%
class Standarized_TimeseriesGenerator(tf.keras.preprocessing.sequence.TimeseriesGenerator):
  def __getitem__(self, index):
    samples, targets  = super(Standarized_TimeseriesGenerator, self).__getitem__(index)
    mean = samples.mean(axis=1)
    std = samples.std(axis=1)
    samples = (samples - mean[:,None,:])/std[:,None,:]
    targets = (targets - mean)/std
    return samples, targets

# %%
def get_gen_train_test(dataframe, n_sequence, n_batch):
    data = dataframe.drop(columns='Date').to_numpy()
    targets = data
    n_samples = data.shape[0]
    train_test_split=int(n_samples*0.9)

    data_gen_train = Standarized_TimeseriesGenerator(data, targets,
                                length=n_sequence, sampling_rate=1,
                                stride=1, batch_size=n_batch,
                                start_index = 0,
                                end_index = train_test_split,
                                shuffle = True)
    data_gen_test = Standarized_TimeseriesGenerator(data, targets,
                                length=n_sequence, sampling_rate=1,
                                stride=1, batch_size=n_batch,
                                start_index = train_test_split,
                                end_index = n_samples-1)

    return data_gen_train, data_gen_test

# %% [markdown]
# # Baseline

# %%
def mean_squared_error(dataset):
    mse=0
    for X_batch, y_batch in dataset:
        mse += np.mean(np.square(X_batch[:, -1, 3:4]-y_batch[:, 3:4]))
    mse /= len(dataset)
    return mse

# %% [markdown]
# # Utilities

# %%
def mse(y_true, y_pred):
    return tf.reduce_mean(tf.square(y_true[:,3]-y_pred[:,3]))
def mae(y_true, y_pred):
    return tf.reduce_mean(tf.keras.backend.abs((y_true[:,3]-y_pred[:,3])))
    # ***The absolute is over the whole thing as y_true can be negative
def mape(y_true, y_pred):
    return tf.reduce_mean(tf.keras.backend.abs((y_true[:,3]-y_pred[:,3])/y_true[:,3]))
    # ***The absolute is over the whole thing as y_true can be negative
def rmse(y_true, y_pred):
    return tf.sqrt(tf.reduce_mean(tf.square(y_true[:,3]-y_pred[:,3])))
def ar(y_true, y_pred):
    mask = tf.cast(y_pred[1:,3] > y_true[:-1,3],tf.float32)
    return tf.reduce_mean((y_true[1:,3]-y_true[:-1,3])*mask)

# %% [markdown]
# # GAN

# %% [markdown]
# ## Perdidas

# %%
def discriminator_loss(real_output, fake_output):
    real_loss = tf.keras.losses.binary_crossentropy(tf.ones_like(real_output), real_output)
    fake_loss = tf.keras.losses.binary_crossentropy(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss
    return total_loss

def generator_loss(x, y, fake_output):
    a1=0.01
    g_loss = tf.keras.losses.binary_crossentropy(tf.ones_like(fake_output), fake_output)
    g_mse = tf.keras.losses.MSE(x, y)
    return a1*g_mse + (1-a1)*g_loss, g_mse

# %% [markdown]
# ## Generator

# %%
def make_generator_model(n_sequence, n_features):
    inputs = Input(shape=(n_sequence, n_features,))
    lstm = Bidirectional(LSTM(units=10, return_sequences=True, activation=None, kernel_initializer='random_normal'))
    lstm_1 = lstm(inputs)
    batch_norm1 = BatchNormalization()(lstm_1)
    lstm_1_LRelu = LeakyReLU(alpha=0.3)(batch_norm1)
    lstm_1_droput = Dropout(0.3)(lstm_1_LRelu)
    lstm_2 = Bidirectional(LSTM(units=10, return_sequences=False, activation=None, kernel_initializer='random_normal'))
    lstm_2_output = lstm_2(lstm_1_droput)
    batch_norm2 = BatchNormalization()(lstm_2_output)
    lstm_2_LRelu = LeakyReLU(alpha=0.3)(batch_norm2)
    lstm_2_dropout = Dropout(0.3)(lstm_2_LRelu)
    output_dense = Dense(n_features, activation=None)(lstm_2_dropout)
    output = LeakyReLU(alpha=0.3)(output_dense)
    model = Model(inputs=inputs, outputs=output)
    model.compile(loss=None, metrics=[mse, mae, mape, rmse, ar])
    model.summary()

    return model

# %% [markdown]
# ## Discriminator

# %%
def make_discriminator_model(n_features):
    model = Sequential()
    model.add(Flatten())
    model.add(Dense(units=72, input_shape=((n_sequence+1) * n_features,), activation=None, kernel_initializer='random_normal'))
    model.add(tf.keras.layers.LeakyReLU(alpha=0.3))
    model.add(tf.keras.layers.GaussianNoise(stddev=0.2))
    model.add(Dropout(0.3))
    model.add(Dense(units=100, activation=None, kernel_initializer='random_normal'))
    model.add(tf.keras.layers.LeakyReLU(alpha=0.3))
    model.add(Dropout(0.3))
    model.add(Dense(units=10, activation=None, kernel_initializer='random_normal'))
    model.add(tf.keras.layers.LeakyReLU(alpha=0.3))
    model.add(Dropout(0.3))
    model.add(Dense(1 ,activation='sigmoid'))
    model.compile(loss=discriminator_loss)
    return model

# %% [markdown]
# # Training

# %%
def train_step_def(sequences, sequences_end):
    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        generated_prediction = generator(sequences, training=True)

        sequences_true = tf.concat((sequences, sequences_end[:, None, :]), axis=1)
        sequences_fake = tf.concat((sequences, generated_prediction[:, None, :]), axis=1)

        real_output = discriminator(sequences_true, training=True)
        fake_output = discriminator(sequences_fake, training=True)

        gen_loss, gen_mse_loss = generator_loss(generated_prediction, 
                                                sequences_end, 
                                                fake_output)
        disc_loss = discriminator_loss(real_output, fake_output)

    gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

    return tf.reduce_mean(gen_loss), tf.reduce_mean(disc_loss), tf.reduce_mean(gen_mse_loss)

def test_step_def(sequences, sequences_end):
    generated_prediction = generator(sequences, training=False)

    sequences_true = tf.concat((sequences, sequences_end[:,None,:]), axis=1)
    sequences_fake = tf.concat((sequences, generated_prediction[:,None,:]), axis=1)

    real_output = discriminator(sequences_true, training=False)
    fake_output = discriminator(sequences_fake, training=False)

    gen_loss, gen_mse_loss = generator_loss(generated_prediction, sequences_end, fake_output)
    disc_loss = discriminator_loss(real_output, fake_output)
    return tf.reduce_mean(gen_loss), tf.reduce_mean(disc_loss), tf.reduce_mean(gen_mse_loss)

# %%
def train(dataset, dataset_val, epochs):
    history = np.empty(shape = (8, epochs))
    history_val = np.empty(shape = (8, epochs))
    len_dataset = len(dataset)
    len_dataset_val = len(dataset_val)
    for epoch in range(epochs):
        start = time.time()

        cur_dis_loss = 0
        cur_gen_loss = 0
        cur_gen_mse_loss = 0
        for sequence_batch, sequence_end_batch in dataset:
            aux_cur_losses = train_step(tf.cast(sequence_batch, tf.float32), 
                                      tf.cast(sequence_end_batch, tf.float32))
            cur_gen_loss += aux_cur_losses[0]/len_dataset
            cur_dis_loss += aux_cur_losses[1]/len_dataset
            cur_gen_mse_loss += aux_cur_losses[2]/len_dataset
        cur_gen_metrics = generator.evaluate(dataset,verbose=False)[1:]

        history[:, epoch] = cur_gen_loss, cur_dis_loss, cur_gen_mse_loss, *cur_gen_metrics

        cur_gen_metrics_val = generator.evaluate(dataset_val,verbose=False)[1: ]

        cur_gen_loss_val = 0
        cur_dis_loss_val = 0
        cur_gen_mse_loss_val = 0
        for sequence_batch, sequence_end_batch in dataset_val:
            aux_cur_losses_val = test_step(tf.cast(sequence_batch, tf.float32), 
                                         tf.cast(sequence_end_batch, tf.float32))
            cur_gen_loss_val += aux_cur_losses_val[0]/len_dataset_val
            cur_dis_loss_val += aux_cur_losses_val[1]/len_dataset_val
            cur_gen_mse_loss_val += aux_cur_losses_val[2]/len_dataset_val
    


        history_val[:, epoch] = cur_gen_loss_val, cur_dis_loss_val, cur_gen_mse_loss_val, *cur_gen_metrics_val

        print ('Time for epoch {} is {} sec Generator Loss: {},  Discriminator_loss: {}'
               .format(epoch + 1, time.time()-start, cur_gen_loss, cur_dis_loss))

        # Save the model every 15 epochs
        if (epoch + 1) % 15 == 0:
            checkpoint.save(file_prefix = checkpoint_prefix)
        # Threshhold
#         if(cur_gen_loss > 0.8):
#                 break;

    return history, history_val

# %% [markdown]
# ## Visualization

# %%
def plot_history(history, history_val):
    metrics = ["gen_loss","dis_loss","gen_mse_loss", 'mse','mae','mape','rmse','ar']
    for i, metric_name in enumerate(metrics):  
        plt.figure()
        plt.title(metric_name)
        plt.plot(history[i], label='train')
        plt.plot(history_val[i], label='test')
        plt.legend()
    plt.show()

# %%
def plot_frame(sequence, target, model):
    y_pred = model.predict(sequence)[...,3]
    y_true = target[...,3]

    plt.figure()
    plt.title("closing price")
    plt.plot(y_true, label="true")
    plt.plot(y_pred, label="prediction")
    plt.legend()
    plt.show()

# %%
def get_best_results(history):
    min_index = np.argmin(history[3, :])
    return history[:, min_index]

# %% [markdown]
# ## Variables

# %%
window = 5
n_sequence = window
n_features = 7
n_batch = 50
EPOCHS = 2000

# %% [markdown]
# ## Data loading

# %%
stock_code = "AAPL"
start = dt.datetime(2000, 1, 1)
end = dt.datetime(2020, 12, 31)
raw_data = pdr.get_data_yahoo(stock_code, start, end,threads=False, proxy="http://127.0.0.1:7890")
df = raw_data.dropna();
df = df.reset_index(level=0)
df = add_Ma(df, window)
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#            Date        Open        High         Low       Close   Adj Close  \
# 5    2000-01-10    0.910714    0.912946    0.845982    0.872768    0.742829
# 6    2000-01-11    0.856585    0.887277    0.808036    0.828125    0.704833
# 7    2000-01-12    0.848214    0.852679    0.772321    0.778460    0.662562
# 8    2000-01-13    0.843610    0.881696    0.825893    0.863839    0.735229
# 9    2000-01-14    0.892857    0.912946    0.887277    0.896763    0.763251
# ...         ...         ...         ...         ...         ...         ...
# 5278 2020-12-23  132.160004  132.429993  130.779999  130.960007  129.209259
# 5279 2020-12-24  131.320007  133.460007  131.100006  131.970001  130.205780
# 5280 2020-12-28  133.990005  137.339996  133.509995  136.690002  134.862701
# 5281 2020-12-29  138.050003  138.789993  134.339996  134.869995  133.067001
# 5282 2020-12-30  135.580002  135.990005  133.399994  133.720001  131.932388
#
#           Volume          Ma
# 5      505064000    0.915960
# 6      441548800    0.890625
# 7      976068800    0.873214
# 8     1032684800    0.843192
# 9      390376000    0.846317
# ...          ...         ...
# 5278    88223700  128.656000
# 5279    54930100  129.286002
# 5280   124486200  129.940002
# 5281   121047300  131.946002
# 5282    96452100  133.274002
#
# [5278 rows x 8 columns]

# %%
for 

start_time = datetime.datetime.now()
df = add_Ma(df)
data_gen_train, data_gen_test = get_gen_train_test(df, n_sequence, n_batch)

generator = make_generator_model(n_sequence, n_features)
discriminator=make_discriminator_model(n_features)

learning_rate=1e-4
generator_optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.5)
discriminator_optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.5)

@tf.function
def train_step(sequences, sequences_end):
  return train_step_def(sequences, sequences_end)

@tf.function
def test_step(sequences, sequences_end):
  return test_step_def(sequences, sequences_end)

checkpoint_dir = './training_checkpoints'+stock_code
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(generator_optimizer=generator_optimizer,
                                 discriminator_optimizer=discriminator_optimizer,
                                 generator=generator,
                                 discriminator=discriminator)

history, history_val = train(data_gen_train, data_gen_test, EPOCHS)

plot_history(history, history_val)
plot_frame(*data_gen_test[0], generator)

print("[MSE Baseline] train:",mean_squared_error(data_gen_train)," test:", mean_squared_error(data_gen_test))
now = datetime.datetime.now()
delta = now - start_time
print("Delta time:", delta)
generator.save("bilstm_ffnn.h5")
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5, 7)]            0
#
#  bidirectional (Bidirectiona  (None, 5, 20)            1440
#  l)
#
#  batch_normalization (BatchN  (None, 5, 20)            80
#  ormalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 5, 20)             0
#
#  dropout (Dropout)           (None, 5, 20)             0
#
#  bidirectional_1 (Bidirectio  (None, 20)               2480
#  nal)
#
#  batch_normalization_1 (Batc  (None, 20)               80
#  hNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 20)                0
#
#  dropout_1 (Dropout)         (None, 20)                0
#
#  dense (Dense)               (None, 7)                 147
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 7)                 0
#
# =================================================================
# Total params: 4,227
# Trainable params: 4,147
# Non-trainable params: 80
# _________________________________________________________________
# Time for epoch 1 is 26.347693920135498 sec Generator Loss: 0.7539727091789246,  Discriminator_loss: 1.3792861700057983
# Time for epoch 2 is 1.3393504619598389 sec Generator Loss: 0.7402515411376953,  Discriminator_loss: 1.3416558504104614
# Time for epoch 3 is 1.485623836517334 sec Generator Loss: 0.7684062123298645,  Discriminator_loss: 1.2926445007324219
# Time for epoch 4 is 1.4400594234466553 sec Generator Loss: 0.8068514466285706,  Discriminator_loss: 1.2363176345825195
# Time for epoch 5 is 1.4188590049743652 sec Generator Loss: 0.860371470451355,  Discriminator_loss: 1.1931487321853638
# Time for epoch 6 is 1.2750499248504639 sec Generator Loss: 0.9193809032440186,  Discriminator_loss: 1.1793906688690186
# Time for epoch 7 is 1.3715338706970215 sec Generator Loss: 0.97059166431427,  Discriminator_loss: 1.165136456489563
# Time for epoch 8 is 1.3690173625946045 sec Generator Loss: 1.0322139263153076,  Discriminator_loss: 1.1531925201416016
# Time for epoch 9 is 1.328439474105835 sec Generator Loss: 1.00166916847229,  Discriminator_loss: 1.2153639793395996
# Time for epoch 10 is 1.3141014575958252 sec Generator Loss: 1.048818588256836,  Discriminator_loss: 1.1651400327682495
# Time for epoch 11 is 1.285818338394165 sec Generator Loss: 1.0153074264526367,  Discriminator_loss: 1.1504976749420166
# Time for epoch 12 is 1.2927162647247314 sec Generator Loss: 0.9829290509223938,  Discriminator_loss: 1.200966477394104
# Time for epoch 13 is 1.2203776836395264 sec Generator Loss: 1.0374104976654053,  Discriminator_loss: 1.2142935991287231
# Time for epoch 14 is 1.247999668121338 sec Generator Loss: 1.0087640285491943,  Discriminator_loss: 1.2106398344039917
# Time for epoch 15 is 1.1722300052642822 sec Generator Loss: 0.9752817153930664,  Discriminator_loss: 1.2249889373779297
# Time for epoch 16 is 1.1774792671203613 sec Generator Loss: 0.9733734726905823,  Discriminator_loss: 1.2046756744384766
# Time for epoch 17 is 1.1864545345306396 sec Generator Loss: 0.9564847350120544,  Discriminator_loss: 1.2192997932434082
# Time for epoch 18 is 1.1785430908203125 sec Generator Loss: 0.9544278383255005,  Discriminator_loss: 1.2144575119018555
# Time for epoch 19 is 1.2182843685150146 sec Generator Loss: 0.9677467942237854,  Discriminator_loss: 1.1945472955703735
# Time for epoch 20 is 1.1716947555541992 sec Generator Loss: 0.9649224877357483,  Discriminator_loss: 1.1945579051971436
# Time for epoch 21 is 1.1664578914642334 sec Generator Loss: 0.9577974677085876,  Discriminator_loss: 1.202958106994629
# Time for epoch 22 is 1.2182412147521973 sec Generator Loss: 0.9656369090080261,  Discriminator_loss: 1.1936125755310059
# Time for epoch 23 is 1.210672378540039 sec Generator Loss: 0.9324108958244324,  Discriminator_loss: 1.2350215911865234
# Time for epoch 24 is 1.1592364311218262 sec Generator Loss: 0.9215012788772583,  Discriminator_loss: 1.2515641450881958
# Time for epoch 25 is 1.1598870754241943 sec Generator Loss: 0.908653736114502,  Discriminator_loss: 1.2688379287719727
# Time for epoch 26 is 1.1454615592956543 sec Generator Loss: 0.8930680155754089,  Discriminator_loss: 1.2847970724105835
# Time for epoch 27 is 1.1412761211395264 sec Generator Loss: 0.8897644281387329,  Discriminator_loss: 1.2713152170181274
# Time for epoch 28 is 1.1824283599853516 sec Generator Loss: 0.8825729489326477,  Discriminator_loss: 1.2932753562927246
# Time for epoch 29 is 1.1453020572662354 sec Generator Loss: 0.884916365146637,  Discriminator_loss: 1.2840678691864014
# Time for epoch 30 is 1.2383718490600586 sec Generator Loss: 0.8609297871589661,  Discriminator_loss: 1.3146848678588867
# Time for epoch 31 is 1.1796035766601562 sec Generator Loss: 0.8475509881973267,  Discriminator_loss: 1.3194432258605957
# Time for epoch 32 is 1.1457107067108154 sec Generator Loss: 0.8523552417755127,  Discriminator_loss: 1.3258057832717896
# Time for epoch 33 is 1.167170763015747 sec Generator Loss: 0.8416450619697571,  Discriminator_loss: 1.3173748254776
# Time for epoch 34 is 1.1777422428131104 sec Generator Loss: 0.8296681642532349,  Discriminator_loss: 1.32233464717865
# Time for epoch 35 is 1.1685786247253418 sec Generator Loss: 0.834919273853302,  Discriminator_loss: 1.3264217376708984
# Time for epoch 36 is 1.182246446609497 sec Generator Loss: 0.8289279937744141,  Discriminator_loss: 1.3250095844268799
# Time for epoch 37 is 1.201763391494751 sec Generator Loss: 0.8271874785423279,  Discriminator_loss: 1.3227643966674805
# Time for epoch 38 is 1.1710646152496338 sec Generator Loss: 0.8336331248283386,  Discriminator_loss: 1.3300080299377441
# Time for epoch 39 is 1.4555506706237793 sec Generator Loss: 0.8210130333900452,  Discriminator_loss: 1.3436930179595947
# Time for epoch 40 is 1.14359712600708 sec Generator Loss: 0.8156877756118774,  Discriminator_loss: 1.3584824800491333
# Time for epoch 41 is 1.1761665344238281 sec Generator Loss: 0.8115602135658264,  Discriminator_loss: 1.3643661737442017
# Time for epoch 42 is 1.1392710208892822 sec Generator Loss: 0.8129823207855225,  Discriminator_loss: 1.3627064228057861
# Time for epoch 43 is 1.1500792503356934 sec Generator Loss: 0.8122288584709167,  Discriminator_loss: 1.3543614149093628
# Time for epoch 44 is 1.1748809814453125 sec Generator Loss: 0.8068259358406067,  Discriminator_loss: 1.3528929948806763
# Time for epoch 45 is 1.1908652782440186 sec Generator Loss: 0.8050295114517212,  Discriminator_loss: 1.3524103164672852
# Time for epoch 46 is 1.1701467037200928 sec Generator Loss: 0.8047291040420532,  Discriminator_loss: 1.3533083200454712
# Time for epoch 47 is 1.1534640789031982 sec Generator Loss: 0.8052698373794556,  Discriminator_loss: 1.3557660579681396
# Time for epoch 48 is 1.1671149730682373 sec Generator Loss: 0.798801839351654,  Discriminator_loss: 1.3591848611831665
# Time for epoch 49 is 1.1840054988861084 sec Generator Loss: 0.7962011098861694,  Discriminator_loss: 1.3603328466415405
# Time for epoch 50 is 1.1603496074676514 sec Generator Loss: 0.7947234511375427,  Discriminator_loss: 1.3595515489578247
# Time for epoch 51 is 1.1598842144012451 sec Generator Loss: 0.7958735823631287,  Discriminator_loss: 1.3582708835601807
# Time for epoch 52 is 1.1251213550567627 sec Generator Loss: 0.7947338819503784,  Discriminator_loss: 1.3645312786102295
# Time for epoch 53 is 1.1575911045074463 sec Generator Loss: 0.7880911231040955,  Discriminator_loss: 1.3706412315368652
# Time for epoch 54 is 1.1715309619903564 sec Generator Loss: 0.7867514491081238,  Discriminator_loss: 1.3729305267333984
# Time for epoch 55 is 1.3682031631469727 sec Generator Loss: 0.7903187274932861,  Discriminator_loss: 1.3696318864822388
# Time for epoch 56 is 1.3713593482971191 sec Generator Loss: 0.7901838421821594,  Discriminator_loss: 1.3669383525848389
# Time for epoch 57 is 1.3248448371887207 sec Generator Loss: 0.7864882349967957,  Discriminator_loss: 1.368868350982666
# Time for epoch 58 is 1.29630708694458 sec Generator Loss: 0.7898542284965515,  Discriminator_loss: 1.3675998449325562
# Time for epoch 59 is 1.093637466430664 sec Generator Loss: 0.7844962477684021,  Discriminator_loss: 1.3635671138763428
# Time for epoch 60 is 1.179440975189209 sec Generator Loss: 0.7848544716835022,  Discriminator_loss: 1.365984320640564
# Time for epoch 61 is 1.190199851989746 sec Generator Loss: 0.781806468963623,  Discriminator_loss: 1.3674046993255615
# Time for epoch 62 is 1.1773757934570312 sec Generator Loss: 0.774466335773468,  Discriminator_loss: 1.37034273147583
# Time for epoch 63 is 1.1977481842041016 sec Generator Loss: 0.7781997323036194,  Discriminator_loss: 1.3734411001205444
# Time for epoch 64 is 1.1812973022460938 sec Generator Loss: 0.7718850374221802,  Discriminator_loss: 1.376577377319336
# Time for epoch 65 is 1.1564877033233643 sec Generator Loss: 0.7832978367805481,  Discriminator_loss: 1.3706449270248413
# Time for epoch 66 is 1.1686174869537354 sec Generator Loss: 0.7749134302139282,  Discriminator_loss: 1.3732703924179077
# Time for epoch 67 is 1.1931147575378418 sec Generator Loss: 0.7771108150482178,  Discriminator_loss: 1.370429515838623
# Time for epoch 68 is 1.1922249794006348 sec Generator Loss: 0.777170717716217,  Discriminator_loss: 1.369836688041687
# Time for epoch 69 is 1.1802501678466797 sec Generator Loss: 0.777238130569458,  Discriminator_loss: 1.3613892793655396
# Time for epoch 70 is 1.1649510860443115 sec Generator Loss: 0.772118091583252,  Discriminator_loss: 1.3663488626480103
# Time for epoch 71 is 1.1620006561279297 sec Generator Loss: 0.7796186208724976,  Discriminator_loss: 1.3647047281265259
# Time for epoch 72 is 1.1508026123046875 sec Generator Loss: 0.7758543491363525,  Discriminator_loss: 1.3623932600021362
# Time for epoch 73 is 1.1967334747314453 sec Generator Loss: 0.7805982232093811,  Discriminator_loss: 1.3632668256759644
# Time for epoch 74 is 1.1840107440948486 sec Generator Loss: 0.7819865345954895,  Discriminator_loss: 1.3625478744506836
# Time for epoch 75 is 1.1640143394470215 sec Generator Loss: 0.7824724912643433,  Discriminator_loss: 1.3610504865646362
# Time for epoch 76 is 1.1815910339355469 sec Generator Loss: 0.781269371509552,  Discriminator_loss: 1.3615812063217163
# Time for epoch 77 is 1.143646240234375 sec Generator Loss: 0.7868149280548096,  Discriminator_loss: 1.3583855628967285
# Time for epoch 78 is 1.1366686820983887 sec Generator Loss: 0.7767141461372375,  Discriminator_loss: 1.3596230745315552
# Time for epoch 79 is 1.155040979385376 sec Generator Loss: 0.7775879502296448,  Discriminator_loss: 1.361222505569458
# Time for epoch 80 is 1.185943365097046 sec Generator Loss: 0.7793769836425781,  Discriminator_loss: 1.3586561679840088
# Time for epoch 81 is 1.166604995727539 sec Generator Loss: 0.7841810584068298,  Discriminator_loss: 1.3537609577178955
# Time for epoch 82 is 1.1870667934417725 sec Generator Loss: 0.7754965424537659,  Discriminator_loss: 1.3575202226638794
# Time for epoch 83 is 1.1616222858428955 sec Generator Loss: 0.7751333713531494,  Discriminator_loss: 1.3587322235107422
# Time for epoch 84 is 1.1564102172851562 sec Generator Loss: 0.7803276777267456,  Discriminator_loss: 1.3601311445236206
# Time for epoch 85 is 1.173729419708252 sec Generator Loss: 0.7759138345718384,  Discriminator_loss: 1.3579849004745483
# Time for epoch 86 is 1.2097389698028564 sec Generator Loss: 0.7870875000953674,  Discriminator_loss: 1.3576751947402954
# Time for epoch 87 is 1.1687266826629639 sec Generator Loss: 0.7831823825836182,  Discriminator_loss: 1.3581351041793823
# Time for epoch 88 is 1.1563103199005127 sec Generator Loss: 0.7797055840492249,  Discriminator_loss: 1.3590376377105713
# Time for epoch 89 is 1.1486785411834717 sec Generator Loss: 0.780301034450531,  Discriminator_loss: 1.357994794845581
# Time for epoch 90 is 1.165330410003662 sec Generator Loss: 0.7808643579483032,  Discriminator_loss: 1.3557896614074707
# Time for epoch 91 is 1.2201693058013916 sec Generator Loss: 0.7820281386375427,  Discriminator_loss: 1.3507475852966309
# Time for epoch 92 is 1.1922214031219482 sec Generator Loss: 0.7788457870483398,  Discriminator_loss: 1.3614896535873413
# Time for epoch 93 is 1.1667861938476562 sec Generator Loss: 0.7836460471153259,  Discriminator_loss: 1.3572158813476562
# Time for epoch 94 is 1.209026575088501 sec Generator Loss: 0.7848315238952637,  Discriminator_loss: 1.3540228605270386
# Time for epoch 95 is 1.1848719120025635 sec Generator Loss: 0.7819889783859253,  Discriminator_loss: 1.359856128692627
# Time for epoch 96 is 1.199065923690796 sec Generator Loss: 0.7834106683731079,  Discriminator_loss: 1.359502911567688
# Time for epoch 97 is 1.1567096710205078 sec Generator Loss: 0.7835725545883179,  Discriminator_loss: 1.353659987449646
# Time for epoch 98 is 1.2195274829864502 sec Generator Loss: 0.7823277115821838,  Discriminator_loss: 1.3541607856750488
# Time for epoch 99 is 1.2382709980010986 sec Generator Loss: 0.7819076776504517,  Discriminator_loss: 1.3590458631515503
# Time for epoch 100 is 1.2058100700378418 sec Generator Loss: 0.7876414060592651,  Discriminator_loss: 1.3561588525772095
# Time for epoch 101 is 1.154881477355957 sec Generator Loss: 0.7803263664245605,  Discriminator_loss: 1.3571159839630127
# Time for epoch 102 is 1.162158489227295 sec Generator Loss: 0.7753446698188782,  Discriminator_loss: 1.3543486595153809
# Time for epoch 103 is 1.1645774841308594 sec Generator Loss: 0.7828897833824158,  Discriminator_loss: 1.3511927127838135
# Time for epoch 104 is 1.16129732131958 sec Generator Loss: 0.7754051685333252,  Discriminator_loss: 1.3559941053390503
# Time for epoch 105 is 1.2017168998718262 sec Generator Loss: 0.7788949608802795,  Discriminator_loss: 1.3561550378799438
# Time for epoch 106 is 1.1950480937957764 sec Generator Loss: 0.7756956219673157,  Discriminator_loss: 1.3634299039840698
# Time for epoch 107 is 1.1489925384521484 sec Generator Loss: 0.7839095592498779,  Discriminator_loss: 1.3525153398513794
# Time for epoch 108 is 1.1485755443572998 sec Generator Loss: 0.7830549478530884,  Discriminator_loss: 1.3554105758666992
# Time for epoch 109 is 1.1808273792266846 sec Generator Loss: 0.7859957814216614,  Discriminator_loss: 1.3525581359863281
# Time for epoch 110 is 1.2084441184997559 sec Generator Loss: 0.7812962532043457,  Discriminator_loss: 1.3555843830108643
# Time for epoch 111 is 1.1689255237579346 sec Generator Loss: 0.7846036553382874,  Discriminator_loss: 1.3557018041610718
# Time for epoch 112 is 1.1424143314361572 sec Generator Loss: 0.7844959497451782,  Discriminator_loss: 1.3582669496536255
# Time for epoch 113 is 1.1291744709014893 sec Generator Loss: 0.7836291193962097,  Discriminator_loss: 1.3521389961242676
# Time for epoch 114 is 1.1737895011901855 sec Generator Loss: 0.7806219458580017,  Discriminator_loss: 1.3535102605819702
# Time for epoch 115 is 1.1557025909423828 sec Generator Loss: 0.7793846726417542,  Discriminator_loss: 1.3580222129821777
# Time for epoch 116 is 1.1645827293395996 sec Generator Loss: 0.7796207070350647,  Discriminator_loss: 1.352966547012329
# Time for epoch 117 is 1.1463961601257324 sec Generator Loss: 0.790960967540741,  Discriminator_loss: 1.352365493774414
# Time for epoch 118 is 1.1429355144500732 sec Generator Loss: 0.7732747197151184,  Discriminator_loss: 1.359122633934021
# Time for epoch 119 is 1.1412849426269531 sec Generator Loss: 0.775745153427124,  Discriminator_loss: 1.3600473403930664
# Time for epoch 120 is 1.1689114570617676 sec Generator Loss: 0.7805414199829102,  Discriminator_loss: 1.357672929763794
# Time for epoch 121 is 1.1664822101593018 sec Generator Loss: 0.7796806693077087,  Discriminator_loss: 1.3561698198318481
# Time for epoch 122 is 1.190279483795166 sec Generator Loss: 0.777990460395813,  Discriminator_loss: 1.3576605319976807
# Time for epoch 123 is 1.1865954399108887 sec Generator Loss: 0.7807026505470276,  Discriminator_loss: 1.3567074537277222
# Time for epoch 124 is 1.1853752136230469 sec Generator Loss: 0.7869019508361816,  Discriminator_loss: 1.3604772090911865
# Time for epoch 125 is 1.1769404411315918 sec Generator Loss: 0.7763130068778992,  Discriminator_loss: 1.3619308471679688
# Time for epoch 126 is 1.2186470031738281 sec Generator Loss: 0.7840287685394287,  Discriminator_loss: 1.3526313304901123
# Time for epoch 127 is 1.1652915477752686 sec Generator Loss: 0.7848483920097351,  Discriminator_loss: 1.3568874597549438
# Time for epoch 128 is 1.2062807083129883 sec Generator Loss: 0.7843276262283325,  Discriminator_loss: 1.3520333766937256
# Time for epoch 129 is 1.1883606910705566 sec Generator Loss: 0.7788184881210327,  Discriminator_loss: 1.3554928302764893
# Time for epoch 130 is 1.1750552654266357 sec Generator Loss: 0.7719323635101318,  Discriminator_loss: 1.364529013633728
# Time for epoch 131 is 1.1758036613464355 sec Generator Loss: 0.7726056575775146,  Discriminator_loss: 1.3627997636795044
# Time for epoch 132 is 1.151581048965454 sec Generator Loss: 0.783344030380249,  Discriminator_loss: 1.3628824949264526
# Time for epoch 133 is 1.1626627445220947 sec Generator Loss: 0.784959614276886,  Discriminator_loss: 1.3593486547470093
# Time for epoch 134 is 1.15814208984375 sec Generator Loss: 0.7808836102485657,  Discriminator_loss: 1.3571994304656982
# Time for epoch 135 is 1.1563332080841064 sec Generator Loss: 0.7881874442100525,  Discriminator_loss: 1.3604856729507446
# Time for epoch 136 is 1.2032256126403809 sec Generator Loss: 0.7838767170906067,  Discriminator_loss: 1.361562967300415
# Time for epoch 137 is 1.1407482624053955 sec Generator Loss: 0.7842528820037842,  Discriminator_loss: 1.3604265451431274
# Time for epoch 138 is 1.176147699356079 sec Generator Loss: 0.777620255947113,  Discriminator_loss: 1.3597050905227661
# Time for epoch 139 is 1.2131576538085938 sec Generator Loss: 0.7844399213790894,  Discriminator_loss: 1.3539233207702637
# Time for epoch 140 is 1.1872973442077637 sec Generator Loss: 0.7801653146743774,  Discriminator_loss: 1.354239583015442
# Time for epoch 141 is 1.1936836242675781 sec Generator Loss: 0.7813879251480103,  Discriminator_loss: 1.3546779155731201
# Time for epoch 142 is 1.1895208358764648 sec Generator Loss: 0.7810428738594055,  Discriminator_loss: 1.354103922843933
# Time for epoch 143 is 1.1861240863800049 sec Generator Loss: 0.7759689092636108,  Discriminator_loss: 1.3642396926879883
# Time for epoch 144 is 1.1605730056762695 sec Generator Loss: 0.7805761098861694,  Discriminator_loss: 1.3575160503387451
# Time for epoch 145 is 1.4469633102416992 sec Generator Loss: 0.783835768699646,  Discriminator_loss: 1.3598064184188843
# Time for epoch 146 is 1.1429579257965088 sec Generator Loss: 0.7802224159240723,  Discriminator_loss: 1.3584593534469604
# Time for epoch 147 is 1.2042548656463623 sec Generator Loss: 0.7818460464477539,  Discriminator_loss: 1.360925316810608
# Time for epoch 148 is 1.2200558185577393 sec Generator Loss: 0.7817054986953735,  Discriminator_loss: 1.3589041233062744
# Time for epoch 149 is 1.2847321033477783 sec Generator Loss: 0.7737269997596741,  Discriminator_loss: 1.3573638200759888
# Time for epoch 150 is 1.2980594635009766 sec Generator Loss: 0.7800530791282654,  Discriminator_loss: 1.3556090593338013
# Time for epoch 151 is 1.2031092643737793 sec Generator Loss: 0.7816862463951111,  Discriminator_loss: 1.3551487922668457
# Time for epoch 152 is 1.2907259464263916 sec Generator Loss: 0.7699791789054871,  Discriminator_loss: 1.361904263496399
# Time for epoch 153 is 1.2204322814941406 sec Generator Loss: 0.7760368585586548,  Discriminator_loss: 1.3631736040115356
# Time for epoch 154 is 1.2173054218292236 sec Generator Loss: 0.7816913723945618,  Discriminator_loss: 1.3580513000488281
# Time for epoch 155 is 1.2699313163757324 sec Generator Loss: 0.7851871252059937,  Discriminator_loss: 1.3577301502227783
# Time for epoch 156 is 1.2387969493865967 sec Generator Loss: 0.7732317447662354,  Discriminator_loss: 1.3691073656082153
# Time for epoch 157 is 1.3270633220672607 sec Generator Loss: 0.7793809771537781,  Discriminator_loss: 1.35647451877594
# Time for epoch 158 is 1.2237603664398193 sec Generator Loss: 0.7791897058486938,  Discriminator_loss: 1.3580913543701172
# Time for epoch 159 is 1.2000632286071777 sec Generator Loss: 0.776272177696228,  Discriminator_loss: 1.3589693307876587
# Time for epoch 160 is 1.2320730686187744 sec Generator Loss: 0.7747471928596497,  Discriminator_loss: 1.3588999509811401
# Time for epoch 161 is 1.3260064125061035 sec Generator Loss: 0.7807510495185852,  Discriminator_loss: 1.356711983680725
# Time for epoch 162 is 1.4513649940490723 sec Generator Loss: 0.7794424295425415,  Discriminator_loss: 1.3594573736190796
# Time for epoch 163 is 1.170213222503662 sec Generator Loss: 0.7804995179176331,  Discriminator_loss: 1.3612931966781616
# Time for epoch 164 is 1.115290880203247 sec Generator Loss: 0.7799473404884338,  Discriminator_loss: 1.3613767623901367
# Time for epoch 165 is 1.1364233493804932 sec Generator Loss: 0.7755231857299805,  Discriminator_loss: 1.3658167123794556
# Time for epoch 166 is 1.1571967601776123 sec Generator Loss: 0.7808118462562561,  Discriminator_loss: 1.3583191633224487
# Time for epoch 167 is 1.1573493480682373 sec Generator Loss: 0.7651119828224182,  Discriminator_loss: 1.3683427572250366
# Time for epoch 168 is 1.1497507095336914 sec Generator Loss: 0.771182119846344,  Discriminator_loss: 1.3620365858078003
# Time for epoch 169 is 1.1616520881652832 sec Generator Loss: 0.7719958424568176,  Discriminator_loss: 1.3578113317489624
# Time for epoch 170 is 1.128349781036377 sec Generator Loss: 0.7779079079627991,  Discriminator_loss: 1.361031413078308
# Time for epoch 171 is 1.1375327110290527 sec Generator Loss: 0.7719324827194214,  Discriminator_loss: 1.3600867986679077
# Time for epoch 172 is 1.1212823390960693 sec Generator Loss: 0.7686455249786377,  Discriminator_loss: 1.3633180856704712
# Time for epoch 173 is 1.1765995025634766 sec Generator Loss: 0.7727633714675903,  Discriminator_loss: 1.3551515340805054
# Time for epoch 174 is 1.1984167098999023 sec Generator Loss: 0.769911527633667,  Discriminator_loss: 1.3606083393096924
# Time for epoch 175 is 1.167412519454956 sec Generator Loss: 0.7766780853271484,  Discriminator_loss: 1.359144687652588
# Time for epoch 176 is 1.1222143173217773 sec Generator Loss: 0.7732570767402649,  Discriminator_loss: 1.3650394678115845
# Time for epoch 177 is 1.1495006084442139 sec Generator Loss: 0.7720295786857605,  Discriminator_loss: 1.3599754571914673
# Time for epoch 178 is 1.1482338905334473 sec Generator Loss: 0.7768717408180237,  Discriminator_loss: 1.356702446937561
# Time for epoch 179 is 1.149674892425537 sec Generator Loss: 0.7755597829818726,  Discriminator_loss: 1.3645302057266235
# Time for epoch 180 is 1.1379809379577637 sec Generator Loss: 0.7798529267311096,  Discriminator_loss: 1.3582501411437988
# Time for epoch 181 is 1.1486947536468506 sec Generator Loss: 0.7728234529495239,  Discriminator_loss: 1.3620953559875488
# Time for epoch 182 is 1.1555280685424805 sec Generator Loss: 0.778220534324646,  Discriminator_loss: 1.3580055236816406
# Time for epoch 183 is 1.151329517364502 sec Generator Loss: 0.7700322270393372,  Discriminator_loss: 1.3666354417800903
# Time for epoch 184 is 1.1579046249389648 sec Generator Loss: 0.7729807496070862,  Discriminator_loss: 1.3605793714523315
# Time for epoch 185 is 1.1416730880737305 sec Generator Loss: 0.7770829200744629,  Discriminator_loss: 1.355486512184143
# Time for epoch 186 is 1.1526670455932617 sec Generator Loss: 0.7754495143890381,  Discriminator_loss: 1.3566467761993408
# Time for epoch 187 is 1.1554558277130127 sec Generator Loss: 0.7803729772567749,  Discriminator_loss: 1.3577080965042114
# Time for epoch 188 is 1.1576240062713623 sec Generator Loss: 0.7727468013763428,  Discriminator_loss: 1.365818738937378
# Time for epoch 189 is 1.141129732131958 sec Generator Loss: 0.7738789916038513,  Discriminator_loss: 1.353951096534729
# Time for epoch 190 is 1.152489423751831 sec Generator Loss: 0.7873930931091309,  Discriminator_loss: 1.3530879020690918
# Time for epoch 191 is 1.1335265636444092 sec Generator Loss: 0.7795397043228149,  Discriminator_loss: 1.3613113164901733
# Time for epoch 192 is 1.1204609870910645 sec Generator Loss: 0.7797150015830994,  Discriminator_loss: 1.359323263168335
# Time for epoch 193 is 1.1527140140533447 sec Generator Loss: 0.7759658694267273,  Discriminator_loss: 1.3594249486923218
# Time for epoch 194 is 1.1245770454406738 sec Generator Loss: 0.777885377407074,  Discriminator_loss: 1.353469729423523
# Time for epoch 195 is 1.148132562637329 sec Generator Loss: 0.7772541642189026,  Discriminator_loss: 1.3577094078063965
# Time for epoch 196 is 1.1268246173858643 sec Generator Loss: 0.7829927802085876,  Discriminator_loss: 1.3544894456863403
# Time for epoch 197 is 1.1205894947052002 sec Generator Loss: 0.7888660430908203,  Discriminator_loss: 1.3557239770889282
# Time for epoch 198 is 1.1300320625305176 sec Generator Loss: 0.7751301527023315,  Discriminator_loss: 1.3569437265396118
# Time for epoch 199 is 1.2448620796203613 sec Generator Loss: 0.7765039801597595,  Discriminator_loss: 1.3578150272369385
# Time for epoch 200 is 1.4005556106567383 sec Generator Loss: 0.7817994952201843,  Discriminator_loss: 1.3557569980621338
# Time for epoch 201 is 1.3170957565307617 sec Generator Loss: 0.774606466293335,  Discriminator_loss: 1.362147569656372
# Time for epoch 202 is 1.5438520908355713 sec Generator Loss: 0.7865993976593018,  Discriminator_loss: 1.3539127111434937
# Time for epoch 203 is 1.3603105545043945 sec Generator Loss: 0.7824952006340027,  Discriminator_loss: 1.353717565536499
# Time for epoch 204 is 1.2419462203979492 sec Generator Loss: 0.7798089981079102,  Discriminator_loss: 1.3533329963684082
# Time for epoch 205 is 1.215104103088379 sec Generator Loss: 0.7792156934738159,  Discriminator_loss: 1.3580268621444702
# Time for epoch 206 is 1.2097375392913818 sec Generator Loss: 0.7873404026031494,  Discriminator_loss: 1.3511475324630737
# Time for epoch 207 is 1.2149698734283447 sec Generator Loss: 0.780142605304718,  Discriminator_loss: 1.35431969165802
# Time for epoch 208 is 1.227546215057373 sec Generator Loss: 0.7870981097221375,  Discriminator_loss: 1.3558106422424316
# Time for epoch 209 is 1.2207834720611572 sec Generator Loss: 0.7791433334350586,  Discriminator_loss: 1.355669617652893
# Time for epoch 210 is 1.2818520069122314 sec Generator Loss: 0.7848290205001831,  Discriminator_loss: 1.3528072834014893
# Time for epoch 211 is 1.254704475402832 sec Generator Loss: 0.7881187200546265,  Discriminator_loss: 1.3543120622634888
# Time for epoch 212 is 1.2526464462280273 sec Generator Loss: 0.7859892845153809,  Discriminator_loss: 1.3516353368759155
# Time for epoch 213 is 1.2276830673217773 sec Generator Loss: 0.7917457222938538,  Discriminator_loss: 1.3480244874954224
# Time for epoch 214 is 1.2073843479156494 sec Generator Loss: 0.7812091708183289,  Discriminator_loss: 1.35123872756958
# Time for epoch 215 is 1.2134037017822266 sec Generator Loss: 0.7854124903678894,  Discriminator_loss: 1.3565725088119507
# Time for epoch 216 is 1.2197020053863525 sec Generator Loss: 0.7776384353637695,  Discriminator_loss: 1.3558565378189087
# Time for epoch 217 is 1.2188692092895508 sec Generator Loss: 0.7872880697250366,  Discriminator_loss: 1.3513723611831665
# Time for epoch 218 is 1.2618882656097412 sec Generator Loss: 0.7910982966423035,  Discriminator_loss: 1.3557376861572266
# Time for epoch 219 is 1.2669603824615479 sec Generator Loss: 0.7887898087501526,  Discriminator_loss: 1.3566834926605225
# Time for epoch 220 is 1.2209084033966064 sec Generator Loss: 0.7879757881164551,  Discriminator_loss: 1.345104694366455
# Time for epoch 221 is 1.210798978805542 sec Generator Loss: 0.7849839925765991,  Discriminator_loss: 1.3563928604125977
# Time for epoch 222 is 1.2297883033752441 sec Generator Loss: 0.7819202542304993,  Discriminator_loss: 1.3507338762283325
# Time for epoch 223 is 1.325073003768921 sec Generator Loss: 0.7836067080497742,  Discriminator_loss: 1.3536686897277832
# Time for epoch 224 is 1.2866833209991455 sec Generator Loss: 0.7834514379501343,  Discriminator_loss: 1.3489253520965576
# Time for epoch 225 is 1.2251391410827637 sec Generator Loss: 0.7831042408943176,  Discriminator_loss: 1.3553942441940308
# Time for epoch 226 is 1.2112760543823242 sec Generator Loss: 0.7863095998764038,  Discriminator_loss: 1.3543413877487183
# Time for epoch 227 is 1.2210252285003662 sec Generator Loss: 0.7829083204269409,  Discriminator_loss: 1.3555763959884644
# Time for epoch 228 is 1.245715856552124 sec Generator Loss: 0.7958160042762756,  Discriminator_loss: 1.3505898714065552
# Time for epoch 229 is 1.2958884239196777 sec Generator Loss: 0.7853051424026489,  Discriminator_loss: 1.3526883125305176
# Time for epoch 230 is 1.2654941082000732 sec Generator Loss: 0.7819678783416748,  Discriminator_loss: 1.355858564376831
# Time for epoch 231 is 1.2738852500915527 sec Generator Loss: 0.7810137271881104,  Discriminator_loss: 1.3569841384887695
# Time for epoch 232 is 1.2239100933074951 sec Generator Loss: 0.7802585363388062,  Discriminator_loss: 1.3541513681411743
# Time for epoch 233 is 1.2122418880462646 sec Generator Loss: 0.7792531251907349,  Discriminator_loss: 1.3571549654006958
# Time for epoch 234 is 1.2429051399230957 sec Generator Loss: 0.7791109681129456,  Discriminator_loss: 1.3510931730270386
# Time for epoch 235 is 1.2735424041748047 sec Generator Loss: 0.7757807970046997,  Discriminator_loss: 1.3606923818588257
# Time for epoch 236 is 1.251037836074829 sec Generator Loss: 0.7818204760551453,  Discriminator_loss: 1.350827693939209
# Time for epoch 237 is 1.211402416229248 sec Generator Loss: 0.782916247844696,  Discriminator_loss: 1.3555742502212524
# Time for epoch 238 is 1.3624446392059326 sec Generator Loss: 0.7823619842529297,  Discriminator_loss: 1.3578718900680542
# Time for epoch 239 is 1.305182933807373 sec Generator Loss: 0.7846219539642334,  Discriminator_loss: 1.3525385856628418
# Time for epoch 240 is 1.4441187381744385 sec Generator Loss: 0.7826023101806641,  Discriminator_loss: 1.35495924949646
# Time for epoch 241 is 1.3154699802398682 sec Generator Loss: 0.7821351289749146,  Discriminator_loss: 1.3542344570159912
# Time for epoch 242 is 1.313744068145752 sec Generator Loss: 0.7856739163398743,  Discriminator_loss: 1.3513822555541992
# Time for epoch 243 is 1.2649106979370117 sec Generator Loss: 0.7820736169815063,  Discriminator_loss: 1.3547537326812744
# Time for epoch 244 is 1.3720242977142334 sec Generator Loss: 0.7736886739730835,  Discriminator_loss: 1.360211968421936
# Time for epoch 245 is 1.4028892517089844 sec Generator Loss: 0.7852952480316162,  Discriminator_loss: 1.3454684019088745
# Time for epoch 246 is 1.3414571285247803 sec Generator Loss: 0.7841883301734924,  Discriminator_loss: 1.3511587381362915
# Time for epoch 247 is 1.340914249420166 sec Generator Loss: 0.7859973907470703,  Discriminator_loss: 1.3557745218276978
# Time for epoch 248 is 1.3984277248382568 sec Generator Loss: 0.7878589034080505,  Discriminator_loss: 1.3596529960632324
# Time for epoch 249 is 1.2864270210266113 sec Generator Loss: 0.7840021848678589,  Discriminator_loss: 1.3552793264389038
# Time for epoch 250 is 1.2527024745941162 sec Generator Loss: 0.7849991321563721,  Discriminator_loss: 1.350555419921875
# Time for epoch 251 is 1.3595454692840576 sec Generator Loss: 0.7881021499633789,  Discriminator_loss: 1.3519622087478638
# Time for epoch 252 is 1.2606348991394043 sec Generator Loss: 0.7905125021934509,  Discriminator_loss: 1.3513717651367188
# Time for epoch 253 is 1.175609827041626 sec Generator Loss: 0.7924384474754333,  Discriminator_loss: 1.3493695259094238
# Time for epoch 254 is 1.2248930931091309 sec Generator Loss: 0.7872433066368103,  Discriminator_loss: 1.3515419960021973
# Time for epoch 255 is 1.2342569828033447 sec Generator Loss: 0.7904843091964722,  Discriminator_loss: 1.3469470739364624
# Time for epoch 256 is 1.3653290271759033 sec Generator Loss: 0.7774897217750549,  Discriminator_loss: 1.3529306650161743
# Time for epoch 257 is 1.3501670360565186 sec Generator Loss: 0.7946852445602417,  Discriminator_loss: 1.346973180770874
# Time for epoch 258 is 1.2765791416168213 sec Generator Loss: 0.7855283617973328,  Discriminator_loss: 1.3536138534545898
# Time for epoch 259 is 1.210252046585083 sec Generator Loss: 0.7834776043891907,  Discriminator_loss: 1.3557695150375366
# Time for epoch 260 is 1.1785321235656738 sec Generator Loss: 0.7852006554603577,  Discriminator_loss: 1.3526723384857178
# Time for epoch 261 is 1.210545301437378 sec Generator Loss: 0.7886633276939392,  Discriminator_loss: 1.3537113666534424
# Time for epoch 262 is 1.209632158279419 sec Generator Loss: 0.7900155186653137,  Discriminator_loss: 1.3535181283950806
# Time for epoch 263 is 1.1749863624572754 sec Generator Loss: 0.7882128357887268,  Discriminator_loss: 1.3502378463745117
# Time for epoch 264 is 1.1687266826629639 sec Generator Loss: 0.7826763391494751,  Discriminator_loss: 1.3505094051361084
# Time for epoch 265 is 1.1702401638031006 sec Generator Loss: 0.7908342480659485,  Discriminator_loss: 1.3500882387161255
# Time for epoch 266 is 1.2076408863067627 sec Generator Loss: 0.7918739914894104,  Discriminator_loss: 1.3531739711761475
# Time for epoch 267 is 1.160581350326538 sec Generator Loss: 0.7845872640609741,  Discriminator_loss: 1.350342035293579
# Time for epoch 268 is 1.1550424098968506 sec Generator Loss: 0.7807149887084961,  Discriminator_loss: 1.3525450229644775
# Time for epoch 269 is 1.1529228687286377 sec Generator Loss: 0.787090539932251,  Discriminator_loss: 1.3528282642364502
# Time for epoch 270 is 1.1769201755523682 sec Generator Loss: 0.7789363265037537,  Discriminator_loss: 1.3553078174591064
# Time for epoch 271 is 1.2324655055999756 sec Generator Loss: 0.7853612899780273,  Discriminator_loss: 1.3489127159118652
# Time for epoch 272 is 1.2136626243591309 sec Generator Loss: 0.7794061303138733,  Discriminator_loss: 1.3546606302261353
# Time for epoch 273 is 1.1771080493927002 sec Generator Loss: 0.779575526714325,  Discriminator_loss: 1.3532586097717285
# Time for epoch 274 is 1.175736665725708 sec Generator Loss: 0.7864105701446533,  Discriminator_loss: 1.3512243032455444
# Time for epoch 275 is 1.3571949005126953 sec Generator Loss: 0.7902979850769043,  Discriminator_loss: 1.3514784574508667
# Time for epoch 276 is 1.4762725830078125 sec Generator Loss: 0.7858403325080872,  Discriminator_loss: 1.350355625152588
# Time for epoch 277 is 1.4231181144714355 sec Generator Loss: 0.7813855409622192,  Discriminator_loss: 1.3540295362472534
# Time for epoch 278 is 1.2419936656951904 sec Generator Loss: 0.7883301377296448,  Discriminator_loss: 1.355737328529358
# Time for epoch 279 is 1.3432984352111816 sec Generator Loss: 0.786051869392395,  Discriminator_loss: 1.3528900146484375
# Time for epoch 280 is 1.235663890838623 sec Generator Loss: 0.7798066735267639,  Discriminator_loss: 1.3482043743133545
# Time for epoch 281 is 1.1809964179992676 sec Generator Loss: 0.7870176434516907,  Discriminator_loss: 1.3535600900650024
# Time for epoch 282 is 1.376429557800293 sec Generator Loss: 0.785636842250824,  Discriminator_loss: 1.352624535560608
# Time for epoch 283 is 1.3825318813323975 sec Generator Loss: 0.7896957993507385,  Discriminator_loss: 1.3510257005691528
# Time for epoch 284 is 1.2569825649261475 sec Generator Loss: 0.7886565327644348,  Discriminator_loss: 1.350396752357483
# Time for epoch 285 is 1.2586591243743896 sec Generator Loss: 0.790152370929718,  Discriminator_loss: 1.351850152015686
# Time for epoch 286 is 1.1828181743621826 sec Generator Loss: 0.7915259003639221,  Discriminator_loss: 1.3463280200958252
# Time for epoch 287 is 1.1642682552337646 sec Generator Loss: 0.7873376607894897,  Discriminator_loss: 1.3550549745559692
# Time for epoch 288 is 1.1816351413726807 sec Generator Loss: 0.7933375835418701,  Discriminator_loss: 1.3489935398101807
# Time for epoch 289 is 1.2508525848388672 sec Generator Loss: 0.7946699261665344,  Discriminator_loss: 1.3408485651016235
# Time for epoch 290 is 1.1826505661010742 sec Generator Loss: 0.7945971488952637,  Discriminator_loss: 1.3476483821868896
# Time for epoch 291 is 1.2347583770751953 sec Generator Loss: 0.7902026176452637,  Discriminator_loss: 1.3558881282806396
# Time for epoch 292 is 1.2668843269348145 sec Generator Loss: 0.7843751907348633,  Discriminator_loss: 1.3462311029434204
# Time for epoch 293 is 1.2857649326324463 sec Generator Loss: 0.7835701107978821,  Discriminator_loss: 1.3522640466690063
# Time for epoch 294 is 1.1962733268737793 sec Generator Loss: 0.7893285751342773,  Discriminator_loss: 1.3531546592712402
# Time for epoch 295 is 1.141324520111084 sec Generator Loss: 0.7832082509994507,  Discriminator_loss: 1.3454618453979492
# Time for epoch 296 is 1.2238850593566895 sec Generator Loss: 0.7882092595100403,  Discriminator_loss: 1.3440015316009521
# Time for epoch 297 is 1.2229490280151367 sec Generator Loss: 0.7774642705917358,  Discriminator_loss: 1.3544182777404785
# Time for epoch 298 is 1.1953566074371338 sec Generator Loss: 0.7770890593528748,  Discriminator_loss: 1.352594256401062
# Time for epoch 299 is 1.2314910888671875 sec Generator Loss: 0.7918325066566467,  Discriminator_loss: 1.3490846157073975
# Time for epoch 300 is 1.222052812576294 sec Generator Loss: 0.7929844856262207,  Discriminator_loss: 1.3500792980194092
# Time for epoch 301 is 1.3019485473632812 sec Generator Loss: 0.7911839485168457,  Discriminator_loss: 1.3461296558380127
# Time for epoch 302 is 1.2236621379852295 sec Generator Loss: 0.7844674587249756,  Discriminator_loss: 1.3542059659957886
# Time for epoch 303 is 1.3032023906707764 sec Generator Loss: 0.793165922164917,  Discriminator_loss: 1.3425109386444092
# Time for epoch 304 is 1.2839245796203613 sec Generator Loss: 0.788954496383667,  Discriminator_loss: 1.3489694595336914
# Time for epoch 305 is 1.236750841140747 sec Generator Loss: 0.7867147326469421,  Discriminator_loss: 1.3525171279907227
# Time for epoch 306 is 1.2943627834320068 sec Generator Loss: 0.7833496332168579,  Discriminator_loss: 1.3538975715637207
# Time for epoch 307 is 1.3059041500091553 sec Generator Loss: 0.79909747838974,  Discriminator_loss: 1.3422373533248901
# Time for epoch 308 is 1.17189621925354 sec Generator Loss: 0.7977736592292786,  Discriminator_loss: 1.343448519706726
# Time for epoch 309 is 1.2589514255523682 sec Generator Loss: 0.7909600138664246,  Discriminator_loss: 1.3473305702209473
# Time for epoch 310 is 1.2610533237457275 sec Generator Loss: 0.7923142910003662,  Discriminator_loss: 1.34499990940094
# Time for epoch 311 is 1.1655652523040771 sec Generator Loss: 0.7861465215682983,  Discriminator_loss: 1.3494982719421387
# Time for epoch 312 is 1.3398396968841553 sec Generator Loss: 0.792775571346283,  Discriminator_loss: 1.347693920135498
# Time for epoch 313 is 1.2678847312927246 sec Generator Loss: 0.7879436016082764,  Discriminator_loss: 1.3490644693374634
# Time for epoch 314 is 1.2189662456512451 sec Generator Loss: 0.7984692454338074,  Discriminator_loss: 1.3451788425445557
# Time for epoch 315 is 1.1806869506835938 sec Generator Loss: 0.7960472702980042,  Discriminator_loss: 1.3408634662628174
# Time for epoch 316 is 1.1824605464935303 sec Generator Loss: 0.7825508117675781,  Discriminator_loss: 1.3519212007522583
# Time for epoch 317 is 1.4490532875061035 sec Generator Loss: 0.7850254774093628,  Discriminator_loss: 1.3569064140319824
# Time for epoch 318 is 1.509126901626587 sec Generator Loss: 0.7914084792137146,  Discriminator_loss: 1.3480316400527954
# Time for epoch 319 is 1.2317073345184326 sec Generator Loss: 0.7930042147636414,  Discriminator_loss: 1.350987434387207
# Time for epoch 320 is 1.177372932434082 sec Generator Loss: 0.7911106944084167,  Discriminator_loss: 1.3410615921020508
# Time for epoch 321 is 1.427201509475708 sec Generator Loss: 0.791262686252594,  Discriminator_loss: 1.3460015058517456
# Time for epoch 322 is 1.2041995525360107 sec Generator Loss: 0.7976851463317871,  Discriminator_loss: 1.3438903093338013
# Time for epoch 323 is 1.187220573425293 sec Generator Loss: 0.8008835911750793,  Discriminator_loss: 1.3450064659118652
# Time for epoch 324 is 1.224827527999878 sec Generator Loss: 0.7914454936981201,  Discriminator_loss: 1.3429572582244873
# Time for epoch 325 is 1.2032084465026855 sec Generator Loss: 0.7955148220062256,  Discriminator_loss: 1.344764232635498
# Time for epoch 326 is 1.186410665512085 sec Generator Loss: 0.8002427220344543,  Discriminator_loss: 1.3455759286880493
# Time for epoch 327 is 1.1566686630249023 sec Generator Loss: 0.7973587512969971,  Discriminator_loss: 1.349770188331604
# Time for epoch 328 is 1.3288867473602295 sec Generator Loss: 0.7962659001350403,  Discriminator_loss: 1.3472877740859985
# Time for epoch 329 is 1.233393907546997 sec Generator Loss: 0.7942638993263245,  Discriminator_loss: 1.3463114500045776
# Time for epoch 330 is 1.2147538661956787 sec Generator Loss: 0.7897509336471558,  Discriminator_loss: 1.3479734659194946
# Time for epoch 331 is 1.1571078300476074 sec Generator Loss: 0.7954815626144409,  Discriminator_loss: 1.351619839668274
# Time for epoch 332 is 1.1650493144989014 sec Generator Loss: 0.7981163859367371,  Discriminator_loss: 1.344795823097229
# Time for epoch 333 is 1.1500425338745117 sec Generator Loss: 0.7899536490440369,  Discriminator_loss: 1.3396576642990112
# Time for epoch 334 is 1.145139217376709 sec Generator Loss: 0.7972991466522217,  Discriminator_loss: 1.3447911739349365
# Time for epoch 335 is 1.4020891189575195 sec Generator Loss: 0.792942464351654,  Discriminator_loss: 1.349939227104187
# Time for epoch 336 is 1.3415839672088623 sec Generator Loss: 0.7950274348258972,  Discriminator_loss: 1.346827745437622
# Time for epoch 337 is 1.2741072177886963 sec Generator Loss: 0.7865864038467407,  Discriminator_loss: 1.3461133241653442
# Time for epoch 338 is 1.2806923389434814 sec Generator Loss: 0.790973961353302,  Discriminator_loss: 1.343241572380066
# Time for epoch 339 is 1.3384907245635986 sec Generator Loss: 0.7939789891242981,  Discriminator_loss: 1.3513323068618774
# Time for epoch 340 is 1.3129246234893799 sec Generator Loss: 0.7886324524879456,  Discriminator_loss: 1.3526004552841187
# Time for epoch 341 is 1.1690244674682617 sec Generator Loss: 0.7876472473144531,  Discriminator_loss: 1.3497008085250854
# Time for epoch 342 is 1.2042577266693115 sec Generator Loss: 0.7957113981246948,  Discriminator_loss: 1.3461031913757324
# Time for epoch 343 is 1.2553517818450928 sec Generator Loss: 0.7927771210670471,  Discriminator_loss: 1.3489575386047363
# Time for epoch 344 is 1.1858768463134766 sec Generator Loss: 0.7973904013633728,  Discriminator_loss: 1.3422788381576538
# Time for epoch 345 is 1.1818056106567383 sec Generator Loss: 0.7906748652458191,  Discriminator_loss: 1.3477922677993774
# Time for epoch 346 is 1.2603373527526855 sec Generator Loss: 0.7927892208099365,  Discriminator_loss: 1.3431071043014526
# Time for epoch 347 is 1.4443614482879639 sec Generator Loss: 0.7884992957115173,  Discriminator_loss: 1.353760004043579
# Time for epoch 348 is 1.3936810493469238 sec Generator Loss: 0.790666401386261,  Discriminator_loss: 1.3505260944366455
# Time for epoch 349 is 1.2521076202392578 sec Generator Loss: 0.7907138466835022,  Discriminator_loss: 1.345014214515686
# Time for epoch 350 is 1.1876356601715088 sec Generator Loss: 0.7945131659507751,  Discriminator_loss: 1.3430781364440918
# Time for epoch 351 is 1.159144639968872 sec Generator Loss: 0.7946463823318481,  Discriminator_loss: 1.3411970138549805
# Time for epoch 352 is 1.2586183547973633 sec Generator Loss: 0.7866050601005554,  Discriminator_loss: 1.3538702726364136
# Time for epoch 353 is 1.2069618701934814 sec Generator Loss: 0.794434666633606,  Discriminator_loss: 1.3480579853057861
# Time for epoch 354 is 1.3983204364776611 sec Generator Loss: 0.7888940572738647,  Discriminator_loss: 1.3522361516952515
# Time for epoch 355 is 1.3181169033050537 sec Generator Loss: 0.8017534017562866,  Discriminator_loss: 1.3375656604766846
# Time for epoch 356 is 1.2577826976776123 sec Generator Loss: 0.7992225289344788,  Discriminator_loss: 1.3478333950042725
# Time for epoch 357 is 1.2856814861297607 sec Generator Loss: 0.7843292355537415,  Discriminator_loss: 1.3461917638778687
# Time for epoch 358 is 1.2470569610595703 sec Generator Loss: 0.7910131812095642,  Discriminator_loss: 1.3475375175476074
# Time for epoch 359 is 1.2512061595916748 sec Generator Loss: 0.7917220592498779,  Discriminator_loss: 1.3477967977523804
# Time for epoch 360 is 1.3335607051849365 sec Generator Loss: 0.7895814180374146,  Discriminator_loss: 1.3486031293869019
# Time for epoch 361 is 1.4076941013336182 sec Generator Loss: 0.7906625866889954,  Discriminator_loss: 1.343334674835205
# Time for epoch 362 is 1.261765480041504 sec Generator Loss: 0.7907581925392151,  Discriminator_loss: 1.3492835760116577
# Time for epoch 363 is 1.3340332508087158 sec Generator Loss: 0.7889184951782227,  Discriminator_loss: 1.3457531929016113
# Time for epoch 364 is 1.2450346946716309 sec Generator Loss: 0.7890178561210632,  Discriminator_loss: 1.350428819656372
# Time for epoch 365 is 1.2087328433990479 sec Generator Loss: 0.7857551574707031,  Discriminator_loss: 1.3507219552993774
# Time for epoch 366 is 1.1600244045257568 sec Generator Loss: 0.7867655754089355,  Discriminator_loss: 1.349941611289978
# Time for epoch 367 is 1.222867727279663 sec Generator Loss: 0.7898688912391663,  Discriminator_loss: 1.342793583869934
# Time for epoch 368 is 1.2226848602294922 sec Generator Loss: 0.7886803150177002,  Discriminator_loss: 1.3457043170928955
# Time for epoch 369 is 1.1802501678466797 sec Generator Loss: 0.7900645732879639,  Discriminator_loss: 1.3424383401870728
# Time for epoch 370 is 1.1706671714782715 sec Generator Loss: 0.7933712601661682,  Discriminator_loss: 1.3374321460723877
# Time for epoch 371 is 1.2094039916992188 sec Generator Loss: 0.7975788712501526,  Discriminator_loss: 1.342430591583252
# Time for epoch 372 is 1.178849458694458 sec Generator Loss: 0.793352484703064,  Discriminator_loss: 1.3437625169754028
# Time for epoch 373 is 1.1659271717071533 sec Generator Loss: 0.800187349319458,  Discriminator_loss: 1.339701533317566
# Time for epoch 374 is 1.170818567276001 sec Generator Loss: 0.7996998429298401,  Discriminator_loss: 1.3418697118759155
# Time for epoch 375 is 1.1521785259246826 sec Generator Loss: 0.788168728351593,  Discriminator_loss: 1.3507450819015503
# Time for epoch 376 is 1.1528618335723877 sec Generator Loss: 0.7967442870140076,  Discriminator_loss: 1.3422356843948364
# Time for epoch 377 is 1.1589350700378418 sec Generator Loss: 0.7861628532409668,  Discriminator_loss: 1.3567700386047363
# Time for epoch 378 is 1.1221208572387695 sec Generator Loss: 0.7929299473762512,  Discriminator_loss: 1.3453744649887085
# Time for epoch 379 is 1.1316022872924805 sec Generator Loss: 0.7946396470069885,  Discriminator_loss: 1.3438756465911865
# Time for epoch 380 is 1.1711513996124268 sec Generator Loss: 0.7979987859725952,  Discriminator_loss: 1.3428359031677246
# Time for epoch 381 is 1.1734752655029297 sec Generator Loss: 0.7910178303718567,  Discriminator_loss: 1.3444578647613525
# ...
# Time for epoch 1871 is 1.0818829536437988 sec Generator Loss: 0.791516125202179,  Discriminator_loss: 1.3488622903823853
# Time for epoch 1872 is 1.0721125602722168 sec Generator Loss: 0.7818345427513123,  Discriminator_loss: 1.354717493057251
# Time for epoch 1873 is 1.072559118270874 sec Generator Loss: 0.7813808917999268,  Discriminator_loss: 1.354643702507019
# Time for epoch 1874 is 1.0974514484405518 sec Generator Loss: 0.7891542315483093,  Discriminator_loss: 1.3556544780731201
# Time for epoch 1875 is 1.064918041229248 sec Generator Loss: 0.7860331535339355,  Discriminator_loss: 1.3524800539016724
# Time for epoch 1876 is 1.1146025657653809 sec Generator Loss: 0.7863138318061829,  Discriminator_loss: 1.3505516052246094
# Time for epoch 1877 is 1.0693790912628174 sec Generator Loss: 0.7837262153625488,  Discriminator_loss: 1.3592036962509155
# Time for epoch 1878 is 1.1189684867858887 sec Generator Loss: 0.7870405316352844,  Discriminator_loss: 1.3540719747543335
# Time for epoch 1879 is 1.0936179161071777 sec Generator Loss: 0.7844193577766418,  Discriminator_loss: 1.3593186140060425
# Time for epoch 1880 is 1.0899863243103027 sec Generator Loss: 0.7837243676185608,  Discriminator_loss: 1.3517847061157227
# Time for epoch 1881 is 1.0975842475891113 sec Generator Loss: 0.7853989005088806,  Discriminator_loss: 1.35952889919281
# Time for epoch 1882 is 1.0831022262573242 sec Generator Loss: 0.7842497229576111,  Discriminator_loss: 1.3541481494903564
# Time for epoch 1883 is 1.1102879047393799 sec Generator Loss: 0.7904309630393982,  Discriminator_loss: 1.3508434295654297
# Time for epoch 1884 is 1.1122283935546875 sec Generator Loss: 0.7776802778244019,  Discriminator_loss: 1.357925534248352
# Time for epoch 1885 is 1.0726118087768555 sec Generator Loss: 0.7848056554794312,  Discriminator_loss: 1.3572856187820435
# Time for epoch 1886 is 1.0625736713409424 sec Generator Loss: 0.7832909822463989,  Discriminator_loss: 1.351852536201477
# Time for epoch 1887 is 1.0682525634765625 sec Generator Loss: 0.7824283838272095,  Discriminator_loss: 1.359233021736145
# Time for epoch 1888 is 1.1048088073730469 sec Generator Loss: 0.7878465056419373,  Discriminator_loss: 1.356705665588379
# Time for epoch 1889 is 1.0694336891174316 sec Generator Loss: 0.7889451384544373,  Discriminator_loss: 1.3538395166397095
# Time for epoch 1890 is 1.0965216159820557 sec Generator Loss: 0.7843067049980164,  Discriminator_loss: 1.3540579080581665
# Time for epoch 1891 is 1.0615599155426025 sec Generator Loss: 0.7825828790664673,  Discriminator_loss: 1.354587435722351
# Time for epoch 1892 is 1.099339246749878 sec Generator Loss: 0.7807276844978333,  Discriminator_loss: 1.3567196130752563
# Time for epoch 1893 is 1.083160400390625 sec Generator Loss: 0.7820783853530884,  Discriminator_loss: 1.357956886291504
# Time for epoch 1894 is 1.0614604949951172 sec Generator Loss: 0.7951304316520691,  Discriminator_loss: 1.3528356552124023
# Time for epoch 1895 is 1.0722086429595947 sec Generator Loss: 0.7894060015678406,  Discriminator_loss: 1.3533148765563965
# Time for epoch 1896 is 2.1642637252807617 sec Generator Loss: 0.7899799346923828,  Discriminator_loss: 1.3495858907699585
# Time for epoch 1897 is 1.1290373802185059 sec Generator Loss: 0.7833803296089172,  Discriminator_loss: 1.3546042442321777
# Time for epoch 1898 is 1.1347262859344482 sec Generator Loss: 0.7840402722358704,  Discriminator_loss: 1.3529565334320068
# Time for epoch 1899 is 1.0473010540008545 sec Generator Loss: 0.7832462787628174,  Discriminator_loss: 1.3527750968933105
# Time for epoch 1900 is 1.0811011791229248 sec Generator Loss: 0.7825754880905151,  Discriminator_loss: 1.3577630519866943
# Time for epoch 1901 is 1.0870656967163086 sec Generator Loss: 0.777857780456543,  Discriminator_loss: 1.3566651344299316
# Time for epoch 1902 is 1.0817921161651611 sec Generator Loss: 0.7844700813293457,  Discriminator_loss: 1.349130392074585
# Time for epoch 1903 is 1.1200954914093018 sec Generator Loss: 0.7903828620910645,  Discriminator_loss: 1.3509416580200195
# Time for epoch 1904 is 1.1231305599212646 sec Generator Loss: 0.782636284828186,  Discriminator_loss: 1.3532689809799194
# Time for epoch 1905 is 1.1267457008361816 sec Generator Loss: 0.791070818901062,  Discriminator_loss: 1.3524278402328491
# Time for epoch 1906 is 1.1545929908752441 sec Generator Loss: 0.7943155169487,  Discriminator_loss: 1.351435899734497
# Time for epoch 1907 is 1.2410850524902344 sec Generator Loss: 0.7899700403213501,  Discriminator_loss: 1.3538962602615356
# Time for epoch 1908 is 1.1433262825012207 sec Generator Loss: 0.7890429496765137,  Discriminator_loss: 1.3540774583816528
# Time for epoch 1909 is 1.1113715171813965 sec Generator Loss: 0.7908065319061279,  Discriminator_loss: 1.3538808822631836
# Time for epoch 1910 is 1.121495246887207 sec Generator Loss: 0.7823967337608337,  Discriminator_loss: 1.3612964153289795
# Time for epoch 1911 is 1.1191341876983643 sec Generator Loss: 0.7743399739265442,  Discriminator_loss: 1.356570839881897
# Time for epoch 1912 is 1.1907875537872314 sec Generator Loss: 0.784791886806488,  Discriminator_loss: 1.3517038822174072
# Time for epoch 1913 is 1.0669825077056885 sec Generator Loss: 0.7866191864013672,  Discriminator_loss: 1.3576180934906006
# Time for epoch 1914 is 1.1557085514068604 sec Generator Loss: 0.7882145047187805,  Discriminator_loss: 1.3509564399719238
# Time for epoch 1915 is 1.0830771923065186 sec Generator Loss: 0.7828850150108337,  Discriminator_loss: 1.3621065616607666
# Time for epoch 1916 is 1.1993029117584229 sec Generator Loss: 0.781802773475647,  Discriminator_loss: 1.35353684425354
# Time for epoch 1917 is 1.0547511577606201 sec Generator Loss: 0.7802813649177551,  Discriminator_loss: 1.3538206815719604
# Time for epoch 1918 is 1.1019260883331299 sec Generator Loss: 0.7844881415367126,  Discriminator_loss: 1.358245611190796
# Time for epoch 1919 is 1.1028621196746826 sec Generator Loss: 0.7878752946853638,  Discriminator_loss: 1.3570802211761475
# Time for epoch 1920 is 1.112884283065796 sec Generator Loss: 0.7797964811325073,  Discriminator_loss: 1.359053373336792
# Time for epoch 1921 is 1.0440645217895508 sec Generator Loss: 0.779308021068573,  Discriminator_loss: 1.3548941612243652
# Time for epoch 1922 is 1.0118927955627441 sec Generator Loss: 0.7796000242233276,  Discriminator_loss: 1.3610743284225464
# Time for epoch 1923 is 1.0173673629760742 sec Generator Loss: 0.7827900648117065,  Discriminator_loss: 1.3582991361618042
# Time for epoch 1924 is 1.0108566284179688 sec Generator Loss: 0.7817193269729614,  Discriminator_loss: 1.3555355072021484
# Time for epoch 1925 is 0.996471643447876 sec Generator Loss: 0.7852623462677002,  Discriminator_loss: 1.3546286821365356
# Time for epoch 1926 is 1.0120184421539307 sec Generator Loss: 0.7828318476676941,  Discriminator_loss: 1.3571745157241821
# Time for epoch 1927 is 1.0057544708251953 sec Generator Loss: 0.7861278653144836,  Discriminator_loss: 1.3525415658950806
# Time for epoch 1928 is 1.0283050537109375 sec Generator Loss: 0.7798591256141663,  Discriminator_loss: 1.3571926355361938
# Time for epoch 1929 is 1.0130441188812256 sec Generator Loss: 0.7801989912986755,  Discriminator_loss: 1.3560062646865845
# Time for epoch 1930 is 1.0285849571228027 sec Generator Loss: 0.7845917344093323,  Discriminator_loss: 1.3544306755065918
# Time for epoch 1931 is 1.074476957321167 sec Generator Loss: 0.7881457209587097,  Discriminator_loss: 1.3543168306350708
# Time for epoch 1932 is 1.0345184803009033 sec Generator Loss: 0.7825260162353516,  Discriminator_loss: 1.3585537672042847
# Time for epoch 1933 is 1.037231206893921 sec Generator Loss: 0.7862164974212646,  Discriminator_loss: 1.3534760475158691
# Time for epoch 1934 is 1.050764560699463 sec Generator Loss: 0.7898959517478943,  Discriminator_loss: 1.3554365634918213
# Time for epoch 1935 is 1.0234971046447754 sec Generator Loss: 0.7897156476974487,  Discriminator_loss: 1.3562932014465332
# Time for epoch 1936 is 0.9994955062866211 sec Generator Loss: 0.7900871634483337,  Discriminator_loss: 1.3470338582992554
# Time for epoch 1937 is 1.0108058452606201 sec Generator Loss: 0.786284863948822,  Discriminator_loss: 1.3605127334594727
# Time for epoch 1938 is 1.012993574142456 sec Generator Loss: 0.7839168310165405,  Discriminator_loss: 1.351500391960144
# Time for epoch 1939 is 1.0098114013671875 sec Generator Loss: 0.7834747433662415,  Discriminator_loss: 1.3581401109695435
# Time for epoch 1940 is 1.013434648513794 sec Generator Loss: 0.7829963564872742,  Discriminator_loss: 1.356569766998291
# Time for epoch 1941 is 1.0228452682495117 sec Generator Loss: 0.7797635793685913,  Discriminator_loss: 1.3543086051940918
# Time for epoch 1942 is 1.0968503952026367 sec Generator Loss: 0.7866674661636353,  Discriminator_loss: 1.347211480140686
# Time for epoch 1943 is 1.0906643867492676 sec Generator Loss: 0.7811764478683472,  Discriminator_loss: 1.3563486337661743
# Time for epoch 1944 is 1.166438102722168 sec Generator Loss: 0.7836651802062988,  Discriminator_loss: 1.3509957790374756
# Time for epoch 1945 is 1.064685344696045 sec Generator Loss: 0.7864563465118408,  Discriminator_loss: 1.3516559600830078
# Time for epoch 1946 is 1.0380771160125732 sec Generator Loss: 0.7843678593635559,  Discriminator_loss: 1.354691982269287
# Time for epoch 1947 is 1.100593090057373 sec Generator Loss: 0.7931715250015259,  Discriminator_loss: 1.3487601280212402
# Time for epoch 1948 is 1.1446950435638428 sec Generator Loss: 0.7872257232666016,  Discriminator_loss: 1.3520817756652832
# Time for epoch 1949 is 1.1120283603668213 sec Generator Loss: 0.7809787392616272,  Discriminator_loss: 1.3576061725616455
# Time for epoch 1950 is 1.0906403064727783 sec Generator Loss: 0.7846599221229553,  Discriminator_loss: 1.3604130744934082
# Time for epoch 1951 is 1.0917184352874756 sec Generator Loss: 0.7948834896087646,  Discriminator_loss: 1.3487111330032349
# Time for epoch 1952 is 1.1007649898529053 sec Generator Loss: 0.7804651260375977,  Discriminator_loss: 1.3593311309814453
# Time for epoch 1953 is 1.0928993225097656 sec Generator Loss: 0.7842086553573608,  Discriminator_loss: 1.352834701538086
# Time for epoch 1954 is 1.0500798225402832 sec Generator Loss: 0.7856506705284119,  Discriminator_loss: 1.353690266609192
# Time for epoch 1955 is 1.0828876495361328 sec Generator Loss: 0.775118350982666,  Discriminator_loss: 1.3592917919158936
# Time for epoch 1956 is 1.0861434936523438 sec Generator Loss: 0.7809206247329712,  Discriminator_loss: 1.3583428859710693
# Time for epoch 1957 is 1.0779576301574707 sec Generator Loss: 0.7871586084365845,  Discriminator_loss: 1.352051854133606
# Time for epoch 1958 is 1.0880799293518066 sec Generator Loss: 0.7904772758483887,  Discriminator_loss: 1.350989580154419
# Time for epoch 1959 is 1.0766973495483398 sec Generator Loss: 0.7818032503128052,  Discriminator_loss: 1.3570476770401
# Time for epoch 1960 is 1.085425615310669 sec Generator Loss: 0.7844160795211792,  Discriminator_loss: 1.3546489477157593
# Time for epoch 1961 is 1.0801868438720703 sec Generator Loss: 0.7890881896018982,  Discriminator_loss: 1.3519665002822876
# Time for epoch 1962 is 1.076765537261963 sec Generator Loss: 0.7910531163215637,  Discriminator_loss: 1.3559168577194214
# Time for epoch 1963 is 1.0654642581939697 sec Generator Loss: 0.7869727611541748,  Discriminator_loss: 1.3562684059143066
# Time for epoch 1964 is 1.0621938705444336 sec Generator Loss: 0.7866538763046265,  Discriminator_loss: 1.3544292449951172
# Time for epoch 1965 is 1.0828166007995605 sec Generator Loss: 0.7920345664024353,  Discriminator_loss: 1.3478325605392456
# Time for epoch 1966 is 1.0790457725524902 sec Generator Loss: 0.786695659160614,  Discriminator_loss: 1.3608134984970093
# Time for epoch 1967 is 1.082505464553833 sec Generator Loss: 0.7879325151443481,  Discriminator_loss: 1.3541929721832275
# Time for epoch 1968 is 1.1129114627838135 sec Generator Loss: 0.7770003080368042,  Discriminator_loss: 1.3603554964065552
# Time for epoch 1969 is 1.0649480819702148 sec Generator Loss: 0.7864340543746948,  Discriminator_loss: 1.355576992034912
# Time for epoch 1970 is 1.0852770805358887 sec Generator Loss: 0.7829914689064026,  Discriminator_loss: 1.3522448539733887
# Time for epoch 1971 is 1.0649023056030273 sec Generator Loss: 0.7884494662284851,  Discriminator_loss: 1.3584588766098022
# Time for epoch 1972 is 1.0838344097137451 sec Generator Loss: 0.7873236536979675,  Discriminator_loss: 1.3572704792022705
# Time for epoch 1973 is 1.094588041305542 sec Generator Loss: 0.7811986207962036,  Discriminator_loss: 1.3513940572738647
# Time for epoch 1974 is 1.071216344833374 sec Generator Loss: 0.7866484522819519,  Discriminator_loss: 1.3483033180236816
# Time for epoch 1975 is 1.085655927658081 sec Generator Loss: 0.7913209795951843,  Discriminator_loss: 1.3482850790023804
# Time for epoch 1976 is 1.0797488689422607 sec Generator Loss: 0.7857910394668579,  Discriminator_loss: 1.3581348657608032
# Time for epoch 1977 is 1.082374095916748 sec Generator Loss: 0.7891577482223511,  Discriminator_loss: 1.3540815114974976
# Time for epoch 1978 is 1.0679116249084473 sec Generator Loss: 0.7865709066390991,  Discriminator_loss: 1.3545632362365723
# Time for epoch 1979 is 1.0830883979797363 sec Generator Loss: 0.7895182967185974,  Discriminator_loss: 1.3574022054672241
# Time for epoch 1980 is 1.0957255363464355 sec Generator Loss: 0.7870414853096008,  Discriminator_loss: 1.353596568107605
# Time for epoch 1981 is 1.0904324054718018 sec Generator Loss: 0.7810720801353455,  Discriminator_loss: 1.3623485565185547
# Time for epoch 1982 is 1.0701842308044434 sec Generator Loss: 0.7818376421928406,  Discriminator_loss: 1.3549273014068604
# Time for epoch 1983 is 1.0627343654632568 sec Generator Loss: 0.7814177870750427,  Discriminator_loss: 1.3570291996002197
# Time for epoch 1984 is 1.0910463333129883 sec Generator Loss: 0.793127715587616,  Discriminator_loss: 1.3531137704849243
# Time for epoch 1985 is 1.0857384204864502 sec Generator Loss: 0.7858755588531494,  Discriminator_loss: 1.3531866073608398
# Time for epoch 1986 is 1.0946075916290283 sec Generator Loss: 0.7898517847061157,  Discriminator_loss: 1.3486498594284058
# Time for epoch 1987 is 1.077502727508545 sec Generator Loss: 0.7893028855323792,  Discriminator_loss: 1.3523335456848145
# Time for epoch 1988 is 1.0823290348052979 sec Generator Loss: 0.7839415073394775,  Discriminator_loss: 1.3555265665054321
# Time for epoch 1989 is 1.0822649002075195 sec Generator Loss: 0.7902058362960815,  Discriminator_loss: 1.3486894369125366
# Time for epoch 1990 is 1.0640003681182861 sec Generator Loss: 0.789061963558197,  Discriminator_loss: 1.3562511205673218
# Time for epoch 1991 is 1.0889556407928467 sec Generator Loss: 0.7857236862182617,  Discriminator_loss: 1.3530248403549194
# Time for epoch 1992 is 1.0741536617279053 sec Generator Loss: 0.779633641242981,  Discriminator_loss: 1.360813021659851
# Time for epoch 1993 is 1.1076140403747559 sec Generator Loss: 0.7821134924888611,  Discriminator_loss: 1.3581817150115967
# Time for epoch 1994 is 1.073047161102295 sec Generator Loss: 0.7887993454933167,  Discriminator_loss: 1.3546268939971924
# Time for epoch 1995 is 1.0815317630767822 sec Generator Loss: 0.7933840751647949,  Discriminator_loss: 1.349929928779602
# Time for epoch 1996 is 1.082467794418335 sec Generator Loss: 0.7818710207939148,  Discriminator_loss: 1.3571743965148926
# Time for epoch 1997 is 1.0643723011016846 sec Generator Loss: 0.7808114290237427,  Discriminator_loss: 1.355220079421997
# Time for epoch 1998 is 1.0823912620544434 sec Generator Loss: 0.7806904911994934,  Discriminator_loss: 1.355736255645752
# Time for epoch 1999 is 1.060028314590454 sec Generator Loss: 0.7894994616508484,  Discriminator_loss: 1.3510239124298096
# Time for epoch 2000 is 1.1003799438476562 sec Generator Loss: 0.7884525656700134,  Discriminator_loss: 1.3524417877197266
# 2/2 [==============================] - 1s 3ms/step
# [MSE Baseline] train: 4.2490969267015535  test: 4.679867713895856
# Delta time: 0:40:37.148489
